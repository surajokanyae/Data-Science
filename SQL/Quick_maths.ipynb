# %% [markdown]
# Questions 1
#
# What the output of the following?

# %%
5*5+10
# Out:
# 35

# %%
a = 1
b = 2
c= 5
a + b / c
# Out:
# 1.4

# %%
SELECT * 
FROM employee 
WHERE first_name = 'surajo';
# Out:
#   Cell In[3], line 1
#     SELECT *
#              ^
# SyntaxError: invalid syntax
