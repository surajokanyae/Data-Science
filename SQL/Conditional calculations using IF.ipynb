# %%
#Preparing sql environment
# %load_ext sql

# %%
# %sql mysql+pymysql://root:0479%40Kanya@127.0.0.1:3306/united_nations

# %% [markdown]
# **1. Replace NULL values for Central and Southern Asia**
#
# Write an IF statement that checks whether the Region is Central and Southern Asia and whether Pct_unemployment is NULL. If both conditions are met, set the value of a new alias column called New_pct_unemployment to 19.59. If the conditions are not met, use -999 as a placeholder value in the New_pct_unemployment column.

# %%
# %%sql
#
# SELECT Region,
#        Pct_unemployment,
#        IF( (Region = "Central and Southern Asia") AND (Pct_unemployment IS NULL), 19.59, -999
#        ) AS New_pct_unemployment
# FROM united_nations.Access_to_Basic_Services
# LIMIT 10; -- Remove this line to see the full result
# Out:
#  * mysql+pymysql://root:***@127.0.0.1:3306/united_nations
# 10 rows affected.
# [('Central and Southern Asia', 4.93, Decimal('-999')),
#  ('Central and Southern Asia', 4.96, Decimal('-999')),
#  ('Central and Southern Asia', 4.9, Decimal('-999')),
#  ('Central and Southern Asia', 4.85, Decimal('-999')),
#  ('Central and Southern Asia', 4.8, Decimal('-999')),
#  ('Central and Southern Asia', 4.89, Decimal('-999')),
#  ('Central and Southern Asia', None, Decimal('19.59')),
#  ('Central and Southern Asia', None, Decimal('19.59')),
#  ('Central and Southern Asia', None, Decimal('19.59')),
#  ('Central and Southern Asia', None, Decimal('19.59'))]

# %% [markdown]
# **2. Replace NULL values for Eastern and South-Eastern Asia**
#
# Now we have our first region sorted, but we have various regions to consider, so we need to add conditions for each region. To begin, add a second condition to the solution to set the New_pct_unemployment for Eastern and South-Eastern Asia to 22.64, using a nested IF statement. If neither condition is met, it should assign a value of -999.

# %%
# %%sql
#
# SELECT Region,
#        Pct_unemployment,
#        IF( (Region = "Central and Southern Asia") AND (Pct_unemployment IS NULL), 19.59,
#             IF( (Region = "Eastern and South-Eastern Asia") AND (Pct_unemployment IS NULL), 22.64,
#                  -999
#             )
#        ) AS New_pct_unemployment
# FROM united_nations.Access_to_Basic_Services;
# Out:
#  * mysql+pymysql://root:***@127.0.0.1:3306/united_nations
# 1048 rows affected.
# [('Central and Southern Asia', 4.93, Decimal('-999')),
#  ('Central and Southern Asia', 4.96, Decimal('-999')),
#  ('Central and Southern Asia', 4.9, Decimal('-999')),
#  ('Central and Southern Asia', 4.85, Decimal('-999')),
#  ('Central and Southern Asia', 4.8, Decimal('-999')),
#  ('Central and Southern Asia', 4.89, Decimal('-999')),
#  ('Central and Southern Asia', None, Decimal('19.59')),
#  ('Central and Southern Asia', None, Decimal('19.59')),
#  ('Central and Southern Asia', None, Decimal('19.59')),
#  ('Central and Southern Asia', None, Decimal('19.59')),
#  ('Central and Southern Asia', None, Decimal('19.59')),
#  ('Central and Southern Asia', None, Decimal('19.59')),
#  ('Central and Southern Asia', None, Decimal('19.59')),
#  ('Central and Southern Asia', 6.9, Decimal('-999')),
#  ('Central and Southern Asia', None, Decimal('19.59')),
#  ('Central and Southern Asia', None, Decimal('19.59')),
#  ('Central and Southern Asia', None, Decimal('19.59')),
#  ('Central and Southern Asia', None, Decimal('19.59')),
#  ('Central and Southern Asia', None, Decimal('19.59')),
#  ('Central and Southern Asia', None, Decimal('19.59')),
#  ('Central and Southern Asia', None, Decimal('19.59')),
#  ('Central and Southern Asia', None, Decimal('19.59')),
#  ('Central and Southern Asia', None, Decimal('19.59')),
#  ('Central and Southern Asia', None, Decimal('19.59')),
#  ('Central and Southern Asia', 5.15, Decimal('-999')),
#  ('Central and Southern Asia', 5.16, Decimal('-999')),
#  ('Central and Southern Asia', 5.83, Decimal('-999')),
#  ('Central and Southern Asia', 9.35, Decimal('-999')),
#  ('Central and Southern Asia', 8.98, Decimal('-999')),
#  ('Central and Southern Asia', 5.29, Decimal('-999')),
#  ('Central and Southern Asia', None, Decimal('19.59')),
#  ('Central and Southern Asia', None, Decimal('19.59')),
#  ('Central and Southern Asia', 11.18, Decimal('-999')),
#  ('Central and Southern Asia', None, Decimal('19.59')),
#  ('Central and Southern Asia', None, Decimal('19.59')),
#  ('Central and Southern Asia', 11.71, Decimal('-999')),
#  ('Central and Southern Asia', None, Decimal('19.59')),
#  ('Central and Southern Asia', 4.35, Decimal('-999')),
#  ('Central and Southern Asia', 4.37, Decimal('-999')),
#  ('Central and Southern Asia', None, Decimal('19.59')),
#  ('Central and Southern Asia', None, Decimal('19.59')),
#  ('Central and Southern Asia', None, Decimal('19.59')),
#  ('Central and Southern Asia', 2.45, Decimal('-999')),
#  ('Central and Southern Asia', None, Decimal('19.59')),
#  ('Central and Southern Asia', None, Decimal('19.59')),
#  ('Central and Southern Asia', 3.35, Decimal('-999')),
#  ('Central and Southern Asia', 2.72, Decimal('-999')),
#  ('Central and Southern Asia', 5.03, Decimal('-999')),
#  ('Central and Southern Asia', None, Decimal('19.59')),
#  ('Central and Southern Asia', None, Decimal('19.59')),
#  ('Central and Southern Asia', None, Decimal('19.59')),
#  ('Central and Southern Asia', 7.65, Decimal('-999')),
#  ('Central and Southern Asia', 6.51, Decimal('-999')),
#  ('Central and Southern Asia', 7.86, Decimal('-999')),
#  ('Central and Southern Asia', None, Decimal('19.59')),
#  ('Central and Southern Asia', None, Decimal('19.59')),
#  ('Central and Southern Asia', None, Decimal('19.59')),
#  ('Central and Southern Asia', None, Decimal('19.59')),
#  ('Central and Southern Asia', None, Decimal('19.59')),
#  ('Central and Southern Asia', None, Decimal('19.59')),
#  ('Central and Southern Asia', None, Decimal('19.59')),
#  ('Central and Southern Asia', 5.77, Decimal('-999')),
#  ('Central and Southern Asia', None, Decimal('19.59')),
#  ('Central and Southern Asia', None, Decimal('19.59')),
#  ('Central and Southern Asia', 4.56, Decimal('-999')),
#  ('Central and Southern Asia', None, Decimal('19.59')),
#  ('Central and Southern Asia', 3.1, Decimal('-999')),
#  ('Central and Southern Asia', None, Decimal('19.59')),
#  ('Central and Southern Asia', 10.66, Decimal('-999')),
#  ('Central and Southern Asia', None, Decimal('19.59')),
#  ('Central and Southern Asia', None, Decimal('19.59')),
#  ('Central and Southern Asia', None, Decimal('19.59')),
#  ('Central and Southern Asia', 3.57, Decimal('-999')),
#  ('Central and Southern Asia', None, Decimal('19.59')),
#  ('Central and Southern Asia', None, Decimal('19.59')),
#  ('Central and Southern Asia', 4.08, Decimal('-999')),
#  ('Central and Southern Asia', 4.83, Decimal('-999')),
#  ('Central and Southern Asia', None, Decimal('19.59')),
#  ('Central and Southern Asia', 4.52, Decimal('-999')),
#  ('Central and Southern Asia', 4.24, Decimal('-999')),
#  ('Central and Southern Asia', 4.05, Decimal('-999')),
#  ('Central and Southern Asia', 4.32, Decimal('-999')),
#  ('Central and Southern Asia', 4.67, Decimal('-999')),
#  ('Central and Southern Asia', 5.36, Decimal('-999')),
#  ('Eastern and South-Eastern Asia', None, Decimal('22.64')),
#  ('Eastern and South-Eastern Asia', None, Decimal('22.64')),
#  ('Eastern and South-Eastern Asia', 3.9, Decimal('-999')),
#  ('Eastern and South-Eastern Asia', 4.93, Decimal('-999')),
#  ('Eastern and South-Eastern Asia', 5.15, Decimal('-999')),
#  ('Eastern and South-Eastern Asia', 5.61, Decimal('-999')),
#  ('Eastern and South-Eastern Asia', None, Decimal('22.64')),
#  ('Eastern and South-Eastern Asia', None, Decimal('22.64')),
#  ('Eastern and South-Eastern Asia', None, Decimal('22.64')),
#  ('Eastern and South-Eastern Asia', None, Decimal('22.64')),
#  ('Eastern and South-Eastern Asia', None, Decimal('22.64')),
#  ('Eastern and South-Eastern Asia', None, Decimal('22.64')),
#  ('Eastern and South-Eastern Asia', 3.39, Decimal('-999')),
#  ('Eastern and South-Eastern Asia', 3.13, Decimal('-999')),
#  ('Eastern and South-Eastern Asia', 2.82, Decimal('-999')),
#  ('Eastern and South-Eastern Asia', 2.47, Decimal('-999')),
#  ('Eastern and South-Eastern Asia', 2.35, Decimal('-999')),
#  ('Eastern and South-Eastern Asia', 2.81, Decimal('-999')),
#  ('Eastern and South-Eastern Asia', 4.86, Decimal('-999')),
#  ('Eastern and South-Eastern Asia', 7.24, Decimal('-999')),
#  ('Eastern and South-Eastern Asia', 6.36, Decimal('-999')),
#  ('Eastern and South-Eastern Asia', 5.38, Decimal('-999')),
#  ('Eastern and South-Eastern Asia', 9.27, Decimal('-999')),
#  ('Eastern and South-Eastern Asia', 6.59, Decimal('-999')),
#  ('Eastern and South-Eastern Asia', None, Decimal('22.64')),
#  ('Eastern and South-Eastern Asia', None, Decimal('22.64')),
#  ('Eastern and South-Eastern Asia', None, Decimal('22.64')),
#  ('Eastern and South-Eastern Asia', None, Decimal('22.64')),
#  ('Eastern and South-Eastern Asia', None, Decimal('22.64')),
#  ('Eastern and South-Eastern Asia', None, Decimal('22.64')),
#  ('Eastern and South-Eastern Asia', None, Decimal('22.64')),
#  ('Eastern and South-Eastern Asia', None, Decimal('22.64')),
#  ('Eastern and South-Eastern Asia', 9.32, Decimal('-999')),
#  ('Eastern and South-Eastern Asia', 8.7, Decimal('-999')),
#  ('Eastern and South-Eastern Asia', 6.6, Decimal('-999')),
#  ('Eastern and South-Eastern Asia', 7.41, Decimal('-999')),
#  ('Eastern and South-Eastern Asia', 0.39, Decimal('-999')),
#  ('Eastern and South-Eastern Asia', 0.72, Decimal('-999')),
#  ('Eastern and South-Eastern Asia', 0.14, Decimal('-999')),
#  ('Eastern and South-Eastern Asia', None, Decimal('22.64')),
#  ('Eastern and South-Eastern Asia', 0.5, Decimal('-999')),
#  ('Eastern and South-Eastern Asia', None, Decimal('22.64')),
#  ('Eastern and South-Eastern Asia', 4.51, Decimal('-999')),
#  ('Eastern and South-Eastern Asia', 4.3, Decimal('-999')),
#  ('Eastern and South-Eastern Asia', 3.78, Decimal('-999')),
#  ('Eastern and South-Eastern Asia', 4.39, Decimal('-999')),
#  ('Eastern and South-Eastern Asia', 3.59, Decimal('-999')),
#  ('Eastern and South-Eastern Asia', 4.25, Decimal('-999')),
#  ('Eastern and South-Eastern Asia', None, Decimal('22.64')),
#  ('Eastern and South-Eastern Asia', None, Decimal('22.64')),
#  ('Eastern and South-Eastern Asia', None, Decimal('22.64')),
#  ('Eastern and South-Eastern Asia', None, Decimal('22.64')),
#  ('Eastern and South-Eastern Asia', None, Decimal('22.64')),
#  ('Eastern and South-Eastern Asia', None, Decimal('22.64')),
#  ('Eastern and South-Eastern Asia', 3.1, Decimal('-999')),
#  ('Eastern and South-Eastern Asia', 3.44, Decimal('-999')),
#  ('Eastern and South-Eastern Asia', 3.41, Decimal('-999')),
#  ('Eastern and South-Eastern Asia', 3.3, Decimal('-999')),
#  ('Eastern and South-Eastern Asia', 3.26, Decimal('-999')),
#  ('Eastern and South-Eastern Asia', 4.54, Decimal('-999')),
#  ('Eastern and South-Eastern Asia', 0.77, Decimal('-999')),
#  ('Eastern and South-Eastern Asia', None, Decimal('22.64')),
#  ('Eastern and South-Eastern Asia', 1.36, Decimal('-999')),
#  ('Eastern and South-Eastern Asia', 0.77, Decimal('-999')),
#  ('Eastern and South-Eastern Asia', 0.41, Decimal('-999')),
#  ('Eastern and South-Eastern Asia', 1.48, Decimal('-999')),
#  ('Eastern and South-Eastern Asia', 3.07, Decimal('-999')),
#  ('Eastern and South-Eastern Asia', 2.7, Decimal('-999')),
#  ('Eastern and South-Eastern Asia', 2.55, Decimal('-999')),
#  ('Eastern and South-Eastern Asia', 2.34, Decimal('-999')),
#  ('Eastern and South-Eastern Asia', 2.24, Decimal('-999')),
#  ('Eastern and South-Eastern Asia', 2.52, Decimal('-999')),
#  ('Eastern and South-Eastern Asia', 3.79, Decimal('-999')),
#  ('Eastern and South-Eastern Asia', 4.08, Decimal('-999')),
#  ('Eastern and South-Eastern Asia', 4.2, Decimal('-999')),
#  ('Eastern and South-Eastern Asia', None, Decimal('22.64')),
#  ('Eastern and South-Eastern Asia', 3.1, Decimal('-999')),
#  ('Eastern and South-Eastern Asia', 4.1, Decimal('-999')),
#  ('Eastern and South-Eastern Asia', 0.6, Decimal('-999')),
#  ('Eastern and South-Eastern Asia', 0.69, Decimal('-999')),
#  ('Eastern and South-Eastern Asia', 0.83, Decimal('-999')),
#  ('Eastern and South-Eastern Asia', 0.77, Decimal('-999')),
#  ('Eastern and South-Eastern Asia', 0.72, Decimal('-999')),
#  ('Eastern and South-Eastern Asia', 1.1, Decimal('-999')),
#  ('Eastern and South-Eastern Asia', None, Decimal('22.64')),
#  ('Eastern and South-Eastern Asia', 4.66, Decimal('-999')),
#  ('Eastern and South-Eastern Asia', None, Decimal('22.64')),
#  ('Eastern and South-Eastern Asia', None, Decimal('22.64')),
#  ('Eastern and South-Eastern Asia', None, Decimal('22.64')),
#  ('Eastern and South-Eastern Asia', None, Decimal('22.64')),
#  ('Eastern and South-Eastern Asia', None, Decimal('22.64')),
#  ('Eastern and South-Eastern Asia', None, Decimal('22.64')),
#  ('Eastern and South-Eastern Asia', None, Decimal('22.64')),
#  ('Eastern and South-Eastern Asia', None, Decimal('22.64')),
#  ('Eastern and South-Eastern Asia', None, Decimal('22.64')),
#  ('Eastern and South-Eastern Asia', None, Decimal('22.64')),
#  ('Europe and Northern America', None, Decimal('-999')),
#  ('Europe and Northern America', None, Decimal('-999')),
#  ('Europe and Northern America', None, Decimal('-999')),
#  ('Europe and Northern America', None, Decimal('-999')),
#  ('Europe and Northern America', None, Decimal('-999')),
#  ('Europe and Northern America', None, Decimal('-999')),
#  ('Europe and Northern America', 6.91, Decimal('-999')),
#  ('Europe and Northern America', 7.0, Decimal('-999')),
#  ('Europe and Northern America', 6.34, Decimal('-999')),
#  ('Europe and Northern America', 5.83, Decimal('-999')),
#  ('Europe and Northern America', 5.66, Decimal('-999')),
#  ('Europe and Northern America', 9.46, Decimal('-999')),
#  ('Europe and Northern America', 9.1, Decimal('-999')),
#  ('Europe and Northern America', None, Decimal('-999')),
#  ('Europe and Northern America', None, Decimal('-999')),
#  ('Europe and Northern America', None, Decimal('-999')),
#  ('Europe and Northern America', None, Decimal('-999')),
#  ('Europe and Northern America', None, Decimal('-999')),
#  ('Europe and Northern America', None, Decimal('-999')),
#  ('Europe and Northern America', None, Decimal('-999')),
#  ('Europe and Northern America', None, Decimal('-999')),
#  ('Europe and Northern America', None, Decimal('-999')),
#  ('Europe and Northern America', None, Decimal('-999')),
#  ('Europe and Northern America', None, Decimal('-999')),
#  ('Europe and Northern America', None, Decimal('-999')),
#  ('Europe and Northern America', None, Decimal('-999')),
#  ('Europe and Northern America', None, Decimal('-999')),
#  ('Europe and Northern America', None, Decimal('-999')),
#  ('Europe and Northern America', None, Decimal('-999')),
#  ('Europe and Northern America', None, Decimal('-999')),
#  ('Latin America and the Caribbean', None, Decimal('-999')),
#  ('Latin America and the Caribbean', None, Decimal('-999')),
#  ('Latin America and the Caribbean', None, Decimal('-999')),
#  ('Latin America and the Caribbean', None, Decimal('-999')),
#  ('Latin America and the Caribbean', None, Decimal('-999')),
#  ('Latin America and the Caribbean', None, Decimal('-999')),
#  ('Latin America and the Caribbean', None, Decimal('-999')),
#  ('Latin America and the Caribbean', None, Decimal('-999')),
#  ('Latin America and the Caribbean', None, Decimal('-999')),
#  ('Latin America and the Caribbean', None, Decimal('-999')),
#  ('Latin America and the Caribbean', None, Decimal('-999')),
#  ('Latin America and the Caribbean', None, Decimal('-999')),
#  ('Latin America and the Caribbean', None, Decimal('-999')),
#  ('Latin America and the Caribbean', 9.8, Decimal('-999')),
#  ('Latin America and the Caribbean', 8.25, Decimal('-999')),
#  ('Latin America and the Caribbean', 8.62, Decimal('-999')),
#  ('Latin America and the Caribbean', 8.32, Decimal('-999')),
#  ('Latin America and the Caribbean', 8.41, Decimal('-999')),
#  ('Latin America and the Caribbean', None, Decimal('-999')),
#  ('Latin America and the Caribbean', None, Decimal('-999')),
#  ('Latin America and the Caribbean', None, Decimal('-999')),
#  ('Latin America and the Caribbean', None, Decimal('-999')),
#  ('Latin America and the Caribbean', None, Decimal('-999')),
#  ('Latin America and the Caribbean', None, Decimal('-999')),
#  ('Latin America and the Caribbean', None, Decimal('-999')),
#  ('Latin America and the Caribbean', 4.24, Decimal('-999')),
#  ('Latin America and the Caribbean', None, Decimal('-999')),
#  ('Latin America and the Caribbean', 2.4, Decimal('-999')),
#  ('Latin America and the Caribbean', 2.0, Decimal('-999')),
#  ('Latin America and the Caribbean', 1.7, Decimal('-999')),
#  ('Latin America and the Caribbean', 1.7, Decimal('-999')),
#  ('Latin America and the Caribbean', None, Decimal('-999')),
#  ('Latin America and the Caribbean', None, Decimal('-999')),
#  ('Latin America and the Caribbean', None, Decimal('-999')),
#  ('Latin America and the Caribbean', None, Decimal('-999')),
#  ('Latin America and the Caribbean', None, Decimal('-999')),
#  ('Latin America and the Caribbean', None, Decimal('-999')),
#  ('Latin America and the Caribbean', None, Decimal('-999')),
#  ('Latin America and the Caribbean', None, Decimal('-999')),
#  ('Latin America and the Caribbean', 7.61, Decimal('-999')),
#  ('Latin America and the Caribbean', 7.28, Decimal('-999')),
#  ('Latin America and the Caribbean', 5.83, Decimal('-999')),
#  ('Latin America and the Caribbean', 5.86, Decimal('-999')),
#  ('Latin America and the Caribbean', 6.18, Decimal('-999')),
#  ('Latin America and the Caribbean', 6.13, Decimal('-999')),
#  ('Latin America and the Caribbean', 22.9, Decimal('-999')),
#  ('Latin America and the Caribbean', None, Decimal('-999')),
#  ('Latin America and the Caribbean', None, Decimal('-999')),
#  ('Latin America and the Caribbean', None, Decimal('-999')),
#  ('Latin America and the Caribbean', None, Decimal('-999')),
#  ('Latin America and the Caribbean', None, Decimal('-999')),
#  ('Latin America and the Caribbean', None, Decimal('-999')),
#  ('Latin America and the Caribbean', None, Decimal('-999')),
#  ('Latin America and the Caribbean', None, Decimal('-999')),
#  ('Latin America and the Caribbean', None, Decimal('-999')),
#  ('Latin America and the Caribbean', None, Decimal('-999')),
#  ('Latin America and the Caribbean', None, Decimal('-999')),
#  ('Latin America and the Caribbean', None, Decimal('-999')),
#  ('Latin America and the Caribbean', None, Decimal('-999')),
#  ('Latin America and the Caribbean', None, Decimal('-999')),
#  ('Latin America and the Caribbean', 13.51, Decimal('-999')),
#  ('Latin America and the Caribbean', 8.63, Decimal('-999')),
#  ('Latin America and the Caribbean', 7.4, Decimal('-999')),
#  ('Latin America and the Caribbean', 5.47, Decimal('-999')),
#  ('Latin America and the Caribbean', 4.99, Decimal('-999')),
#  ('Latin America and the Caribbean', 6.5, Decimal('-999')),
#  ('Latin America and the Caribbean', None, Decimal('-999')),
#  ('Latin America and the Caribbean', None, Decimal('-999')),
#  ('Latin America and the Caribbean', None, Decimal('-999')),
#  ('Latin America and the Caribbean', None, Decimal('-999')),
#  ('Latin America and the Caribbean', None, Decimal('-999')),
#  ('Latin America and the Caribbean', None, Decimal('-999')),
#  ('Latin America and the Caribbean', None, Decimal('-999')),
#  ('Latin America and the Caribbean', None, Decimal('-999')),
#  ('Latin America and the Caribbean', None, Decimal('-999')),
#  ('Latin America and the Caribbean', None, Decimal('-999')),
#  ('Latin America and the Caribbean', None, Decimal('-999')),
#  ('Latin America and the Caribbean', None, Decimal('-999')),
#  ('Latin America and the Caribbean', 12.0, Decimal('-999')),
#  ('Latin America and the Caribbean', 11.8, Decimal('-999')),
#  ('Latin America and the Caribbean', 10.8, Decimal('-999')),
#  ('Latin America and the Caribbean', 9.2, Decimal('-999')),
#  ('Latin America and the Caribbean', 8.3, Decimal('-999')),
#  ('Latin America and the Caribbean', None, Decimal('-999')),
#  ('Latin America and the Caribbean', None, Decimal('-999')),
#  ('Latin America and the Caribbean', None, Decimal('-999')),
#  ('Latin America and the Caribbean', None, Decimal('-999')),
#  ('Latin America and the Caribbean', None, Decimal('-999')),
#  ('Latin America and the Caribbean', None, Decimal('-999')),
#  ('Latin America and the Caribbean', None, Decimal('-999')),
#  ('Latin America and the Caribbean', None, Decimal('-999')),
#  ('Latin America and the Caribbean', None, Decimal('-999')),
#  ('Latin America and the Caribbean', None, Decimal('-999')),
#  ('Latin America and the Caribbean', None, Decimal('-999')),
#  ('Latin America and the Caribbean', None, Decimal('-999')),
#  ('Latin America and the Caribbean', None, Decimal('-999')),
#  ('Latin America and the Caribbean', None, Decimal('-999')),
#  ('Latin America and the Caribbean', None, Decimal('-999')),
#  ('Latin America and the Caribbean', None, Decimal('-999')),
#  ('Latin America and the Caribbean', None, Decimal('-999')),
#  ('Latin America and the Caribbean', None, Decimal('-999')),
#  ('Latin America and the Caribbean', None, Decimal('-999')),
#  ('Latin America and the Caribbean', None, Decimal('-999')),
#  ('Latin America and the Caribbean', None, Decimal('-999')),
#  ('Latin America and the Caribbean', None, Decimal('-999')),
#  ('Latin America and the Caribbean', None, Decimal('-999')),
#  ('Latin America and the Caribbean', None, Decimal('-999')),
#  ('Latin America and the Caribbean', None, Decimal('-999')),
#  ('Latin America and the Caribbean', None, Decimal('-999')),
#  ('Latin America and the Caribbean', None, Decimal('-999')),
#  ('Latin America and the Caribbean', None, Decimal('-999')),
#  ('Latin America and the Caribbean', None, Decimal('-999')),
#  ('Latin America and the Caribbean', 2.43, Decimal('-999')),
#  ('Latin America and the Caribbean', 3.21, Decimal('-999')),
#  ('Latin America and the Caribbean', None, Decimal('-999')),
#  ('Latin America and the Caribbean', None, Decimal('-999')),
#  ('Latin America and the Caribbean', 3.52, Decimal('-999')),
#  ('Latin America and the Caribbean', 4.21, Decimal('-999')),
#  ('Latin America and the Caribbean', None, Decimal('-999')),
#  ('Latin America and the Caribbean', None, Decimal('-999')),
#  ('Latin America and the Caribbean', None, Decimal('-999')),
#  ('Latin America and the Caribbean', None, Decimal('-999')),
#  ('Latin America and the Caribbean', None, Decimal('-999')),
#  ('Latin America and the Caribbean', None, Decimal('-999')),
#  ('Latin America and the Caribbean', None, Decimal('-999')),
#  ('Latin America and the Caribbean', None, Decimal('-999')),
#  ('Latin America and the Caribbean', None, Decimal('-999')),
#  ('Latin America and the Caribbean', None, Decimal('-999')),
#  ('Latin America and the Caribbean', 7.58, Decimal('-999')),
#  ('Latin America and the Caribbean', 7.0, Decimal('-999')),
#  ('Latin America and the Caribbean', 6.6, Decimal('-999')),
#  ('Latin America and the Caribbean', None, Decimal('-999')),
#  ('Latin America and the Caribbean', 9.05, Decimal('-999')),
#  ('Latin America and the Caribbean', None, Decimal('-999')),
#  ('Latin America and the Caribbean', 8.42, Decimal('-999')),
#  ('Latin America and the Caribbean', 8.09, Decimal('-999')),
#  ('Latin America and the Caribbean', 7.73, Decimal('-999')),
#  ('Latin America and the Caribbean', 9.01, Decimal('-999')),
#  ('Latin America and the Caribbean', 10.81, Decimal('-999')),
#  ('Latin America and the Caribbean', 16.43, Decimal('-999')),
#  ('Latin America and the Caribbean', 4.0, Decimal('-999')),
#  ('Latin America and the Caribbean', 4.42, Decimal('-999')),
#  ('Latin America and the Caribbean', 4.39, Decimal('-999')),
#  ('Latin America and the Caribbean', 4.01, Decimal('-999')),
#  ('Latin America and the Caribbean', 4.17, Decimal('-999')),
#  ('Latin America and the Caribbean', 5.01, Decimal('-999')),
#  ('Latin America and the Caribbean', 2.51, Decimal('-999')),
#  ('Latin America and the Caribbean', 2.58, Decimal('-999')),
#  ('Latin America and the Caribbean', 2.46, Decimal('-999')),
#  ('Latin America and the Caribbean', 2.28, Decimal('-999')),
#  ('Latin America and the Caribbean', 2.19, Decimal('-999')),
#  ('Latin America and the Caribbean', None, Decimal('-999')),
#  ('Latin America and the Caribbean', 6.15, Decimal('-999')),
#  ('Latin America and the Caribbean', 6.73, Decimal('-999')),
#  ('Latin America and the Caribbean', 5.53, Decimal('-999')),
#  ('Latin America and the Caribbean', 5.62, Decimal('-999')),
#  ('Latin America and the Caribbean', 5.55, Decimal('-999')),
#  ('Latin America and the Caribbean', 10.68, Decimal('-999')),
#  ('Latin America and the Caribbean', 4.31, Decimal('-999')),
#  ('Latin America and the Caribbean', 3.85, Decimal('-999')),
#  ('Latin America and the Caribbean', 3.42, Decimal('-999')),
#  ('Latin America and the Caribbean', 3.27, Decimal('-999')),
#  ('Latin America and the Caribbean', 3.48, Decimal('-999')),
#  ('Latin America and the Caribbean', 4.44, Decimal('-999')),
#  ('Latin America and the Caribbean', 4.7, Decimal('-999')),
#  ('Latin America and the Caribbean', 3.9, Decimal('-999')),
#  ('Latin America and the Caribbean', 3.3, Decimal('-999')),
#  ('Latin America and the Caribbean', 5.2, Decimal('-999')),
#  ('Latin America and the Caribbean', None, Decimal('-999')),
#  ('Latin America and the Caribbean', None, Decimal('-999')),
#  ('Latin America and the Caribbean', 4.4, Decimal('-999')),
#  ('Latin America and the Caribbean', 4.84, Decimal('-999')),
#  ('Latin America and the Caribbean', 5.46, Decimal('-999')),
#  ('Latin America and the Caribbean', 5.31, Decimal('-999')),
#  ('Latin America and the Caribbean', 6.41, Decimal('-999')),
#  ('Latin America and the Caribbean', 18.55, Decimal('-999')),
#  ('Latin America and the Caribbean', None, Decimal('-999')),
#  ('Latin America and the Caribbean', None, Decimal('-999')),
#  ('Latin America and the Caribbean', 8.35, Decimal('-999')),
#  ('Latin America and the Caribbean', 9.22, Decimal('-999')),
#  ('Latin America and the Caribbean', 9.84, Decimal('-999')),
#  ('Latin America and the Caribbean', 11.46, Decimal('-999')),
#  ('Latin America and the Caribbean', None, Decimal('-999')),
#  ('Latin America and the Caribbean', None, Decimal('-999')),
#  ('Latin America and the Caribbean', None, Decimal('-999')),
#  ('Latin America and the Caribbean', None, Decimal('-999')),
#  ('Latin America and the Caribbean', None, Decimal('-999')),
#  ('Latin America and the Caribbean', None, Decimal('-999')),
#  ('Latin America and the Caribbean', 8.54, Decimal('-999')),
#  ('Latin America and the Caribbean', 11.58, Decimal('-999')),
#  ('Latin America and the Caribbean', 12.79, Decimal('-999')),
#  ('Latin America and the Caribbean', 12.33, Decimal('-999')),
#  ('Latin America and the Caribbean', 11.94, Decimal('-999')),
#  ('Latin America and the Caribbean', 13.7, Decimal('-999')),
#  ('Latin America and the Caribbean', 6.49, Decimal('-999')),
#  ('Latin America and the Caribbean', 6.73, Decimal('-999')),
#  ('Latin America and the Caribbean', 6.95, Decimal('-999')),
#  ('Latin America and the Caribbean', 7.21, Decimal('-999')),
#  ('Latin America and the Caribbean', 7.27, Decimal('-999')),
#  ('Latin America and the Caribbean', 10.94, Decimal('-999')),
#  ('Latin America and the Caribbean', 8.57, Decimal('-999')),
#  ('Latin America and the Caribbean', 8.92, Decimal('-999')),
#  ('Latin America and the Caribbean', 9.09, Decimal('-999')),
#  ('Latin America and the Caribbean', 9.36, Decimal('-999')),
#  ('Latin America and the Caribbean', 10.28, Decimal('-999')),
#  ('Latin America and the Caribbean', 15.98, Decimal('-999')),
#  ('Latin America and the Caribbean', 3.62, Decimal('-999')),
#  ('Latin America and the Caribbean', 4.6, Decimal('-999')),
#  ('Latin America and the Caribbean', 3.84, Decimal('-999')),
#  ('Latin America and the Caribbean', 3.53, Decimal('-999')),
#  ('Latin America and the Caribbean', 3.81, Decimal('-999')),
#  ('Latin America and the Caribbean', 6.11, Decimal('-999')),
#  ('Latin America and the Caribbean', None, Decimal('-999')),
#  ('Latin America and the Caribbean', None, Decimal('-999')),
#  ('Latin America and the Caribbean', None, Decimal('-999')),
#  ('Latin America and the Caribbean', None, Decimal('-999')),
#  ('Latin America and the Caribbean', None, Decimal('-999')),
#  ('Latin America and the Caribbean', None, Decimal('-999')),
#  ('Latin America and the Caribbean', None, Decimal('-999')),
#  ('Latin America and the Caribbean', None, Decimal('-999')),
#  ('Latin America and the Caribbean', None, Decimal('-999')),
#  ('Latin America and the Caribbean', None, Decimal('-999')),
#  ('Latin America and the Caribbean', None, Decimal('-999')),
#  ('Latin America and the Caribbean', None, Decimal('-999')),
#  ('Latin America and the Caribbean', None, Decimal('-999')),
#  ('Latin America and the Caribbean', None, Decimal('-999')),
#  ('Latin America and the Caribbean', None, Decimal('-999')),
#  ('Latin America and the Caribbean', 14.02, Decimal('-999')),
#  ('Latin America and the Caribbean', 13.52, Decimal('-999')),
#  ('Latin America and the Caribbean', None, Decimal('-999')),
#  ('Latin America and the Caribbean', 4.56, Decimal('-999')),
#  ('Latin America and the Caribbean', 5.25, Decimal('-999')),
#  ('Latin America and the Caribbean', 4.61, Decimal('-999')),
#  ('Latin America and the Caribbean', 6.22, Decimal('-999')),
#  ('Latin America and the Caribbean', 6.59, Decimal('-999')),
#  ('Latin America and the Caribbean', 7.55, Decimal('-999')),
#  ('Latin America and the Caribbean', 3.27, Decimal('-999')),
#  ('Latin America and the Caribbean', 3.74, Decimal('-999')),
#  ('Latin America and the Caribbean', 3.69, Decimal('-999')),
#  ('Latin America and the Caribbean', 3.49, Decimal('-999')),
#  ('Latin America and the Caribbean', 3.38, Decimal('-999')),
#  ('Latin America and the Caribbean', 7.18, Decimal('-999')),
#  ('Latin America and the Caribbean', 7.22, Decimal('-999')),
#  ('Latin America and the Caribbean', 7.92, Decimal('-999')),
#  ('Latin America and the Caribbean', None, Decimal('-999')),
#  ('Latin America and the Caribbean', None, Decimal('-999')),
#  ('Latin America and the Caribbean', None, Decimal('-999')),
#  ('Latin America and the Caribbean', None, Decimal('-999')),
#  ('Latin America and the Caribbean', 7.49, Decimal('-999')),
#  ('Latin America and the Caribbean', 7.84, Decimal('-999')),
#  ('Latin America and the Caribbean', 7.89, Decimal('-999')),
#  ('Latin America and the Caribbean', 8.34, Decimal('-999')),
#  ('Latin America and the Caribbean', 8.73, Decimal('-999')),
#  ('Latin America and the Caribbean', 10.33, Decimal('-999')),
#  ('Latin America and the Caribbean', None, Decimal('-999')),
#  ('Latin America and the Caribbean', None, Decimal('-999')),
#  ('Latin America and the Caribbean', None, Decimal('-999')),
#  ('Latin America and the Caribbean', None, Decimal('-999')),
#  ('Latin America and the Caribbean', None, Decimal('-999')),
#  ('Latin America and the Caribbean', None, Decimal('-999')),
#  ('Northern Africa and Western Asia', 11.21, Decimal('-999')),
#  ('Northern Africa and Western Asia', 10.2, Decimal('-999')),
#  ('Northern Africa and Western Asia', 12.0, Decimal('-999')),
#  ('Northern Africa and Western Asia', None, Decimal('-999')),
#  ('Northern Africa and Western Asia', None, Decimal('-999')),
#  ('Northern Africa and Western Asia', None, Decimal('-999')),
#  ('Northern Africa and Western Asia', None, Decimal('-999')),
#  ('Northern Africa and Western Asia', None, Decimal('-999')),
#  ('Northern Africa and Western Asia', None, Decimal('-999')),
#  ('Northern Africa and Western Asia', None, Decimal('-999')),
#  ('Northern Africa and Western Asia', None, Decimal('-999')),
#  ('Northern Africa and Western Asia', None, Decimal('-999')),
#  ('Northern Africa and Western Asia', None, Decimal('-999')),
#  ('Northern Africa and Western Asia', None, Decimal('-999')),
#  ('Northern Africa and Western Asia', None, Decimal('-999')),
#  ('Northern Africa and Western Asia', None, Decimal('-999')),
#  ('Northern Africa and Western Asia', None, Decimal('-999')),
#  ('Northern Africa and Western Asia', None, Decimal('-999')),
#  ('Northern Africa and Western Asia', 9.46, Decimal('-999')),
#  ('Northern Africa and Western Asia', 9.3, Decimal('-999')),
#  ('Northern Africa and Western Asia', None, Decimal('-999')),
#  ('Northern Africa and Western Asia', None, Decimal('-999')),
#  ('Northern Africa and Western Asia', None, Decimal('-999')),
#  ('Northern Africa and Western Asia', None, Decimal('-999')),
#  ('Northern Africa and Western Asia', None, Decimal('-999')),
#  ('Northern Africa and Western Asia', None, Decimal('-999')),
#  ('Northern Africa and Western Asia', None, Decimal('-999')),
#  ('Northern Africa and Western Asia', None, Decimal('-999')),
#  ('Northern Africa and Western Asia', None, Decimal('-999')),
#  ('Northern Africa and Western Asia', None, Decimal('-999')),
#  ('Northern Africa and Western Asia', 15.16, Decimal('-999')),
#  ('Northern Africa and Western Asia', 15.56, Decimal('-999')),
#  ('Northern Africa and Western Asia', 15.33, Decimal('-999')),
#  ('Northern Africa and Western Asia', 15.46, Decimal('-999')),
#  ('Northern Africa and Western Asia', 15.13, Decimal('-999')),
#  ('Northern Africa and Western Asia', None, Decimal('-999')),
#  ('Northern Africa and Western Asia', 18.26, Decimal('-999')),
#  ('Northern Africa and Western Asia', 17.62, Decimal('-999')),
#  ('Northern Africa and Western Asia', 17.7, Decimal('-999')),
#  ('Northern Africa and Western Asia', 13.21, Decimal('-999')),
#  ('Northern Africa and Western Asia', 12.2, Decimal('-999')),
#  ('Northern Africa and Western Asia', 12.18, Decimal('-999')),
#  ('Northern Africa and Western Asia', 4.96, Decimal('-999')),
#  ('Northern Africa and Western Asia', 5.0, Decimal('-999')),
#  ('Northern Africa and Western Asia', 4.96, Decimal('-999')),
#  ('Northern Africa and Western Asia', 4.94, Decimal('-999')),
#  ('Northern Africa and Western Asia', 4.85, Decimal('-999')),
#  ('Northern Africa and Western Asia', 7.16, Decimal('-999')),
#  ('Northern Africa and Western Asia', None, Decimal('-999')),
#  ('Northern Africa and Western Asia', None, Decimal('-999')),
#  ('Northern Africa and Western Asia', None, Decimal('-999')),
#  ('Northern Africa and Western Asia', None, Decimal('-999')),
#  ('Northern Africa and Western Asia', None, Decimal('-999')),
#  ('Northern Africa and Western Asia', None, Decimal('-999')),
#  ('Northern Africa and Western Asia', 15.03, Decimal('-999')),
#  ('Northern Africa and Western Asia', 13.01, Decimal('-999')),
#  ('Northern Africa and Western Asia', 11.16, Decimal('-999')),
#  ('Northern Africa and Western Asia', 8.5, Decimal('-999')),
#  ('Northern Africa and Western Asia', 7.15, Decimal('-999')),
#  ('Northern Africa and Western Asia', 7.76, Decimal('-999')),
#  ('Northern Africa and Western Asia', 16.51, Decimal('-999')),
#  ('Northern Africa and Western Asia', 16.6, Decimal('-999')),
#  ('Northern Africa and Western Asia', 13.94, Decimal('-999')),
#  ('Northern Africa and Western Asia', 12.67, Decimal('-999')),
#  ('Northern Africa and Western Asia', 11.57, Decimal('-999')),
#  ('Northern Africa and Western Asia', 11.73, Decimal('-999')),
#  ('Northern Africa and Western Asia', None, Decimal('-999')),
#  ('Northern Africa and Western Asia', 10.82, Decimal('-999')),
#  ('Northern Africa and Western Asia', 13.02, Decimal('-999')),
#  ('Northern Africa and Western Asia', None, Decimal('-999')),
#  ('Northern Africa and Western Asia', None, Decimal('-999')),
#  ('Northern Africa and Western Asia', None, Decimal('-999')),
#  ('Northern Africa and Western Asia', 5.18, Decimal('-999')),
#  ('Northern Africa and Western Asia', 4.72, Decimal('-999')),
#  ('Northern Africa and Western Asia', 4.14, Decimal('-999')),
#  ('Northern Africa and Western Asia', 3.92, Decimal('-999')),
#  ('Northern Africa and Western Asia', 3.73, Decimal('-999')),
#  ('Northern Africa and Western Asia', 4.17, Decimal('-999')),
#  ('Northern Africa and Western Asia', 13.08, Decimal('-999')),
#  ('Northern Africa and Western Asia', 15.28, Decimal('-999')),
#  ('Northern Africa and Western Asia', 18.12, Decimal('-999')),
#  ('Northern Africa and Western Asia', 18.26, Decimal('-999')),
#  ('Northern Africa and Western Asia', 16.8, Decimal('-999')),
#  ('Northern Africa and Western Asia', 19.21, Decimal('-999')),
#  ('Northern Africa and Western Asia', 2.2, Decimal('-999')),
#  ('Northern Africa and Western Asia', 2.16, Decimal('-999')),
#  ('Northern Africa and Western Asia', None, Decimal('-999')),
#  ('Northern Africa and Western Asia', None, Decimal('-999')),
#  ('Northern Africa and Western Asia', None, Decimal('-999')),
#  ('Northern Africa and Western Asia', None, Decimal('-999')),
#  ('Northern Africa and Western Asia', None, Decimal('-999')),
#  ('Northern Africa and Western Asia', None, Decimal('-999')),
#  ('Northern Africa and Western Asia', None, Decimal('-999')),
#  ('Northern Africa and Western Asia', None, Decimal('-999')),
#  ('Northern Africa and Western Asia', 11.3, Decimal('-999')),
#  ('Northern Africa and Western Asia', None, Decimal('-999')),
#  ('Northern Africa and Western Asia', None, Decimal('-999')),
#  ('Northern Africa and Western Asia', 3.27, Decimal('-999')),
#  ('Northern Africa and Western Asia', None, Decimal('-999')),
#  ('Northern Africa and Western Asia', 1.8, Decimal('-999')),
#  ('Northern Africa and Western Asia', None, Decimal('-999')),
#  ('Northern Africa and Western Asia', 2.94, Decimal('-999')),
#  ('Northern Africa and Western Asia', 0.17, Decimal('-999')),
#  ('Northern Africa and Western Asia', 0.15, Decimal('-999')),
#  ('Northern Africa and Western Asia', 0.14, Decimal('-999')),
#  ('Northern Africa and Western Asia', 0.11, Decimal('-999')),
#  ('Northern Africa and Western Asia', 0.1, Decimal('-999')),
#  ('Northern Africa and Western Asia', 0.14, Decimal('-999')),
#  ('Northern Africa and Western Asia', 5.6, Decimal('-999')),
#  ('Northern Africa and Western Asia', 5.6, Decimal('-999')),
#  ('Northern Africa and Western Asia', 5.89, Decimal('-999')),
#  ('Northern Africa and Western Asia', 6.03, Decimal('-999')),
#  ('Northern Africa and Western Asia', 5.64, Decimal('-999')),
#  ('Northern Africa and Western Asia', 7.66, Decimal('-999')),
#  ('Northern Africa and Western Asia', None, Decimal('-999')),
#  ('Northern Africa and Western Asia', None, Decimal('-999')),
#  ('Northern Africa and Western Asia', None, Decimal('-999')),
#  ('Northern Africa and Western Asia', None, Decimal('-999')),
#  ('Northern Africa and Western Asia', None, Decimal('-999')),
#  ('Northern Africa and Western Asia', None, Decimal('-999')),
#  ('Northern Africa and Western Asia', None, Decimal('-999')),
#  ('Northern Africa and Western Asia', None, Decimal('-999')),
#  ('Northern Africa and Western Asia', None, Decimal('-999')),
#  ('Northern Africa and Western Asia', None, Decimal('-999')),
#  ('Northern Africa and Western Asia', None, Decimal('-999')),
#  ('Northern Africa and Western Asia', None, Decimal('-999')),
#  ('Northern Africa and Western Asia', None, Decimal('-999')),
#  ('Northern Africa and Western Asia', None, Decimal('-999')),
#  ('Northern Africa and Western Asia', None, Decimal('-999')),
#  ('Northern Africa and Western Asia', None, Decimal('-999')),
#  ('Northern Africa and Western Asia', None, Decimal('-999')),
#  ('Northern Africa and Western Asia', None, Decimal('-999')),
#  ('Northern Africa and Western Asia', None, Decimal('-999')),
#  ('Northern Africa and Western Asia', 1.64, Decimal('-999')),
#  ('Northern Africa and Western Asia', 2.46, Decimal('-999')),
#  ('Northern Africa and Western Asia', 2.24, Decimal('-999')),
#  ('Northern Africa and Western Asia', 2.33, Decimal('-999')),
#  ('Northern Africa and Western Asia', 4.29, Decimal('-999')),
#  ('Northern Africa and Western Asia', None, Decimal('-999')),
#  ('Northern Africa and Western Asia', None, Decimal('-999')),
#  ('Northern Africa and Western Asia', None, Decimal('-999')),
#  ('Northern Africa and Western Asia', None, Decimal('-999')),
#  ('Northern Africa and Western Asia', None, Decimal('-999')),
#  ('Northern Africa and Western Asia', None, Decimal('-999')),
#  ('Oceania', 6.06, Decimal('-999')),
#  ('Oceania', 5.71, Decimal('-999')),
#  ('Oceania', 5.59, Decimal('-999')),
#  ('Oceania', 5.3, Decimal('-999')),
#  ('Oceania', 5.16, Decimal('-999')),
#  ('Oceania', 6.46, Decimal('-999')),
#  ('Oceania', 5.42, Decimal('-999')),
#  ('Oceania', 5.15, Decimal('-999')),
#  ('Oceania', 4.74, Decimal('-999')),
#  ('Oceania', 4.34, Decimal('-999')),
#  ('Oceania', 4.11, Decimal('-999')),
#  ('Oceania', 4.6, Decimal('-999')),
#  ('Oceania', None, Decimal('-999')),
#  ('Oceania', 4.32, Decimal('-999')),
#  ('Oceania', None, Decimal('-999')),
#  ('Oceania', None, Decimal('-999')),
#  ('Oceania', None, Decimal('-999')),
#  ('Oceania', None, Decimal('-999')),
#  ('Oceania', None, Decimal('-999')),
#  ('Oceania', None, Decimal('-999')),
#  ('Oceania', 11.68, Decimal('-999')),
#  ('Oceania', 11.7, Decimal('-999')),
#  ('Oceania', 10.88, Decimal('-999')),
#  ('Oceania', 13.56, Decimal('-999')),
#  ('Oceania', None, Decimal('-999')),
#  ('Oceania', None, Decimal('-999')),
#  ('Oceania', None, Decimal('-999')),
#  ('Oceania', None, Decimal('-999')),
#  ('Oceania', None, Decimal('-999')),
#  ('Oceania', None, Decimal('-999')),
#  ('Oceania', None, Decimal('-999')),
#  ('Oceania', None, Decimal('-999')),
#  ('Oceania', None, Decimal('-999')),
#  ('Oceania', None, Decimal('-999')),
#  ('Oceania', None, Decimal('-999')),
#  ('Oceania', None, Decimal('-999')),
#  ('Oceania', None, Decimal('-999')),
#  ('Oceania', None, Decimal('-999')),
#  ('Oceania', None, Decimal('-999')),
#  ('Oceania', None, Decimal('-999')),
#  ('Oceania', 5.44, Decimal('-999')),
#  ('Oceania', 4.05, Decimal('-999')),
#  ('Oceania', 6.9, Decimal('-999')),
#  ('Oceania', 5.4, Decimal('-999')),
#  ('Oceania', None, Decimal('-999')),
#  ('Oceania', None, Decimal('-999')),
#  ('Oceania', None, Decimal('-999')),
#  ('Oceania', None, Decimal('-999')),
#  ('Oceania', 9.33, Decimal('-999')),
#  ('Oceania', None, Decimal('-999')),
#  ('Oceania', None, Decimal('-999')),
#  ('Oceania', None, Decimal('-999')),
#  ('Oceania', 8.56, Decimal('-999')),
#  ('Oceania', 10.97, Decimal('-999')),
#  ('Oceania', None, Decimal('-999')),
#  ('Oceania', None, Decimal('-999')),
#  ('Oceania', None, Decimal('-999')),
#  ('Oceania', None, Decimal('-999')),
#  ('Oceania', 6.34, Decimal('-999')),
#  ('Oceania', None, Decimal('-999')),
#  ('Oceania', None, Decimal('-999')),
#  ('Oceania', None, Decimal('-999')),
#  ('Oceania', None, Decimal('-999')),
#  ('Oceania', None, Decimal('-999')),
#  ('Oceania', None, Decimal('-999')),
#  ('Oceania', None, Decimal('-999')),
#  ('Oceania', None, Decimal('-999')),
#  ('Oceania', None, Decimal('-999')),
#  ('Oceania', None, Decimal('-999')),
#  ('Oceania', None, Decimal('-999')),
#  ('Oceania', None, Decimal('-999')),
#  ('Oceania', None, Decimal('-999')),
#  ('Oceania', None, Decimal('-999')),
#  ('Oceania', None, Decimal('-999')),
#  ('Oceania', None, Decimal('-999')),
#  ('Oceania', None, Decimal('-999')),
#  ('Oceania', None, Decimal('-999')),
#  ('Oceania', None, Decimal('-999')),
#  ('Oceania', None, Decimal('-999')),
#  ('Oceania', None, Decimal('-999')),
#  ('Oceania', None, Decimal('-999')),
#  ('Oceania', None, Decimal('-999')),
#  ('Oceania', 0.77, Decimal('-999')),
#  ('Oceania', None, Decimal('-999')),
#  ('Oceania', None, Decimal('-999')),
#  ('Oceania', None, Decimal('-999')),
#  ('Oceania', None, Decimal('-999')),
#  ('Oceania', None, Decimal('-999')),
#  ('Oceania', None, Decimal('-999')),
#  ('Oceania', None, Decimal('-999')),
#  ('Oceania', None, Decimal('-999')),
#  ('Oceania', None, Decimal('-999')),
#  ('Oceania', None, Decimal('-999')),
#  ('Oceania', None, Decimal('-999')),
#  ('Oceania', None, Decimal('-999')),
#  ('Oceania', None, Decimal('-999')),
#  ('Oceania', None, Decimal('-999')),
#  ('Oceania', None, Decimal('-999')),
#  ('Oceania', None, Decimal('-999')),
#  ('Oceania', None, Decimal('-999')),
#  ('Oceania', None, Decimal('-999')),
#  ('Oceania', None, Decimal('-999')),
#  ('Oceania', None, Decimal('-999')),
#  ('Oceania', None, Decimal('-999')),
#  ('Oceania', None, Decimal('-999')),
#  ('Oceania', None, Decimal('-999')),
#  ('Oceania', None, Decimal('-999')),
#  ('Oceania', None, Decimal('-999')),
#  ('Oceania', None, Decimal('-999')),
#  ('Oceania', 9.4, Decimal('-999')),
#  ('Oceania', None, Decimal('-999')),
#  ('Oceania', None, Decimal('-999')),
#  ('Oceania', None, Decimal('-999')),
#  ('Oceania', None, Decimal('-999')),
#  ('Oceania', None, Decimal('-999')),
#  ('Oceania', None, Decimal('-999')),
#  ('Oceania', None, Decimal('-999')),
#  ('Oceania', None, Decimal('-999')),
#  ('Oceania', None, Decimal('-999')),
#  ('Oceania', None, Decimal('-999')),
#  ('Oceania', None, Decimal('-999')),
#  ('Oceania', None, Decimal('-999')),
#  ('Oceania', 2.25, Decimal('-999')),
#  ('Oceania', None, Decimal('-999')),
#  ('Oceania', None, Decimal('-999')),
#  ('Oceania', None, Decimal('-999')),
#  ('Oceania', 8.49, Decimal('-999')),
#  ('Oceania', 26.55, Decimal('-999')),
#  ('Oceania', None, Decimal('-999')),
#  ('Oceania', None, Decimal('-999')),
#  ('Oceania', None, Decimal('-999')),
#  ('Oceania', None, Decimal('-999')),
#  ('Oceania', None, Decimal('-999')),
#  ('Oceania', None, Decimal('-999')),
#  ('Oceania', None, Decimal('-999')),
#  ('Oceania', None, Decimal('-999')),
#  ('Oceania', None, Decimal('-999')),
#  ('Sub-Saharan Africa', None, Decimal('-999')),
#  ('Sub-Saharan Africa', None, Decimal('-999')),
#  ('Sub-Saharan Africa', None, Decimal('-999')),
#  ('Sub-Saharan Africa', None, Decimal('-999')),
#  ('Sub-Saharan Africa', None, Decimal('-999')),
#  ('Sub-Saharan Africa', 1.03, Decimal('-999')),
#  ('Sub-Saharan Africa', None, Decimal('-999')),
#  ('Sub-Saharan Africa', None, Decimal('-999')),
#  ('Sub-Saharan Africa', None, Decimal('-999')),
#  ('Sub-Saharan Africa', None, Decimal('-999')),
#  ('Sub-Saharan Africa', None, Decimal('-999')),
#  ('Sub-Saharan Africa', None, Decimal('-999')),
#  ('Sub-Saharan Africa', None, Decimal('-999')),
#  ('Sub-Saharan Africa', 26.06, Decimal('-999')),
#  ('Sub-Saharan Africa', None, Decimal('-999')),
#  ('Sub-Saharan Africa', None, Decimal('-999')),
#  ('Sub-Saharan Africa', None, Decimal('-999')),
#  ('Sub-Saharan Africa', None, Decimal('-999')),
#  ('Sub-Saharan Africa', None, Decimal('-999')),
#  ('Sub-Saharan Africa', None, Decimal('-999')),
#  ('Sub-Saharan Africa', None, Decimal('-999')),
#  ('Sub-Saharan Africa', None, Decimal('-999')),
#  ('Sub-Saharan Africa', None, Decimal('-999')),
#  ('Sub-Saharan Africa', None, Decimal('-999')),
#  ('Sub-Saharan Africa', None, Decimal('-999')),
#  ('Sub-Saharan Africa', None, Decimal('-999')),
#  ('Sub-Saharan Africa', 2.76, Decimal('-999')),
#  ('Sub-Saharan Africa', None, Decimal('-999')),
#  ('Sub-Saharan Africa', None, Decimal('-999')),
#  ('Sub-Saharan Africa', 5.01, Decimal('-999')),
#  ('Sub-Saharan Africa', None, Decimal('-999')),
#  ('Sub-Saharan Africa', 1.79, Decimal('-999')),
#  ('Sub-Saharan Africa', None, Decimal('-999')),
#  ('Sub-Saharan Africa', None, Decimal('-999')),
#  ('Sub-Saharan Africa', None, Decimal('-999')),
#  ('Sub-Saharan Africa', None, Decimal('-999')),
#  ('Sub-Saharan Africa', None, Decimal('-999')),
#  ('Sub-Saharan Africa', None, Decimal('-999')),
#  ('Sub-Saharan Africa', None, Decimal('-999')),
#  ('Sub-Saharan Africa', 3.54, Decimal('-999')),
#  ('Sub-Saharan Africa', None, Decimal('-999')),
#  ('Sub-Saharan Africa', None, Decimal('-999')),
#  ('Sub-Saharan Africa', 0.91, Decimal('-999')),
#  ('Sub-Saharan Africa', 7.41, Decimal('-999')),
#  ('Sub-Saharan Africa', 6.81, Decimal('-999')),
#  ('Sub-Saharan Africa', 6.75, Decimal('-999')),
#  ('Sub-Saharan Africa', 6.43, Decimal('-999')),
#  ('Sub-Saharan Africa', 6.33, Decimal('-999')),
#  ('Sub-Saharan Africa', 8.63, Decimal('-999')),
#  ('Sub-Saharan Africa', None, Decimal('-999')),
#  ('Sub-Saharan Africa', None, Decimal('-999')),
#  ('Sub-Saharan Africa', None, Decimal('-999')),
#  ('Sub-Saharan Africa', None, Decimal('-999')),
#  ('Sub-Saharan Africa', None, Decimal('-999')),
#  ('Sub-Saharan Africa', None, Decimal('-999')),
#  ('Sub-Saharan Africa', 3.43, Decimal('-999')),
#  ('Sub-Saharan Africa', None, Decimal('-999')),
#  ('Sub-Saharan Africa', None, Decimal('-999')),
#  ('Sub-Saharan Africa', None, Decimal('-999')),
#  ('Sub-Saharan Africa', None, Decimal('-999')),
#  ('Sub-Saharan Africa', None, Decimal('-999')),
#  ('Sub-Saharan Africa', None, Decimal('-999')),
#  ('Sub-Saharan Africa', None, Decimal('-999')),
#  ('Sub-Saharan Africa', 11.88, Decimal('-999')),
#  ('Sub-Saharan Africa', 10.76, Decimal('-999')),
#  ('Sub-Saharan Africa', 11.24, Decimal('-999')),
#  ('Sub-Saharan Africa', 11.83, Decimal('-999')),
#  ('Sub-Saharan Africa', None, Decimal('-999')),
#  ('Sub-Saharan Africa', None, Decimal('-999')),
#  ('Sub-Saharan Africa', None, Decimal('-999')),
#  ('Sub-Saharan Africa', None, Decimal('-999')),
#  ('Sub-Saharan Africa', None, Decimal('-999')),
#  ('Sub-Saharan Africa', None, Decimal('-999')),
#  ('Sub-Saharan Africa', 4.15, Decimal('-999')),
#  ('Sub-Saharan Africa', 3.96, Decimal('-999')),
#  ('Sub-Saharan Africa', 3.71, Decimal('-999')),
#  ('Sub-Saharan Africa', 3.53, Decimal('-999')),
#  ('Sub-Saharan Africa', 2.97, Decimal('-999')),
#  ('Sub-Saharan Africa', None, Decimal('-999')),
#  ('Sub-Saharan Africa', None, Decimal('-999')),
#  ('Sub-Saharan Africa', None, Decimal('-999')),
#  ('Sub-Saharan Africa', None, Decimal('-999')),
#  ('Sub-Saharan Africa', 18.83, Decimal('-999')),
#  ('Sub-Saharan Africa', None, Decimal('-999')),
#  ('Sub-Saharan Africa', None, Decimal('-999')),
#  ('Sub-Saharan Africa', None, Decimal('-999')),
#  ('Sub-Saharan Africa', None, Decimal('-999')),
#  ('Sub-Saharan Africa', None, Decimal('-999')),
#  ('Sub-Saharan Africa', None, Decimal('-999')),
#  ('Sub-Saharan Africa', None, Decimal('-999')),
#  ('Sub-Saharan Africa', None, Decimal('-999')),
#  ('Sub-Saharan Africa', None, Decimal('-999')),
#  ('Sub-Saharan Africa', 3.64, Decimal('-999')),
#  ('Sub-Saharan Africa', None, Decimal('-999')),
#  ('Sub-Saharan Africa', None, Decimal('-999')),
#  ('Sub-Saharan Africa', None, Decimal('-999')),
#  ('Sub-Saharan Africa', None, Decimal('-999')),
#  ('Sub-Saharan Africa', None, Decimal('-999')),
#  ('Sub-Saharan Africa', None, Decimal('-999')),
#  ('Sub-Saharan Africa', None, Decimal('-999')),
#  ('Sub-Saharan Africa', None, Decimal('-999')),
#  ('Sub-Saharan Africa', None, Decimal('-999')),
#  ('Sub-Saharan Africa', None, Decimal('-999')),
#  ('Sub-Saharan Africa', None, Decimal('-999')),
#  ('Sub-Saharan Africa', 8.52, Decimal('-999')),
#  ('Sub-Saharan Africa', 5.03, Decimal('-999')),
#  ('Sub-Saharan Africa', 5.54, Decimal('-999')),
#  ('Sub-Saharan Africa', 6.03, Decimal('-999')),
#  ('Sub-Saharan Africa', None, Decimal('-999')),
#  ('Sub-Saharan Africa', None, Decimal('-999')),
#  ('Sub-Saharan Africa', None, Decimal('-999')),
#  ('Sub-Saharan Africa', None, Decimal('-999')),
#  ('Sub-Saharan Africa', 7.37, Decimal('-999')),
#  ('Sub-Saharan Africa', None, Decimal('-999')),
#  ('Sub-Saharan Africa', None, Decimal('-999')),
#  ('Sub-Saharan Africa', None, Decimal('-999')),
#  ('Sub-Saharan Africa', None, Decimal('-999')),
#  ('Sub-Saharan Africa', None, Decimal('-999')),
#  ('Sub-Saharan Africa', 16.5, Decimal('-999')),
#  ('Sub-Saharan Africa', None, Decimal('-999')),
#  ('Sub-Saharan Africa', None, Decimal('-999')),
#  ('Sub-Saharan Africa', None, Decimal('-999')),
#  ('Sub-Saharan Africa', None, Decimal('-999')),
#  ('Sub-Saharan Africa', None, Decimal('-999')),
#  ('Sub-Saharan Africa', None, Decimal('-999')),
#  ('Sub-Saharan Africa', None, Decimal('-999')),
#  ('Sub-Saharan Africa', None, Decimal('-999')),
#  ('Sub-Saharan Africa', None, Decimal('-999')),
#  ('Sub-Saharan Africa', None, Decimal('-999')),
#  ('Sub-Saharan Africa', None, Decimal('-999')),
#  ('Sub-Saharan Africa', None, Decimal('-999')),
#  ('Sub-Saharan Africa', None, Decimal('-999')),
#  ('Sub-Saharan Africa', None, Decimal('-999')),
#  ('Sub-Saharan Africa', None, Decimal('-999')),
#  ('Sub-Saharan Africa', None, Decimal('-999')),
#  ('Sub-Saharan Africa', 1.13, Decimal('-999')),
#  ('Sub-Saharan Africa', None, Decimal('-999')),
#  ('Sub-Saharan Africa', None, Decimal('-999')),
#  ('Sub-Saharan Africa', None, Decimal('-999')),
#  ('Sub-Saharan Africa', None, Decimal('-999')),
#  ('Sub-Saharan Africa', None, Decimal('-999')),
#  ('Sub-Saharan Africa', None, Decimal('-999')),
#  ('Sub-Saharan Africa', None, Decimal('-999')),
#  ('Sub-Saharan Africa', None, Decimal('-999')),
#  ('Sub-Saharan Africa', None, Decimal('-999')),
#  ('Sub-Saharan Africa', None, Decimal('-999')),
#  ('Sub-Saharan Africa', None, Decimal('-999')),
#  ('Sub-Saharan Africa', None, Decimal('-999')),
#  ('Sub-Saharan Africa', None, Decimal('-999')),
#  ('Sub-Saharan Africa', None, Decimal('-999')),
#  ('Sub-Saharan Africa', None, Decimal('-999')),
#  ('Sub-Saharan Africa', None, Decimal('-999')),
#  ('Sub-Saharan Africa', None, Decimal('-999')),
#  ('Sub-Saharan Africa', None, Decimal('-999')),
#  ('Sub-Saharan Africa', None, Decimal('-999')),
#  ('Sub-Saharan Africa', None, Decimal('-999')),
#  ('Sub-Saharan Africa', None, Decimal('-999')),
#  ('Sub-Saharan Africa', None, Decimal('-999')),
#  ('Sub-Saharan Africa', None, Decimal('-999')),
#  ('Sub-Saharan Africa', None, Decimal('-999')),
#  ('Sub-Saharan Africa', None, Decimal('-999')),
#  ('Sub-Saharan Africa', None, Decimal('-999')),
#  ('Sub-Saharan Africa', None, Decimal('-999')),
#  ('Sub-Saharan Africa', None, Decimal('-999')),
#  ('Sub-Saharan Africa', None, Decimal('-999')),
#  ('Sub-Saharan Africa', None, Decimal('-999')),
#  ('Sub-Saharan Africa', None, Decimal('-999')),
#  ('Sub-Saharan Africa', None, Decimal('-999')),
#  ('Sub-Saharan Africa', None, Decimal('-999')),
#  ('Sub-Saharan Africa', 20.09, Decimal('-999')),
#  ('Sub-Saharan Africa', 21.02, Decimal('-999')),
#  ('Sub-Saharan Africa', None, Decimal('-999')),
#  ('Sub-Saharan Africa', 22.72, Decimal('-999')),
#  ('Sub-Saharan Africa', None, Decimal('-999')),
#  ('Sub-Saharan Africa', None, Decimal('-999')),
#  ('Sub-Saharan Africa', None, Decimal('-999')),
#  ('Sub-Saharan Africa', None, Decimal('-999')),
#  ('Sub-Saharan Africa', None, Decimal('-999')),
#  ('Sub-Saharan Africa', None, Decimal('-999')),
#  ('Sub-Saharan Africa', None, Decimal('-999')),
#  ('Sub-Saharan Africa', None, Decimal('-999')),
#  ('Sub-Saharan Africa', 16.88, Decimal('-999')),
#  ('Sub-Saharan Africa', None, Decimal('-999')),
#  ('Sub-Saharan Africa', None, Decimal('-999')),
#  ('Sub-Saharan Africa', 23.35, Decimal('-999')),
#  ('Sub-Saharan Africa', None, Decimal('-999')),
#  ('Sub-Saharan Africa', 19.88, Decimal('-999')),
#  ('Sub-Saharan Africa', None, Decimal('-999')),
#  ('Sub-Saharan Africa', None, Decimal('-999')),
#  ('Sub-Saharan Africa', 22.87, Decimal('-999')),
#  ('Sub-Saharan Africa', 24.02, Decimal('-999')),
#  ('Sub-Saharan Africa', 23.99, Decimal('-999')),
#  ('Sub-Saharan Africa', 24.22, Decimal('-999')),
#  ('Sub-Saharan Africa', 25.54, Decimal('-999')),
#  ('Sub-Saharan Africa', 24.34, Decimal('-999')),
#  ('Sub-Saharan Africa', None, Decimal('-999')),
#  ('Sub-Saharan Africa', None, Decimal('-999')),
#  ('Sub-Saharan Africa', None, Decimal('-999')),
#  ('Sub-Saharan Africa', 1.47, Decimal('-999')),
#  ('Sub-Saharan Africa', None, Decimal('-999')),
#  ('Sub-Saharan Africa', None, Decimal('-999')),
#  ('Sub-Saharan Africa', None, Decimal('-999')),
#  ('Sub-Saharan Africa', None, Decimal('-999')),
#  ('Sub-Saharan Africa', None, Decimal('-999')),
#  ('Sub-Saharan Africa', 4.69, Decimal('-999')),
#  ('Sub-Saharan Africa', None, Decimal('-999')),
#  ('Sub-Saharan Africa', None, Decimal('-999')),
#  ('Sub-Saharan Africa', 31.31, Decimal('-999')),
#  ('Sub-Saharan Africa', None, Decimal('-999')),
#  ('Sub-Saharan Africa', 12.24, Decimal('-999')),
#  ('Sub-Saharan Africa', 12.17, Decimal('-999')),
#  ('Sub-Saharan Africa', 11.29, Decimal('-999')),
#  ('Sub-Saharan Africa', None, Decimal('-999')),
#  ('Sub-Saharan Africa', None, Decimal('-999')),
#  ('Sub-Saharan Africa', None, Decimal('-999')),
#  ('Sub-Saharan Africa', None, Decimal('-999')),
#  ('Sub-Saharan Africa', None, Decimal('-999')),
#  ('Sub-Saharan Africa', None, Decimal('-999')),
#  ('Sub-Saharan Africa', None, Decimal('-999')),
#  ('Sub-Saharan Africa', None, Decimal('-999')),
#  ('Sub-Saharan Africa', None, Decimal('-999')),
#  ('Sub-Saharan Africa', None, Decimal('-999')),
#  ('Sub-Saharan Africa', None, Decimal('-999')),
#  ('Sub-Saharan Africa', None, Decimal('-999')),
#  ('Sub-Saharan Africa', None, Decimal('-999')),
#  ('Sub-Saharan Africa', 6.81, Decimal('-999')),
#  ('Sub-Saharan Africa', None, Decimal('-999')),
#  ('Sub-Saharan Africa', 3.37, Decimal('-999')),
#  ('Sub-Saharan Africa', None, Decimal('-999')),
#  ('Sub-Saharan Africa', None, Decimal('-999')),
#  ('Sub-Saharan Africa', None, Decimal('-999')),
#  ('Sub-Saharan Africa', None, Decimal('-999')),
#  ('Sub-Saharan Africa', None, Decimal('-999')),
#  ('Sub-Saharan Africa', None, Decimal('-999')),
#  ('Sub-Saharan Africa', None, Decimal('-999')),
#  ('Sub-Saharan Africa', 5.02, Decimal('-999')),
#  ('Sub-Saharan Africa', None, Decimal('-999')),
#  ('Sub-Saharan Africa', None, Decimal('-999')),
#  ('Sub-Saharan Africa', None, Decimal('-999')),
#  ('Sub-Saharan Africa', None, Decimal('-999')),
#  ('Sub-Saharan Africa', 3.2, Decimal('-999')),
#  ('Sub-Saharan Africa', None, Decimal('-999')),
#  ('Sub-Saharan Africa', None, Decimal('-999')),
#  ('Sub-Saharan Africa', None, Decimal('-999')),
#  ('Sub-Saharan Africa', 3.08, Decimal('-999')),
#  ('Sub-Saharan Africa', 5.95, Decimal('-999')),
#  ('Sub-Saharan Africa', None, Decimal('-999')),
#  ('Sub-Saharan Africa', None, Decimal('-999')),
#  ('Sub-Saharan Africa', None, Decimal('-999')),
#  ...]

# %% [markdown]
# **3. Replace NULL values for remaining regions**
#
# Now, let's add more conditions to assign the New_pct_unemployment values for the remaining regions. We have five more regions to assign Pct_unemployment values for. Add five more layers to the nested IF statement to set the unemployment percentage for these regions as follows:
#
# Europe and Northern America to 24.43
# Latin America and the Caribbean to 24.23
# Northern Africa and Western Asia to 17.84
# Oceania to 4.98
# Sub-Saharan Africa to 33.65
# Assign -999 if none of the conditions are met.

# %%
# %%sql
#
# SELECT
#     Region,
#     Pct_unemployment,
#     IF( (Region = 'Central and Southern Asia') AND (Pct_unemployment IS NULL), 19.59,
#         IF( (Region = 'Eastern and South-Eastern Asia') AND (Pct_unemployment IS NULL), 22.64,
#             IF( (Region = 'Europe and Northern America') AND (Pct_unemployment IS NULL), 24.43,
#                 IF( (Region = 'Latin America and the Caribbean') AND (Pct_unemployment IS NULL), 24.23,
#                     IF( (Region = 'Northern Africa and Western Asia') AND (Pct_unemployment IS NULL), 17.84,
#                         IF( (Region = 'Oceania') AND (Pct_unemployment IS NULL), 4.98,
#                             IF( (Region = 'Sub-Saharan Africa') AND (Pct_unemployment IS NULL), 33.65,
#                                 -999
#                             )
#                         )
#                     )
#                 )
#             )
#         )
#     ) AS New_pct_unemployment
# FROM united_nations.Access_to_Basic_Services;
# Out:
#  * mysql+pymysql://root:***@127.0.0.1:3306/united_nations
# 1048 rows affected.
# [('Central and Southern Asia', 4.93, Decimal('-999')),
#  ('Central and Southern Asia', 4.96, Decimal('-999')),
#  ('Central and Southern Asia', 4.9, Decimal('-999')),
#  ('Central and Southern Asia', 4.85, Decimal('-999')),
#  ('Central and Southern Asia', 4.8, Decimal('-999')),
#  ('Central and Southern Asia', 4.89, Decimal('-999')),
#  ('Central and Southern Asia', None, Decimal('19.59')),
#  ('Central and Southern Asia', None, Decimal('19.59')),
#  ('Central and Southern Asia', None, Decimal('19.59')),
#  ('Central and Southern Asia', None, Decimal('19.59')),
#  ('Central and Southern Asia', None, Decimal('19.59')),
#  ('Central and Southern Asia', None, Decimal('19.59')),
#  ('Central and Southern Asia', None, Decimal('19.59')),
#  ('Central and Southern Asia', 6.9, Decimal('-999')),
#  ('Central and Southern Asia', None, Decimal('19.59')),
#  ('Central and Southern Asia', None, Decimal('19.59')),
#  ('Central and Southern Asia', None, Decimal('19.59')),
#  ('Central and Southern Asia', None, Decimal('19.59')),
#  ('Central and Southern Asia', None, Decimal('19.59')),
#  ('Central and Southern Asia', None, Decimal('19.59')),
#  ('Central and Southern Asia', None, Decimal('19.59')),
#  ('Central and Southern Asia', None, Decimal('19.59')),
#  ('Central and Southern Asia', None, Decimal('19.59')),
#  ('Central and Southern Asia', None, Decimal('19.59')),
#  ('Central and Southern Asia', 5.15, Decimal('-999')),
#  ('Central and Southern Asia', 5.16, Decimal('-999')),
#  ('Central and Southern Asia', 5.83, Decimal('-999')),
#  ('Central and Southern Asia', 9.35, Decimal('-999')),
#  ('Central and Southern Asia', 8.98, Decimal('-999')),
#  ('Central and Southern Asia', 5.29, Decimal('-999')),
#  ('Central and Southern Asia', None, Decimal('19.59')),
#  ('Central and Southern Asia', None, Decimal('19.59')),
#  ('Central and Southern Asia', 11.18, Decimal('-999')),
#  ('Central and Southern Asia', None, Decimal('19.59')),
#  ('Central and Southern Asia', None, Decimal('19.59')),
#  ('Central and Southern Asia', 11.71, Decimal('-999')),
#  ('Central and Southern Asia', None, Decimal('19.59')),
#  ('Central and Southern Asia', 4.35, Decimal('-999')),
#  ('Central and Southern Asia', 4.37, Decimal('-999')),
#  ('Central and Southern Asia', None, Decimal('19.59')),
#  ('Central and Southern Asia', None, Decimal('19.59')),
#  ('Central and Southern Asia', None, Decimal('19.59')),
#  ('Central and Southern Asia', 2.45, Decimal('-999')),
#  ('Central and Southern Asia', None, Decimal('19.59')),
#  ('Central and Southern Asia', None, Decimal('19.59')),
#  ('Central and Southern Asia', 3.35, Decimal('-999')),
#  ('Central and Southern Asia', 2.72, Decimal('-999')),
#  ('Central and Southern Asia', 5.03, Decimal('-999')),
#  ('Central and Southern Asia', None, Decimal('19.59')),
#  ('Central and Southern Asia', None, Decimal('19.59')),
#  ('Central and Southern Asia', None, Decimal('19.59')),
#  ('Central and Southern Asia', 7.65, Decimal('-999')),
#  ('Central and Southern Asia', 6.51, Decimal('-999')),
#  ('Central and Southern Asia', 7.86, Decimal('-999')),
#  ('Central and Southern Asia', None, Decimal('19.59')),
#  ('Central and Southern Asia', None, Decimal('19.59')),
#  ('Central and Southern Asia', None, Decimal('19.59')),
#  ('Central and Southern Asia', None, Decimal('19.59')),
#  ('Central and Southern Asia', None, Decimal('19.59')),
#  ('Central and Southern Asia', None, Decimal('19.59')),
#  ('Central and Southern Asia', None, Decimal('19.59')),
#  ('Central and Southern Asia', 5.77, Decimal('-999')),
#  ('Central and Southern Asia', None, Decimal('19.59')),
#  ('Central and Southern Asia', None, Decimal('19.59')),
#  ('Central and Southern Asia', 4.56, Decimal('-999')),
#  ('Central and Southern Asia', None, Decimal('19.59')),
#  ('Central and Southern Asia', 3.1, Decimal('-999')),
#  ('Central and Southern Asia', None, Decimal('19.59')),
#  ('Central and Southern Asia', 10.66, Decimal('-999')),
#  ('Central and Southern Asia', None, Decimal('19.59')),
#  ('Central and Southern Asia', None, Decimal('19.59')),
#  ('Central and Southern Asia', None, Decimal('19.59')),
#  ('Central and Southern Asia', 3.57, Decimal('-999')),
#  ('Central and Southern Asia', None, Decimal('19.59')),
#  ('Central and Southern Asia', None, Decimal('19.59')),
#  ('Central and Southern Asia', 4.08, Decimal('-999')),
#  ('Central and Southern Asia', 4.83, Decimal('-999')),
#  ('Central and Southern Asia', None, Decimal('19.59')),
#  ('Central and Southern Asia', 4.52, Decimal('-999')),
#  ('Central and Southern Asia', 4.24, Decimal('-999')),
#  ('Central and Southern Asia', 4.05, Decimal('-999')),
#  ('Central and Southern Asia', 4.32, Decimal('-999')),
#  ('Central and Southern Asia', 4.67, Decimal('-999')),
#  ('Central and Southern Asia', 5.36, Decimal('-999')),
#  ('Eastern and South-Eastern Asia', None, Decimal('22.64')),
#  ('Eastern and South-Eastern Asia', None, Decimal('22.64')),
#  ('Eastern and South-Eastern Asia', 3.9, Decimal('-999')),
#  ('Eastern and South-Eastern Asia', 4.93, Decimal('-999')),
#  ('Eastern and South-Eastern Asia', 5.15, Decimal('-999')),
#  ('Eastern and South-Eastern Asia', 5.61, Decimal('-999')),
#  ('Eastern and South-Eastern Asia', None, Decimal('22.64')),
#  ('Eastern and South-Eastern Asia', None, Decimal('22.64')),
#  ('Eastern and South-Eastern Asia', None, Decimal('22.64')),
#  ('Eastern and South-Eastern Asia', None, Decimal('22.64')),
#  ('Eastern and South-Eastern Asia', None, Decimal('22.64')),
#  ('Eastern and South-Eastern Asia', None, Decimal('22.64')),
#  ('Eastern and South-Eastern Asia', 3.39, Decimal('-999')),
#  ('Eastern and South-Eastern Asia', 3.13, Decimal('-999')),
#  ('Eastern and South-Eastern Asia', 2.82, Decimal('-999')),
#  ('Eastern and South-Eastern Asia', 2.47, Decimal('-999')),
#  ('Eastern and South-Eastern Asia', 2.35, Decimal('-999')),
#  ('Eastern and South-Eastern Asia', 2.81, Decimal('-999')),
#  ('Eastern and South-Eastern Asia', 4.86, Decimal('-999')),
#  ('Eastern and South-Eastern Asia', 7.24, Decimal('-999')),
#  ('Eastern and South-Eastern Asia', 6.36, Decimal('-999')),
#  ('Eastern and South-Eastern Asia', 5.38, Decimal('-999')),
#  ('Eastern and South-Eastern Asia', 9.27, Decimal('-999')),
#  ('Eastern and South-Eastern Asia', 6.59, Decimal('-999')),
#  ('Eastern and South-Eastern Asia', None, Decimal('22.64')),
#  ('Eastern and South-Eastern Asia', None, Decimal('22.64')),
#  ('Eastern and South-Eastern Asia', None, Decimal('22.64')),
#  ('Eastern and South-Eastern Asia', None, Decimal('22.64')),
#  ('Eastern and South-Eastern Asia', None, Decimal('22.64')),
#  ('Eastern and South-Eastern Asia', None, Decimal('22.64')),
#  ('Eastern and South-Eastern Asia', None, Decimal('22.64')),
#  ('Eastern and South-Eastern Asia', None, Decimal('22.64')),
#  ('Eastern and South-Eastern Asia', 9.32, Decimal('-999')),
#  ('Eastern and South-Eastern Asia', 8.7, Decimal('-999')),
#  ('Eastern and South-Eastern Asia', 6.6, Decimal('-999')),
#  ('Eastern and South-Eastern Asia', 7.41, Decimal('-999')),
#  ('Eastern and South-Eastern Asia', 0.39, Decimal('-999')),
#  ('Eastern and South-Eastern Asia', 0.72, Decimal('-999')),
#  ('Eastern and South-Eastern Asia', 0.14, Decimal('-999')),
#  ('Eastern and South-Eastern Asia', None, Decimal('22.64')),
#  ('Eastern and South-Eastern Asia', 0.5, Decimal('-999')),
#  ('Eastern and South-Eastern Asia', None, Decimal('22.64')),
#  ('Eastern and South-Eastern Asia', 4.51, Decimal('-999')),
#  ('Eastern and South-Eastern Asia', 4.3, Decimal('-999')),
#  ('Eastern and South-Eastern Asia', 3.78, Decimal('-999')),
#  ('Eastern and South-Eastern Asia', 4.39, Decimal('-999')),
#  ('Eastern and South-Eastern Asia', 3.59, Decimal('-999')),
#  ('Eastern and South-Eastern Asia', 4.25, Decimal('-999')),
#  ('Eastern and South-Eastern Asia', None, Decimal('22.64')),
#  ('Eastern and South-Eastern Asia', None, Decimal('22.64')),
#  ('Eastern and South-Eastern Asia', None, Decimal('22.64')),
#  ('Eastern and South-Eastern Asia', None, Decimal('22.64')),
#  ('Eastern and South-Eastern Asia', None, Decimal('22.64')),
#  ('Eastern and South-Eastern Asia', None, Decimal('22.64')),
#  ('Eastern and South-Eastern Asia', 3.1, Decimal('-999')),
#  ('Eastern and South-Eastern Asia', 3.44, Decimal('-999')),
#  ('Eastern and South-Eastern Asia', 3.41, Decimal('-999')),
#  ('Eastern and South-Eastern Asia', 3.3, Decimal('-999')),
#  ('Eastern and South-Eastern Asia', 3.26, Decimal('-999')),
#  ('Eastern and South-Eastern Asia', 4.54, Decimal('-999')),
#  ('Eastern and South-Eastern Asia', 0.77, Decimal('-999')),
#  ('Eastern and South-Eastern Asia', None, Decimal('22.64')),
#  ('Eastern and South-Eastern Asia', 1.36, Decimal('-999')),
#  ('Eastern and South-Eastern Asia', 0.77, Decimal('-999')),
#  ('Eastern and South-Eastern Asia', 0.41, Decimal('-999')),
#  ('Eastern and South-Eastern Asia', 1.48, Decimal('-999')),
#  ('Eastern and South-Eastern Asia', 3.07, Decimal('-999')),
#  ('Eastern and South-Eastern Asia', 2.7, Decimal('-999')),
#  ('Eastern and South-Eastern Asia', 2.55, Decimal('-999')),
#  ('Eastern and South-Eastern Asia', 2.34, Decimal('-999')),
#  ('Eastern and South-Eastern Asia', 2.24, Decimal('-999')),
#  ('Eastern and South-Eastern Asia', 2.52, Decimal('-999')),
#  ('Eastern and South-Eastern Asia', 3.79, Decimal('-999')),
#  ('Eastern and South-Eastern Asia', 4.08, Decimal('-999')),
#  ('Eastern and South-Eastern Asia', 4.2, Decimal('-999')),
#  ('Eastern and South-Eastern Asia', None, Decimal('22.64')),
#  ('Eastern and South-Eastern Asia', 3.1, Decimal('-999')),
#  ('Eastern and South-Eastern Asia', 4.1, Decimal('-999')),
#  ('Eastern and South-Eastern Asia', 0.6, Decimal('-999')),
#  ('Eastern and South-Eastern Asia', 0.69, Decimal('-999')),
#  ('Eastern and South-Eastern Asia', 0.83, Decimal('-999')),
#  ('Eastern and South-Eastern Asia', 0.77, Decimal('-999')),
#  ('Eastern and South-Eastern Asia', 0.72, Decimal('-999')),
#  ('Eastern and South-Eastern Asia', 1.1, Decimal('-999')),
#  ('Eastern and South-Eastern Asia', None, Decimal('22.64')),
#  ('Eastern and South-Eastern Asia', 4.66, Decimal('-999')),
#  ('Eastern and South-Eastern Asia', None, Decimal('22.64')),
#  ('Eastern and South-Eastern Asia', None, Decimal('22.64')),
#  ('Eastern and South-Eastern Asia', None, Decimal('22.64')),
#  ('Eastern and South-Eastern Asia', None, Decimal('22.64')),
#  ('Eastern and South-Eastern Asia', None, Decimal('22.64')),
#  ('Eastern and South-Eastern Asia', None, Decimal('22.64')),
#  ('Eastern and South-Eastern Asia', None, Decimal('22.64')),
#  ('Eastern and South-Eastern Asia', None, Decimal('22.64')),
#  ('Eastern and South-Eastern Asia', None, Decimal('22.64')),
#  ('Eastern and South-Eastern Asia', None, Decimal('22.64')),
#  ('Europe and Northern America', None, Decimal('24.43')),
#  ('Europe and Northern America', None, Decimal('24.43')),
#  ('Europe and Northern America', None, Decimal('24.43')),
#  ('Europe and Northern America', None, Decimal('24.43')),
#  ('Europe and Northern America', None, Decimal('24.43')),
#  ('Europe and Northern America', None, Decimal('24.43')),
#  ('Europe and Northern America', 6.91, Decimal('-999')),
#  ('Europe and Northern America', 7.0, Decimal('-999')),
#  ('Europe and Northern America', 6.34, Decimal('-999')),
#  ('Europe and Northern America', 5.83, Decimal('-999')),
#  ('Europe and Northern America', 5.66, Decimal('-999')),
#  ('Europe and Northern America', 9.46, Decimal('-999')),
#  ('Europe and Northern America', 9.1, Decimal('-999')),
#  ('Europe and Northern America', None, Decimal('24.43')),
#  ('Europe and Northern America', None, Decimal('24.43')),
#  ('Europe and Northern America', None, Decimal('24.43')),
#  ('Europe and Northern America', None, Decimal('24.43')),
#  ('Europe and Northern America', None, Decimal('24.43')),
#  ('Europe and Northern America', None, Decimal('24.43')),
#  ('Europe and Northern America', None, Decimal('24.43')),
#  ('Europe and Northern America', None, Decimal('24.43')),
#  ('Europe and Northern America', None, Decimal('24.43')),
#  ('Europe and Northern America', None, Decimal('24.43')),
#  ('Europe and Northern America', None, Decimal('24.43')),
#  ('Europe and Northern America', None, Decimal('24.43')),
#  ('Europe and Northern America', None, Decimal('24.43')),
#  ('Europe and Northern America', None, Decimal('24.43')),
#  ('Europe and Northern America', None, Decimal('24.43')),
#  ('Europe and Northern America', None, Decimal('24.43')),
#  ('Europe and Northern America', None, Decimal('24.43')),
#  ('Latin America and the Caribbean', None, Decimal('24.23')),
#  ('Latin America and the Caribbean', None, Decimal('24.23')),
#  ('Latin America and the Caribbean', None, Decimal('24.23')),
#  ('Latin America and the Caribbean', None, Decimal('24.23')),
#  ('Latin America and the Caribbean', None, Decimal('24.23')),
#  ('Latin America and the Caribbean', None, Decimal('24.23')),
#  ('Latin America and the Caribbean', None, Decimal('24.23')),
#  ('Latin America and the Caribbean', None, Decimal('24.23')),
#  ('Latin America and the Caribbean', None, Decimal('24.23')),
#  ('Latin America and the Caribbean', None, Decimal('24.23')),
#  ('Latin America and the Caribbean', None, Decimal('24.23')),
#  ('Latin America and the Caribbean', None, Decimal('24.23')),
#  ('Latin America and the Caribbean', None, Decimal('24.23')),
#  ('Latin America and the Caribbean', 9.8, Decimal('-999')),
#  ('Latin America and the Caribbean', 8.25, Decimal('-999')),
#  ('Latin America and the Caribbean', 8.62, Decimal('-999')),
#  ('Latin America and the Caribbean', 8.32, Decimal('-999')),
#  ('Latin America and the Caribbean', 8.41, Decimal('-999')),
#  ('Latin America and the Caribbean', None, Decimal('24.23')),
#  ('Latin America and the Caribbean', None, Decimal('24.23')),
#  ('Latin America and the Caribbean', None, Decimal('24.23')),
#  ('Latin America and the Caribbean', None, Decimal('24.23')),
#  ('Latin America and the Caribbean', None, Decimal('24.23')),
#  ('Latin America and the Caribbean', None, Decimal('24.23')),
#  ('Latin America and the Caribbean', None, Decimal('24.23')),
#  ('Latin America and the Caribbean', 4.24, Decimal('-999')),
#  ('Latin America and the Caribbean', None, Decimal('24.23')),
#  ('Latin America and the Caribbean', 2.4, Decimal('-999')),
#  ('Latin America and the Caribbean', 2.0, Decimal('-999')),
#  ('Latin America and the Caribbean', 1.7, Decimal('-999')),
#  ('Latin America and the Caribbean', 1.7, Decimal('-999')),
#  ('Latin America and the Caribbean', None, Decimal('24.23')),
#  ('Latin America and the Caribbean', None, Decimal('24.23')),
#  ('Latin America and the Caribbean', None, Decimal('24.23')),
#  ('Latin America and the Caribbean', None, Decimal('24.23')),
#  ('Latin America and the Caribbean', None, Decimal('24.23')),
#  ('Latin America and the Caribbean', None, Decimal('24.23')),
#  ('Latin America and the Caribbean', None, Decimal('24.23')),
#  ('Latin America and the Caribbean', None, Decimal('24.23')),
#  ('Latin America and the Caribbean', 7.61, Decimal('-999')),
#  ('Latin America and the Caribbean', 7.28, Decimal('-999')),
#  ('Latin America and the Caribbean', 5.83, Decimal('-999')),
#  ('Latin America and the Caribbean', 5.86, Decimal('-999')),
#  ('Latin America and the Caribbean', 6.18, Decimal('-999')),
#  ('Latin America and the Caribbean', 6.13, Decimal('-999')),
#  ('Latin America and the Caribbean', 22.9, Decimal('-999')),
#  ('Latin America and the Caribbean', None, Decimal('24.23')),
#  ('Latin America and the Caribbean', None, Decimal('24.23')),
#  ('Latin America and the Caribbean', None, Decimal('24.23')),
#  ('Latin America and the Caribbean', None, Decimal('24.23')),
#  ('Latin America and the Caribbean', None, Decimal('24.23')),
#  ('Latin America and the Caribbean', None, Decimal('24.23')),
#  ('Latin America and the Caribbean', None, Decimal('24.23')),
#  ('Latin America and the Caribbean', None, Decimal('24.23')),
#  ('Latin America and the Caribbean', None, Decimal('24.23')),
#  ('Latin America and the Caribbean', None, Decimal('24.23')),
#  ('Latin America and the Caribbean', None, Decimal('24.23')),
#  ('Latin America and the Caribbean', None, Decimal('24.23')),
#  ('Latin America and the Caribbean', None, Decimal('24.23')),
#  ('Latin America and the Caribbean', None, Decimal('24.23')),
#  ('Latin America and the Caribbean', 13.51, Decimal('-999')),
#  ('Latin America and the Caribbean', 8.63, Decimal('-999')),
#  ('Latin America and the Caribbean', 7.4, Decimal('-999')),
#  ('Latin America and the Caribbean', 5.47, Decimal('-999')),
#  ('Latin America and the Caribbean', 4.99, Decimal('-999')),
#  ('Latin America and the Caribbean', 6.5, Decimal('-999')),
#  ('Latin America and the Caribbean', None, Decimal('24.23')),
#  ('Latin America and the Caribbean', None, Decimal('24.23')),
#  ('Latin America and the Caribbean', None, Decimal('24.23')),
#  ('Latin America and the Caribbean', None, Decimal('24.23')),
#  ('Latin America and the Caribbean', None, Decimal('24.23')),
#  ('Latin America and the Caribbean', None, Decimal('24.23')),
#  ('Latin America and the Caribbean', None, Decimal('24.23')),
#  ('Latin America and the Caribbean', None, Decimal('24.23')),
#  ('Latin America and the Caribbean', None, Decimal('24.23')),
#  ('Latin America and the Caribbean', None, Decimal('24.23')),
#  ('Latin America and the Caribbean', None, Decimal('24.23')),
#  ('Latin America and the Caribbean', None, Decimal('24.23')),
#  ('Latin America and the Caribbean', 12.0, Decimal('-999')),
#  ('Latin America and the Caribbean', 11.8, Decimal('-999')),
#  ('Latin America and the Caribbean', 10.8, Decimal('-999')),
#  ('Latin America and the Caribbean', 9.2, Decimal('-999')),
#  ('Latin America and the Caribbean', 8.3, Decimal('-999')),
#  ('Latin America and the Caribbean', None, Decimal('24.23')),
#  ('Latin America and the Caribbean', None, Decimal('24.23')),
#  ('Latin America and the Caribbean', None, Decimal('24.23')),
#  ('Latin America and the Caribbean', None, Decimal('24.23')),
#  ('Latin America and the Caribbean', None, Decimal('24.23')),
#  ('Latin America and the Caribbean', None, Decimal('24.23')),
#  ('Latin America and the Caribbean', None, Decimal('24.23')),
#  ('Latin America and the Caribbean', None, Decimal('24.23')),
#  ('Latin America and the Caribbean', None, Decimal('24.23')),
#  ('Latin America and the Caribbean', None, Decimal('24.23')),
#  ('Latin America and the Caribbean', None, Decimal('24.23')),
#  ('Latin America and the Caribbean', None, Decimal('24.23')),
#  ('Latin America and the Caribbean', None, Decimal('24.23')),
#  ('Latin America and the Caribbean', None, Decimal('24.23')),
#  ('Latin America and the Caribbean', None, Decimal('24.23')),
#  ('Latin America and the Caribbean', None, Decimal('24.23')),
#  ('Latin America and the Caribbean', None, Decimal('24.23')),
#  ('Latin America and the Caribbean', None, Decimal('24.23')),
#  ('Latin America and the Caribbean', None, Decimal('24.23')),
#  ('Latin America and the Caribbean', None, Decimal('24.23')),
#  ('Latin America and the Caribbean', None, Decimal('24.23')),
#  ('Latin America and the Caribbean', None, Decimal('24.23')),
#  ('Latin America and the Caribbean', None, Decimal('24.23')),
#  ('Latin America and the Caribbean', None, Decimal('24.23')),
#  ('Latin America and the Caribbean', None, Decimal('24.23')),
#  ('Latin America and the Caribbean', None, Decimal('24.23')),
#  ('Latin America and the Caribbean', None, Decimal('24.23')),
#  ('Latin America and the Caribbean', None, Decimal('24.23')),
#  ('Latin America and the Caribbean', None, Decimal('24.23')),
#  ('Latin America and the Caribbean', 2.43, Decimal('-999')),
#  ('Latin America and the Caribbean', 3.21, Decimal('-999')),
#  ('Latin America and the Caribbean', None, Decimal('24.23')),
#  ('Latin America and the Caribbean', None, Decimal('24.23')),
#  ('Latin America and the Caribbean', 3.52, Decimal('-999')),
#  ('Latin America and the Caribbean', 4.21, Decimal('-999')),
#  ('Latin America and the Caribbean', None, Decimal('24.23')),
#  ('Latin America and the Caribbean', None, Decimal('24.23')),
#  ('Latin America and the Caribbean', None, Decimal('24.23')),
#  ('Latin America and the Caribbean', None, Decimal('24.23')),
#  ('Latin America and the Caribbean', None, Decimal('24.23')),
#  ('Latin America and the Caribbean', None, Decimal('24.23')),
#  ('Latin America and the Caribbean', None, Decimal('24.23')),
#  ('Latin America and the Caribbean', None, Decimal('24.23')),
#  ('Latin America and the Caribbean', None, Decimal('24.23')),
#  ('Latin America and the Caribbean', None, Decimal('24.23')),
#  ('Latin America and the Caribbean', 7.58, Decimal('-999')),
#  ('Latin America and the Caribbean', 7.0, Decimal('-999')),
#  ('Latin America and the Caribbean', 6.6, Decimal('-999')),
#  ('Latin America and the Caribbean', None, Decimal('24.23')),
#  ('Latin America and the Caribbean', 9.05, Decimal('-999')),
#  ('Latin America and the Caribbean', None, Decimal('24.23')),
#  ('Latin America and the Caribbean', 8.42, Decimal('-999')),
#  ('Latin America and the Caribbean', 8.09, Decimal('-999')),
#  ('Latin America and the Caribbean', 7.73, Decimal('-999')),
#  ('Latin America and the Caribbean', 9.01, Decimal('-999')),
#  ('Latin America and the Caribbean', 10.81, Decimal('-999')),
#  ('Latin America and the Caribbean', 16.43, Decimal('-999')),
#  ('Latin America and the Caribbean', 4.0, Decimal('-999')),
#  ('Latin America and the Caribbean', 4.42, Decimal('-999')),
#  ('Latin America and the Caribbean', 4.39, Decimal('-999')),
#  ('Latin America and the Caribbean', 4.01, Decimal('-999')),
#  ('Latin America and the Caribbean', 4.17, Decimal('-999')),
#  ('Latin America and the Caribbean', 5.01, Decimal('-999')),
#  ('Latin America and the Caribbean', 2.51, Decimal('-999')),
#  ('Latin America and the Caribbean', 2.58, Decimal('-999')),
#  ('Latin America and the Caribbean', 2.46, Decimal('-999')),
#  ('Latin America and the Caribbean', 2.28, Decimal('-999')),
#  ('Latin America and the Caribbean', 2.19, Decimal('-999')),
#  ('Latin America and the Caribbean', None, Decimal('24.23')),
#  ('Latin America and the Caribbean', 6.15, Decimal('-999')),
#  ('Latin America and the Caribbean', 6.73, Decimal('-999')),
#  ('Latin America and the Caribbean', 5.53, Decimal('-999')),
#  ('Latin America and the Caribbean', 5.62, Decimal('-999')),
#  ('Latin America and the Caribbean', 5.55, Decimal('-999')),
#  ('Latin America and the Caribbean', 10.68, Decimal('-999')),
#  ('Latin America and the Caribbean', 4.31, Decimal('-999')),
#  ('Latin America and the Caribbean', 3.85, Decimal('-999')),
#  ('Latin America and the Caribbean', 3.42, Decimal('-999')),
#  ('Latin America and the Caribbean', 3.27, Decimal('-999')),
#  ('Latin America and the Caribbean', 3.48, Decimal('-999')),
#  ('Latin America and the Caribbean', 4.44, Decimal('-999')),
#  ('Latin America and the Caribbean', 4.7, Decimal('-999')),
#  ('Latin America and the Caribbean', 3.9, Decimal('-999')),
#  ('Latin America and the Caribbean', 3.3, Decimal('-999')),
#  ('Latin America and the Caribbean', 5.2, Decimal('-999')),
#  ('Latin America and the Caribbean', None, Decimal('24.23')),
#  ('Latin America and the Caribbean', None, Decimal('24.23')),
#  ('Latin America and the Caribbean', 4.4, Decimal('-999')),
#  ('Latin America and the Caribbean', 4.84, Decimal('-999')),
#  ('Latin America and the Caribbean', 5.46, Decimal('-999')),
#  ('Latin America and the Caribbean', 5.31, Decimal('-999')),
#  ('Latin America and the Caribbean', 6.41, Decimal('-999')),
#  ('Latin America and the Caribbean', 18.55, Decimal('-999')),
#  ('Latin America and the Caribbean', None, Decimal('24.23')),
#  ('Latin America and the Caribbean', None, Decimal('24.23')),
#  ('Latin America and the Caribbean', 8.35, Decimal('-999')),
#  ('Latin America and the Caribbean', 9.22, Decimal('-999')),
#  ('Latin America and the Caribbean', 9.84, Decimal('-999')),
#  ('Latin America and the Caribbean', 11.46, Decimal('-999')),
#  ('Latin America and the Caribbean', None, Decimal('24.23')),
#  ('Latin America and the Caribbean', None, Decimal('24.23')),
#  ('Latin America and the Caribbean', None, Decimal('24.23')),
#  ('Latin America and the Caribbean', None, Decimal('24.23')),
#  ('Latin America and the Caribbean', None, Decimal('24.23')),
#  ('Latin America and the Caribbean', None, Decimal('24.23')),
#  ('Latin America and the Caribbean', 8.54, Decimal('-999')),
#  ('Latin America and the Caribbean', 11.58, Decimal('-999')),
#  ('Latin America and the Caribbean', 12.79, Decimal('-999')),
#  ('Latin America and the Caribbean', 12.33, Decimal('-999')),
#  ('Latin America and the Caribbean', 11.94, Decimal('-999')),
#  ('Latin America and the Caribbean', 13.7, Decimal('-999')),
#  ('Latin America and the Caribbean', 6.49, Decimal('-999')),
#  ('Latin America and the Caribbean', 6.73, Decimal('-999')),
#  ('Latin America and the Caribbean', 6.95, Decimal('-999')),
#  ('Latin America and the Caribbean', 7.21, Decimal('-999')),
#  ('Latin America and the Caribbean', 7.27, Decimal('-999')),
#  ('Latin America and the Caribbean', 10.94, Decimal('-999')),
#  ('Latin America and the Caribbean', 8.57, Decimal('-999')),
#  ('Latin America and the Caribbean', 8.92, Decimal('-999')),
#  ('Latin America and the Caribbean', 9.09, Decimal('-999')),
#  ('Latin America and the Caribbean', 9.36, Decimal('-999')),
#  ('Latin America and the Caribbean', 10.28, Decimal('-999')),
#  ('Latin America and the Caribbean', 15.98, Decimal('-999')),
#  ('Latin America and the Caribbean', 3.62, Decimal('-999')),
#  ('Latin America and the Caribbean', 4.6, Decimal('-999')),
#  ('Latin America and the Caribbean', 3.84, Decimal('-999')),
#  ('Latin America and the Caribbean', 3.53, Decimal('-999')),
#  ('Latin America and the Caribbean', 3.81, Decimal('-999')),
#  ('Latin America and the Caribbean', 6.11, Decimal('-999')),
#  ('Latin America and the Caribbean', None, Decimal('24.23')),
#  ('Latin America and the Caribbean', None, Decimal('24.23')),
#  ('Latin America and the Caribbean', None, Decimal('24.23')),
#  ('Latin America and the Caribbean', None, Decimal('24.23')),
#  ('Latin America and the Caribbean', None, Decimal('24.23')),
#  ('Latin America and the Caribbean', None, Decimal('24.23')),
#  ('Latin America and the Caribbean', None, Decimal('24.23')),
#  ('Latin America and the Caribbean', None, Decimal('24.23')),
#  ('Latin America and the Caribbean', None, Decimal('24.23')),
#  ('Latin America and the Caribbean', None, Decimal('24.23')),
#  ('Latin America and the Caribbean', None, Decimal('24.23')),
#  ('Latin America and the Caribbean', None, Decimal('24.23')),
#  ('Latin America and the Caribbean', None, Decimal('24.23')),
#  ('Latin America and the Caribbean', None, Decimal('24.23')),
#  ('Latin America and the Caribbean', None, Decimal('24.23')),
#  ('Latin America and the Caribbean', 14.02, Decimal('-999')),
#  ('Latin America and the Caribbean', 13.52, Decimal('-999')),
#  ('Latin America and the Caribbean', None, Decimal('24.23')),
#  ('Latin America and the Caribbean', 4.56, Decimal('-999')),
#  ('Latin America and the Caribbean', 5.25, Decimal('-999')),
#  ('Latin America and the Caribbean', 4.61, Decimal('-999')),
#  ('Latin America and the Caribbean', 6.22, Decimal('-999')),
#  ('Latin America and the Caribbean', 6.59, Decimal('-999')),
#  ('Latin America and the Caribbean', 7.55, Decimal('-999')),
#  ('Latin America and the Caribbean', 3.27, Decimal('-999')),
#  ('Latin America and the Caribbean', 3.74, Decimal('-999')),
#  ('Latin America and the Caribbean', 3.69, Decimal('-999')),
#  ('Latin America and the Caribbean', 3.49, Decimal('-999')),
#  ('Latin America and the Caribbean', 3.38, Decimal('-999')),
#  ('Latin America and the Caribbean', 7.18, Decimal('-999')),
#  ('Latin America and the Caribbean', 7.22, Decimal('-999')),
#  ('Latin America and the Caribbean', 7.92, Decimal('-999')),
#  ('Latin America and the Caribbean', None, Decimal('24.23')),
#  ('Latin America and the Caribbean', None, Decimal('24.23')),
#  ('Latin America and the Caribbean', None, Decimal('24.23')),
#  ('Latin America and the Caribbean', None, Decimal('24.23')),
#  ('Latin America and the Caribbean', 7.49, Decimal('-999')),
#  ('Latin America and the Caribbean', 7.84, Decimal('-999')),
#  ('Latin America and the Caribbean', 7.89, Decimal('-999')),
#  ('Latin America and the Caribbean', 8.34, Decimal('-999')),
#  ('Latin America and the Caribbean', 8.73, Decimal('-999')),
#  ('Latin America and the Caribbean', 10.33, Decimal('-999')),
#  ('Latin America and the Caribbean', None, Decimal('24.23')),
#  ('Latin America and the Caribbean', None, Decimal('24.23')),
#  ('Latin America and the Caribbean', None, Decimal('24.23')),
#  ('Latin America and the Caribbean', None, Decimal('24.23')),
#  ('Latin America and the Caribbean', None, Decimal('24.23')),
#  ('Latin America and the Caribbean', None, Decimal('24.23')),
#  ('Northern Africa and Western Asia', 11.21, Decimal('-999')),
#  ('Northern Africa and Western Asia', 10.2, Decimal('-999')),
#  ('Northern Africa and Western Asia', 12.0, Decimal('-999')),
#  ('Northern Africa and Western Asia', None, Decimal('17.84')),
#  ('Northern Africa and Western Asia', None, Decimal('17.84')),
#  ('Northern Africa and Western Asia', None, Decimal('17.84')),
#  ('Northern Africa and Western Asia', None, Decimal('17.84')),
#  ('Northern Africa and Western Asia', None, Decimal('17.84')),
#  ('Northern Africa and Western Asia', None, Decimal('17.84')),
#  ('Northern Africa and Western Asia', None, Decimal('17.84')),
#  ('Northern Africa and Western Asia', None, Decimal('17.84')),
#  ('Northern Africa and Western Asia', None, Decimal('17.84')),
#  ('Northern Africa and Western Asia', None, Decimal('17.84')),
#  ('Northern Africa and Western Asia', None, Decimal('17.84')),
#  ('Northern Africa and Western Asia', None, Decimal('17.84')),
#  ('Northern Africa and Western Asia', None, Decimal('17.84')),
#  ('Northern Africa and Western Asia', None, Decimal('17.84')),
#  ('Northern Africa and Western Asia', None, Decimal('17.84')),
#  ('Northern Africa and Western Asia', 9.46, Decimal('-999')),
#  ('Northern Africa and Western Asia', 9.3, Decimal('-999')),
#  ('Northern Africa and Western Asia', None, Decimal('17.84')),
#  ('Northern Africa and Western Asia', None, Decimal('17.84')),
#  ('Northern Africa and Western Asia', None, Decimal('17.84')),
#  ('Northern Africa and Western Asia', None, Decimal('17.84')),
#  ('Northern Africa and Western Asia', None, Decimal('17.84')),
#  ('Northern Africa and Western Asia', None, Decimal('17.84')),
#  ('Northern Africa and Western Asia', None, Decimal('17.84')),
#  ('Northern Africa and Western Asia', None, Decimal('17.84')),
#  ('Northern Africa and Western Asia', None, Decimal('17.84')),
#  ('Northern Africa and Western Asia', None, Decimal('17.84')),
#  ('Northern Africa and Western Asia', 15.16, Decimal('-999')),
#  ('Northern Africa and Western Asia', 15.56, Decimal('-999')),
#  ('Northern Africa and Western Asia', 15.33, Decimal('-999')),
#  ('Northern Africa and Western Asia', 15.46, Decimal('-999')),
#  ('Northern Africa and Western Asia', 15.13, Decimal('-999')),
#  ('Northern Africa and Western Asia', None, Decimal('17.84')),
#  ('Northern Africa and Western Asia', 18.26, Decimal('-999')),
#  ('Northern Africa and Western Asia', 17.62, Decimal('-999')),
#  ('Northern Africa and Western Asia', 17.7, Decimal('-999')),
#  ('Northern Africa and Western Asia', 13.21, Decimal('-999')),
#  ('Northern Africa and Western Asia', 12.2, Decimal('-999')),
#  ('Northern Africa and Western Asia', 12.18, Decimal('-999')),
#  ('Northern Africa and Western Asia', 4.96, Decimal('-999')),
#  ('Northern Africa and Western Asia', 5.0, Decimal('-999')),
#  ('Northern Africa and Western Asia', 4.96, Decimal('-999')),
#  ('Northern Africa and Western Asia', 4.94, Decimal('-999')),
#  ('Northern Africa and Western Asia', 4.85, Decimal('-999')),
#  ('Northern Africa and Western Asia', 7.16, Decimal('-999')),
#  ('Northern Africa and Western Asia', None, Decimal('17.84')),
#  ('Northern Africa and Western Asia', None, Decimal('17.84')),
#  ('Northern Africa and Western Asia', None, Decimal('17.84')),
#  ('Northern Africa and Western Asia', None, Decimal('17.84')),
#  ('Northern Africa and Western Asia', None, Decimal('17.84')),
#  ('Northern Africa and Western Asia', None, Decimal('17.84')),
#  ('Northern Africa and Western Asia', 15.03, Decimal('-999')),
#  ('Northern Africa and Western Asia', 13.01, Decimal('-999')),
#  ('Northern Africa and Western Asia', 11.16, Decimal('-999')),
#  ('Northern Africa and Western Asia', 8.5, Decimal('-999')),
#  ('Northern Africa and Western Asia', 7.15, Decimal('-999')),
#  ('Northern Africa and Western Asia', 7.76, Decimal('-999')),
#  ('Northern Africa and Western Asia', 16.51, Decimal('-999')),
#  ('Northern Africa and Western Asia', 16.6, Decimal('-999')),
#  ('Northern Africa and Western Asia', 13.94, Decimal('-999')),
#  ('Northern Africa and Western Asia', 12.67, Decimal('-999')),
#  ('Northern Africa and Western Asia', 11.57, Decimal('-999')),
#  ('Northern Africa and Western Asia', 11.73, Decimal('-999')),
#  ('Northern Africa and Western Asia', None, Decimal('17.84')),
#  ('Northern Africa and Western Asia', 10.82, Decimal('-999')),
#  ('Northern Africa and Western Asia', 13.02, Decimal('-999')),
#  ('Northern Africa and Western Asia', None, Decimal('17.84')),
#  ('Northern Africa and Western Asia', None, Decimal('17.84')),
#  ('Northern Africa and Western Asia', None, Decimal('17.84')),
#  ('Northern Africa and Western Asia', 5.18, Decimal('-999')),
#  ('Northern Africa and Western Asia', 4.72, Decimal('-999')),
#  ('Northern Africa and Western Asia', 4.14, Decimal('-999')),
#  ('Northern Africa and Western Asia', 3.92, Decimal('-999')),
#  ('Northern Africa and Western Asia', 3.73, Decimal('-999')),
#  ('Northern Africa and Western Asia', 4.17, Decimal('-999')),
#  ('Northern Africa and Western Asia', 13.08, Decimal('-999')),
#  ('Northern Africa and Western Asia', 15.28, Decimal('-999')),
#  ('Northern Africa and Western Asia', 18.12, Decimal('-999')),
#  ('Northern Africa and Western Asia', 18.26, Decimal('-999')),
#  ('Northern Africa and Western Asia', 16.8, Decimal('-999')),
#  ('Northern Africa and Western Asia', 19.21, Decimal('-999')),
#  ('Northern Africa and Western Asia', 2.2, Decimal('-999')),
#  ('Northern Africa and Western Asia', 2.16, Decimal('-999')),
#  ('Northern Africa and Western Asia', None, Decimal('17.84')),
#  ('Northern Africa and Western Asia', None, Decimal('17.84')),
#  ('Northern Africa and Western Asia', None, Decimal('17.84')),
#  ('Northern Africa and Western Asia', None, Decimal('17.84')),
#  ('Northern Africa and Western Asia', None, Decimal('17.84')),
#  ('Northern Africa and Western Asia', None, Decimal('17.84')),
#  ('Northern Africa and Western Asia', None, Decimal('17.84')),
#  ('Northern Africa and Western Asia', None, Decimal('17.84')),
#  ('Northern Africa and Western Asia', 11.3, Decimal('-999')),
#  ('Northern Africa and Western Asia', None, Decimal('17.84')),
#  ('Northern Africa and Western Asia', None, Decimal('17.84')),
#  ('Northern Africa and Western Asia', 3.27, Decimal('-999')),
#  ('Northern Africa and Western Asia', None, Decimal('17.84')),
#  ('Northern Africa and Western Asia', 1.8, Decimal('-999')),
#  ('Northern Africa and Western Asia', None, Decimal('17.84')),
#  ('Northern Africa and Western Asia', 2.94, Decimal('-999')),
#  ('Northern Africa and Western Asia', 0.17, Decimal('-999')),
#  ('Northern Africa and Western Asia', 0.15, Decimal('-999')),
#  ('Northern Africa and Western Asia', 0.14, Decimal('-999')),
#  ('Northern Africa and Western Asia', 0.11, Decimal('-999')),
#  ('Northern Africa and Western Asia', 0.1, Decimal('-999')),
#  ('Northern Africa and Western Asia', 0.14, Decimal('-999')),
#  ('Northern Africa and Western Asia', 5.6, Decimal('-999')),
#  ('Northern Africa and Western Asia', 5.6, Decimal('-999')),
#  ('Northern Africa and Western Asia', 5.89, Decimal('-999')),
#  ('Northern Africa and Western Asia', 6.03, Decimal('-999')),
#  ('Northern Africa and Western Asia', 5.64, Decimal('-999')),
#  ('Northern Africa and Western Asia', 7.66, Decimal('-999')),
#  ('Northern Africa and Western Asia', None, Decimal('17.84')),
#  ('Northern Africa and Western Asia', None, Decimal('17.84')),
#  ('Northern Africa and Western Asia', None, Decimal('17.84')),
#  ('Northern Africa and Western Asia', None, Decimal('17.84')),
#  ('Northern Africa and Western Asia', None, Decimal('17.84')),
#  ('Northern Africa and Western Asia', None, Decimal('17.84')),
#  ('Northern Africa and Western Asia', None, Decimal('17.84')),
#  ('Northern Africa and Western Asia', None, Decimal('17.84')),
#  ('Northern Africa and Western Asia', None, Decimal('17.84')),
#  ('Northern Africa and Western Asia', None, Decimal('17.84')),
#  ('Northern Africa and Western Asia', None, Decimal('17.84')),
#  ('Northern Africa and Western Asia', None, Decimal('17.84')),
#  ('Northern Africa and Western Asia', None, Decimal('17.84')),
#  ('Northern Africa and Western Asia', None, Decimal('17.84')),
#  ('Northern Africa and Western Asia', None, Decimal('17.84')),
#  ('Northern Africa and Western Asia', None, Decimal('17.84')),
#  ('Northern Africa and Western Asia', None, Decimal('17.84')),
#  ('Northern Africa and Western Asia', None, Decimal('17.84')),
#  ('Northern Africa and Western Asia', None, Decimal('17.84')),
#  ('Northern Africa and Western Asia', 1.64, Decimal('-999')),
#  ('Northern Africa and Western Asia', 2.46, Decimal('-999')),
#  ('Northern Africa and Western Asia', 2.24, Decimal('-999')),
#  ('Northern Africa and Western Asia', 2.33, Decimal('-999')),
#  ('Northern Africa and Western Asia', 4.29, Decimal('-999')),
#  ('Northern Africa and Western Asia', None, Decimal('17.84')),
#  ('Northern Africa and Western Asia', None, Decimal('17.84')),
#  ('Northern Africa and Western Asia', None, Decimal('17.84')),
#  ('Northern Africa and Western Asia', None, Decimal('17.84')),
#  ('Northern Africa and Western Asia', None, Decimal('17.84')),
#  ('Northern Africa and Western Asia', None, Decimal('17.84')),
#  ('Oceania', 6.06, Decimal('-999')),
#  ('Oceania', 5.71, Decimal('-999')),
#  ('Oceania', 5.59, Decimal('-999')),
#  ('Oceania', 5.3, Decimal('-999')),
#  ('Oceania', 5.16, Decimal('-999')),
#  ('Oceania', 6.46, Decimal('-999')),
#  ('Oceania', 5.42, Decimal('-999')),
#  ('Oceania', 5.15, Decimal('-999')),
#  ('Oceania', 4.74, Decimal('-999')),
#  ('Oceania', 4.34, Decimal('-999')),
#  ('Oceania', 4.11, Decimal('-999')),
#  ('Oceania', 4.6, Decimal('-999')),
#  ('Oceania', None, Decimal('4.98')),
#  ('Oceania', 4.32, Decimal('-999')),
#  ('Oceania', None, Decimal('4.98')),
#  ('Oceania', None, Decimal('4.98')),
#  ('Oceania', None, Decimal('4.98')),
#  ('Oceania', None, Decimal('4.98')),
#  ('Oceania', None, Decimal('4.98')),
#  ('Oceania', None, Decimal('4.98')),
#  ('Oceania', 11.68, Decimal('-999')),
#  ('Oceania', 11.7, Decimal('-999')),
#  ('Oceania', 10.88, Decimal('-999')),
#  ('Oceania', 13.56, Decimal('-999')),
#  ('Oceania', None, Decimal('4.98')),
#  ('Oceania', None, Decimal('4.98')),
#  ('Oceania', None, Decimal('4.98')),
#  ('Oceania', None, Decimal('4.98')),
#  ('Oceania', None, Decimal('4.98')),
#  ('Oceania', None, Decimal('4.98')),
#  ('Oceania', None, Decimal('4.98')),
#  ('Oceania', None, Decimal('4.98')),
#  ('Oceania', None, Decimal('4.98')),
#  ('Oceania', None, Decimal('4.98')),
#  ('Oceania', None, Decimal('4.98')),
#  ('Oceania', None, Decimal('4.98')),
#  ('Oceania', None, Decimal('4.98')),
#  ('Oceania', None, Decimal('4.98')),
#  ('Oceania', None, Decimal('4.98')),
#  ('Oceania', None, Decimal('4.98')),
#  ('Oceania', 5.44, Decimal('-999')),
#  ('Oceania', 4.05, Decimal('-999')),
#  ('Oceania', 6.9, Decimal('-999')),
#  ('Oceania', 5.4, Decimal('-999')),
#  ('Oceania', None, Decimal('4.98')),
#  ('Oceania', None, Decimal('4.98')),
#  ('Oceania', None, Decimal('4.98')),
#  ('Oceania', None, Decimal('4.98')),
#  ('Oceania', 9.33, Decimal('-999')),
#  ('Oceania', None, Decimal('4.98')),
#  ('Oceania', None, Decimal('4.98')),
#  ('Oceania', None, Decimal('4.98')),
#  ('Oceania', 8.56, Decimal('-999')),
#  ('Oceania', 10.97, Decimal('-999')),
#  ('Oceania', None, Decimal('4.98')),
#  ('Oceania', None, Decimal('4.98')),
#  ('Oceania', None, Decimal('4.98')),
#  ('Oceania', None, Decimal('4.98')),
#  ('Oceania', 6.34, Decimal('-999')),
#  ('Oceania', None, Decimal('4.98')),
#  ('Oceania', None, Decimal('4.98')),
#  ('Oceania', None, Decimal('4.98')),
#  ('Oceania', None, Decimal('4.98')),
#  ('Oceania', None, Decimal('4.98')),
#  ('Oceania', None, Decimal('4.98')),
#  ('Oceania', None, Decimal('4.98')),
#  ('Oceania', None, Decimal('4.98')),
#  ('Oceania', None, Decimal('4.98')),
#  ('Oceania', None, Decimal('4.98')),
#  ('Oceania', None, Decimal('4.98')),
#  ('Oceania', None, Decimal('4.98')),
#  ('Oceania', None, Decimal('4.98')),
#  ('Oceania', None, Decimal('4.98')),
#  ('Oceania', None, Decimal('4.98')),
#  ('Oceania', None, Decimal('4.98')),
#  ('Oceania', None, Decimal('4.98')),
#  ('Oceania', None, Decimal('4.98')),
#  ('Oceania', None, Decimal('4.98')),
#  ('Oceania', None, Decimal('4.98')),
#  ('Oceania', None, Decimal('4.98')),
#  ('Oceania', None, Decimal('4.98')),
#  ('Oceania', None, Decimal('4.98')),
#  ('Oceania', 0.77, Decimal('-999')),
#  ('Oceania', None, Decimal('4.98')),
#  ('Oceania', None, Decimal('4.98')),
#  ('Oceania', None, Decimal('4.98')),
#  ('Oceania', None, Decimal('4.98')),
#  ('Oceania', None, Decimal('4.98')),
#  ('Oceania', None, Decimal('4.98')),
#  ('Oceania', None, Decimal('4.98')),
#  ('Oceania', None, Decimal('4.98')),
#  ('Oceania', None, Decimal('4.98')),
#  ('Oceania', None, Decimal('4.98')),
#  ('Oceania', None, Decimal('4.98')),
#  ('Oceania', None, Decimal('4.98')),
#  ('Oceania', None, Decimal('4.98')),
#  ('Oceania', None, Decimal('4.98')),
#  ('Oceania', None, Decimal('4.98')),
#  ('Oceania', None, Decimal('4.98')),
#  ('Oceania', None, Decimal('4.98')),
#  ('Oceania', None, Decimal('4.98')),
#  ('Oceania', None, Decimal('4.98')),
#  ('Oceania', None, Decimal('4.98')),
#  ('Oceania', None, Decimal('4.98')),
#  ('Oceania', None, Decimal('4.98')),
#  ('Oceania', None, Decimal('4.98')),
#  ('Oceania', None, Decimal('4.98')),
#  ('Oceania', None, Decimal('4.98')),
#  ('Oceania', None, Decimal('4.98')),
#  ('Oceania', 9.4, Decimal('-999')),
#  ('Oceania', None, Decimal('4.98')),
#  ('Oceania', None, Decimal('4.98')),
#  ('Oceania', None, Decimal('4.98')),
#  ('Oceania', None, Decimal('4.98')),
#  ('Oceania', None, Decimal('4.98')),
#  ('Oceania', None, Decimal('4.98')),
#  ('Oceania', None, Decimal('4.98')),
#  ('Oceania', None, Decimal('4.98')),
#  ('Oceania', None, Decimal('4.98')),
#  ('Oceania', None, Decimal('4.98')),
#  ('Oceania', None, Decimal('4.98')),
#  ('Oceania', None, Decimal('4.98')),
#  ('Oceania', 2.25, Decimal('-999')),
#  ('Oceania', None, Decimal('4.98')),
#  ('Oceania', None, Decimal('4.98')),
#  ('Oceania', None, Decimal('4.98')),
#  ('Oceania', 8.49, Decimal('-999')),
#  ('Oceania', 26.55, Decimal('-999')),
#  ('Oceania', None, Decimal('4.98')),
#  ('Oceania', None, Decimal('4.98')),
#  ('Oceania', None, Decimal('4.98')),
#  ('Oceania', None, Decimal('4.98')),
#  ('Oceania', None, Decimal('4.98')),
#  ('Oceania', None, Decimal('4.98')),
#  ('Oceania', None, Decimal('4.98')),
#  ('Oceania', None, Decimal('4.98')),
#  ('Oceania', None, Decimal('4.98')),
#  ('Sub-Saharan Africa', None, Decimal('33.65')),
#  ('Sub-Saharan Africa', None, Decimal('33.65')),
#  ('Sub-Saharan Africa', None, Decimal('33.65')),
#  ('Sub-Saharan Africa', None, Decimal('33.65')),
#  ('Sub-Saharan Africa', None, Decimal('33.65')),
#  ('Sub-Saharan Africa', 1.03, Decimal('-999')),
#  ('Sub-Saharan Africa', None, Decimal('33.65')),
#  ('Sub-Saharan Africa', None, Decimal('33.65')),
#  ('Sub-Saharan Africa', None, Decimal('33.65')),
#  ('Sub-Saharan Africa', None, Decimal('33.65')),
#  ('Sub-Saharan Africa', None, Decimal('33.65')),
#  ('Sub-Saharan Africa', None, Decimal('33.65')),
#  ('Sub-Saharan Africa', None, Decimal('33.65')),
#  ('Sub-Saharan Africa', 26.06, Decimal('-999')),
#  ('Sub-Saharan Africa', None, Decimal('33.65')),
#  ('Sub-Saharan Africa', None, Decimal('33.65')),
#  ('Sub-Saharan Africa', None, Decimal('33.65')),
#  ('Sub-Saharan Africa', None, Decimal('33.65')),
#  ('Sub-Saharan Africa', None, Decimal('33.65')),
#  ('Sub-Saharan Africa', None, Decimal('33.65')),
#  ('Sub-Saharan Africa', None, Decimal('33.65')),
#  ('Sub-Saharan Africa', None, Decimal('33.65')),
#  ('Sub-Saharan Africa', None, Decimal('33.65')),
#  ('Sub-Saharan Africa', None, Decimal('33.65')),
#  ('Sub-Saharan Africa', None, Decimal('33.65')),
#  ('Sub-Saharan Africa', None, Decimal('33.65')),
#  ('Sub-Saharan Africa', 2.76, Decimal('-999')),
#  ('Sub-Saharan Africa', None, Decimal('33.65')),
#  ('Sub-Saharan Africa', None, Decimal('33.65')),
#  ('Sub-Saharan Africa', 5.01, Decimal('-999')),
#  ('Sub-Saharan Africa', None, Decimal('33.65')),
#  ('Sub-Saharan Africa', 1.79, Decimal('-999')),
#  ('Sub-Saharan Africa', None, Decimal('33.65')),
#  ('Sub-Saharan Africa', None, Decimal('33.65')),
#  ('Sub-Saharan Africa', None, Decimal('33.65')),
#  ('Sub-Saharan Africa', None, Decimal('33.65')),
#  ('Sub-Saharan Africa', None, Decimal('33.65')),
#  ('Sub-Saharan Africa', None, Decimal('33.65')),
#  ('Sub-Saharan Africa', None, Decimal('33.65')),
#  ('Sub-Saharan Africa', 3.54, Decimal('-999')),
#  ('Sub-Saharan Africa', None, Decimal('33.65')),
#  ('Sub-Saharan Africa', None, Decimal('33.65')),
#  ('Sub-Saharan Africa', 0.91, Decimal('-999')),
#  ('Sub-Saharan Africa', 7.41, Decimal('-999')),
#  ('Sub-Saharan Africa', 6.81, Decimal('-999')),
#  ('Sub-Saharan Africa', 6.75, Decimal('-999')),
#  ('Sub-Saharan Africa', 6.43, Decimal('-999')),
#  ('Sub-Saharan Africa', 6.33, Decimal('-999')),
#  ('Sub-Saharan Africa', 8.63, Decimal('-999')),
#  ('Sub-Saharan Africa', None, Decimal('33.65')),
#  ('Sub-Saharan Africa', None, Decimal('33.65')),
#  ('Sub-Saharan Africa', None, Decimal('33.65')),
#  ('Sub-Saharan Africa', None, Decimal('33.65')),
#  ('Sub-Saharan Africa', None, Decimal('33.65')),
#  ('Sub-Saharan Africa', None, Decimal('33.65')),
#  ('Sub-Saharan Africa', 3.43, Decimal('-999')),
#  ('Sub-Saharan Africa', None, Decimal('33.65')),
#  ('Sub-Saharan Africa', None, Decimal('33.65')),
#  ('Sub-Saharan Africa', None, Decimal('33.65')),
#  ('Sub-Saharan Africa', None, Decimal('33.65')),
#  ('Sub-Saharan Africa', None, Decimal('33.65')),
#  ('Sub-Saharan Africa', None, Decimal('33.65')),
#  ('Sub-Saharan Africa', None, Decimal('33.65')),
#  ('Sub-Saharan Africa', 11.88, Decimal('-999')),
#  ('Sub-Saharan Africa', 10.76, Decimal('-999')),
#  ('Sub-Saharan Africa', 11.24, Decimal('-999')),
#  ('Sub-Saharan Africa', 11.83, Decimal('-999')),
#  ('Sub-Saharan Africa', None, Decimal('33.65')),
#  ('Sub-Saharan Africa', None, Decimal('33.65')),
#  ('Sub-Saharan Africa', None, Decimal('33.65')),
#  ('Sub-Saharan Africa', None, Decimal('33.65')),
#  ('Sub-Saharan Africa', None, Decimal('33.65')),
#  ('Sub-Saharan Africa', None, Decimal('33.65')),
#  ('Sub-Saharan Africa', 4.15, Decimal('-999')),
#  ('Sub-Saharan Africa', 3.96, Decimal('-999')),
#  ('Sub-Saharan Africa', 3.71, Decimal('-999')),
#  ('Sub-Saharan Africa', 3.53, Decimal('-999')),
#  ('Sub-Saharan Africa', 2.97, Decimal('-999')),
#  ('Sub-Saharan Africa', None, Decimal('33.65')),
#  ('Sub-Saharan Africa', None, Decimal('33.65')),
#  ('Sub-Saharan Africa', None, Decimal('33.65')),
#  ('Sub-Saharan Africa', None, Decimal('33.65')),
#  ('Sub-Saharan Africa', 18.83, Decimal('-999')),
#  ('Sub-Saharan Africa', None, Decimal('33.65')),
#  ('Sub-Saharan Africa', None, Decimal('33.65')),
#  ('Sub-Saharan Africa', None, Decimal('33.65')),
#  ('Sub-Saharan Africa', None, Decimal('33.65')),
#  ('Sub-Saharan Africa', None, Decimal('33.65')),
#  ('Sub-Saharan Africa', None, Decimal('33.65')),
#  ('Sub-Saharan Africa', None, Decimal('33.65')),
#  ('Sub-Saharan Africa', None, Decimal('33.65')),
#  ('Sub-Saharan Africa', None, Decimal('33.65')),
#  ('Sub-Saharan Africa', 3.64, Decimal('-999')),
#  ('Sub-Saharan Africa', None, Decimal('33.65')),
#  ('Sub-Saharan Africa', None, Decimal('33.65')),
#  ('Sub-Saharan Africa', None, Decimal('33.65')),
#  ('Sub-Saharan Africa', None, Decimal('33.65')),
#  ('Sub-Saharan Africa', None, Decimal('33.65')),
#  ('Sub-Saharan Africa', None, Decimal('33.65')),
#  ('Sub-Saharan Africa', None, Decimal('33.65')),
#  ('Sub-Saharan Africa', None, Decimal('33.65')),
#  ('Sub-Saharan Africa', None, Decimal('33.65')),
#  ('Sub-Saharan Africa', None, Decimal('33.65')),
#  ('Sub-Saharan Africa', None, Decimal('33.65')),
#  ('Sub-Saharan Africa', 8.52, Decimal('-999')),
#  ('Sub-Saharan Africa', 5.03, Decimal('-999')),
#  ('Sub-Saharan Africa', 5.54, Decimal('-999')),
#  ('Sub-Saharan Africa', 6.03, Decimal('-999')),
#  ('Sub-Saharan Africa', None, Decimal('33.65')),
#  ('Sub-Saharan Africa', None, Decimal('33.65')),
#  ('Sub-Saharan Africa', None, Decimal('33.65')),
#  ('Sub-Saharan Africa', None, Decimal('33.65')),
#  ('Sub-Saharan Africa', 7.37, Decimal('-999')),
#  ('Sub-Saharan Africa', None, Decimal('33.65')),
#  ('Sub-Saharan Africa', None, Decimal('33.65')),
#  ('Sub-Saharan Africa', None, Decimal('33.65')),
#  ('Sub-Saharan Africa', None, Decimal('33.65')),
#  ('Sub-Saharan Africa', None, Decimal('33.65')),
#  ('Sub-Saharan Africa', 16.5, Decimal('-999')),
#  ('Sub-Saharan Africa', None, Decimal('33.65')),
#  ('Sub-Saharan Africa', None, Decimal('33.65')),
#  ('Sub-Saharan Africa', None, Decimal('33.65')),
#  ('Sub-Saharan Africa', None, Decimal('33.65')),
#  ('Sub-Saharan Africa', None, Decimal('33.65')),
#  ('Sub-Saharan Africa', None, Decimal('33.65')),
#  ('Sub-Saharan Africa', None, Decimal('33.65')),
#  ('Sub-Saharan Africa', None, Decimal('33.65')),
#  ('Sub-Saharan Africa', None, Decimal('33.65')),
#  ('Sub-Saharan Africa', None, Decimal('33.65')),
#  ('Sub-Saharan Africa', None, Decimal('33.65')),
#  ('Sub-Saharan Africa', None, Decimal('33.65')),
#  ('Sub-Saharan Africa', None, Decimal('33.65')),
#  ('Sub-Saharan Africa', None, Decimal('33.65')),
#  ('Sub-Saharan Africa', None, Decimal('33.65')),
#  ('Sub-Saharan Africa', None, Decimal('33.65')),
#  ('Sub-Saharan Africa', 1.13, Decimal('-999')),
#  ('Sub-Saharan Africa', None, Decimal('33.65')),
#  ('Sub-Saharan Africa', None, Decimal('33.65')),
#  ('Sub-Saharan Africa', None, Decimal('33.65')),
#  ('Sub-Saharan Africa', None, Decimal('33.65')),
#  ('Sub-Saharan Africa', None, Decimal('33.65')),
#  ('Sub-Saharan Africa', None, Decimal('33.65')),
#  ('Sub-Saharan Africa', None, Decimal('33.65')),
#  ('Sub-Saharan Africa', None, Decimal('33.65')),
#  ('Sub-Saharan Africa', None, Decimal('33.65')),
#  ('Sub-Saharan Africa', None, Decimal('33.65')),
#  ('Sub-Saharan Africa', None, Decimal('33.65')),
#  ('Sub-Saharan Africa', None, Decimal('33.65')),
#  ('Sub-Saharan Africa', None, Decimal('33.65')),
#  ('Sub-Saharan Africa', None, Decimal('33.65')),
#  ('Sub-Saharan Africa', None, Decimal('33.65')),
#  ('Sub-Saharan Africa', None, Decimal('33.65')),
#  ('Sub-Saharan Africa', None, Decimal('33.65')),
#  ('Sub-Saharan Africa', None, Decimal('33.65')),
#  ('Sub-Saharan Africa', None, Decimal('33.65')),
#  ('Sub-Saharan Africa', None, Decimal('33.65')),
#  ('Sub-Saharan Africa', None, Decimal('33.65')),
#  ('Sub-Saharan Africa', None, Decimal('33.65')),
#  ('Sub-Saharan Africa', None, Decimal('33.65')),
#  ('Sub-Saharan Africa', None, Decimal('33.65')),
#  ('Sub-Saharan Africa', None, Decimal('33.65')),
#  ('Sub-Saharan Africa', None, Decimal('33.65')),
#  ('Sub-Saharan Africa', None, Decimal('33.65')),
#  ('Sub-Saharan Africa', None, Decimal('33.65')),
#  ('Sub-Saharan Africa', None, Decimal('33.65')),
#  ('Sub-Saharan Africa', None, Decimal('33.65')),
#  ('Sub-Saharan Africa', None, Decimal('33.65')),
#  ('Sub-Saharan Africa', None, Decimal('33.65')),
#  ('Sub-Saharan Africa', None, Decimal('33.65')),
#  ('Sub-Saharan Africa', 20.09, Decimal('-999')),
#  ('Sub-Saharan Africa', 21.02, Decimal('-999')),
#  ('Sub-Saharan Africa', None, Decimal('33.65')),
#  ('Sub-Saharan Africa', 22.72, Decimal('-999')),
#  ('Sub-Saharan Africa', None, Decimal('33.65')),
#  ('Sub-Saharan Africa', None, Decimal('33.65')),
#  ('Sub-Saharan Africa', None, Decimal('33.65')),
#  ('Sub-Saharan Africa', None, Decimal('33.65')),
#  ('Sub-Saharan Africa', None, Decimal('33.65')),
#  ('Sub-Saharan Africa', None, Decimal('33.65')),
#  ('Sub-Saharan Africa', None, Decimal('33.65')),
#  ('Sub-Saharan Africa', None, Decimal('33.65')),
#  ('Sub-Saharan Africa', 16.88, Decimal('-999')),
#  ('Sub-Saharan Africa', None, Decimal('33.65')),
#  ('Sub-Saharan Africa', None, Decimal('33.65')),
#  ('Sub-Saharan Africa', 23.35, Decimal('-999')),
#  ('Sub-Saharan Africa', None, Decimal('33.65')),
#  ('Sub-Saharan Africa', 19.88, Decimal('-999')),
#  ('Sub-Saharan Africa', None, Decimal('33.65')),
#  ('Sub-Saharan Africa', None, Decimal('33.65')),
#  ('Sub-Saharan Africa', 22.87, Decimal('-999')),
#  ('Sub-Saharan Africa', 24.02, Decimal('-999')),
#  ('Sub-Saharan Africa', 23.99, Decimal('-999')),
#  ('Sub-Saharan Africa', 24.22, Decimal('-999')),
#  ('Sub-Saharan Africa', 25.54, Decimal('-999')),
#  ('Sub-Saharan Africa', 24.34, Decimal('-999')),
#  ('Sub-Saharan Africa', None, Decimal('33.65')),
#  ('Sub-Saharan Africa', None, Decimal('33.65')),
#  ('Sub-Saharan Africa', None, Decimal('33.65')),
#  ('Sub-Saharan Africa', 1.47, Decimal('-999')),
#  ('Sub-Saharan Africa', None, Decimal('33.65')),
#  ('Sub-Saharan Africa', None, Decimal('33.65')),
#  ('Sub-Saharan Africa', None, Decimal('33.65')),
#  ('Sub-Saharan Africa', None, Decimal('33.65')),
#  ('Sub-Saharan Africa', None, Decimal('33.65')),
#  ('Sub-Saharan Africa', 4.69, Decimal('-999')),
#  ('Sub-Saharan Africa', None, Decimal('33.65')),
#  ('Sub-Saharan Africa', None, Decimal('33.65')),
#  ('Sub-Saharan Africa', 31.31, Decimal('-999')),
#  ('Sub-Saharan Africa', None, Decimal('33.65')),
#  ('Sub-Saharan Africa', 12.24, Decimal('-999')),
#  ('Sub-Saharan Africa', 12.17, Decimal('-999')),
#  ('Sub-Saharan Africa', 11.29, Decimal('-999')),
#  ('Sub-Saharan Africa', None, Decimal('33.65')),
#  ('Sub-Saharan Africa', None, Decimal('33.65')),
#  ('Sub-Saharan Africa', None, Decimal('33.65')),
#  ('Sub-Saharan Africa', None, Decimal('33.65')),
#  ('Sub-Saharan Africa', None, Decimal('33.65')),
#  ('Sub-Saharan Africa', None, Decimal('33.65')),
#  ('Sub-Saharan Africa', None, Decimal('33.65')),
#  ('Sub-Saharan Africa', None, Decimal('33.65')),
#  ('Sub-Saharan Africa', None, Decimal('33.65')),
#  ('Sub-Saharan Africa', None, Decimal('33.65')),
#  ('Sub-Saharan Africa', None, Decimal('33.65')),
#  ('Sub-Saharan Africa', None, Decimal('33.65')),
#  ('Sub-Saharan Africa', None, Decimal('33.65')),
#  ('Sub-Saharan Africa', 6.81, Decimal('-999')),
#  ('Sub-Saharan Africa', None, Decimal('33.65')),
#  ('Sub-Saharan Africa', 3.37, Decimal('-999')),
#  ('Sub-Saharan Africa', None, Decimal('33.65')),
#  ('Sub-Saharan Africa', None, Decimal('33.65')),
#  ('Sub-Saharan Africa', None, Decimal('33.65')),
#  ('Sub-Saharan Africa', None, Decimal('33.65')),
#  ('Sub-Saharan Africa', None, Decimal('33.65')),
#  ('Sub-Saharan Africa', None, Decimal('33.65')),
#  ('Sub-Saharan Africa', None, Decimal('33.65')),
#  ('Sub-Saharan Africa', 5.02, Decimal('-999')),
#  ('Sub-Saharan Africa', None, Decimal('33.65')),
#  ('Sub-Saharan Africa', None, Decimal('33.65')),
#  ('Sub-Saharan Africa', None, Decimal('33.65')),
#  ('Sub-Saharan Africa', None, Decimal('33.65')),
#  ('Sub-Saharan Africa', 3.2, Decimal('-999')),
#  ('Sub-Saharan Africa', None, Decimal('33.65')),
#  ('Sub-Saharan Africa', None, Decimal('33.65')),
#  ('Sub-Saharan Africa', None, Decimal('33.65')),
#  ('Sub-Saharan Africa', 3.08, Decimal('-999')),
#  ('Sub-Saharan Africa', 5.95, Decimal('-999')),
#  ('Sub-Saharan Africa', None, Decimal('33.65')),
#  ('Sub-Saharan Africa', None, Decimal('33.65')),
#  ('Sub-Saharan Africa', None, Decimal('33.65')),
#  ...]

# %% [markdown]
# **4. Replace the placeholder value**
# Finally, replace the placeholder value of -999 with the actual Pct_unemployment value for records where none of our conditions are met.

# %%
# %%sql
#
# SELECT
#     Region,
#     Pct_unemployment,
#     CASE
#         WHEN Region = 'Central and Southern Asia' AND Pct_unemployment IS NULL THEN 19.59
#         WHEN Region = 'Eastern and South-Eastern Asia' AND Pct_unemployment IS NULL THEN 22.64
#         WHEN Region = 'Europe and Northern America' AND Pct_unemployment IS NULL THEN 24.43
#         WHEN Region = 'Latin America and the Caribbean' AND Pct_unemployment IS NULL THEN 24.23
#         WHEN Region = 'Northern Africa and Western Asia' AND Pct_unemployment IS NULL THEN 17.84
#         WHEN Region = 'Oceania' AND Pct_unemployment IS NULL THEN 4.98
#         WHEN Region = 'Sub-Saharan Africa' AND Pct_unemployment IS NULL THEN 33.65
#         ELSE Pct_unemployment
#     END AS New_pct_unemployment
# FROM united_nations.Access_to_Basic_Services;
# Out:
#  * mysql+pymysql://root:***@127.0.0.1:3306/united_nations
# 1048 rows affected.
# [('Central and Southern Asia', 4.93, 4.93),
#  ('Central and Southern Asia', 4.96, 4.96),
#  ('Central and Southern Asia', 4.9, 4.9),
#  ('Central and Southern Asia', 4.85, 4.85),
#  ('Central and Southern Asia', 4.8, 4.8),
#  ('Central and Southern Asia', 4.89, 4.89),
#  ('Central and Southern Asia', None, 19.59),
#  ('Central and Southern Asia', None, 19.59),
#  ('Central and Southern Asia', None, 19.59),
#  ('Central and Southern Asia', None, 19.59),
#  ('Central and Southern Asia', None, 19.59),
#  ('Central and Southern Asia', None, 19.59),
#  ('Central and Southern Asia', None, 19.59),
#  ('Central and Southern Asia', 6.9, 6.9),
#  ('Central and Southern Asia', None, 19.59),
#  ('Central and Southern Asia', None, 19.59),
#  ('Central and Southern Asia', None, 19.59),
#  ('Central and Southern Asia', None, 19.59),
#  ('Central and Southern Asia', None, 19.59),
#  ('Central and Southern Asia', None, 19.59),
#  ('Central and Southern Asia', None, 19.59),
#  ('Central and Southern Asia', None, 19.59),
#  ('Central and Southern Asia', None, 19.59),
#  ('Central and Southern Asia', None, 19.59),
#  ('Central and Southern Asia', 5.15, 5.15),
#  ('Central and Southern Asia', 5.16, 5.16),
#  ('Central and Southern Asia', 5.83, 5.83),
#  ('Central and Southern Asia', 9.35, 9.35),
#  ('Central and Southern Asia', 8.98, 8.98),
#  ('Central and Southern Asia', 5.29, 5.29),
#  ('Central and Southern Asia', None, 19.59),
#  ('Central and Southern Asia', None, 19.59),
#  ('Central and Southern Asia', 11.18, 11.18),
#  ('Central and Southern Asia', None, 19.59),
#  ('Central and Southern Asia', None, 19.59),
#  ('Central and Southern Asia', 11.71, 11.71),
#  ('Central and Southern Asia', None, 19.59),
#  ('Central and Southern Asia', 4.35, 4.35),
#  ('Central and Southern Asia', 4.37, 4.37),
#  ('Central and Southern Asia', None, 19.59),
#  ('Central and Southern Asia', None, 19.59),
#  ('Central and Southern Asia', None, 19.59),
#  ('Central and Southern Asia', 2.45, 2.45),
#  ('Central and Southern Asia', None, 19.59),
#  ('Central and Southern Asia', None, 19.59),
#  ('Central and Southern Asia', 3.35, 3.35),
#  ('Central and Southern Asia', 2.72, 2.72),
#  ('Central and Southern Asia', 5.03, 5.03),
#  ('Central and Southern Asia', None, 19.59),
#  ('Central and Southern Asia', None, 19.59),
#  ('Central and Southern Asia', None, 19.59),
#  ('Central and Southern Asia', 7.65, 7.65),
#  ('Central and Southern Asia', 6.51, 6.51),
#  ('Central and Southern Asia', 7.86, 7.86),
#  ('Central and Southern Asia', None, 19.59),
#  ('Central and Southern Asia', None, 19.59),
#  ('Central and Southern Asia', None, 19.59),
#  ('Central and Southern Asia', None, 19.59),
#  ('Central and Southern Asia', None, 19.59),
#  ('Central and Southern Asia', None, 19.59),
#  ('Central and Southern Asia', None, 19.59),
#  ('Central and Southern Asia', 5.77, 5.77),
#  ('Central and Southern Asia', None, 19.59),
#  ('Central and Southern Asia', None, 19.59),
#  ('Central and Southern Asia', 4.56, 4.56),
#  ('Central and Southern Asia', None, 19.59),
#  ('Central and Southern Asia', 3.1, 3.1),
#  ('Central and Southern Asia', None, 19.59),
#  ('Central and Southern Asia', 10.66, 10.66),
#  ('Central and Southern Asia', None, 19.59),
#  ('Central and Southern Asia', None, 19.59),
#  ('Central and Southern Asia', None, 19.59),
#  ('Central and Southern Asia', 3.57, 3.57),
#  ('Central and Southern Asia', None, 19.59),
#  ('Central and Southern Asia', None, 19.59),
#  ('Central and Southern Asia', 4.08, 4.08),
#  ('Central and Southern Asia', 4.83, 4.83),
#  ('Central and Southern Asia', None, 19.59),
#  ('Central and Southern Asia', 4.52, 4.52),
#  ('Central and Southern Asia', 4.24, 4.24),
#  ('Central and Southern Asia', 4.05, 4.05),
#  ('Central and Southern Asia', 4.32, 4.32),
#  ('Central and Southern Asia', 4.67, 4.67),
#  ('Central and Southern Asia', 5.36, 5.36),
#  ('Eastern and South-Eastern Asia', None, 22.64),
#  ('Eastern and South-Eastern Asia', None, 22.64),
#  ('Eastern and South-Eastern Asia', 3.9, 3.9),
#  ('Eastern and South-Eastern Asia', 4.93, 4.93),
#  ('Eastern and South-Eastern Asia', 5.15, 5.15),
#  ('Eastern and South-Eastern Asia', 5.61, 5.61),
#  ('Eastern and South-Eastern Asia', None, 22.64),
#  ('Eastern and South-Eastern Asia', None, 22.64),
#  ('Eastern and South-Eastern Asia', None, 22.64),
#  ('Eastern and South-Eastern Asia', None, 22.64),
#  ('Eastern and South-Eastern Asia', None, 22.64),
#  ('Eastern and South-Eastern Asia', None, 22.64),
#  ('Eastern and South-Eastern Asia', 3.39, 3.39),
#  ('Eastern and South-Eastern Asia', 3.13, 3.13),
#  ('Eastern and South-Eastern Asia', 2.82, 2.82),
#  ('Eastern and South-Eastern Asia', 2.47, 2.47),
#  ('Eastern and South-Eastern Asia', 2.35, 2.35),
#  ('Eastern and South-Eastern Asia', 2.81, 2.81),
#  ('Eastern and South-Eastern Asia', 4.86, 4.86),
#  ('Eastern and South-Eastern Asia', 7.24, 7.24),
#  ('Eastern and South-Eastern Asia', 6.36, 6.36),
#  ('Eastern and South-Eastern Asia', 5.38, 5.38),
#  ('Eastern and South-Eastern Asia', 9.27, 9.27),
#  ('Eastern and South-Eastern Asia', 6.59, 6.59),
#  ('Eastern and South-Eastern Asia', None, 22.64),
#  ('Eastern and South-Eastern Asia', None, 22.64),
#  ('Eastern and South-Eastern Asia', None, 22.64),
#  ('Eastern and South-Eastern Asia', None, 22.64),
#  ('Eastern and South-Eastern Asia', None, 22.64),
#  ('Eastern and South-Eastern Asia', None, 22.64),
#  ('Eastern and South-Eastern Asia', None, 22.64),
#  ('Eastern and South-Eastern Asia', None, 22.64),
#  ('Eastern and South-Eastern Asia', 9.32, 9.32),
#  ('Eastern and South-Eastern Asia', 8.7, 8.7),
#  ('Eastern and South-Eastern Asia', 6.6, 6.6),
#  ('Eastern and South-Eastern Asia', 7.41, 7.41),
#  ('Eastern and South-Eastern Asia', 0.39, 0.39),
#  ('Eastern and South-Eastern Asia', 0.72, 0.72),
#  ('Eastern and South-Eastern Asia', 0.14, 0.14),
#  ('Eastern and South-Eastern Asia', None, 22.64),
#  ('Eastern and South-Eastern Asia', 0.5, 0.5),
#  ('Eastern and South-Eastern Asia', None, 22.64),
#  ('Eastern and South-Eastern Asia', 4.51, 4.51),
#  ('Eastern and South-Eastern Asia', 4.3, 4.3),
#  ('Eastern and South-Eastern Asia', 3.78, 3.78),
#  ('Eastern and South-Eastern Asia', 4.39, 4.39),
#  ('Eastern and South-Eastern Asia', 3.59, 3.59),
#  ('Eastern and South-Eastern Asia', 4.25, 4.25),
#  ('Eastern and South-Eastern Asia', None, 22.64),
#  ('Eastern and South-Eastern Asia', None, 22.64),
#  ('Eastern and South-Eastern Asia', None, 22.64),
#  ('Eastern and South-Eastern Asia', None, 22.64),
#  ('Eastern and South-Eastern Asia', None, 22.64),
#  ('Eastern and South-Eastern Asia', None, 22.64),
#  ('Eastern and South-Eastern Asia', 3.1, 3.1),
#  ('Eastern and South-Eastern Asia', 3.44, 3.44),
#  ('Eastern and South-Eastern Asia', 3.41, 3.41),
#  ('Eastern and South-Eastern Asia', 3.3, 3.3),
#  ('Eastern and South-Eastern Asia', 3.26, 3.26),
#  ('Eastern and South-Eastern Asia', 4.54, 4.54),
#  ('Eastern and South-Eastern Asia', 0.77, 0.77),
#  ('Eastern and South-Eastern Asia', None, 22.64),
#  ('Eastern and South-Eastern Asia', 1.36, 1.36),
#  ('Eastern and South-Eastern Asia', 0.77, 0.77),
#  ('Eastern and South-Eastern Asia', 0.41, 0.41),
#  ('Eastern and South-Eastern Asia', 1.48, 1.48),
#  ('Eastern and South-Eastern Asia', 3.07, 3.07),
#  ('Eastern and South-Eastern Asia', 2.7, 2.7),
#  ('Eastern and South-Eastern Asia', 2.55, 2.55),
#  ('Eastern and South-Eastern Asia', 2.34, 2.34),
#  ('Eastern and South-Eastern Asia', 2.24, 2.24),
#  ('Eastern and South-Eastern Asia', 2.52, 2.52),
#  ('Eastern and South-Eastern Asia', 3.79, 3.79),
#  ('Eastern and South-Eastern Asia', 4.08, 4.08),
#  ('Eastern and South-Eastern Asia', 4.2, 4.2),
#  ('Eastern and South-Eastern Asia', None, 22.64),
#  ('Eastern and South-Eastern Asia', 3.1, 3.1),
#  ('Eastern and South-Eastern Asia', 4.1, 4.1),
#  ('Eastern and South-Eastern Asia', 0.6, 0.6),
#  ('Eastern and South-Eastern Asia', 0.69, 0.69),
#  ('Eastern and South-Eastern Asia', 0.83, 0.83),
#  ('Eastern and South-Eastern Asia', 0.77, 0.77),
#  ('Eastern and South-Eastern Asia', 0.72, 0.72),
#  ('Eastern and South-Eastern Asia', 1.1, 1.1),
#  ('Eastern and South-Eastern Asia', None, 22.64),
#  ('Eastern and South-Eastern Asia', 4.66, 4.66),
#  ('Eastern and South-Eastern Asia', None, 22.64),
#  ('Eastern and South-Eastern Asia', None, 22.64),
#  ('Eastern and South-Eastern Asia', None, 22.64),
#  ('Eastern and South-Eastern Asia', None, 22.64),
#  ('Eastern and South-Eastern Asia', None, 22.64),
#  ('Eastern and South-Eastern Asia', None, 22.64),
#  ('Eastern and South-Eastern Asia', None, 22.64),
#  ('Eastern and South-Eastern Asia', None, 22.64),
#  ('Eastern and South-Eastern Asia', None, 22.64),
#  ('Eastern and South-Eastern Asia', None, 22.64),
#  ('Europe and Northern America', None, 24.43),
#  ('Europe and Northern America', None, 24.43),
#  ('Europe and Northern America', None, 24.43),
#  ('Europe and Northern America', None, 24.43),
#  ('Europe and Northern America', None, 24.43),
#  ('Europe and Northern America', None, 24.43),
#  ('Europe and Northern America', 6.91, 6.91),
#  ('Europe and Northern America', 7.0, 7.0),
#  ('Europe and Northern America', 6.34, 6.34),
#  ('Europe and Northern America', 5.83, 5.83),
#  ('Europe and Northern America', 5.66, 5.66),
#  ('Europe and Northern America', 9.46, 9.46),
#  ('Europe and Northern America', 9.1, 9.1),
#  ('Europe and Northern America', None, 24.43),
#  ('Europe and Northern America', None, 24.43),
#  ('Europe and Northern America', None, 24.43),
#  ('Europe and Northern America', None, 24.43),
#  ('Europe and Northern America', None, 24.43),
#  ('Europe and Northern America', None, 24.43),
#  ('Europe and Northern America', None, 24.43),
#  ('Europe and Northern America', None, 24.43),
#  ('Europe and Northern America', None, 24.43),
#  ('Europe and Northern America', None, 24.43),
#  ('Europe and Northern America', None, 24.43),
#  ('Europe and Northern America', None, 24.43),
#  ('Europe and Northern America', None, 24.43),
#  ('Europe and Northern America', None, 24.43),
#  ('Europe and Northern America', None, 24.43),
#  ('Europe and Northern America', None, 24.43),
#  ('Europe and Northern America', None, 24.43),
#  ('Latin America and the Caribbean', None, 24.23),
#  ('Latin America and the Caribbean', None, 24.23),
#  ('Latin America and the Caribbean', None, 24.23),
#  ('Latin America and the Caribbean', None, 24.23),
#  ('Latin America and the Caribbean', None, 24.23),
#  ('Latin America and the Caribbean', None, 24.23),
#  ('Latin America and the Caribbean', None, 24.23),
#  ('Latin America and the Caribbean', None, 24.23),
#  ('Latin America and the Caribbean', None, 24.23),
#  ('Latin America and the Caribbean', None, 24.23),
#  ('Latin America and the Caribbean', None, 24.23),
#  ('Latin America and the Caribbean', None, 24.23),
#  ('Latin America and the Caribbean', None, 24.23),
#  ('Latin America and the Caribbean', 9.8, 9.8),
#  ('Latin America and the Caribbean', 8.25, 8.25),
#  ('Latin America and the Caribbean', 8.62, 8.62),
#  ('Latin America and the Caribbean', 8.32, 8.32),
#  ('Latin America and the Caribbean', 8.41, 8.41),
#  ('Latin America and the Caribbean', None, 24.23),
#  ('Latin America and the Caribbean', None, 24.23),
#  ('Latin America and the Caribbean', None, 24.23),
#  ('Latin America and the Caribbean', None, 24.23),
#  ('Latin America and the Caribbean', None, 24.23),
#  ('Latin America and the Caribbean', None, 24.23),
#  ('Latin America and the Caribbean', None, 24.23),
#  ('Latin America and the Caribbean', 4.24, 4.24),
#  ('Latin America and the Caribbean', None, 24.23),
#  ('Latin America and the Caribbean', 2.4, 2.4),
#  ('Latin America and the Caribbean', 2.0, 2.0),
#  ('Latin America and the Caribbean', 1.7, 1.7),
#  ('Latin America and the Caribbean', 1.7, 1.7),
#  ('Latin America and the Caribbean', None, 24.23),
#  ('Latin America and the Caribbean', None, 24.23),
#  ('Latin America and the Caribbean', None, 24.23),
#  ('Latin America and the Caribbean', None, 24.23),
#  ('Latin America and the Caribbean', None, 24.23),
#  ('Latin America and the Caribbean', None, 24.23),
#  ('Latin America and the Caribbean', None, 24.23),
#  ('Latin America and the Caribbean', None, 24.23),
#  ('Latin America and the Caribbean', 7.61, 7.61),
#  ('Latin America and the Caribbean', 7.28, 7.28),
#  ('Latin America and the Caribbean', 5.83, 5.83),
#  ('Latin America and the Caribbean', 5.86, 5.86),
#  ('Latin America and the Caribbean', 6.18, 6.18),
#  ('Latin America and the Caribbean', 6.13, 6.13),
#  ('Latin America and the Caribbean', 22.9, 22.9),
#  ('Latin America and the Caribbean', None, 24.23),
#  ('Latin America and the Caribbean', None, 24.23),
#  ('Latin America and the Caribbean', None, 24.23),
#  ('Latin America and the Caribbean', None, 24.23),
#  ('Latin America and the Caribbean', None, 24.23),
#  ('Latin America and the Caribbean', None, 24.23),
#  ('Latin America and the Caribbean', None, 24.23),
#  ('Latin America and the Caribbean', None, 24.23),
#  ('Latin America and the Caribbean', None, 24.23),
#  ('Latin America and the Caribbean', None, 24.23),
#  ('Latin America and the Caribbean', None, 24.23),
#  ('Latin America and the Caribbean', None, 24.23),
#  ('Latin America and the Caribbean', None, 24.23),
#  ('Latin America and the Caribbean', None, 24.23),
#  ('Latin America and the Caribbean', 13.51, 13.51),
#  ('Latin America and the Caribbean', 8.63, 8.63),
#  ('Latin America and the Caribbean', 7.4, 7.4),
#  ('Latin America and the Caribbean', 5.47, 5.47),
#  ('Latin America and the Caribbean', 4.99, 4.99),
#  ('Latin America and the Caribbean', 6.5, 6.5),
#  ('Latin America and the Caribbean', None, 24.23),
#  ('Latin America and the Caribbean', None, 24.23),
#  ('Latin America and the Caribbean', None, 24.23),
#  ('Latin America and the Caribbean', None, 24.23),
#  ('Latin America and the Caribbean', None, 24.23),
#  ('Latin America and the Caribbean', None, 24.23),
#  ('Latin America and the Caribbean', None, 24.23),
#  ('Latin America and the Caribbean', None, 24.23),
#  ('Latin America and the Caribbean', None, 24.23),
#  ('Latin America and the Caribbean', None, 24.23),
#  ('Latin America and the Caribbean', None, 24.23),
#  ('Latin America and the Caribbean', None, 24.23),
#  ('Latin America and the Caribbean', 12.0, 12.0),
#  ('Latin America and the Caribbean', 11.8, 11.8),
#  ('Latin America and the Caribbean', 10.8, 10.8),
#  ('Latin America and the Caribbean', 9.2, 9.2),
#  ('Latin America and the Caribbean', 8.3, 8.3),
#  ('Latin America and the Caribbean', None, 24.23),
#  ('Latin America and the Caribbean', None, 24.23),
#  ('Latin America and the Caribbean', None, 24.23),
#  ('Latin America and the Caribbean', None, 24.23),
#  ('Latin America and the Caribbean', None, 24.23),
#  ('Latin America and the Caribbean', None, 24.23),
#  ('Latin America and the Caribbean', None, 24.23),
#  ('Latin America and the Caribbean', None, 24.23),
#  ('Latin America and the Caribbean', None, 24.23),
#  ('Latin America and the Caribbean', None, 24.23),
#  ('Latin America and the Caribbean', None, 24.23),
#  ('Latin America and the Caribbean', None, 24.23),
#  ('Latin America and the Caribbean', None, 24.23),
#  ('Latin America and the Caribbean', None, 24.23),
#  ('Latin America and the Caribbean', None, 24.23),
#  ('Latin America and the Caribbean', None, 24.23),
#  ('Latin America and the Caribbean', None, 24.23),
#  ('Latin America and the Caribbean', None, 24.23),
#  ('Latin America and the Caribbean', None, 24.23),
#  ('Latin America and the Caribbean', None, 24.23),
#  ('Latin America and the Caribbean', None, 24.23),
#  ('Latin America and the Caribbean', None, 24.23),
#  ('Latin America and the Caribbean', None, 24.23),
#  ('Latin America and the Caribbean', None, 24.23),
#  ('Latin America and the Caribbean', None, 24.23),
#  ('Latin America and the Caribbean', None, 24.23),
#  ('Latin America and the Caribbean', None, 24.23),
#  ('Latin America and the Caribbean', None, 24.23),
#  ('Latin America and the Caribbean', None, 24.23),
#  ('Latin America and the Caribbean', 2.43, 2.43),
#  ('Latin America and the Caribbean', 3.21, 3.21),
#  ('Latin America and the Caribbean', None, 24.23),
#  ('Latin America and the Caribbean', None, 24.23),
#  ('Latin America and the Caribbean', 3.52, 3.52),
#  ('Latin America and the Caribbean', 4.21, 4.21),
#  ('Latin America and the Caribbean', None, 24.23),
#  ('Latin America and the Caribbean', None, 24.23),
#  ('Latin America and the Caribbean', None, 24.23),
#  ('Latin America and the Caribbean', None, 24.23),
#  ('Latin America and the Caribbean', None, 24.23),
#  ('Latin America and the Caribbean', None, 24.23),
#  ('Latin America and the Caribbean', None, 24.23),
#  ('Latin America and the Caribbean', None, 24.23),
#  ('Latin America and the Caribbean', None, 24.23),
#  ('Latin America and the Caribbean', None, 24.23),
#  ('Latin America and the Caribbean', 7.58, 7.58),
#  ('Latin America and the Caribbean', 7.0, 7.0),
#  ('Latin America and the Caribbean', 6.6, 6.6),
#  ('Latin America and the Caribbean', None, 24.23),
#  ('Latin America and the Caribbean', 9.05, 9.05),
#  ('Latin America and the Caribbean', None, 24.23),
#  ('Latin America and the Caribbean', 8.42, 8.42),
#  ('Latin America and the Caribbean', 8.09, 8.09),
#  ('Latin America and the Caribbean', 7.73, 7.73),
#  ('Latin America and the Caribbean', 9.01, 9.01),
#  ('Latin America and the Caribbean', 10.81, 10.81),
#  ('Latin America and the Caribbean', 16.43, 16.43),
#  ('Latin America and the Caribbean', 4.0, 4.0),
#  ('Latin America and the Caribbean', 4.42, 4.42),
#  ('Latin America and the Caribbean', 4.39, 4.39),
#  ('Latin America and the Caribbean', 4.01, 4.01),
#  ('Latin America and the Caribbean', 4.17, 4.17),
#  ('Latin America and the Caribbean', 5.01, 5.01),
#  ('Latin America and the Caribbean', 2.51, 2.51),
#  ('Latin America and the Caribbean', 2.58, 2.58),
#  ('Latin America and the Caribbean', 2.46, 2.46),
#  ('Latin America and the Caribbean', 2.28, 2.28),
#  ('Latin America and the Caribbean', 2.19, 2.19),
#  ('Latin America and the Caribbean', None, 24.23),
#  ('Latin America and the Caribbean', 6.15, 6.15),
#  ('Latin America and the Caribbean', 6.73, 6.73),
#  ('Latin America and the Caribbean', 5.53, 5.53),
#  ('Latin America and the Caribbean', 5.62, 5.62),
#  ('Latin America and the Caribbean', 5.55, 5.55),
#  ('Latin America and the Caribbean', 10.68, 10.68),
#  ('Latin America and the Caribbean', 4.31, 4.31),
#  ('Latin America and the Caribbean', 3.85, 3.85),
#  ('Latin America and the Caribbean', 3.42, 3.42),
#  ('Latin America and the Caribbean', 3.27, 3.27),
#  ('Latin America and the Caribbean', 3.48, 3.48),
#  ('Latin America and the Caribbean', 4.44, 4.44),
#  ('Latin America and the Caribbean', 4.7, 4.7),
#  ('Latin America and the Caribbean', 3.9, 3.9),
#  ('Latin America and the Caribbean', 3.3, 3.3),
#  ('Latin America and the Caribbean', 5.2, 5.2),
#  ('Latin America and the Caribbean', None, 24.23),
#  ('Latin America and the Caribbean', None, 24.23),
#  ('Latin America and the Caribbean', 4.4, 4.4),
#  ('Latin America and the Caribbean', 4.84, 4.84),
#  ('Latin America and the Caribbean', 5.46, 5.46),
#  ('Latin America and the Caribbean', 5.31, 5.31),
#  ('Latin America and the Caribbean', 6.41, 6.41),
#  ('Latin America and the Caribbean', 18.55, 18.55),
#  ('Latin America and the Caribbean', None, 24.23),
#  ('Latin America and the Caribbean', None, 24.23),
#  ('Latin America and the Caribbean', 8.35, 8.35),
#  ('Latin America and the Caribbean', 9.22, 9.22),
#  ('Latin America and the Caribbean', 9.84, 9.84),
#  ('Latin America and the Caribbean', 11.46, 11.46),
#  ('Latin America and the Caribbean', None, 24.23),
#  ('Latin America and the Caribbean', None, 24.23),
#  ('Latin America and the Caribbean', None, 24.23),
#  ('Latin America and the Caribbean', None, 24.23),
#  ('Latin America and the Caribbean', None, 24.23),
#  ('Latin America and the Caribbean', None, 24.23),
#  ('Latin America and the Caribbean', 8.54, 8.54),
#  ('Latin America and the Caribbean', 11.58, 11.58),
#  ('Latin America and the Caribbean', 12.79, 12.79),
#  ('Latin America and the Caribbean', 12.33, 12.33),
#  ('Latin America and the Caribbean', 11.94, 11.94),
#  ('Latin America and the Caribbean', 13.7, 13.7),
#  ('Latin America and the Caribbean', 6.49, 6.49),
#  ('Latin America and the Caribbean', 6.73, 6.73),
#  ('Latin America and the Caribbean', 6.95, 6.95),
#  ('Latin America and the Caribbean', 7.21, 7.21),
#  ('Latin America and the Caribbean', 7.27, 7.27),
#  ('Latin America and the Caribbean', 10.94, 10.94),
#  ('Latin America and the Caribbean', 8.57, 8.57),
#  ('Latin America and the Caribbean', 8.92, 8.92),
#  ('Latin America and the Caribbean', 9.09, 9.09),
#  ('Latin America and the Caribbean', 9.36, 9.36),
#  ('Latin America and the Caribbean', 10.28, 10.28),
#  ('Latin America and the Caribbean', 15.98, 15.98),
#  ('Latin America and the Caribbean', 3.62, 3.62),
#  ('Latin America and the Caribbean', 4.6, 4.6),
#  ('Latin America and the Caribbean', 3.84, 3.84),
#  ('Latin America and the Caribbean', 3.53, 3.53),
#  ('Latin America and the Caribbean', 3.81, 3.81),
#  ('Latin America and the Caribbean', 6.11, 6.11),
#  ('Latin America and the Caribbean', None, 24.23),
#  ('Latin America and the Caribbean', None, 24.23),
#  ('Latin America and the Caribbean', None, 24.23),
#  ('Latin America and the Caribbean', None, 24.23),
#  ('Latin America and the Caribbean', None, 24.23),
#  ('Latin America and the Caribbean', None, 24.23),
#  ('Latin America and the Caribbean', None, 24.23),
#  ('Latin America and the Caribbean', None, 24.23),
#  ('Latin America and the Caribbean', None, 24.23),
#  ('Latin America and the Caribbean', None, 24.23),
#  ('Latin America and the Caribbean', None, 24.23),
#  ('Latin America and the Caribbean', None, 24.23),
#  ('Latin America and the Caribbean', None, 24.23),
#  ('Latin America and the Caribbean', None, 24.23),
#  ('Latin America and the Caribbean', None, 24.23),
#  ('Latin America and the Caribbean', 14.02, 14.02),
#  ('Latin America and the Caribbean', 13.52, 13.52),
#  ('Latin America and the Caribbean', None, 24.23),
#  ('Latin America and the Caribbean', 4.56, 4.56),
#  ('Latin America and the Caribbean', 5.25, 5.25),
#  ('Latin America and the Caribbean', 4.61, 4.61),
#  ('Latin America and the Caribbean', 6.22, 6.22),
#  ('Latin America and the Caribbean', 6.59, 6.59),
#  ('Latin America and the Caribbean', 7.55, 7.55),
#  ('Latin America and the Caribbean', 3.27, 3.27),
#  ('Latin America and the Caribbean', 3.74, 3.74),
#  ('Latin America and the Caribbean', 3.69, 3.69),
#  ('Latin America and the Caribbean', 3.49, 3.49),
#  ('Latin America and the Caribbean', 3.38, 3.38),
#  ('Latin America and the Caribbean', 7.18, 7.18),
#  ('Latin America and the Caribbean', 7.22, 7.22),
#  ('Latin America and the Caribbean', 7.92, 7.92),
#  ('Latin America and the Caribbean', None, 24.23),
#  ('Latin America and the Caribbean', None, 24.23),
#  ('Latin America and the Caribbean', None, 24.23),
#  ('Latin America and the Caribbean', None, 24.23),
#  ('Latin America and the Caribbean', 7.49, 7.49),
#  ('Latin America and the Caribbean', 7.84, 7.84),
#  ('Latin America and the Caribbean', 7.89, 7.89),
#  ('Latin America and the Caribbean', 8.34, 8.34),
#  ('Latin America and the Caribbean', 8.73, 8.73),
#  ('Latin America and the Caribbean', 10.33, 10.33),
#  ('Latin America and the Caribbean', None, 24.23),
#  ('Latin America and the Caribbean', None, 24.23),
#  ('Latin America and the Caribbean', None, 24.23),
#  ('Latin America and the Caribbean', None, 24.23),
#  ('Latin America and the Caribbean', None, 24.23),
#  ('Latin America and the Caribbean', None, 24.23),
#  ('Northern Africa and Western Asia', 11.21, 11.21),
#  ('Northern Africa and Western Asia', 10.2, 10.2),
#  ('Northern Africa and Western Asia', 12.0, 12.0),
#  ('Northern Africa and Western Asia', None, 17.84),
#  ('Northern Africa and Western Asia', None, 17.84),
#  ('Northern Africa and Western Asia', None, 17.84),
#  ('Northern Africa and Western Asia', None, 17.84),
#  ('Northern Africa and Western Asia', None, 17.84),
#  ('Northern Africa and Western Asia', None, 17.84),
#  ('Northern Africa and Western Asia', None, 17.84),
#  ('Northern Africa and Western Asia', None, 17.84),
#  ('Northern Africa and Western Asia', None, 17.84),
#  ('Northern Africa and Western Asia', None, 17.84),
#  ('Northern Africa and Western Asia', None, 17.84),
#  ('Northern Africa and Western Asia', None, 17.84),
#  ('Northern Africa and Western Asia', None, 17.84),
#  ('Northern Africa and Western Asia', None, 17.84),
#  ('Northern Africa and Western Asia', None, 17.84),
#  ('Northern Africa and Western Asia', 9.46, 9.46),
#  ('Northern Africa and Western Asia', 9.3, 9.3),
#  ('Northern Africa and Western Asia', None, 17.84),
#  ('Northern Africa and Western Asia', None, 17.84),
#  ('Northern Africa and Western Asia', None, 17.84),
#  ('Northern Africa and Western Asia', None, 17.84),
#  ('Northern Africa and Western Asia', None, 17.84),
#  ('Northern Africa and Western Asia', None, 17.84),
#  ('Northern Africa and Western Asia', None, 17.84),
#  ('Northern Africa and Western Asia', None, 17.84),
#  ('Northern Africa and Western Asia', None, 17.84),
#  ('Northern Africa and Western Asia', None, 17.84),
#  ('Northern Africa and Western Asia', 15.16, 15.16),
#  ('Northern Africa and Western Asia', 15.56, 15.56),
#  ('Northern Africa and Western Asia', 15.33, 15.33),
#  ('Northern Africa and Western Asia', 15.46, 15.46),
#  ('Northern Africa and Western Asia', 15.13, 15.13),
#  ('Northern Africa and Western Asia', None, 17.84),
#  ('Northern Africa and Western Asia', 18.26, 18.26),
#  ('Northern Africa and Western Asia', 17.62, 17.62),
#  ('Northern Africa and Western Asia', 17.7, 17.7),
#  ('Northern Africa and Western Asia', 13.21, 13.21),
#  ('Northern Africa and Western Asia', 12.2, 12.2),
#  ('Northern Africa and Western Asia', 12.18, 12.18),
#  ('Northern Africa and Western Asia', 4.96, 4.96),
#  ('Northern Africa and Western Asia', 5.0, 5.0),
#  ('Northern Africa and Western Asia', 4.96, 4.96),
#  ('Northern Africa and Western Asia', 4.94, 4.94),
#  ('Northern Africa and Western Asia', 4.85, 4.85),
#  ('Northern Africa and Western Asia', 7.16, 7.16),
#  ('Northern Africa and Western Asia', None, 17.84),
#  ('Northern Africa and Western Asia', None, 17.84),
#  ('Northern Africa and Western Asia', None, 17.84),
#  ('Northern Africa and Western Asia', None, 17.84),
#  ('Northern Africa and Western Asia', None, 17.84),
#  ('Northern Africa and Western Asia', None, 17.84),
#  ('Northern Africa and Western Asia', 15.03, 15.03),
#  ('Northern Africa and Western Asia', 13.01, 13.01),
#  ('Northern Africa and Western Asia', 11.16, 11.16),
#  ('Northern Africa and Western Asia', 8.5, 8.5),
#  ('Northern Africa and Western Asia', 7.15, 7.15),
#  ('Northern Africa and Western Asia', 7.76, 7.76),
#  ('Northern Africa and Western Asia', 16.51, 16.51),
#  ('Northern Africa and Western Asia', 16.6, 16.6),
#  ('Northern Africa and Western Asia', 13.94, 13.94),
#  ('Northern Africa and Western Asia', 12.67, 12.67),
#  ('Northern Africa and Western Asia', 11.57, 11.57),
#  ('Northern Africa and Western Asia', 11.73, 11.73),
#  ('Northern Africa and Western Asia', None, 17.84),
#  ('Northern Africa and Western Asia', 10.82, 10.82),
#  ('Northern Africa and Western Asia', 13.02, 13.02),
#  ('Northern Africa and Western Asia', None, 17.84),
#  ('Northern Africa and Western Asia', None, 17.84),
#  ('Northern Africa and Western Asia', None, 17.84),
#  ('Northern Africa and Western Asia', 5.18, 5.18),
#  ('Northern Africa and Western Asia', 4.72, 4.72),
#  ('Northern Africa and Western Asia', 4.14, 4.14),
#  ('Northern Africa and Western Asia', 3.92, 3.92),
#  ('Northern Africa and Western Asia', 3.73, 3.73),
#  ('Northern Africa and Western Asia', 4.17, 4.17),
#  ('Northern Africa and Western Asia', 13.08, 13.08),
#  ('Northern Africa and Western Asia', 15.28, 15.28),
#  ('Northern Africa and Western Asia', 18.12, 18.12),
#  ('Northern Africa and Western Asia', 18.26, 18.26),
#  ('Northern Africa and Western Asia', 16.8, 16.8),
#  ('Northern Africa and Western Asia', 19.21, 19.21),
#  ('Northern Africa and Western Asia', 2.2, 2.2),
#  ('Northern Africa and Western Asia', 2.16, 2.16),
#  ('Northern Africa and Western Asia', None, 17.84),
#  ('Northern Africa and Western Asia', None, 17.84),
#  ('Northern Africa and Western Asia', None, 17.84),
#  ('Northern Africa and Western Asia', None, 17.84),
#  ('Northern Africa and Western Asia', None, 17.84),
#  ('Northern Africa and Western Asia', None, 17.84),
#  ('Northern Africa and Western Asia', None, 17.84),
#  ('Northern Africa and Western Asia', None, 17.84),
#  ('Northern Africa and Western Asia', 11.3, 11.3),
#  ('Northern Africa and Western Asia', None, 17.84),
#  ('Northern Africa and Western Asia', None, 17.84),
#  ('Northern Africa and Western Asia', 3.27, 3.27),
#  ('Northern Africa and Western Asia', None, 17.84),
#  ('Northern Africa and Western Asia', 1.8, 1.8),
#  ('Northern Africa and Western Asia', None, 17.84),
#  ('Northern Africa and Western Asia', 2.94, 2.94),
#  ('Northern Africa and Western Asia', 0.17, 0.17),
#  ('Northern Africa and Western Asia', 0.15, 0.15),
#  ('Northern Africa and Western Asia', 0.14, 0.14),
#  ('Northern Africa and Western Asia', 0.11, 0.11),
#  ('Northern Africa and Western Asia', 0.1, 0.1),
#  ('Northern Africa and Western Asia', 0.14, 0.14),
#  ('Northern Africa and Western Asia', 5.6, 5.6),
#  ('Northern Africa and Western Asia', 5.6, 5.6),
#  ('Northern Africa and Western Asia', 5.89, 5.89),
#  ('Northern Africa and Western Asia', 6.03, 6.03),
#  ('Northern Africa and Western Asia', 5.64, 5.64),
#  ('Northern Africa and Western Asia', 7.66, 7.66),
#  ('Northern Africa and Western Asia', None, 17.84),
#  ('Northern Africa and Western Asia', None, 17.84),
#  ('Northern Africa and Western Asia', None, 17.84),
#  ('Northern Africa and Western Asia', None, 17.84),
#  ('Northern Africa and Western Asia', None, 17.84),
#  ('Northern Africa and Western Asia', None, 17.84),
#  ('Northern Africa and Western Asia', None, 17.84),
#  ('Northern Africa and Western Asia', None, 17.84),
#  ('Northern Africa and Western Asia', None, 17.84),
#  ('Northern Africa and Western Asia', None, 17.84),
#  ('Northern Africa and Western Asia', None, 17.84),
#  ('Northern Africa and Western Asia', None, 17.84),
#  ('Northern Africa and Western Asia', None, 17.84),
#  ('Northern Africa and Western Asia', None, 17.84),
#  ('Northern Africa and Western Asia', None, 17.84),
#  ('Northern Africa and Western Asia', None, 17.84),
#  ('Northern Africa and Western Asia', None, 17.84),
#  ('Northern Africa and Western Asia', None, 17.84),
#  ('Northern Africa and Western Asia', None, 17.84),
#  ('Northern Africa and Western Asia', 1.64, 1.64),
#  ('Northern Africa and Western Asia', 2.46, 2.46),
#  ('Northern Africa and Western Asia', 2.24, 2.24),
#  ('Northern Africa and Western Asia', 2.33, 2.33),
#  ('Northern Africa and Western Asia', 4.29, 4.29),
#  ('Northern Africa and Western Asia', None, 17.84),
#  ('Northern Africa and Western Asia', None, 17.84),
#  ('Northern Africa and Western Asia', None, 17.84),
#  ('Northern Africa and Western Asia', None, 17.84),
#  ('Northern Africa and Western Asia', None, 17.84),
#  ('Northern Africa and Western Asia', None, 17.84),
#  ('Oceania', 6.06, 6.06),
#  ('Oceania', 5.71, 5.71),
#  ('Oceania', 5.59, 5.59),
#  ('Oceania', 5.3, 5.3),
#  ('Oceania', 5.16, 5.16),
#  ('Oceania', 6.46, 6.46),
#  ('Oceania', 5.42, 5.42),
#  ('Oceania', 5.15, 5.15),
#  ('Oceania', 4.74, 4.74),
#  ('Oceania', 4.34, 4.34),
#  ('Oceania', 4.11, 4.11),
#  ('Oceania', 4.6, 4.6),
#  ('Oceania', None, 4.98),
#  ('Oceania', 4.32, 4.32),
#  ('Oceania', None, 4.98),
#  ('Oceania', None, 4.98),
#  ('Oceania', None, 4.98),
#  ('Oceania', None, 4.98),
#  ('Oceania', None, 4.98),
#  ('Oceania', None, 4.98),
#  ('Oceania', 11.68, 11.68),
#  ('Oceania', 11.7, 11.7),
#  ('Oceania', 10.88, 10.88),
#  ('Oceania', 13.56, 13.56),
#  ('Oceania', None, 4.98),
#  ('Oceania', None, 4.98),
#  ('Oceania', None, 4.98),
#  ('Oceania', None, 4.98),
#  ('Oceania', None, 4.98),
#  ('Oceania', None, 4.98),
#  ('Oceania', None, 4.98),
#  ('Oceania', None, 4.98),
#  ('Oceania', None, 4.98),
#  ('Oceania', None, 4.98),
#  ('Oceania', None, 4.98),
#  ('Oceania', None, 4.98),
#  ('Oceania', None, 4.98),
#  ('Oceania', None, 4.98),
#  ('Oceania', None, 4.98),
#  ('Oceania', None, 4.98),
#  ('Oceania', 5.44, 5.44),
#  ('Oceania', 4.05, 4.05),
#  ('Oceania', 6.9, 6.9),
#  ('Oceania', 5.4, 5.4),
#  ('Oceania', None, 4.98),
#  ('Oceania', None, 4.98),
#  ('Oceania', None, 4.98),
#  ('Oceania', None, 4.98),
#  ('Oceania', 9.33, 9.33),
#  ('Oceania', None, 4.98),
#  ('Oceania', None, 4.98),
#  ('Oceania', None, 4.98),
#  ('Oceania', 8.56, 8.56),
#  ('Oceania', 10.97, 10.97),
#  ('Oceania', None, 4.98),
#  ('Oceania', None, 4.98),
#  ('Oceania', None, 4.98),
#  ('Oceania', None, 4.98),
#  ('Oceania', 6.34, 6.34),
#  ('Oceania', None, 4.98),
#  ('Oceania', None, 4.98),
#  ('Oceania', None, 4.98),
#  ('Oceania', None, 4.98),
#  ('Oceania', None, 4.98),
#  ('Oceania', None, 4.98),
#  ('Oceania', None, 4.98),
#  ('Oceania', None, 4.98),
#  ('Oceania', None, 4.98),
#  ('Oceania', None, 4.98),
#  ('Oceania', None, 4.98),
#  ('Oceania', None, 4.98),
#  ('Oceania', None, 4.98),
#  ('Oceania', None, 4.98),
#  ('Oceania', None, 4.98),
#  ('Oceania', None, 4.98),
#  ('Oceania', None, 4.98),
#  ('Oceania', None, 4.98),
#  ('Oceania', None, 4.98),
#  ('Oceania', None, 4.98),
#  ('Oceania', None, 4.98),
#  ('Oceania', None, 4.98),
#  ('Oceania', None, 4.98),
#  ('Oceania', 0.77, 0.77),
#  ('Oceania', None, 4.98),
#  ('Oceania', None, 4.98),
#  ('Oceania', None, 4.98),
#  ('Oceania', None, 4.98),
#  ('Oceania', None, 4.98),
#  ('Oceania', None, 4.98),
#  ('Oceania', None, 4.98),
#  ('Oceania', None, 4.98),
#  ('Oceania', None, 4.98),
#  ('Oceania', None, 4.98),
#  ('Oceania', None, 4.98),
#  ('Oceania', None, 4.98),
#  ('Oceania', None, 4.98),
#  ('Oceania', None, 4.98),
#  ('Oceania', None, 4.98),
#  ('Oceania', None, 4.98),
#  ('Oceania', None, 4.98),
#  ('Oceania', None, 4.98),
#  ('Oceania', None, 4.98),
#  ('Oceania', None, 4.98),
#  ('Oceania', None, 4.98),
#  ('Oceania', None, 4.98),
#  ('Oceania', None, 4.98),
#  ('Oceania', None, 4.98),
#  ('Oceania', None, 4.98),
#  ('Oceania', None, 4.98),
#  ('Oceania', 9.4, 9.4),
#  ('Oceania', None, 4.98),
#  ('Oceania', None, 4.98),
#  ('Oceania', None, 4.98),
#  ('Oceania', None, 4.98),
#  ('Oceania', None, 4.98),
#  ('Oceania', None, 4.98),
#  ('Oceania', None, 4.98),
#  ('Oceania', None, 4.98),
#  ('Oceania', None, 4.98),
#  ('Oceania', None, 4.98),
#  ('Oceania', None, 4.98),
#  ('Oceania', None, 4.98),
#  ('Oceania', 2.25, 2.25),
#  ('Oceania', None, 4.98),
#  ('Oceania', None, 4.98),
#  ('Oceania', None, 4.98),
#  ('Oceania', 8.49, 8.49),
#  ('Oceania', 26.55, 26.55),
#  ('Oceania', None, 4.98),
#  ('Oceania', None, 4.98),
#  ('Oceania', None, 4.98),
#  ('Oceania', None, 4.98),
#  ('Oceania', None, 4.98),
#  ('Oceania', None, 4.98),
#  ('Oceania', None, 4.98),
#  ('Oceania', None, 4.98),
#  ('Oceania', None, 4.98),
#  ('Sub-Saharan Africa', None, 33.65),
#  ('Sub-Saharan Africa', None, 33.65),
#  ('Sub-Saharan Africa', None, 33.65),
#  ('Sub-Saharan Africa', None, 33.65),
#  ('Sub-Saharan Africa', None, 33.65),
#  ('Sub-Saharan Africa', 1.03, 1.03),
#  ('Sub-Saharan Africa', None, 33.65),
#  ('Sub-Saharan Africa', None, 33.65),
#  ('Sub-Saharan Africa', None, 33.65),
#  ('Sub-Saharan Africa', None, 33.65),
#  ('Sub-Saharan Africa', None, 33.65),
#  ('Sub-Saharan Africa', None, 33.65),
#  ('Sub-Saharan Africa', None, 33.65),
#  ('Sub-Saharan Africa', 26.06, 26.06),
#  ('Sub-Saharan Africa', None, 33.65),
#  ('Sub-Saharan Africa', None, 33.65),
#  ('Sub-Saharan Africa', None, 33.65),
#  ('Sub-Saharan Africa', None, 33.65),
#  ('Sub-Saharan Africa', None, 33.65),
#  ('Sub-Saharan Africa', None, 33.65),
#  ('Sub-Saharan Africa', None, 33.65),
#  ('Sub-Saharan Africa', None, 33.65),
#  ('Sub-Saharan Africa', None, 33.65),
#  ('Sub-Saharan Africa', None, 33.65),
#  ('Sub-Saharan Africa', None, 33.65),
#  ('Sub-Saharan Africa', None, 33.65),
#  ('Sub-Saharan Africa', 2.76, 2.76),
#  ('Sub-Saharan Africa', None, 33.65),
#  ('Sub-Saharan Africa', None, 33.65),
#  ('Sub-Saharan Africa', 5.01, 5.01),
#  ('Sub-Saharan Africa', None, 33.65),
#  ('Sub-Saharan Africa', 1.79, 1.79),
#  ('Sub-Saharan Africa', None, 33.65),
#  ('Sub-Saharan Africa', None, 33.65),
#  ('Sub-Saharan Africa', None, 33.65),
#  ('Sub-Saharan Africa', None, 33.65),
#  ('Sub-Saharan Africa', None, 33.65),
#  ('Sub-Saharan Africa', None, 33.65),
#  ('Sub-Saharan Africa', None, 33.65),
#  ('Sub-Saharan Africa', 3.54, 3.54),
#  ('Sub-Saharan Africa', None, 33.65),
#  ('Sub-Saharan Africa', None, 33.65),
#  ('Sub-Saharan Africa', 0.91, 0.91),
#  ('Sub-Saharan Africa', 7.41, 7.41),
#  ('Sub-Saharan Africa', 6.81, 6.81),
#  ('Sub-Saharan Africa', 6.75, 6.75),
#  ('Sub-Saharan Africa', 6.43, 6.43),
#  ('Sub-Saharan Africa', 6.33, 6.33),
#  ('Sub-Saharan Africa', 8.63, 8.63),
#  ('Sub-Saharan Africa', None, 33.65),
#  ('Sub-Saharan Africa', None, 33.65),
#  ('Sub-Saharan Africa', None, 33.65),
#  ('Sub-Saharan Africa', None, 33.65),
#  ('Sub-Saharan Africa', None, 33.65),
#  ('Sub-Saharan Africa', None, 33.65),
#  ('Sub-Saharan Africa', 3.43, 3.43),
#  ('Sub-Saharan Africa', None, 33.65),
#  ('Sub-Saharan Africa', None, 33.65),
#  ('Sub-Saharan Africa', None, 33.65),
#  ('Sub-Saharan Africa', None, 33.65),
#  ('Sub-Saharan Africa', None, 33.65),
#  ('Sub-Saharan Africa', None, 33.65),
#  ('Sub-Saharan Africa', None, 33.65),
#  ('Sub-Saharan Africa', 11.88, 11.88),
#  ('Sub-Saharan Africa', 10.76, 10.76),
#  ('Sub-Saharan Africa', 11.24, 11.24),
#  ('Sub-Saharan Africa', 11.83, 11.83),
#  ('Sub-Saharan Africa', None, 33.65),
#  ('Sub-Saharan Africa', None, 33.65),
#  ('Sub-Saharan Africa', None, 33.65),
#  ('Sub-Saharan Africa', None, 33.65),
#  ('Sub-Saharan Africa', None, 33.65),
#  ('Sub-Saharan Africa', None, 33.65),
#  ('Sub-Saharan Africa', 4.15, 4.15),
#  ('Sub-Saharan Africa', 3.96, 3.96),
#  ('Sub-Saharan Africa', 3.71, 3.71),
#  ('Sub-Saharan Africa', 3.53, 3.53),
#  ('Sub-Saharan Africa', 2.97, 2.97),
#  ('Sub-Saharan Africa', None, 33.65),
#  ('Sub-Saharan Africa', None, 33.65),
#  ('Sub-Saharan Africa', None, 33.65),
#  ('Sub-Saharan Africa', None, 33.65),
#  ('Sub-Saharan Africa', 18.83, 18.83),
#  ('Sub-Saharan Africa', None, 33.65),
#  ('Sub-Saharan Africa', None, 33.65),
#  ('Sub-Saharan Africa', None, 33.65),
#  ('Sub-Saharan Africa', None, 33.65),
#  ('Sub-Saharan Africa', None, 33.65),
#  ('Sub-Saharan Africa', None, 33.65),
#  ('Sub-Saharan Africa', None, 33.65),
#  ('Sub-Saharan Africa', None, 33.65),
#  ('Sub-Saharan Africa', None, 33.65),
#  ('Sub-Saharan Africa', 3.64, 3.64),
#  ('Sub-Saharan Africa', None, 33.65),
#  ('Sub-Saharan Africa', None, 33.65),
#  ('Sub-Saharan Africa', None, 33.65),
#  ('Sub-Saharan Africa', None, 33.65),
#  ('Sub-Saharan Africa', None, 33.65),
#  ('Sub-Saharan Africa', None, 33.65),
#  ('Sub-Saharan Africa', None, 33.65),
#  ('Sub-Saharan Africa', None, 33.65),
#  ('Sub-Saharan Africa', None, 33.65),
#  ('Sub-Saharan Africa', None, 33.65),
#  ('Sub-Saharan Africa', None, 33.65),
#  ('Sub-Saharan Africa', 8.52, 8.52),
#  ('Sub-Saharan Africa', 5.03, 5.03),
#  ('Sub-Saharan Africa', 5.54, 5.54),
#  ('Sub-Saharan Africa', 6.03, 6.03),
#  ('Sub-Saharan Africa', None, 33.65),
#  ('Sub-Saharan Africa', None, 33.65),
#  ('Sub-Saharan Africa', None, 33.65),
#  ('Sub-Saharan Africa', None, 33.65),
#  ('Sub-Saharan Africa', 7.37, 7.37),
#  ('Sub-Saharan Africa', None, 33.65),
#  ('Sub-Saharan Africa', None, 33.65),
#  ('Sub-Saharan Africa', None, 33.65),
#  ('Sub-Saharan Africa', None, 33.65),
#  ('Sub-Saharan Africa', None, 33.65),
#  ('Sub-Saharan Africa', 16.5, 16.5),
#  ('Sub-Saharan Africa', None, 33.65),
#  ('Sub-Saharan Africa', None, 33.65),
#  ('Sub-Saharan Africa', None, 33.65),
#  ('Sub-Saharan Africa', None, 33.65),
#  ('Sub-Saharan Africa', None, 33.65),
#  ('Sub-Saharan Africa', None, 33.65),
#  ('Sub-Saharan Africa', None, 33.65),
#  ('Sub-Saharan Africa', None, 33.65),
#  ('Sub-Saharan Africa', None, 33.65),
#  ('Sub-Saharan Africa', None, 33.65),
#  ('Sub-Saharan Africa', None, 33.65),
#  ('Sub-Saharan Africa', None, 33.65),
#  ('Sub-Saharan Africa', None, 33.65),
#  ('Sub-Saharan Africa', None, 33.65),
#  ('Sub-Saharan Africa', None, 33.65),
#  ('Sub-Saharan Africa', None, 33.65),
#  ('Sub-Saharan Africa', 1.13, 1.13),
#  ('Sub-Saharan Africa', None, 33.65),
#  ('Sub-Saharan Africa', None, 33.65),
#  ('Sub-Saharan Africa', None, 33.65),
#  ('Sub-Saharan Africa', None, 33.65),
#  ('Sub-Saharan Africa', None, 33.65),
#  ('Sub-Saharan Africa', None, 33.65),
#  ('Sub-Saharan Africa', None, 33.65),
#  ('Sub-Saharan Africa', None, 33.65),
#  ('Sub-Saharan Africa', None, 33.65),
#  ('Sub-Saharan Africa', None, 33.65),
#  ('Sub-Saharan Africa', None, 33.65),
#  ('Sub-Saharan Africa', None, 33.65),
#  ('Sub-Saharan Africa', None, 33.65),
#  ('Sub-Saharan Africa', None, 33.65),
#  ('Sub-Saharan Africa', None, 33.65),
#  ('Sub-Saharan Africa', None, 33.65),
#  ('Sub-Saharan Africa', None, 33.65),
#  ('Sub-Saharan Africa', None, 33.65),
#  ('Sub-Saharan Africa', None, 33.65),
#  ('Sub-Saharan Africa', None, 33.65),
#  ('Sub-Saharan Africa', None, 33.65),
#  ('Sub-Saharan Africa', None, 33.65),
#  ('Sub-Saharan Africa', None, 33.65),
#  ('Sub-Saharan Africa', None, 33.65),
#  ('Sub-Saharan Africa', None, 33.65),
#  ('Sub-Saharan Africa', None, 33.65),
#  ('Sub-Saharan Africa', None, 33.65),
#  ('Sub-Saharan Africa', None, 33.65),
#  ('Sub-Saharan Africa', None, 33.65),
#  ('Sub-Saharan Africa', None, 33.65),
#  ('Sub-Saharan Africa', None, 33.65),
#  ('Sub-Saharan Africa', None, 33.65),
#  ('Sub-Saharan Africa', None, 33.65),
#  ('Sub-Saharan Africa', 20.09, 20.09),
#  ('Sub-Saharan Africa', 21.02, 21.02),
#  ('Sub-Saharan Africa', None, 33.65),
#  ('Sub-Saharan Africa', 22.72, 22.72),
#  ('Sub-Saharan Africa', None, 33.65),
#  ('Sub-Saharan Africa', None, 33.65),
#  ('Sub-Saharan Africa', None, 33.65),
#  ('Sub-Saharan Africa', None, 33.65),
#  ('Sub-Saharan Africa', None, 33.65),
#  ('Sub-Saharan Africa', None, 33.65),
#  ('Sub-Saharan Africa', None, 33.65),
#  ('Sub-Saharan Africa', None, 33.65),
#  ('Sub-Saharan Africa', 16.88, 16.88),
#  ('Sub-Saharan Africa', None, 33.65),
#  ('Sub-Saharan Africa', None, 33.65),
#  ('Sub-Saharan Africa', 23.35, 23.35),
#  ('Sub-Saharan Africa', None, 33.65),
#  ('Sub-Saharan Africa', 19.88, 19.88),
#  ('Sub-Saharan Africa', None, 33.65),
#  ('Sub-Saharan Africa', None, 33.65),
#  ('Sub-Saharan Africa', 22.87, 22.87),
#  ('Sub-Saharan Africa', 24.02, 24.02),
#  ('Sub-Saharan Africa', 23.99, 23.99),
#  ('Sub-Saharan Africa', 24.22, 24.22),
#  ('Sub-Saharan Africa', 25.54, 25.54),
#  ('Sub-Saharan Africa', 24.34, 24.34),
#  ('Sub-Saharan Africa', None, 33.65),
#  ('Sub-Saharan Africa', None, 33.65),
#  ('Sub-Saharan Africa', None, 33.65),
#  ('Sub-Saharan Africa', 1.47, 1.47),
#  ('Sub-Saharan Africa', None, 33.65),
#  ('Sub-Saharan Africa', None, 33.65),
#  ('Sub-Saharan Africa', None, 33.65),
#  ('Sub-Saharan Africa', None, 33.65),
#  ('Sub-Saharan Africa', None, 33.65),
#  ('Sub-Saharan Africa', 4.69, 4.69),
#  ('Sub-Saharan Africa', None, 33.65),
#  ('Sub-Saharan Africa', None, 33.65),
#  ('Sub-Saharan Africa', 31.31, 31.31),
#  ('Sub-Saharan Africa', None, 33.65),
#  ('Sub-Saharan Africa', 12.24, 12.24),
#  ('Sub-Saharan Africa', 12.17, 12.17),
#  ('Sub-Saharan Africa', 11.29, 11.29),
#  ('Sub-Saharan Africa', None, 33.65),
#  ('Sub-Saharan Africa', None, 33.65),
#  ('Sub-Saharan Africa', None, 33.65),
#  ('Sub-Saharan Africa', None, 33.65),
#  ('Sub-Saharan Africa', None, 33.65),
#  ('Sub-Saharan Africa', None, 33.65),
#  ('Sub-Saharan Africa', None, 33.65),
#  ('Sub-Saharan Africa', None, 33.65),
#  ('Sub-Saharan Africa', None, 33.65),
#  ('Sub-Saharan Africa', None, 33.65),
#  ('Sub-Saharan Africa', None, 33.65),
#  ('Sub-Saharan Africa', None, 33.65),
#  ('Sub-Saharan Africa', None, 33.65),
#  ('Sub-Saharan Africa', 6.81, 6.81),
#  ('Sub-Saharan Africa', None, 33.65),
#  ('Sub-Saharan Africa', 3.37, 3.37),
#  ('Sub-Saharan Africa', None, 33.65),
#  ('Sub-Saharan Africa', None, 33.65),
#  ('Sub-Saharan Africa', None, 33.65),
#  ('Sub-Saharan Africa', None, 33.65),
#  ('Sub-Saharan Africa', None, 33.65),
#  ('Sub-Saharan Africa', None, 33.65),
#  ('Sub-Saharan Africa', None, 33.65),
#  ('Sub-Saharan Africa', 5.02, 5.02),
#  ('Sub-Saharan Africa', None, 33.65),
#  ('Sub-Saharan Africa', None, 33.65),
#  ('Sub-Saharan Africa', None, 33.65),
#  ('Sub-Saharan Africa', None, 33.65),
#  ('Sub-Saharan Africa', 3.2, 3.2),
#  ('Sub-Saharan Africa', None, 33.65),
#  ('Sub-Saharan Africa', None, 33.65),
#  ('Sub-Saharan Africa', None, 33.65),
#  ('Sub-Saharan Africa', 3.08, 3.08),
#  ('Sub-Saharan Africa', 5.95, 5.95),
#  ('Sub-Saharan Africa', None, 33.65),
#  ('Sub-Saharan Africa', None, 33.65),
#  ('Sub-Saharan Africa', None, 33.65),
#  ...]
