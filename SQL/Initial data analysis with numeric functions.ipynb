# %%
#Preparing sql environment
# %load_ext sql

# %%
# %sql mysql+pymysql://root:0479%40Kanya@127.0.0.1:3306/united_nations

# %%
# %%sql
# SELECT * FROM Access_to_Basic_Services
# LIMIT 5;
# Out:
#  * mysql+pymysql://root:***@127.0.0.1:3306/united_nations
# 5 rows affected.
# [('Central and Southern Asia', 'Central Asia', 'Kazakhstan', 2015, 94.67, 98, 17.542806, 184.39, 2699700, 4.93),
#  ('Central and Southern Asia', 'Central Asia', 'Kazakhstan', 2016, 94.67, 98, 17.794055, 137.28, 2699700, 4.96),
#  ('Central and Southern Asia', 'Central Asia', 'Kazakhstan', 2017, 95.0, 98, 18.037776, 166.81, 2699700, 4.9),
#  ('Central and Southern Asia', 'Central Asia', 'Kazakhstan', 2018, 95.0, 98, 18.276452, 179.34, 2699700, 4.85),
#  ('Central and Southern Asia', 'Central Asia', 'Kazakhstan', 2019, 95.0, 98, 18.513673, 181.67, 2699700, 4.8)]

# %% [markdown]
# **1. What is the total number of entries in the dataset?**
#
# Count the number of entries in the dataset using the COUNT function. Return the result with an alias.

# %%
# %%sql
# SELECT
#      COUNT(*) AS total_number_of_entries_in_the_dataset
#
# FROM Access_to_Basic_Services;
# Out:
#  * mysql+pymysql://root:***@127.0.0.1:3306/united_nations
# 1 rows affected.
# [(1048,)]

# %% [markdown]
# **2. What are the earliest and latest years for which we have data?**
#
# Determine the earliest and latest years by calculating the minimum and maximum of the Time_period column using the MIN and MAX functions respectively. Use aliases to name the results.

# %%
# %%sql
# SELECT
#      COUNT(*) AS total_number_of_entries_in_the_dataset,
#      MIN(time_period) AS Year_minimum_of_time_period,
#      MAX(time_period) AS  Year_maximum_of_time_period
#
# FROM Access_to_Basic_Services;
# Out:
#  * mysql+pymysql://root:***@127.0.0.1:3306/united_nations
# 1 rows affected.
# [(1048, 2015, 2020)]

# %% [markdown]
# **3. How many countries are included in this dataset?**
#
# Count the number of countries in the Country_name column. Note, if we only use the COUNT function without an additional keyword, SQL will return the total number of entries in the column, including duplicates. Use the DISTINCT keyword to only return unique country names. Return the result with an alias.

# %%
# %%sql
# SELECT
#      COUNT(DISTINCT Country_name) AS unique_country_name,
#      MIN(time_period) AS Year_minimum_of_time_period,
#      MAX(time_period) AS  Year_maximum_of_time_period
#
# FROM Access_to_Basic_Services;
# Out:
#  * mysql+pymysql://root:***@127.0.0.1:3306/united_nations
# 1 rows affected.
# [(182, 2015, 2020)]

# %% [markdown]
# **4. What is the average percentage of people who have access to managed drinking water services across all years and all countries included in our dataset?**
#
# Use the AVG function to calculate the average of the Pct_managed_drinking_water_services column. Use an alias.

# %%
# %%sql
# SELECT
#      COUNT(DISTINCT Country_name) AS country_number,
#      MIN(time_period) AS Year_minimum_of_time_period,
#      MAX(time_period) AS  Year_maximum_of_time_period,
#      AVG(Pct_managed_drinking_water_services) AS average_percentage_have_access_to_water_all_countries
#
# FROM Access_to_Basic_Services;
# Out:
#  * mysql+pymysql://root:***@127.0.0.1:3306/united_nations
# 1 rows affected.
# [(182, 2015, 2020, 87.18910305343516)]

# %% [markdown]
# **5. What is the GDP per year for each country?**
#
# Calculate the GDP per year for each country using the Country_name, Time_period, and Est_gdp_in_billions columns.

# %%
# %%sql
#
# Select Country_name,
#     Time_period,
#     Est_gdp_in_billions
# FROM Access_to_Basic_Services;
# Out:
#  * mysql+pymysql://root:***@127.0.0.1:3306/united_nations
# 1048 rows affected.
# [('Kazakhstan', 2015, 184.39),
#  ('Kazakhstan', 2016, 137.28),
#  ('Kazakhstan', 2017, 166.81),
#  ('Kazakhstan', 2018, 179.34),
#  ('Kazakhstan', 2019, 181.67),
#  ('Kazakhstan', 2020, 171.08),
#  ('Kyrgyzstan', 2015, None),
#  ('Kyrgyzstan', 2016, None),
#  ('Kyrgyzstan', 2017, None),
#  ('Kyrgyzstan', 2018, None),
#  ('Kyrgyzstan', 2019, None),
#  ('Kyrgyzstan', 2020, None),
#  ('Tajikistan', 2015, 8.27),
#  ('Tajikistan', 2016, 6.99),
#  ('Tajikistan', 2017, 7.54),
#  ('Tajikistan', 2018, 7.77),
#  ('Tajikistan', 2019, 8.3),
#  ('Tajikistan', 2020, 8.13),
#  ('Turkmenistan', 2015, 35.8),
#  ('Turkmenistan', 2016, 36.17),
#  ('Turkmenistan', 2017, 37.93),
#  ('Turkmenistan', 2018, 40.77),
#  ('Turkmenistan', 2019, 45.23),
#  ('Turkmenistan', 2020, None),
#  ('Uzbekistan', 2015, 86.2),
#  ('Uzbekistan', 2016, 86.14),
#  ('Uzbekistan', 2017, 62.08),
#  ('Uzbekistan', 2018, 52.63),
#  ('Uzbekistan', 2019, 59.91),
#  ('Uzbekistan', 2020, 59.89),
#  ('Afghanistan', 2015, 20.0),
#  ('Afghanistan', 2016, 18.02),
#  ('Afghanistan', 2017, 18.9),
#  ('Afghanistan', 2018, 18.42),
#  ('Afghanistan', 2019, 18.9),
#  ('Afghanistan', 2020, 20.14),
#  ('Bangladesh', 2015, 195.08),
#  ('Bangladesh', 2016, 265.24),
#  ('Bangladesh', 2017, 293.75),
#  ('Bangladesh', 2018, 321.38),
#  ('Bangladesh', 2019, 351.24),
#  ('Bangladesh', 2020, 373.9),
#  ('Bhutan', 2015, 2.0),
#  ('Bhutan', 2016, 2.16),
#  ('Bhutan', 2017, 2.45),
#  ('Bhutan', 2018, 2.45),
#  ('Bhutan', 2019, 2.54),
#  ('Bhutan', 2020, 2.33),
#  ('India', 2015, 2103.59),
#  ('India', 2016, 2294.8),
#  ('India', 2017, 2651.47),
#  ('India', 2018, 2702.93),
#  ('India', 2019, 2831.55),
#  ('India', 2020, 2667.69),
#  ('Iran (Islamic Republic of)', 2015, None),
#  ('Iran (Islamic Republic of)', 2016, None),
#  ('Iran (Islamic Republic of)', 2017, None),
#  ('Iran (Islamic Republic of)', 2018, None),
#  ('Iran (Islamic Republic of)', 2019, None),
#  ('Iran (Islamic Republic of)', 2020, None),
#  ('Maldives', 2015, 4.11),
#  ('Maldives', 2016, 4.38),
#  ('Maldives', 2017, 4.75),
#  ('Maldives', 2018, 5.3),
#  ('Maldives', 2019, 5.61),
#  ('Maldives', 2020, 3.75),
#  ('Nepal', 2015, 24.36),
#  ('Nepal', 2016, 24.52),
#  ('Nepal', 2017, 28.97),
#  ('Nepal', 2018, 33.11),
#  ('Nepal', 2019, 34.19),
#  ('Nepal', 2020, 33.43),
#  ('Pakistan', 2015, 270.56),
#  ('Pakistan', 2016, 313.63),
#  ('Pakistan', 2017, 339.21),
#  ('Pakistan', 2018, 356.13),
#  ('Pakistan', 2019, 320.91),
#  ('Pakistan', 2020, 300.43),
#  ('Sri Lanka', 2015, 85.14),
#  ('Sri Lanka', 2016, 88.01),
#  ('Sri Lanka', 2017, 94.38),
#  ('Sri Lanka', 2018, 94.49),
#  ('Sri Lanka', 2019, 89.01),
#  ('Sri Lanka', 2020, 85.35),
#  ('China', 2015, 11061.55),
#  ('China', 2016, 11233.28),
#  ('China', 2017, 12310.41),
#  ('China', 2018, 13894.82),
#  ('China', 2019, 14279.94),
#  ('China', 2020, 14687.67),
#  ("Democratic People's Republic of Korea", 2015, None),
#  ("Democratic People's Republic of Korea", 2016, None),
#  ("Democratic People's Republic of Korea", 2017, None),
#  ("Democratic People's Republic of Korea", 2018, None),
#  ("Democratic People's Republic of Korea", 2019, None),
#  ("Democratic People's Republic of Korea", 2020, None),
#  ('Japan', 2015, 4444.93),
#  ('Japan', 2016, 5003.68),
#  ('Japan', 2017, 4930.84),
#  ('Japan', 2018, 5037.84),
#  ('Japan', 2019, 5123.32),
#  ('Japan', 2020, 5040.11),
#  ('Mongolia', 2015, 11.62),
#  ('Mongolia', 2016, 11.18),
#  ('Mongolia', 2017, 11.48),
#  ('Mongolia', 2018, 13.18),
#  ('Mongolia', 2019, 14.21),
#  ('Mongolia', 2020, 13.31),
#  ('Republic of Korea', 2015, None),
#  ('Republic of Korea', 2016, None),
#  ('Republic of Korea', 2017, None),
#  ('Republic of Korea', 2018, None),
#  ('Republic of Korea', 2019, None),
#  ('Republic of Korea', 2020, None),
#  ('Brunei Darussalam', 2015, 12.93),
#  ('Brunei Darussalam', 2016, 11.4),
#  ('Brunei Darussalam', 2017, 12.13),
#  ('Brunei Darussalam', 2018, 13.57),
#  ('Brunei Darussalam', 2019, 13.47),
#  ('Brunei Darussalam', 2020, 12.01),
#  ('Cambodia', 2015, 18.05),
#  ('Cambodia', 2016, 20.02),
#  ('Cambodia', 2017, 22.18),
#  ('Cambodia', 2018, 24.57),
#  ('Cambodia', 2019, 27.09),
#  ('Cambodia', 2020, 25.87),
#  ('Indonesia', 2015, 860.85),
#  ('Indonesia', 2016, 931.88),
#  ('Indonesia', 2017, 1015.62),
#  ('Indonesia', 2018, 1042.27),
#  ('Indonesia', 2019, 1119.1),
#  ('Indonesia', 2020, 1058.69),
#  ("Lao People's Democratic Republic", 2015, None),
#  ("Lao People's Democratic Republic", 2016, None),
#  ("Lao People's Democratic Republic", 2017, None),
#  ("Lao People's Democratic Republic", 2018, None),
#  ("Lao People's Democratic Republic", 2019, None),
#  ("Lao People's Democratic Republic", 2020, None),
#  ('Malaysia', 2015, 301.35),
#  ('Malaysia', 2016, 301.26),
#  ('Malaysia', 2017, 319.11),
#  ('Malaysia', 2018, 358.79),
#  ('Malaysia', 2019, 365.18),
#  ('Malaysia', 2020, 337.34),
#  ('Myanmar', 2015, 63.05),
#  ('Myanmar', 2016, 60.29),
#  ('Myanmar', 2017, 61.45),
#  ('Myanmar', 2018, 67.14),
#  ('Myanmar', 2019, 68.7),
#  ('Myanmar', 2020, 78.93),
#  ('Philippines', 2015, 306.45),
#  ('Philippines', 2016, 318.63),
#  ('Philippines', 2017, 328.48),
#  ('Philippines', 2018, 346.84),
#  ('Philippines', 2019, 376.82),
#  ('Philippines', 2020, 361.75),
#  ('Singapore', 2015, 308.0),
#  ('Singapore', 2016, 318.83),
#  ('Singapore', 2017, 343.19),
#  ('Singapore', 2018, 377.0),
#  ('Singapore', 2019, 375.47),
#  ('Singapore', 2020, 345.3),
#  ('Thailand', 2015, 401.3),
#  ('Thailand', 2016, 413.37),
#  ('Thailand', 2017, 456.36),
#  ('Thailand', 2018, 506.75),
#  ('Thailand', 2019, 544.08),
#  ('Thailand', 2020, 499.68),
#  ('Timor-Leste', 2015, 1.59),
#  ('Timor-Leste', 2016, 1.65),
#  ('Timor-Leste', 2017, 1.6),
#  ('Timor-Leste', 2018, 1.56),
#  ('Timor-Leste', 2019, 2.03),
#  ('Timor-Leste', 2020, 2.16),
#  ('Viet Nam', 2015, None),
#  ('Viet Nam', 2016, None),
#  ('Viet Nam', 2017, None),
#  ('Viet Nam', 2018, None),
#  ('Viet Nam', 2019, None),
#  ('Viet Nam', 2020, None),
#  ('Bermuda', 2015, 6.65),
#  ('Bermuda', 2016, 6.9),
#  ('Bermuda', 2017, 7.14),
#  ('Bermuda', 2018, 7.23),
#  ('Bermuda', 2019, 7.42),
#  ('Bermuda', 2020, 6.89),
#  ('Canada', 2015, 1556.51),
#  ('Canada', 2016, 1527.99),
#  ('Canada', 2017, 1649.27),
#  ('Canada', 2018, 1725.33),
#  ('Canada', 2019, 1742.02),
#  ('Canada', 2020, 1645.42),
#  ('Greenland', 2015, 2.5),
#  ('Greenland', 2016, 2.71),
#  ('Greenland', 2017, 2.85),
#  ('Greenland', 2018, 3.06),
#  ('Greenland', 2019, 2.99),
#  ('Greenland', 2020, 3.08),
#  ('Saint Pierre and Miquelon', 2015, None),
#  ('Saint Pierre and Miquelon', 2016, None),
#  ('Saint Pierre and Miquelon', 2017, None),
#  ('Saint Pierre and Miquelon', 2018, None),
#  ('Saint Pierre and Miquelon', 2019, None),
#  ('Saint Pierre and Miquelon', 2020, None),
#  ('United States of America', 2015, None),
#  ('United States of America', 2016, None),
#  ('United States of America', 2017, None),
#  ('United States of America', 2018, None),
#  ('United States of America', 2019, None),
#  ('United States of America', 2020, None),
#  ('Anguilla', 2015, None),
#  ('Anguilla', 2016, None),
#  ('Anguilla', 2017, None),
#  ('Antigua and Barbuda', 2015, 1.34),
#  ('Antigua and Barbuda', 2016, 1.44),
#  ('Antigua and Barbuda', 2017, 1.47),
#  ('Aruba', 2015, 2.96),
#  ('Aruba', 2016, 2.98),
#  ('Bahamas', 2015, None),
#  ('Bahamas', 2016, None),
#  ('Bahamas', 2017, None),
#  ('Bahamas', 2018, None),
#  ('Bahamas', 2019, None),
#  ('Barbados', 2015, 4.72),
#  ('Barbados', 2016, 4.83),
#  ('Barbados', 2017, 4.98),
#  ('Barbados', 2018, 5.1),
#  ('Barbados', 2019, 5.32),
#  ('Barbados', 2020, 4.67),
#  ('British Virgin Islands', 2015, None),
#  ('British Virgin Islands', 2016, None),
#  ('British Virgin Islands', 2017, None),
#  ('British Virgin Islands', 2018, None),
#  ('British Virgin Islands', 2019, None),
#  ('British Virgin Islands', 2020, None),
#  ('Cayman Islands', 2015, 4.71),
#  ('Cayman Islands', 2016, 4.91),
#  ('Cuba', 2015, 87.13),
#  ('Cuba', 2016, 91.37),
#  ('Cuba', 2017, 96.85),
#  ('Cuba', 2018, 100.05),
#  ('Cuba', 2019, 103.43),
#  ('Cuba', 2020, 107.35),
#  ('CuraÃ§ao', 2015, None),
#  ('CuraÃ§ao', 2016, None),
#  ('CuraÃ§ao', 2017, None),
#  ('Dominica', 2015, 0.54),
#  ('Dominica', 2016, 0.58),
#  ('Dominica', 2017, 0.52),
#  ('Dominican Republic', 2015, 71.16),
#  ('Dominican Republic', 2016, 75.7),
#  ('Dominican Republic', 2017, 80.0),
#  ('Dominican Republic', 2018, 85.56),
#  ('Dominican Republic', 2019, 88.94),
#  ('Dominican Republic', 2020, 78.84),
#  ('Grenada', 2015, 1.0),
#  ('Grenada', 2016, 1.06),
#  ('Grenada', 2017, 1.13),
#  ('Guadeloupe', 2015, None),
#  ('Guadeloupe', 2016, None),
#  ('Guadeloupe', 2017, None),
#  ('Guadeloupe', 2018, None),
#  ('Guadeloupe', 2019, None),
#  ('Guadeloupe', 2020, None),
#  ('Haiti', 2015, 14.83),
#  ('Haiti', 2016, 13.99),
#  ('Haiti', 2017, 15.04),
#  ('Haiti', 2018, 16.46),
#  ('Haiti', 2019, 14.79),
#  ('Haiti', 2020, 14.51),
#  ('Jamaica', 2015, 14.19),
#  ('Jamaica', 2016, 14.08),
#  ('Jamaica', 2017, 14.81),
#  ('Jamaica', 2018, 15.73),
#  ('Jamaica', 2019, 15.83),
#  ('Jamaica', 2020, 13.81),
#  ('Martinique', 2015, None),
#  ('Martinique', 2016, None),
#  ('Martinique', 2017, None),
#  ('Martinique', 2018, None),
#  ('Martinique', 2019, None),
#  ('Martinique', 2020, None),
#  ('Montserrat', 2015, None),
#  ('Montserrat', 2016, None),
#  ('Montserrat', 2017, None),
#  ('Montserrat', 2018, None),
#  ('Montserrat', 2019, None),
#  ('Montserrat', 2020, None),
#  ('Puerto Rico', 2015, 103.38),
#  ('Puerto Rico', 2016, 104.34),
#  ('Puerto Rico', 2017, 103.45),
#  ('Puerto Rico', 2018, 100.96),
#  ('Puerto Rico', 2019, 105.13),
#  ('Puerto Rico', 2020, 103.02),
#  ('Saint BarthÃ©lemy', 2015, None),
#  ('Saint BarthÃ©lemy', 2016, None),
#  ('Saint BarthÃ©lemy', 2017, None),
#  ('Saint BarthÃ©lemy', 2018, None),
#  ('Saint BarthÃ©lemy', 2019, None),
#  ('Saint BarthÃ©lemy', 2020, None),
#  ('Saint Kitts and Nevis', 2015, None),
#  ('Saint Kitts and Nevis', 2016, None),
#  ('Saint Kitts and Nevis', 2017, None),
#  ('Saint Lucia', 2015, None),
#  ('Saint Lucia', 2016, None),
#  ('Saint Lucia', 2017, None),
#  ('Saint Lucia', 2018, None),
#  ('Saint Lucia', 2019, None),
#  ('Saint Lucia', 2020, None),
#  ('Saint Martin (French Part)', 2015, None),
#  ('Saint Martin (French Part)', 2016, None),
#  ('Saint Martin (French Part)', 2017, None),
#  ('Saint Martin (French Part)', 2018, None),
#  ('Saint Martin (French Part)', 2019, None),
#  ('Saint Martin (French Part)', 2020, None),
#  ('Saint Vincent and the Grenadines', 2015, None),
#  ('Saint Vincent and the Grenadines', 2016, None),
#  ('Saint Vincent and the Grenadines', 2017, None),
#  ('Saint Vincent and the Grenadines', 2018, None),
#  ('Sint Maarten (Dutch part)', 2015, 1.25),
#  ('Sint Maarten (Dutch part)', 2016, 1.26),
#  ('Sint Maarten (Dutch part)', 2017, 1.19),
#  ('Trinidad and Tobago', 2015, 26.85),
#  ('Trinidad and Tobago', 2016, 23.5),
#  ('Trinidad and Tobago', 2017, 23.8),
#  ('Trinidad and Tobago', 2018, 24.32),
#  ('Trinidad and Tobago', 2019, 23.85),
#  ('Trinidad and Tobago', 2020, 21.06),
#  ('Turks and Caicos Islands', 2015, 0.94),
#  ('Turks and Caicos Islands', 2016, 1.03),
#  ('Turks and Caicos Islands', 2017, 1.02),
#  ('Turks and Caicos Islands', 2018, 1.11),
#  ('United States Virgin Islands', 2015, None),
#  ('United States Virgin Islands', 2016, None),
#  ('United States Virgin Islands', 2017, None),
#  ('United States Virgin Islands', 2018, None),
#  ('United States Virgin Islands', 2019, None),
#  ('United States Virgin Islands', 2020, None),
#  ('Belize', 2015, 2.21),
#  ('Belize', 2016, 2.26),
#  ('Belize', 2017, 2.29),
#  ('Belize', 2018, 2.31),
#  ('Belize', 2019, 2.42),
#  ('Belize', 2020, 2.08),
#  ('Costa Rica', 2015, 56.44),
#  ('Costa Rica', 2016, 58.85),
#  ('Costa Rica', 2017, 60.52),
#  ('Costa Rica', 2018, 62.42),
#  ('Costa Rica', 2019, 64.42),
#  ('Costa Rica', 2020, 62.16),
#  ('El Salvador', 2015, 23.44),
#  ('El Salvador', 2016, 24.19),
#  ('El Salvador', 2017, 24.98),
#  ('El Salvador', 2018, 26.02),
#  ('El Salvador', 2019, 26.88),
#  ('El Salvador', 2020, 24.56),
#  ('Guatemala', 2015, 62.19),
#  ('Guatemala', 2016, 66.05),
#  ('Guatemala', 2017, 71.65),
#  ('Guatemala', 2018, 73.33),
#  ('Guatemala', 2019, 77.17),
#  ('Guatemala', 2020, 77.63),
#  ('Honduras', 2015, 20.98),
#  ('Honduras', 2016, 21.72),
#  ('Honduras', 2017, 23.14),
#  ('Honduras', 2018, 24.07),
#  ('Honduras', 2019, 25.09),
#  ('Honduras', 2020, 23.83),
#  ('Mexico', 2015, 1171.87),
#  ('Mexico', 2016, 1078.49),
#  ('Mexico', 2017, 1158.91),
#  ('Mexico', 2018, 1222.41),
#  ('Mexico', 2019, 1269.01),
#  ('Mexico', 2020, 1090.52),
#  ('Nicaragua', 2015, 12.76),
#  ('Nicaragua', 2016, 13.29),
#  ('Nicaragua', 2017, 13.79),
#  ('Nicaragua', 2018, 13.03),
#  ('Nicaragua', 2019, 12.6),
#  ('Nicaragua', 2020, 12.59),
#  ('Panama', 2015, 54.09),
#  ('Panama', 2016, 57.91),
#  ('Panama', 2017, 62.2),
#  ('Panama', 2018, 64.93),
#  ('Panama', 2019, 66.98),
#  ('Panama', 2020, 53.98),
#  ('Argentina', 2015, 594.75),
#  ('Argentina', 2016, 557.53),
#  ('Argentina', 2017, 643.63),
#  ('Argentina', 2018, 524.82),
#  ('Argentina', 2019, 447.75),
#  ('Argentina', 2020, 385.54),
#  ('Bolivia (Plurinational State of)', 2015, None),
#  ('Bolivia (Plurinational State of)', 2016, None),
#  ('Bolivia (Plurinational State of)', 2017, None),
#  ('Bolivia (Plurinational State of)', 2018, None),
#  ('Bolivia (Plurinational State of)', 2019, None),
#  ('Bolivia (Plurinational State of)', 2020, None),
#  ('Brazil', 2015, 1802.21),
#  ('Brazil', 2016, 1795.7),
#  ('Brazil', 2017, 2063.51),
#  ('Brazil', 2018, 1916.95),
#  ('Brazil', 2019, 1873.27),
#  ('Brazil', 2020, 1448.56),
#  ('Chile', 2015, 242.5),
#  ('Chile', 2016, 249.3),
#  ('Chile', 2017, 276.36),
#  ('Chile', 2018, 295.4),
#  ('Chile', 2019, 278.58),
#  ('Chile', 2020, 252.73),
#  ('Colombia', 2015, 293.48),
#  ('Colombia', 2016, 282.83),
#  ('Colombia', 2017, 311.88),
#  ('Colombia', 2018, 334.2),
#  ('Colombia', 2019, 323.11),
#  ('Colombia', 2020, 270.3),
#  ('Ecuador', 2015, 99.29),
#  ('Ecuador', 2016, 99.94),
#  ('Ecuador', 2017, 104.3),
#  ('Ecuador', 2018, 107.56),
#  ('Ecuador', 2019, 108.11),
#  ('Ecuador', 2020, 99.29),
#  ('Falkland Islands (Malvinas)', 2015, None),
#  ('Falkland Islands (Malvinas)', 2016, None),
#  ('Falkland Islands (Malvinas)', 2017, None),
#  ('Falkland Islands (Malvinas)', 2018, None),
#  ('Falkland Islands (Malvinas)', 2019, None),
#  ('Falkland Islands (Malvinas)', 2020, None),
#  ('French Guiana', 2015, None),
#  ('French Guiana', 2016, None),
#  ('French Guiana', 2017, None),
#  ('French Guiana', 2018, None),
#  ('French Guiana', 2019, None),
#  ('French Guiana', 2020, None),
#  ('Guyana', 2015, 4.28),
#  ('Guyana', 2016, 4.48),
#  ('Guyana', 2017, 4.75),
#  ('Guyana', 2018, 4.79),
#  ('Guyana', 2019, 5.17),
#  ('Guyana', 2020, 5.47),
#  ('Paraguay', 2015, 36.21),
#  ('Paraguay', 2016, 36.09),
#  ('Paraguay', 2017, 39.0),
#  ('Paraguay', 2018, 40.23),
#  ('Paraguay', 2019, 37.93),
#  ('Paraguay', 2020, 35.43),
#  ('Peru', 2015, 189.81),
#  ('Peru', 2016, 191.9),
#  ('Peru', 2017, 211.01),
#  ('Peru', 2018, 222.6),
#  ('Peru', 2019, 228.32),
#  ('Peru', 2020, 201.71),
#  ('Suriname', 2015, 5.13),
#  ('Suriname', 2016, 3.32),
#  ('Suriname', 2017, 3.59),
#  ('Suriname', 2018, 4.0),
#  ('Suriname', 2019, 4.02),
#  ('Suriname', 2020, 2.91),
#  ('Uruguay', 2015, 53.27),
#  ('Uruguay', 2016, 57.24),
#  ('Uruguay', 2017, 64.23),
#  ('Uruguay', 2018, 64.52),
#  ('Uruguay', 2019, 61.23),
#  ('Uruguay', 2020, 53.56),
#  ('Venezuela (Bolivarian Republic of)', 2015, None),
#  ('Venezuela (Bolivarian Republic of)', 2016, None),
#  ('Venezuela (Bolivarian Republic of)', 2017, None),
#  ('Venezuela (Bolivarian Republic of)', 2018, None),
#  ('Venezuela (Bolivarian Republic of)', 2019, None),
#  ('Venezuela (Bolivarian Republic of)', 2020, None),
#  ('Algeria', 2015, 165.98),
#  ('Algeria', 2016, 160.03),
#  ('Algeria', 2017, 170.1),
#  ('Algeria', 2018, 174.91),
#  ('Algeria', 2019, 171.77),
#  ('Algeria', 2020, 145.01),
#  ('Egypt', 2015, None),
#  ('Egypt', 2016, None),
#  ('Egypt', 2017, None),
#  ('Egypt', 2018, None),
#  ('Egypt', 2019, None),
#  ('Egypt', 2020, None),
#  ('Libya', 2015, 48.72),
#  ('Libya', 2016, 49.91),
#  ('Libya', 2017, 67.16),
#  ('Libya', 2018, 76.68),
#  ('Libya', 2019, 69.25),
#  ('Libya', 2020, 50.36),
#  ('Morocco', 2015, 110.41),
#  ('Morocco', 2016, 111.57),
#  ('Morocco', 2017, 118.54),
#  ('Morocco', 2018, 127.34),
#  ('Morocco', 2019, 128.92),
#  ('Morocco', 2020, 121.35),
#  ('Sudan', 2015, 84.99),
#  ('Sudan', 2016, 102.94),
#  ('Sudan', 2017, 129.72),
#  ('Sudan', 2018, 32.33),
#  ('Sudan', 2019, 32.34),
#  ('Sudan', 2020, 27.03),
#  ('Tunisia', 2015, 45.78),
#  ('Tunisia', 2016, 44.36),
#  ('Tunisia', 2017, 42.16),
#  ('Tunisia', 2018, 42.69),
#  ('Tunisia', 2019, 41.91),
#  ('Tunisia', 2020, 42.54),
#  ('Armenia', 2015, 10.55),
#  ('Armenia', 2016, 10.55),
#  ('Armenia', 2017, 11.53),
#  ('Armenia', 2018, 12.46),
#  ('Armenia', 2019, 13.62),
#  ('Armenia', 2020, 12.64),
#  ('Azerbaijan', 2015, 53.07),
#  ('Azerbaijan', 2016, 37.87),
#  ('Azerbaijan', 2017, 40.87),
#  ('Azerbaijan', 2018, 47.11),
#  ('Azerbaijan', 2019, 48.17),
#  ('Azerbaijan', 2020, 42.69),
#  ('Bahrain', 2015, 31.05),
#  ('Bahrain', 2016, 32.23),
#  ('Bahrain', 2017, 35.47),
#  ('Bahrain', 2018, 37.8),
#  ('Bahrain', 2019, 38.65),
#  ('Bahrain', 2020, 34.72),
#  ('Cyprus', 2015, 19.91),
#  ('Cyprus', 2016, 21.05),
#  ('Cyprus', 2017, 22.95),
#  ('Cyprus', 2018, 25.6),
#  ('Cyprus', 2019, 25.94),
#  ('Cyprus', 2020, 25.01),
#  ('Georgia', 2015, 14.95),
#  ('Georgia', 2016, 15.14),
#  ('Georgia', 2017, 16.24),
#  ('Georgia', 2018, 17.6),
#  ('Georgia', 2019, 17.47),
#  ('Georgia', 2020, 15.84),
#  ('Iraq', 2015, 166.77),
#  ('Iraq', 2016, 166.6),
#  ('Iraq', 2017, 187.22),
#  ('Iraq', 2018, 227.37),
#  ('Iraq', 2019, 233.64),
#  ('Iraq', 2020, 184.37),
#  ('Israel', 2015, 303.41),
#  ('Israel', 2016, 322.1),
#  ('Israel', 2017, 358.25),
#  ('Israel', 2018, 376.69),
#  ('Israel', 2019, 402.47),
#  ('Israel', 2020, 413.27),
#  ('Jordan', 2015, 38.59),
#  ('Jordan', 2016, 39.89),
#  ('Jordan', 2017, 41.61),
#  ('Jordan', 2018, 43.37),
#  ('Jordan', 2019, 44.99),
#  ('Jordan', 2020, 44.18),
#  ('Kuwait', 2015, 114.57),
#  ('Kuwait', 2016, 109.42),
#  ('Kuwait', 2017, 120.71),
#  ('Kuwait', 2018, 138.18),
#  ('Kuwait', 2019, 136.2),
#  ('Kuwait', 2020, 105.96),
#  ('Lebanon', 2015, 49.93),
#  ('Lebanon', 2016, 51.15),
#  ('Lebanon', 2017, 53.03),
#  ('Lebanon', 2018, 54.9),
#  ('Lebanon', 2019, 51.95),
#  ('Lebanon', 2020, 31.71),
#  ('Oman', 2015, 78.71),
#  ('Oman', 2016, 75.13),
#  ('Oman', 2017, 80.86),
#  ('Oman', 2018, 91.51),
#  ('Oman', 2019, 88.06),
#  ('Oman', 2020, 75.91),
#  ('Qatar', 2015, 161.74),
#  ('Qatar', 2016, 151.73),
#  ('Qatar', 2017, 161.1),
#  ('Qatar', 2018, 183.33),
#  ('Qatar', 2019, 175.84),
#  ('Qatar', 2020, 144.41),
#  ('Saudi Arabia', 2015, 654.27),
#  ('Saudi Arabia', 2016, 644.94),
#  ('Saudi Arabia', 2017, 688.59),
#  ('Saudi Arabia', 2018, 816.58),
#  ('Saudi Arabia', 2019, 803.62),
#  ('Saudi Arabia', 2020, 703.37),
#  ('State of Palestine', 2015, None),
#  ('State of Palestine', 2016, None),
#  ('State of Palestine', 2017, None),
#  ('State of Palestine', 2018, None),
#  ('State of Palestine', 2019, None),
#  ('State of Palestine', 2020, None),
#  ('Syrian Arab Republic', 2015, 16.47),
#  ('Syrian Arab Republic', 2016, 12.6),
#  ('Syrian Arab Republic', 2017, 16.37),
#  ('Syrian Arab Republic', 2018, 21.35),
#  ('Syrian Arab Republic', 2019, 22.44),
#  ('Syrian Arab Republic', 2020, 11.08),
#  ('TÃ¼rkiye', 2015, None),
#  ('TÃ¼rkiye', 2016, None),
#  ('TÃ¼rkiye', 2017, None),
#  ('TÃ¼rkiye', 2018, None),
#  ('TÃ¼rkiye', 2019, None),
#  ('TÃ¼rkiye', 2020, None),
#  ('United Arab Emirates', 2015, 370.28),
#  ('United Arab Emirates', 2016, 369.26),
#  ('United Arab Emirates', 2017, 390.52),
#  ('United Arab Emirates', 2018, 427.05),
#  ('United Arab Emirates', 2019, 417.99),
#  ('United Arab Emirates', 2020, 349.47),
#  ('Yemen', 2015, None),
#  ('Yemen', 2016, None),
#  ('Yemen', 2017, None),
#  ('Yemen', 2018, None),
#  ('Yemen', 2019, None),
#  ('Yemen', 2020, None),
#  ('Australia', 2015, 1350.62),
#  ('Australia', 2016, 1206.54),
#  ('Australia', 2017, 1326.52),
#  ('Australia', 2018, 1428.29),
#  ('Australia', 2019, 1392.23),
#  ('Australia', 2020, 1326.9),
#  ('New Zealand', 2015, 178.06),
#  ('New Zealand', 2016, 188.84),
#  ('New Zealand', 2017, 206.62),
#  ('New Zealand', 2018, 211.95),
#  ('New Zealand', 2019, 213.43),
#  ('New Zealand', 2020, 211.73),
#  ('Fiji', 2015, 4.68),
#  ('Fiji', 2016, 4.93),
#  ('Fiji', 2017, 5.35),
#  ('Fiji', 2018, 5.58),
#  ('Fiji', 2019, 5.48),
#  ('Fiji', 2020, 4.48),
#  ('New Caledonia', 2015, 8.74),
#  ('New Caledonia', 2016, 8.72),
#  ('New Caledonia', 2017, 9.17),
#  ('New Caledonia', 2018, 9.85),
#  ('New Caledonia', 2019, 9.44),
#  ('New Caledonia', 2020, 9.44),
#  ('Papua New Guinea', 2015, 21.72),
#  ('Papua New Guinea', 2016, 20.76),
#  ('Papua New Guinea', 2017, 22.74),
#  ('Papua New Guinea', 2018, 24.11),
#  ('Papua New Guinea', 2019, 24.75),
#  ('Papua New Guinea', 2020, 23.85),
#  ('Solomon Islands', 2015, 1.31),
#  ('Solomon Islands', 2016, 1.38),
#  ('Solomon Islands', 2017, 1.47),
#  ('Solomon Islands', 2018, 1.62),
#  ('Solomon Islands', 2019, 1.62),
#  ('Solomon Islands', 2020, 1.54),
#  ('Vanuatu', 2015, 0.73),
#  ('Vanuatu', 2016, 0.78),
#  ('Vanuatu', 2017, 0.88),
#  ('Vanuatu', 2018, 0.91),
#  ('Vanuatu', 2019, 0.94),
#  ('Vanuatu', 2020, 0.9),
#  ('Guam', 2015, 5.8),
#  ('Guam', 2016, 5.9),
#  ('Guam', 2017, 6.01),
#  ('Guam', 2018, 6.06),
#  ('Guam', 2019, 6.37),
#  ('Guam', 2020, 5.89),
#  ('Kiribati', 2015, 0.17),
#  ('Kiribati', 2016, 0.18),
#  ('Kiribati', 2017, 0.19),
#  ('Kiribati', 2018, 0.2),
#  ('Kiribati', 2019, 0.18),
#  ('Kiribati', 2020, 0.18),
#  ('Marshall Islands', 2015, 0.18),
#  ('Marshall Islands', 2016, 0.2),
#  ('Marshall Islands', 2017, 0.21),
#  ('Marshall Islands', 2018, 0.22),
#  ('Marshall Islands', 2019, 0.23),
#  ('Marshall Islands', 2020, 0.24),
#  ('Micronesia (Federated States of)', 2015, None),
#  ('Micronesia (Federated States of)', 2016, None),
#  ('Micronesia (Federated States of)', 2017, None),
#  ('Micronesia (Federated States of)', 2018, None),
#  ('Micronesia (Federated States of)', 2019, None),
#  ('Nauru', 2015, 0.09),
#  ('Nauru', 2016, 0.1),
#  ('Nauru', 2017, 0.11),
#  ('Nauru', 2018, 0.12),
#  ('Nauru', 2019, 0.12),
#  ('Nauru', 2020, 0.11),
#  ('Northern Mariana Islands', 2015, 0.91),
#  ('Northern Mariana Islands', 2016, 1.23),
#  ('Northern Mariana Islands', 2017, 1.56),
#  ('Northern Mariana Islands', 2018, 1.3),
#  ('Northern Mariana Islands', 2019, 1.18),
#  ('Northern Mariana Islands', 2020, None),
#  ('Palau', 2015, 0.28),
#  ('Palau', 2016, 0.3),
#  ('Palau', 2017, 0.29),
#  ('Palau', 2018, 0.28),
#  ('Palau', 2019, 0.28),
#  ('Palau', 2020, 0.25),
#  ('American Samoa', 2015, 0.67),
#  ('American Samoa', 2016, 0.67),
#  ('American Samoa', 2017, 0.61),
#  ('American Samoa', 2018, 0.64),
#  ('American Samoa', 2019, 0.65),
#  ('American Samoa', 2020, 0.72),
#  ('Cook Islands', 2015, None),
#  ('Cook Islands', 2016, None),
#  ('Cook Islands', 2017, None),
#  ('Cook Islands', 2018, None),
#  ('Cook Islands', 2019, None),
#  ('Cook Islands', 2020, None),
#  ('French Polynesia', 2015, 5.33),
#  ('French Polynesia', 2016, 5.5),
#  ('French Polynesia', 2017, 5.83),
#  ('French Polynesia', 2018, 6.14),
#  ('French Polynesia', 2019, 6.0),
#  ('French Polynesia', 2020, 5.71),
#  ('Niue', 2015, None),
#  ('Niue', 2016, None),
#  ('Niue', 2017, None),
#  ('Niue', 2018, None),
#  ('Niue', 2019, None),
#  ('Niue', 2020, None),
#  ('Samoa', 2015, 0.82),
#  ('Samoa', 2016, 0.84),
#  ('Samoa', 2017, 0.88),
#  ('Samoa', 2018, 0.88),
#  ('Samoa', 2019, 0.91),
#  ('Samoa', 2020, 0.87),
#  ('Tokelau', 2015, None),
#  ('Tokelau', 2016, None),
#  ('Tokelau', 2017, None),
#  ('Tokelau', 2018, None),
#  ('Tokelau', 2019, None),
#  ('Tokelau', 2020, None),
#  ('Tonga', 2015, 0.44),
#  ('Tonga', 2016, 0.42),
#  ('Tonga', 2017, 0.46),
#  ('Tonga', 2018, 0.49),
#  ('Tonga', 2019, 0.51),
#  ('Tonga', 2020, 0.48),
#  ('Tuvalu', 2015, 0.04),
#  ('Tuvalu', 2016, 0.04),
#  ('Tuvalu', 2017, 0.05),
#  ('Tuvalu', 2018, 0.05),
#  ('Tuvalu', 2019, 0.05),
#  ('Tuvalu', 2020, 0.06),
#  ('Wallis and Futuna Islands', 2015, None),
#  ('Wallis and Futuna Islands', 2016, None),
#  ('Wallis and Futuna Islands', 2017, None),
#  ('Wallis and Futuna Islands', 2018, None),
#  ('Wallis and Futuna Islands', 2019, None),
#  ('Wallis and Futuna Islands', 2020, None),
#  ('Burundi', 2015, 3.1),
#  ('Burundi', 2016, 2.64),
#  ('Burundi', 2017, 2.71),
#  ('Burundi', 2018, 2.66),
#  ('Burundi', 2019, 2.58),
#  ('Burundi', 2020, 2.65),
#  ('Comoros', 2015, 0.97),
#  ('Comoros', 2016, 1.01),
#  ('Comoros', 2017, 1.08),
#  ('Comoros', 2018, 1.19),
#  ('Comoros', 2019, 1.2),
#  ('Djibouti', 2015, 2.42),
#  ('Djibouti', 2016, 2.6),
#  ('Djibouti', 2017, 2.76),
#  ('Djibouti', 2018, 2.91),
#  ('Djibouti', 2019, 3.09),
#  ('Djibouti', 2020, 3.18),
#  ('Eritrea', 2015, None),
#  ('Eritrea', 2016, None),
#  ('Ethiopia', 2015, 64.59),
#  ('Ethiopia', 2016, 74.3),
#  ('Ethiopia', 2017, 81.77),
#  ('Ethiopia', 2018, 84.27),
#  ('Ethiopia', 2019, 95.91),
#  ('Ethiopia', 2020, 107.66),
#  ('Kenya', 2015, 70.12),
#  ('Kenya', 2016, 74.82),
#  ('Kenya', 2017, 82.04),
#  ('Kenya', 2018, 92.2),
#  ('Kenya', 2019, 100.38),
#  ('Kenya', 2020, 100.67),
#  ('Madagascar', 2015, 11.32),
#  ('Madagascar', 2016, 11.85),
#  ('Madagascar', 2017, 13.18),
#  ('Madagascar', 2018, 13.76),
#  ('Madagascar', 2019, 14.1),
#  ('Madagascar', 2020, 13.05),
#  ('Malawi', 2015, 6.37),
#  ('Malawi', 2016, 5.43),
#  ('Malawi', 2017, 8.94),
#  ('Malawi', 2018, 9.88),
#  ('Malawi', 2019, 11.03),
#  ('Malawi', 2020, 12.18),
#  ('Mauritius', 2015, 12.01),
#  ('Mauritius', 2016, 12.59),
#  ('Mauritius', 2017, 13.71),
#  ('Mauritius', 2018, 14.74),
#  ('Mauritius', 2019, 14.44),
#  ('Mauritius', 2020, 11.4),
#  ('Mayotte', 2015, None),
#  ('Mayotte', 2016, None),
#  ('Mayotte', 2017, None),
#  ('Mayotte', 2018, None),
#  ('Mayotte', 2019, None),
#  ('Mayotte', 2020, None),
#  ('Mozambique', 2015, 15.95),
#  ('Mozambique', 2016, 11.94),
#  ('Mozambique', 2017, 13.22),
#  ('Mozambique', 2018, 14.85),
#  ('Mozambique', 2019, 15.39),
#  ('Mozambique', 2020, 14.03),
#  ('Rwanda', 2015, 8.54),
#  ('Rwanda', 2016, 8.69),
#  ('Rwanda', 2017, 9.25),
#  ('Rwanda', 2018, 9.64),
#  ('Rwanda', 2019, 10.36),
#  ('Rwanda', 2020, 10.18),
#  ('RÃ©union', 2015, None),
#  ('RÃ©union', 2016, None),
#  ('RÃ©union', 2017, None),
#  ('RÃ©union', 2018, None),
#  ('RÃ©union', 2019, None),
#  ('RÃ©union', 2020, None),
#  ('Seychelles', 2015, 1.42),
#  ('Seychelles', 2016, 1.49),
#  ('Seychelles', 2017, 1.57),
#  ('Seychelles', 2018, 1.64),
#  ('Seychelles', 2019, 1.68),
#  ('Somalia', 2015, 5.33),
#  ('Somalia', 2016, 5.53),
#  ('Somalia', 2017, 5.61),
#  ('Somalia', 2018, 5.86),
#  ('Somalia', 2019, 6.49),
#  ('Somalia', 2020, 6.88),
#  ('South Sudan', 2015, 12.0),
#  ('South Sudan', 2016, None),
#  ('South Sudan', 2017, None),
#  ('South Sudan', 2018, None),
#  ('South Sudan', 2019, None),
#  ('South Sudan', 2020, None),
#  ('Uganda', 2015, 32.39),
#  ('Uganda', 2016, 29.2),
#  ('Uganda', 2017, 30.74),
#  ('Uganda', 2018, 32.93),
#  ('Uganda', 2019, 35.35),
#  ('Uganda', 2020, 37.6),
#  ('United Republic of Tanzania', 2015, None),
#  ('United Republic of Tanzania', 2016, None),
#  ('United Republic of Tanzania', 2017, None),
#  ('United Republic of Tanzania', 2018, None),
#  ('United Republic of Tanzania', 2019, None),
#  ('United Republic of Tanzania', 2020, None),
#  ('Zambia', 2015, 21.25),
#  ('Zambia', 2016, 20.96),
#  ('Zambia', 2017, 25.87),
#  ('Zambia', 2018, 26.31),
#  ('Zambia', 2019, 23.31),
#  ('Zambia', 2020, 18.11),
#  ('Zimbabwe', 2015, 19.96),
#  ('Zimbabwe', 2016, 20.55),
#  ('Zimbabwe', 2017, 17.58),
#  ('Zimbabwe', 2018, 34.16),
#  ('Zimbabwe', 2019, 21.83),
#  ('Zimbabwe', 2020, 21.51),
#  ('Angola', 2015, 87.22),
#  ('Angola', 2016, 49.84),
#  ('Angola', 2017, 68.97),
#  ('Angola', 2018, 77.79),
#  ('Angola', 2019, 69.31),
#  ('Angola', 2020, 53.62),
#  ('Cameroon', 2015, 32.21),
#  ('Cameroon', 2016, 33.81),
#  ('Cameroon', 2017, 36.1),
#  ('Cameroon', 2018, 39.97),
#  ('Cameroon', 2019, 39.67),
#  ('Cameroon', 2020, 40.77),
#  ('Central African Republic', 2015, 1.7),
#  ('Central African Republic', 2016, 1.83),
#  ('Central African Republic', 2017, 2.07),
#  ('Central African Republic', 2018, 2.22),
#  ('Central African Republic', 2019, 2.22),
#  ('Central African Republic', 2020, 2.33),
#  ('Chad', 2015, 10.95),
#  ('Chad', 2016, 10.1),
#  ('Chad', 2017, 10.0),
#  ('Chad', 2018, 11.24),
#  ('Chad', 2019, 11.31),
#  ('Chad', 2020, 10.72),
#  ('Congo', 2015, None),
#  ('Congo', 2016, None),
#  ('Congo', 2017, None),
#  ('Congo', 2018, None),
#  ('Congo', 2019, None),
#  ('Congo', 2020, None),
#  ('Democratic Republic of the Congo', 2015, None),
#  ('Democratic Republic of the Congo', 2016, None),
#  ('Democratic Republic of the Congo', 2017, None),
#  ('Democratic Republic of the Congo', 2018, None),
#  ('Democratic Republic of the Congo', 2019, None),
#  ('Democratic Republic of the Congo', 2020, None),
#  ('Equatorial Guinea', 2015, 13.19),
#  ('Equatorial Guinea', 2016, 11.24),
#  ('Equatorial Guinea', 2017, 12.2),
#  ('Gabon', 2015, 14.38),
#  ('Gabon', 2016, 14.02),
#  ('Gabon', 2017, 14.93),
#  ('Gabon', 2018, 16.87),
#  ('Gabon', 2019, 16.87),
#  ('Gabon', 2020, 15.31),
#  ('Sao Tome and Principe', 2015, 0.32),
#  ('Sao Tome and Principe', 2016, 0.35),
#  ('Sao Tome and Principe', 2017, 0.38),
#  ('Sao Tome and Principe', 2018, 0.41),
#  ('Sao Tome and Principe', 2019, 0.43),
#  ('Sao Tome and Principe', 2020, 0.47),
#  ('Botswana', 2015, 13.53),
#  ('Botswana', 2016, 15.08),
#  ('Botswana', 2017, 16.11),
#  ('Botswana', 2018, 17.03),
#  ('Botswana', 2019, 16.7),
#  ('Botswana', 2020, 14.93),
#  ('Eswatini', 2015, 4.06),
#  ('Eswatini', 2016, 3.82),
#  ('Eswatini', 2017, 4.4),
#  ('Eswatini', 2018, 4.67),
#  ('Eswatini', 2019, 4.5),
#  ('Eswatini', 2020, 3.98),
#  ('Lesotho', 2015, 2.36),
#  ('Lesotho', 2016, 2.11),
#  ('Lesotho', 2017, 2.31),
#  ('Lesotho', 2018, 2.55),
#  ('Lesotho', 2019, 2.45),
#  ('Lesotho', 2020, 2.23),
#  ('Namibia', 2015, 11.34),
#  ('Namibia', 2016, 10.72),
#  ('Namibia', 2017, 12.9),
#  ('Namibia', 2018, 13.68),
#  ('Namibia', 2019, 12.54),
#  ('Namibia', 2020, 10.58),
#  ('South Africa', 2015, 346.71),
#  ('South Africa', 2016, 323.59),
#  ('South Africa', 2017, 381.45),
#  ('South Africa', 2018, 404.16),
#  ('South Africa', 2019, 388.53),
#  ('South Africa', 2020, 337.62),
#  ('Benin', 2015, 11.39),
#  ('Benin', 2016, 11.82),
#  ('Benin', 2017, 12.7),
#  ('Benin', 2018, 14.26),
#  ('Benin', 2019, 14.39),
#  ('Benin', 2020, 15.65),
#  ('Burkina Faso', 2015, 11.83),
#  ('Burkina Faso', 2016, 12.83),
#  ('Burkina Faso', 2017, 14.11),
#  ('Burkina Faso', 2018, 15.89),
#  ('Burkina Faso', 2019, 16.18),
#  ('Burkina Faso', 2020, 17.93),
#  ('Cabo Verde', 2015, 1.6),
#  ('Cabo Verde', 2016, 1.66),
#  ('Cabo Verde', 2017, 1.77),
#  ('Cabo Verde', 2018, 1.97),
#  ('Cabo Verde', 2019, 1.98),
#  ('Cabo Verde', 2020, 1.7),
#  ("CÃ´te d'Ivoire", 2015, None),
#  ("CÃ´te d'Ivoire", 2016, None),
#  ("CÃ´te d'Ivoire", 2017, None),
#  ("CÃ´te d'Ivoire", 2018, None),
#  ("CÃ´te d'Ivoire", 2019, None),
#  ("CÃ´te d'Ivoire", 2020, None),
#  ('Gambia', 2015, None),
#  ('Gambia', 2016, None),
#  ('Gambia', 2017, None),
#  ('Gambia', 2018, None),
#  ('Gambia', 2019, None),
#  ('Gambia', 2020, None),
#  ('Ghana', 2015, 49.41),
#  ('Ghana', 2016, 56.17),
#  ('Ghana', 2017, 60.41),
#  ('Ghana', 2018, 67.3),
#  ('Ghana', 2019, 68.34),
#  ('Ghana', 2020, 70.04),
#  ('Guinea', 2015, 8.79),
#  ('Guinea', 2016, 8.6),
#  ('Guinea', 2017, 10.32),
#  ('Guinea', 2018, 11.86),
#  ('Guinea', 2019, 13.44),
#  ('Guinea', 2020, 14.18),
#  ('Guinea-Bissau', 2015, 1.05),
#  ('Guinea-Bissau', 2016, 1.18),
#  ('Guinea-Bissau', 2017, 1.35),
#  ('Guinea-Bissau', 2018, 1.5),
#  ('Guinea-Bissau', 2019, 1.44),
#  ('Guinea-Bissau', 2020, 1.43),
#  ('Liberia', 2015, 3.23),
#  ('Liberia', 2016, 3.4),
#  ('Liberia', 2017, 3.39),
#  ('Liberia', 2018, 3.42),
#  ('Liberia', 2019, 3.32),
#  ('Liberia', 2020, 3.04),
#  ...]

# %% [markdown]
# **6. What are the rounded-off values of the Est_gdp_in_billions column?**
#
# When looking at many billion-dollar figures, the decimal places can be a little distracting. We can round off the numbers in the Est_gdp_in_billions column to make them more manageable.
#
# Using the same query executed above, round off the values in the Est_gdp_in_billions column using the ROUND function.

# %%
# %%sql
#
# Select Country_name,
#     Time_period,
#     ROUND(Est_gdp_in_billions) AS Rounded_est_gdp_in_billions
# FROM Access_to_Basic_Services;
# Out:
#  * mysql+pymysql://root:***@127.0.0.1:3306/united_nations
# 1048 rows affected.
# [('Kazakhstan', 2015, 184.0),
#  ('Kazakhstan', 2016, 137.0),
#  ('Kazakhstan', 2017, 167.0),
#  ('Kazakhstan', 2018, 179.0),
#  ('Kazakhstan', 2019, 182.0),
#  ('Kazakhstan', 2020, 171.0),
#  ('Kyrgyzstan', 2015, None),
#  ('Kyrgyzstan', 2016, None),
#  ('Kyrgyzstan', 2017, None),
#  ('Kyrgyzstan', 2018, None),
#  ('Kyrgyzstan', 2019, None),
#  ('Kyrgyzstan', 2020, None),
#  ('Tajikistan', 2015, 8.0),
#  ('Tajikistan', 2016, 7.0),
#  ('Tajikistan', 2017, 8.0),
#  ('Tajikistan', 2018, 8.0),
#  ('Tajikistan', 2019, 8.0),
#  ('Tajikistan', 2020, 8.0),
#  ('Turkmenistan', 2015, 36.0),
#  ('Turkmenistan', 2016, 36.0),
#  ('Turkmenistan', 2017, 38.0),
#  ('Turkmenistan', 2018, 41.0),
#  ('Turkmenistan', 2019, 45.0),
#  ('Turkmenistan', 2020, None),
#  ('Uzbekistan', 2015, 86.0),
#  ('Uzbekistan', 2016, 86.0),
#  ('Uzbekistan', 2017, 62.0),
#  ('Uzbekistan', 2018, 53.0),
#  ('Uzbekistan', 2019, 60.0),
#  ('Uzbekistan', 2020, 60.0),
#  ('Afghanistan', 2015, 20.0),
#  ('Afghanistan', 2016, 18.0),
#  ('Afghanistan', 2017, 19.0),
#  ('Afghanistan', 2018, 18.0),
#  ('Afghanistan', 2019, 19.0),
#  ('Afghanistan', 2020, 20.0),
#  ('Bangladesh', 2015, 195.0),
#  ('Bangladesh', 2016, 265.0),
#  ('Bangladesh', 2017, 294.0),
#  ('Bangladesh', 2018, 321.0),
#  ('Bangladesh', 2019, 351.0),
#  ('Bangladesh', 2020, 374.0),
#  ('Bhutan', 2015, 2.0),
#  ('Bhutan', 2016, 2.0),
#  ('Bhutan', 2017, 2.0),
#  ('Bhutan', 2018, 2.0),
#  ('Bhutan', 2019, 3.0),
#  ('Bhutan', 2020, 2.0),
#  ('India', 2015, 2104.0),
#  ('India', 2016, 2295.0),
#  ('India', 2017, 2651.0),
#  ('India', 2018, 2703.0),
#  ('India', 2019, 2832.0),
#  ('India', 2020, 2668.0),
#  ('Iran (Islamic Republic of)', 2015, None),
#  ('Iran (Islamic Republic of)', 2016, None),
#  ('Iran (Islamic Republic of)', 2017, None),
#  ('Iran (Islamic Republic of)', 2018, None),
#  ('Iran (Islamic Republic of)', 2019, None),
#  ('Iran (Islamic Republic of)', 2020, None),
#  ('Maldives', 2015, 4.0),
#  ('Maldives', 2016, 4.0),
#  ('Maldives', 2017, 5.0),
#  ('Maldives', 2018, 5.0),
#  ('Maldives', 2019, 6.0),
#  ('Maldives', 2020, 4.0),
#  ('Nepal', 2015, 24.0),
#  ('Nepal', 2016, 25.0),
#  ('Nepal', 2017, 29.0),
#  ('Nepal', 2018, 33.0),
#  ('Nepal', 2019, 34.0),
#  ('Nepal', 2020, 33.0),
#  ('Pakistan', 2015, 271.0),
#  ('Pakistan', 2016, 314.0),
#  ('Pakistan', 2017, 339.0),
#  ('Pakistan', 2018, 356.0),
#  ('Pakistan', 2019, 321.0),
#  ('Pakistan', 2020, 300.0),
#  ('Sri Lanka', 2015, 85.0),
#  ('Sri Lanka', 2016, 88.0),
#  ('Sri Lanka', 2017, 94.0),
#  ('Sri Lanka', 2018, 94.0),
#  ('Sri Lanka', 2019, 89.0),
#  ('Sri Lanka', 2020, 85.0),
#  ('China', 2015, 11062.0),
#  ('China', 2016, 11233.0),
#  ('China', 2017, 12310.0),
#  ('China', 2018, 13895.0),
#  ('China', 2019, 14280.0),
#  ('China', 2020, 14688.0),
#  ("Democratic People's Republic of Korea", 2015, None),
#  ("Democratic People's Republic of Korea", 2016, None),
#  ("Democratic People's Republic of Korea", 2017, None),
#  ("Democratic People's Republic of Korea", 2018, None),
#  ("Democratic People's Republic of Korea", 2019, None),
#  ("Democratic People's Republic of Korea", 2020, None),
#  ('Japan', 2015, 4445.0),
#  ('Japan', 2016, 5004.0),
#  ('Japan', 2017, 4931.0),
#  ('Japan', 2018, 5038.0),
#  ('Japan', 2019, 5123.0),
#  ('Japan', 2020, 5040.0),
#  ('Mongolia', 2015, 12.0),
#  ('Mongolia', 2016, 11.0),
#  ('Mongolia', 2017, 11.0),
#  ('Mongolia', 2018, 13.0),
#  ('Mongolia', 2019, 14.0),
#  ('Mongolia', 2020, 13.0),
#  ('Republic of Korea', 2015, None),
#  ('Republic of Korea', 2016, None),
#  ('Republic of Korea', 2017, None),
#  ('Republic of Korea', 2018, None),
#  ('Republic of Korea', 2019, None),
#  ('Republic of Korea', 2020, None),
#  ('Brunei Darussalam', 2015, 13.0),
#  ('Brunei Darussalam', 2016, 11.0),
#  ('Brunei Darussalam', 2017, 12.0),
#  ('Brunei Darussalam', 2018, 14.0),
#  ('Brunei Darussalam', 2019, 13.0),
#  ('Brunei Darussalam', 2020, 12.0),
#  ('Cambodia', 2015, 18.0),
#  ('Cambodia', 2016, 20.0),
#  ('Cambodia', 2017, 22.0),
#  ('Cambodia', 2018, 25.0),
#  ('Cambodia', 2019, 27.0),
#  ('Cambodia', 2020, 26.0),
#  ('Indonesia', 2015, 861.0),
#  ('Indonesia', 2016, 932.0),
#  ('Indonesia', 2017, 1016.0),
#  ('Indonesia', 2018, 1042.0),
#  ('Indonesia', 2019, 1119.0),
#  ('Indonesia', 2020, 1059.0),
#  ("Lao People's Democratic Republic", 2015, None),
#  ("Lao People's Democratic Republic", 2016, None),
#  ("Lao People's Democratic Republic", 2017, None),
#  ("Lao People's Democratic Republic", 2018, None),
#  ("Lao People's Democratic Republic", 2019, None),
#  ("Lao People's Democratic Republic", 2020, None),
#  ('Malaysia', 2015, 301.0),
#  ('Malaysia', 2016, 301.0),
#  ('Malaysia', 2017, 319.0),
#  ('Malaysia', 2018, 359.0),
#  ('Malaysia', 2019, 365.0),
#  ('Malaysia', 2020, 337.0),
#  ('Myanmar', 2015, 63.0),
#  ('Myanmar', 2016, 60.0),
#  ('Myanmar', 2017, 61.0),
#  ('Myanmar', 2018, 67.0),
#  ('Myanmar', 2019, 69.0),
#  ('Myanmar', 2020, 79.0),
#  ('Philippines', 2015, 306.0),
#  ('Philippines', 2016, 319.0),
#  ('Philippines', 2017, 328.0),
#  ('Philippines', 2018, 347.0),
#  ('Philippines', 2019, 377.0),
#  ('Philippines', 2020, 362.0),
#  ('Singapore', 2015, 308.0),
#  ('Singapore', 2016, 319.0),
#  ('Singapore', 2017, 343.0),
#  ('Singapore', 2018, 377.0),
#  ('Singapore', 2019, 375.0),
#  ('Singapore', 2020, 345.0),
#  ('Thailand', 2015, 401.0),
#  ('Thailand', 2016, 413.0),
#  ('Thailand', 2017, 456.0),
#  ('Thailand', 2018, 507.0),
#  ('Thailand', 2019, 544.0),
#  ('Thailand', 2020, 500.0),
#  ('Timor-Leste', 2015, 2.0),
#  ('Timor-Leste', 2016, 2.0),
#  ('Timor-Leste', 2017, 2.0),
#  ('Timor-Leste', 2018, 2.0),
#  ('Timor-Leste', 2019, 2.0),
#  ('Timor-Leste', 2020, 2.0),
#  ('Viet Nam', 2015, None),
#  ('Viet Nam', 2016, None),
#  ('Viet Nam', 2017, None),
#  ('Viet Nam', 2018, None),
#  ('Viet Nam', 2019, None),
#  ('Viet Nam', 2020, None),
#  ('Bermuda', 2015, 7.0),
#  ('Bermuda', 2016, 7.0),
#  ('Bermuda', 2017, 7.0),
#  ('Bermuda', 2018, 7.0),
#  ('Bermuda', 2019, 7.0),
#  ('Bermuda', 2020, 7.0),
#  ('Canada', 2015, 1557.0),
#  ('Canada', 2016, 1528.0),
#  ('Canada', 2017, 1649.0),
#  ('Canada', 2018, 1725.0),
#  ('Canada', 2019, 1742.0),
#  ('Canada', 2020, 1645.0),
#  ('Greenland', 2015, 2.0),
#  ('Greenland', 2016, 3.0),
#  ('Greenland', 2017, 3.0),
#  ('Greenland', 2018, 3.0),
#  ('Greenland', 2019, 3.0),
#  ('Greenland', 2020, 3.0),
#  ('Saint Pierre and Miquelon', 2015, None),
#  ('Saint Pierre and Miquelon', 2016, None),
#  ('Saint Pierre and Miquelon', 2017, None),
#  ('Saint Pierre and Miquelon', 2018, None),
#  ('Saint Pierre and Miquelon', 2019, None),
#  ('Saint Pierre and Miquelon', 2020, None),
#  ('United States of America', 2015, None),
#  ('United States of America', 2016, None),
#  ('United States of America', 2017, None),
#  ('United States of America', 2018, None),
#  ('United States of America', 2019, None),
#  ('United States of America', 2020, None),
#  ('Anguilla', 2015, None),
#  ('Anguilla', 2016, None),
#  ('Anguilla', 2017, None),
#  ('Antigua and Barbuda', 2015, 1.0),
#  ('Antigua and Barbuda', 2016, 1.0),
#  ('Antigua and Barbuda', 2017, 1.0),
#  ('Aruba', 2015, 3.0),
#  ('Aruba', 2016, 3.0),
#  ('Bahamas', 2015, None),
#  ('Bahamas', 2016, None),
#  ('Bahamas', 2017, None),
#  ('Bahamas', 2018, None),
#  ('Bahamas', 2019, None),
#  ('Barbados', 2015, 5.0),
#  ('Barbados', 2016, 5.0),
#  ('Barbados', 2017, 5.0),
#  ('Barbados', 2018, 5.0),
#  ('Barbados', 2019, 5.0),
#  ('Barbados', 2020, 5.0),
#  ('British Virgin Islands', 2015, None),
#  ('British Virgin Islands', 2016, None),
#  ('British Virgin Islands', 2017, None),
#  ('British Virgin Islands', 2018, None),
#  ('British Virgin Islands', 2019, None),
#  ('British Virgin Islands', 2020, None),
#  ('Cayman Islands', 2015, 5.0),
#  ('Cayman Islands', 2016, 5.0),
#  ('Cuba', 2015, 87.0),
#  ('Cuba', 2016, 91.0),
#  ('Cuba', 2017, 97.0),
#  ('Cuba', 2018, 100.0),
#  ('Cuba', 2019, 103.0),
#  ('Cuba', 2020, 107.0),
#  ('CuraÃ§ao', 2015, None),
#  ('CuraÃ§ao', 2016, None),
#  ('CuraÃ§ao', 2017, None),
#  ('Dominica', 2015, 1.0),
#  ('Dominica', 2016, 1.0),
#  ('Dominica', 2017, 1.0),
#  ('Dominican Republic', 2015, 71.0),
#  ('Dominican Republic', 2016, 76.0),
#  ('Dominican Republic', 2017, 80.0),
#  ('Dominican Republic', 2018, 86.0),
#  ('Dominican Republic', 2019, 89.0),
#  ('Dominican Republic', 2020, 79.0),
#  ('Grenada', 2015, 1.0),
#  ('Grenada', 2016, 1.0),
#  ('Grenada', 2017, 1.0),
#  ('Guadeloupe', 2015, None),
#  ('Guadeloupe', 2016, None),
#  ('Guadeloupe', 2017, None),
#  ('Guadeloupe', 2018, None),
#  ('Guadeloupe', 2019, None),
#  ('Guadeloupe', 2020, None),
#  ('Haiti', 2015, 15.0),
#  ('Haiti', 2016, 14.0),
#  ('Haiti', 2017, 15.0),
#  ('Haiti', 2018, 16.0),
#  ('Haiti', 2019, 15.0),
#  ('Haiti', 2020, 15.0),
#  ('Jamaica', 2015, 14.0),
#  ('Jamaica', 2016, 14.0),
#  ('Jamaica', 2017, 15.0),
#  ('Jamaica', 2018, 16.0),
#  ('Jamaica', 2019, 16.0),
#  ('Jamaica', 2020, 14.0),
#  ('Martinique', 2015, None),
#  ('Martinique', 2016, None),
#  ('Martinique', 2017, None),
#  ('Martinique', 2018, None),
#  ('Martinique', 2019, None),
#  ('Martinique', 2020, None),
#  ('Montserrat', 2015, None),
#  ('Montserrat', 2016, None),
#  ('Montserrat', 2017, None),
#  ('Montserrat', 2018, None),
#  ('Montserrat', 2019, None),
#  ('Montserrat', 2020, None),
#  ('Puerto Rico', 2015, 103.0),
#  ('Puerto Rico', 2016, 104.0),
#  ('Puerto Rico', 2017, 103.0),
#  ('Puerto Rico', 2018, 101.0),
#  ('Puerto Rico', 2019, 105.0),
#  ('Puerto Rico', 2020, 103.0),
#  ('Saint BarthÃ©lemy', 2015, None),
#  ('Saint BarthÃ©lemy', 2016, None),
#  ('Saint BarthÃ©lemy', 2017, None),
#  ('Saint BarthÃ©lemy', 2018, None),
#  ('Saint BarthÃ©lemy', 2019, None),
#  ('Saint BarthÃ©lemy', 2020, None),
#  ('Saint Kitts and Nevis', 2015, None),
#  ('Saint Kitts and Nevis', 2016, None),
#  ('Saint Kitts and Nevis', 2017, None),
#  ('Saint Lucia', 2015, None),
#  ('Saint Lucia', 2016, None),
#  ('Saint Lucia', 2017, None),
#  ('Saint Lucia', 2018, None),
#  ('Saint Lucia', 2019, None),
#  ('Saint Lucia', 2020, None),
#  ('Saint Martin (French Part)', 2015, None),
#  ('Saint Martin (French Part)', 2016, None),
#  ('Saint Martin (French Part)', 2017, None),
#  ('Saint Martin (French Part)', 2018, None),
#  ('Saint Martin (French Part)', 2019, None),
#  ('Saint Martin (French Part)', 2020, None),
#  ('Saint Vincent and the Grenadines', 2015, None),
#  ('Saint Vincent and the Grenadines', 2016, None),
#  ('Saint Vincent and the Grenadines', 2017, None),
#  ('Saint Vincent and the Grenadines', 2018, None),
#  ('Sint Maarten (Dutch part)', 2015, 1.0),
#  ('Sint Maarten (Dutch part)', 2016, 1.0),
#  ('Sint Maarten (Dutch part)', 2017, 1.0),
#  ('Trinidad and Tobago', 2015, 27.0),
#  ('Trinidad and Tobago', 2016, 24.0),
#  ('Trinidad and Tobago', 2017, 24.0),
#  ('Trinidad and Tobago', 2018, 24.0),
#  ('Trinidad and Tobago', 2019, 24.0),
#  ('Trinidad and Tobago', 2020, 21.0),
#  ('Turks and Caicos Islands', 2015, 1.0),
#  ('Turks and Caicos Islands', 2016, 1.0),
#  ('Turks and Caicos Islands', 2017, 1.0),
#  ('Turks and Caicos Islands', 2018, 1.0),
#  ('United States Virgin Islands', 2015, None),
#  ('United States Virgin Islands', 2016, None),
#  ('United States Virgin Islands', 2017, None),
#  ('United States Virgin Islands', 2018, None),
#  ('United States Virgin Islands', 2019, None),
#  ('United States Virgin Islands', 2020, None),
#  ('Belize', 2015, 2.0),
#  ('Belize', 2016, 2.0),
#  ('Belize', 2017, 2.0),
#  ('Belize', 2018, 2.0),
#  ('Belize', 2019, 2.0),
#  ('Belize', 2020, 2.0),
#  ('Costa Rica', 2015, 56.0),
#  ('Costa Rica', 2016, 59.0),
#  ('Costa Rica', 2017, 61.0),
#  ('Costa Rica', 2018, 62.0),
#  ('Costa Rica', 2019, 64.0),
#  ('Costa Rica', 2020, 62.0),
#  ('El Salvador', 2015, 23.0),
#  ('El Salvador', 2016, 24.0),
#  ('El Salvador', 2017, 25.0),
#  ('El Salvador', 2018, 26.0),
#  ('El Salvador', 2019, 27.0),
#  ('El Salvador', 2020, 25.0),
#  ('Guatemala', 2015, 62.0),
#  ('Guatemala', 2016, 66.0),
#  ('Guatemala', 2017, 72.0),
#  ('Guatemala', 2018, 73.0),
#  ('Guatemala', 2019, 77.0),
#  ('Guatemala', 2020, 78.0),
#  ('Honduras', 2015, 21.0),
#  ('Honduras', 2016, 22.0),
#  ('Honduras', 2017, 23.0),
#  ('Honduras', 2018, 24.0),
#  ('Honduras', 2019, 25.0),
#  ('Honduras', 2020, 24.0),
#  ('Mexico', 2015, 1172.0),
#  ('Mexico', 2016, 1078.0),
#  ('Mexico', 2017, 1159.0),
#  ('Mexico', 2018, 1222.0),
#  ('Mexico', 2019, 1269.0),
#  ('Mexico', 2020, 1091.0),
#  ('Nicaragua', 2015, 13.0),
#  ('Nicaragua', 2016, 13.0),
#  ('Nicaragua', 2017, 14.0),
#  ('Nicaragua', 2018, 13.0),
#  ('Nicaragua', 2019, 13.0),
#  ('Nicaragua', 2020, 13.0),
#  ('Panama', 2015, 54.0),
#  ('Panama', 2016, 58.0),
#  ('Panama', 2017, 62.0),
#  ('Panama', 2018, 65.0),
#  ('Panama', 2019, 67.0),
#  ('Panama', 2020, 54.0),
#  ('Argentina', 2015, 595.0),
#  ('Argentina', 2016, 558.0),
#  ('Argentina', 2017, 644.0),
#  ('Argentina', 2018, 525.0),
#  ('Argentina', 2019, 448.0),
#  ('Argentina', 2020, 386.0),
#  ('Bolivia (Plurinational State of)', 2015, None),
#  ('Bolivia (Plurinational State of)', 2016, None),
#  ('Bolivia (Plurinational State of)', 2017, None),
#  ('Bolivia (Plurinational State of)', 2018, None),
#  ('Bolivia (Plurinational State of)', 2019, None),
#  ('Bolivia (Plurinational State of)', 2020, None),
#  ('Brazil', 2015, 1802.0),
#  ('Brazil', 2016, 1796.0),
#  ('Brazil', 2017, 2064.0),
#  ('Brazil', 2018, 1917.0),
#  ('Brazil', 2019, 1873.0),
#  ('Brazil', 2020, 1449.0),
#  ('Chile', 2015, 242.0),
#  ('Chile', 2016, 249.0),
#  ('Chile', 2017, 276.0),
#  ('Chile', 2018, 295.0),
#  ('Chile', 2019, 279.0),
#  ('Chile', 2020, 253.0),
#  ('Colombia', 2015, 293.0),
#  ('Colombia', 2016, 283.0),
#  ('Colombia', 2017, 312.0),
#  ('Colombia', 2018, 334.0),
#  ('Colombia', 2019, 323.0),
#  ('Colombia', 2020, 270.0),
#  ('Ecuador', 2015, 99.0),
#  ('Ecuador', 2016, 100.0),
#  ('Ecuador', 2017, 104.0),
#  ('Ecuador', 2018, 108.0),
#  ('Ecuador', 2019, 108.0),
#  ('Ecuador', 2020, 99.0),
#  ('Falkland Islands (Malvinas)', 2015, None),
#  ('Falkland Islands (Malvinas)', 2016, None),
#  ('Falkland Islands (Malvinas)', 2017, None),
#  ('Falkland Islands (Malvinas)', 2018, None),
#  ('Falkland Islands (Malvinas)', 2019, None),
#  ('Falkland Islands (Malvinas)', 2020, None),
#  ('French Guiana', 2015, None),
#  ('French Guiana', 2016, None),
#  ('French Guiana', 2017, None),
#  ('French Guiana', 2018, None),
#  ('French Guiana', 2019, None),
#  ('French Guiana', 2020, None),
#  ('Guyana', 2015, 4.0),
#  ('Guyana', 2016, 4.0),
#  ('Guyana', 2017, 5.0),
#  ('Guyana', 2018, 5.0),
#  ('Guyana', 2019, 5.0),
#  ('Guyana', 2020, 5.0),
#  ('Paraguay', 2015, 36.0),
#  ('Paraguay', 2016, 36.0),
#  ('Paraguay', 2017, 39.0),
#  ('Paraguay', 2018, 40.0),
#  ('Paraguay', 2019, 38.0),
#  ('Paraguay', 2020, 35.0),
#  ('Peru', 2015, 190.0),
#  ('Peru', 2016, 192.0),
#  ('Peru', 2017, 211.0),
#  ('Peru', 2018, 223.0),
#  ('Peru', 2019, 228.0),
#  ('Peru', 2020, 202.0),
#  ('Suriname', 2015, 5.0),
#  ('Suriname', 2016, 3.0),
#  ('Suriname', 2017, 4.0),
#  ('Suriname', 2018, 4.0),
#  ('Suriname', 2019, 4.0),
#  ('Suriname', 2020, 3.0),
#  ('Uruguay', 2015, 53.0),
#  ('Uruguay', 2016, 57.0),
#  ('Uruguay', 2017, 64.0),
#  ('Uruguay', 2018, 65.0),
#  ('Uruguay', 2019, 61.0),
#  ('Uruguay', 2020, 54.0),
#  ('Venezuela (Bolivarian Republic of)', 2015, None),
#  ('Venezuela (Bolivarian Republic of)', 2016, None),
#  ('Venezuela (Bolivarian Republic of)', 2017, None),
#  ('Venezuela (Bolivarian Republic of)', 2018, None),
#  ('Venezuela (Bolivarian Republic of)', 2019, None),
#  ('Venezuela (Bolivarian Republic of)', 2020, None),
#  ('Algeria', 2015, 166.0),
#  ('Algeria', 2016, 160.0),
#  ('Algeria', 2017, 170.0),
#  ('Algeria', 2018, 175.0),
#  ('Algeria', 2019, 172.0),
#  ('Algeria', 2020, 145.0),
#  ('Egypt', 2015, None),
#  ('Egypt', 2016, None),
#  ('Egypt', 2017, None),
#  ('Egypt', 2018, None),
#  ('Egypt', 2019, None),
#  ('Egypt', 2020, None),
#  ('Libya', 2015, 49.0),
#  ('Libya', 2016, 50.0),
#  ('Libya', 2017, 67.0),
#  ('Libya', 2018, 77.0),
#  ('Libya', 2019, 69.0),
#  ('Libya', 2020, 50.0),
#  ('Morocco', 2015, 110.0),
#  ('Morocco', 2016, 112.0),
#  ('Morocco', 2017, 119.0),
#  ('Morocco', 2018, 127.0),
#  ('Morocco', 2019, 129.0),
#  ('Morocco', 2020, 121.0),
#  ('Sudan', 2015, 85.0),
#  ('Sudan', 2016, 103.0),
#  ('Sudan', 2017, 130.0),
#  ('Sudan', 2018, 32.0),
#  ('Sudan', 2019, 32.0),
#  ('Sudan', 2020, 27.0),
#  ('Tunisia', 2015, 46.0),
#  ('Tunisia', 2016, 44.0),
#  ('Tunisia', 2017, 42.0),
#  ('Tunisia', 2018, 43.0),
#  ('Tunisia', 2019, 42.0),
#  ('Tunisia', 2020, 43.0),
#  ('Armenia', 2015, 11.0),
#  ('Armenia', 2016, 11.0),
#  ('Armenia', 2017, 12.0),
#  ('Armenia', 2018, 12.0),
#  ('Armenia', 2019, 14.0),
#  ('Armenia', 2020, 13.0),
#  ('Azerbaijan', 2015, 53.0),
#  ('Azerbaijan', 2016, 38.0),
#  ('Azerbaijan', 2017, 41.0),
#  ('Azerbaijan', 2018, 47.0),
#  ('Azerbaijan', 2019, 48.0),
#  ('Azerbaijan', 2020, 43.0),
#  ('Bahrain', 2015, 31.0),
#  ('Bahrain', 2016, 32.0),
#  ('Bahrain', 2017, 35.0),
#  ('Bahrain', 2018, 38.0),
#  ('Bahrain', 2019, 39.0),
#  ('Bahrain', 2020, 35.0),
#  ('Cyprus', 2015, 20.0),
#  ('Cyprus', 2016, 21.0),
#  ('Cyprus', 2017, 23.0),
#  ('Cyprus', 2018, 26.0),
#  ('Cyprus', 2019, 26.0),
#  ('Cyprus', 2020, 25.0),
#  ('Georgia', 2015, 15.0),
#  ('Georgia', 2016, 15.0),
#  ('Georgia', 2017, 16.0),
#  ('Georgia', 2018, 18.0),
#  ('Georgia', 2019, 17.0),
#  ('Georgia', 2020, 16.0),
#  ('Iraq', 2015, 167.0),
#  ('Iraq', 2016, 167.0),
#  ('Iraq', 2017, 187.0),
#  ('Iraq', 2018, 227.0),
#  ('Iraq', 2019, 234.0),
#  ('Iraq', 2020, 184.0),
#  ('Israel', 2015, 303.0),
#  ('Israel', 2016, 322.0),
#  ('Israel', 2017, 358.0),
#  ('Israel', 2018, 377.0),
#  ('Israel', 2019, 402.0),
#  ('Israel', 2020, 413.0),
#  ('Jordan', 2015, 39.0),
#  ('Jordan', 2016, 40.0),
#  ('Jordan', 2017, 42.0),
#  ('Jordan', 2018, 43.0),
#  ('Jordan', 2019, 45.0),
#  ('Jordan', 2020, 44.0),
#  ('Kuwait', 2015, 115.0),
#  ('Kuwait', 2016, 109.0),
#  ('Kuwait', 2017, 121.0),
#  ('Kuwait', 2018, 138.0),
#  ('Kuwait', 2019, 136.0),
#  ('Kuwait', 2020, 106.0),
#  ('Lebanon', 2015, 50.0),
#  ('Lebanon', 2016, 51.0),
#  ('Lebanon', 2017, 53.0),
#  ('Lebanon', 2018, 55.0),
#  ('Lebanon', 2019, 52.0),
#  ('Lebanon', 2020, 32.0),
#  ('Oman', 2015, 79.0),
#  ('Oman', 2016, 75.0),
#  ('Oman', 2017, 81.0),
#  ('Oman', 2018, 92.0),
#  ('Oman', 2019, 88.0),
#  ('Oman', 2020, 76.0),
#  ('Qatar', 2015, 162.0),
#  ('Qatar', 2016, 152.0),
#  ('Qatar', 2017, 161.0),
#  ('Qatar', 2018, 183.0),
#  ('Qatar', 2019, 176.0),
#  ('Qatar', 2020, 144.0),
#  ('Saudi Arabia', 2015, 654.0),
#  ('Saudi Arabia', 2016, 645.0),
#  ('Saudi Arabia', 2017, 689.0),
#  ('Saudi Arabia', 2018, 817.0),
#  ('Saudi Arabia', 2019, 804.0),
#  ('Saudi Arabia', 2020, 703.0),
#  ('State of Palestine', 2015, None),
#  ('State of Palestine', 2016, None),
#  ('State of Palestine', 2017, None),
#  ('State of Palestine', 2018, None),
#  ('State of Palestine', 2019, None),
#  ('State of Palestine', 2020, None),
#  ('Syrian Arab Republic', 2015, 16.0),
#  ('Syrian Arab Republic', 2016, 13.0),
#  ('Syrian Arab Republic', 2017, 16.0),
#  ('Syrian Arab Republic', 2018, 21.0),
#  ('Syrian Arab Republic', 2019, 22.0),
#  ('Syrian Arab Republic', 2020, 11.0),
#  ('TÃ¼rkiye', 2015, None),
#  ('TÃ¼rkiye', 2016, None),
#  ('TÃ¼rkiye', 2017, None),
#  ('TÃ¼rkiye', 2018, None),
#  ('TÃ¼rkiye', 2019, None),
#  ('TÃ¼rkiye', 2020, None),
#  ('United Arab Emirates', 2015, 370.0),
#  ('United Arab Emirates', 2016, 369.0),
#  ('United Arab Emirates', 2017, 391.0),
#  ('United Arab Emirates', 2018, 427.0),
#  ('United Arab Emirates', 2019, 418.0),
#  ('United Arab Emirates', 2020, 349.0),
#  ('Yemen', 2015, None),
#  ('Yemen', 2016, None),
#  ('Yemen', 2017, None),
#  ('Yemen', 2018, None),
#  ('Yemen', 2019, None),
#  ('Yemen', 2020, None),
#  ('Australia', 2015, 1351.0),
#  ('Australia', 2016, 1207.0),
#  ('Australia', 2017, 1327.0),
#  ('Australia', 2018, 1428.0),
#  ('Australia', 2019, 1392.0),
#  ('Australia', 2020, 1327.0),
#  ('New Zealand', 2015, 178.0),
#  ('New Zealand', 2016, 189.0),
#  ('New Zealand', 2017, 207.0),
#  ('New Zealand', 2018, 212.0),
#  ('New Zealand', 2019, 213.0),
#  ('New Zealand', 2020, 212.0),
#  ('Fiji', 2015, 5.0),
#  ('Fiji', 2016, 5.0),
#  ('Fiji', 2017, 5.0),
#  ('Fiji', 2018, 6.0),
#  ('Fiji', 2019, 5.0),
#  ('Fiji', 2020, 4.0),
#  ('New Caledonia', 2015, 9.0),
#  ('New Caledonia', 2016, 9.0),
#  ('New Caledonia', 2017, 9.0),
#  ('New Caledonia', 2018, 10.0),
#  ('New Caledonia', 2019, 9.0),
#  ('New Caledonia', 2020, 9.0),
#  ('Papua New Guinea', 2015, 22.0),
#  ('Papua New Guinea', 2016, 21.0),
#  ('Papua New Guinea', 2017, 23.0),
#  ('Papua New Guinea', 2018, 24.0),
#  ('Papua New Guinea', 2019, 25.0),
#  ('Papua New Guinea', 2020, 24.0),
#  ('Solomon Islands', 2015, 1.0),
#  ('Solomon Islands', 2016, 1.0),
#  ('Solomon Islands', 2017, 1.0),
#  ('Solomon Islands', 2018, 2.0),
#  ('Solomon Islands', 2019, 2.0),
#  ('Solomon Islands', 2020, 2.0),
#  ('Vanuatu', 2015, 1.0),
#  ('Vanuatu', 2016, 1.0),
#  ('Vanuatu', 2017, 1.0),
#  ('Vanuatu', 2018, 1.0),
#  ('Vanuatu', 2019, 1.0),
#  ('Vanuatu', 2020, 1.0),
#  ('Guam', 2015, 6.0),
#  ('Guam', 2016, 6.0),
#  ('Guam', 2017, 6.0),
#  ('Guam', 2018, 6.0),
#  ('Guam', 2019, 6.0),
#  ('Guam', 2020, 6.0),
#  ('Kiribati', 2015, 0.0),
#  ('Kiribati', 2016, 0.0),
#  ('Kiribati', 2017, 0.0),
#  ('Kiribati', 2018, 0.0),
#  ('Kiribati', 2019, 0.0),
#  ('Kiribati', 2020, 0.0),
#  ('Marshall Islands', 2015, 0.0),
#  ('Marshall Islands', 2016, 0.0),
#  ('Marshall Islands', 2017, 0.0),
#  ('Marshall Islands', 2018, 0.0),
#  ('Marshall Islands', 2019, 0.0),
#  ('Marshall Islands', 2020, 0.0),
#  ('Micronesia (Federated States of)', 2015, None),
#  ('Micronesia (Federated States of)', 2016, None),
#  ('Micronesia (Federated States of)', 2017, None),
#  ('Micronesia (Federated States of)', 2018, None),
#  ('Micronesia (Federated States of)', 2019, None),
#  ('Nauru', 2015, 0.0),
#  ('Nauru', 2016, 0.0),
#  ('Nauru', 2017, 0.0),
#  ('Nauru', 2018, 0.0),
#  ('Nauru', 2019, 0.0),
#  ('Nauru', 2020, 0.0),
#  ('Northern Mariana Islands', 2015, 1.0),
#  ('Northern Mariana Islands', 2016, 1.0),
#  ('Northern Mariana Islands', 2017, 2.0),
#  ('Northern Mariana Islands', 2018, 1.0),
#  ('Northern Mariana Islands', 2019, 1.0),
#  ('Northern Mariana Islands', 2020, None),
#  ('Palau', 2015, 0.0),
#  ('Palau', 2016, 0.0),
#  ('Palau', 2017, 0.0),
#  ('Palau', 2018, 0.0),
#  ('Palau', 2019, 0.0),
#  ('Palau', 2020, 0.0),
#  ('American Samoa', 2015, 1.0),
#  ('American Samoa', 2016, 1.0),
#  ('American Samoa', 2017, 1.0),
#  ('American Samoa', 2018, 1.0),
#  ('American Samoa', 2019, 1.0),
#  ('American Samoa', 2020, 1.0),
#  ('Cook Islands', 2015, None),
#  ('Cook Islands', 2016, None),
#  ('Cook Islands', 2017, None),
#  ('Cook Islands', 2018, None),
#  ('Cook Islands', 2019, None),
#  ('Cook Islands', 2020, None),
#  ('French Polynesia', 2015, 5.0),
#  ('French Polynesia', 2016, 6.0),
#  ('French Polynesia', 2017, 6.0),
#  ('French Polynesia', 2018, 6.0),
#  ('French Polynesia', 2019, 6.0),
#  ('French Polynesia', 2020, 6.0),
#  ('Niue', 2015, None),
#  ('Niue', 2016, None),
#  ('Niue', 2017, None),
#  ('Niue', 2018, None),
#  ('Niue', 2019, None),
#  ('Niue', 2020, None),
#  ('Samoa', 2015, 1.0),
#  ('Samoa', 2016, 1.0),
#  ('Samoa', 2017, 1.0),
#  ('Samoa', 2018, 1.0),
#  ('Samoa', 2019, 1.0),
#  ('Samoa', 2020, 1.0),
#  ('Tokelau', 2015, None),
#  ('Tokelau', 2016, None),
#  ('Tokelau', 2017, None),
#  ('Tokelau', 2018, None),
#  ('Tokelau', 2019, None),
#  ('Tokelau', 2020, None),
#  ('Tonga', 2015, 0.0),
#  ('Tonga', 2016, 0.0),
#  ('Tonga', 2017, 0.0),
#  ('Tonga', 2018, 0.0),
#  ('Tonga', 2019, 1.0),
#  ('Tonga', 2020, 0.0),
#  ('Tuvalu', 2015, 0.0),
#  ('Tuvalu', 2016, 0.0),
#  ('Tuvalu', 2017, 0.0),
#  ('Tuvalu', 2018, 0.0),
#  ('Tuvalu', 2019, 0.0),
#  ('Tuvalu', 2020, 0.0),
#  ('Wallis and Futuna Islands', 2015, None),
#  ('Wallis and Futuna Islands', 2016, None),
#  ('Wallis and Futuna Islands', 2017, None),
#  ('Wallis and Futuna Islands', 2018, None),
#  ('Wallis and Futuna Islands', 2019, None),
#  ('Wallis and Futuna Islands', 2020, None),
#  ('Burundi', 2015, 3.0),
#  ('Burundi', 2016, 3.0),
#  ('Burundi', 2017, 3.0),
#  ('Burundi', 2018, 3.0),
#  ('Burundi', 2019, 3.0),
#  ('Burundi', 2020, 3.0),
#  ('Comoros', 2015, 1.0),
#  ('Comoros', 2016, 1.0),
#  ('Comoros', 2017, 1.0),
#  ('Comoros', 2018, 1.0),
#  ('Comoros', 2019, 1.0),
#  ('Djibouti', 2015, 2.0),
#  ('Djibouti', 2016, 3.0),
#  ('Djibouti', 2017, 3.0),
#  ('Djibouti', 2018, 3.0),
#  ('Djibouti', 2019, 3.0),
#  ('Djibouti', 2020, 3.0),
#  ('Eritrea', 2015, None),
#  ('Eritrea', 2016, None),
#  ('Ethiopia', 2015, 65.0),
#  ('Ethiopia', 2016, 74.0),
#  ('Ethiopia', 2017, 82.0),
#  ('Ethiopia', 2018, 84.0),
#  ('Ethiopia', 2019, 96.0),
#  ('Ethiopia', 2020, 108.0),
#  ('Kenya', 2015, 70.0),
#  ('Kenya', 2016, 75.0),
#  ('Kenya', 2017, 82.0),
#  ('Kenya', 2018, 92.0),
#  ('Kenya', 2019, 100.0),
#  ('Kenya', 2020, 101.0),
#  ('Madagascar', 2015, 11.0),
#  ('Madagascar', 2016, 12.0),
#  ('Madagascar', 2017, 13.0),
#  ('Madagascar', 2018, 14.0),
#  ('Madagascar', 2019, 14.0),
#  ('Madagascar', 2020, 13.0),
#  ('Malawi', 2015, 6.0),
#  ('Malawi', 2016, 5.0),
#  ('Malawi', 2017, 9.0),
#  ('Malawi', 2018, 10.0),
#  ('Malawi', 2019, 11.0),
#  ('Malawi', 2020, 12.0),
#  ('Mauritius', 2015, 12.0),
#  ('Mauritius', 2016, 13.0),
#  ('Mauritius', 2017, 14.0),
#  ('Mauritius', 2018, 15.0),
#  ('Mauritius', 2019, 14.0),
#  ('Mauritius', 2020, 11.0),
#  ('Mayotte', 2015, None),
#  ('Mayotte', 2016, None),
#  ('Mayotte', 2017, None),
#  ('Mayotte', 2018, None),
#  ('Mayotte', 2019, None),
#  ('Mayotte', 2020, None),
#  ('Mozambique', 2015, 16.0),
#  ('Mozambique', 2016, 12.0),
#  ('Mozambique', 2017, 13.0),
#  ('Mozambique', 2018, 15.0),
#  ('Mozambique', 2019, 15.0),
#  ('Mozambique', 2020, 14.0),
#  ('Rwanda', 2015, 9.0),
#  ('Rwanda', 2016, 9.0),
#  ('Rwanda', 2017, 9.0),
#  ('Rwanda', 2018, 10.0),
#  ('Rwanda', 2019, 10.0),
#  ('Rwanda', 2020, 10.0),
#  ('RÃ©union', 2015, None),
#  ('RÃ©union', 2016, None),
#  ('RÃ©union', 2017, None),
#  ('RÃ©union', 2018, None),
#  ('RÃ©union', 2019, None),
#  ('RÃ©union', 2020, None),
#  ('Seychelles', 2015, 1.0),
#  ('Seychelles', 2016, 1.0),
#  ('Seychelles', 2017, 2.0),
#  ('Seychelles', 2018, 2.0),
#  ('Seychelles', 2019, 2.0),
#  ('Somalia', 2015, 5.0),
#  ('Somalia', 2016, 6.0),
#  ('Somalia', 2017, 6.0),
#  ('Somalia', 2018, 6.0),
#  ('Somalia', 2019, 6.0),
#  ('Somalia', 2020, 7.0),
#  ('South Sudan', 2015, 12.0),
#  ('South Sudan', 2016, None),
#  ('South Sudan', 2017, None),
#  ('South Sudan', 2018, None),
#  ('South Sudan', 2019, None),
#  ('South Sudan', 2020, None),
#  ('Uganda', 2015, 32.0),
#  ('Uganda', 2016, 29.0),
#  ('Uganda', 2017, 31.0),
#  ('Uganda', 2018, 33.0),
#  ('Uganda', 2019, 35.0),
#  ('Uganda', 2020, 38.0),
#  ('United Republic of Tanzania', 2015, None),
#  ('United Republic of Tanzania', 2016, None),
#  ('United Republic of Tanzania', 2017, None),
#  ('United Republic of Tanzania', 2018, None),
#  ('United Republic of Tanzania', 2019, None),
#  ('United Republic of Tanzania', 2020, None),
#  ('Zambia', 2015, 21.0),
#  ('Zambia', 2016, 21.0),
#  ('Zambia', 2017, 26.0),
#  ('Zambia', 2018, 26.0),
#  ('Zambia', 2019, 23.0),
#  ('Zambia', 2020, 18.0),
#  ('Zimbabwe', 2015, 20.0),
#  ('Zimbabwe', 2016, 21.0),
#  ('Zimbabwe', 2017, 18.0),
#  ('Zimbabwe', 2018, 34.0),
#  ('Zimbabwe', 2019, 22.0),
#  ('Zimbabwe', 2020, 22.0),
#  ('Angola', 2015, 87.0),
#  ('Angola', 2016, 50.0),
#  ('Angola', 2017, 69.0),
#  ('Angola', 2018, 78.0),
#  ('Angola', 2019, 69.0),
#  ('Angola', 2020, 54.0),
#  ('Cameroon', 2015, 32.0),
#  ('Cameroon', 2016, 34.0),
#  ('Cameroon', 2017, 36.0),
#  ('Cameroon', 2018, 40.0),
#  ('Cameroon', 2019, 40.0),
#  ('Cameroon', 2020, 41.0),
#  ('Central African Republic', 2015, 2.0),
#  ('Central African Republic', 2016, 2.0),
#  ('Central African Republic', 2017, 2.0),
#  ('Central African Republic', 2018, 2.0),
#  ('Central African Republic', 2019, 2.0),
#  ('Central African Republic', 2020, 2.0),
#  ('Chad', 2015, 11.0),
#  ('Chad', 2016, 10.0),
#  ('Chad', 2017, 10.0),
#  ('Chad', 2018, 11.0),
#  ('Chad', 2019, 11.0),
#  ('Chad', 2020, 11.0),
#  ('Congo', 2015, None),
#  ('Congo', 2016, None),
#  ('Congo', 2017, None),
#  ('Congo', 2018, None),
#  ('Congo', 2019, None),
#  ('Congo', 2020, None),
#  ('Democratic Republic of the Congo', 2015, None),
#  ('Democratic Republic of the Congo', 2016, None),
#  ('Democratic Republic of the Congo', 2017, None),
#  ('Democratic Republic of the Congo', 2018, None),
#  ('Democratic Republic of the Congo', 2019, None),
#  ('Democratic Republic of the Congo', 2020, None),
#  ('Equatorial Guinea', 2015, 13.0),
#  ('Equatorial Guinea', 2016, 11.0),
#  ('Equatorial Guinea', 2017, 12.0),
#  ('Gabon', 2015, 14.0),
#  ('Gabon', 2016, 14.0),
#  ('Gabon', 2017, 15.0),
#  ('Gabon', 2018, 17.0),
#  ('Gabon', 2019, 17.0),
#  ('Gabon', 2020, 15.0),
#  ('Sao Tome and Principe', 2015, 0.0),
#  ('Sao Tome and Principe', 2016, 0.0),
#  ('Sao Tome and Principe', 2017, 0.0),
#  ('Sao Tome and Principe', 2018, 0.0),
#  ('Sao Tome and Principe', 2019, 0.0),
#  ('Sao Tome and Principe', 2020, 0.0),
#  ('Botswana', 2015, 14.0),
#  ('Botswana', 2016, 15.0),
#  ('Botswana', 2017, 16.0),
#  ('Botswana', 2018, 17.0),
#  ('Botswana', 2019, 17.0),
#  ('Botswana', 2020, 15.0),
#  ('Eswatini', 2015, 4.0),
#  ('Eswatini', 2016, 4.0),
#  ('Eswatini', 2017, 4.0),
#  ('Eswatini', 2018, 5.0),
#  ('Eswatini', 2019, 4.0),
#  ('Eswatini', 2020, 4.0),
#  ('Lesotho', 2015, 2.0),
#  ('Lesotho', 2016, 2.0),
#  ('Lesotho', 2017, 2.0),
#  ('Lesotho', 2018, 3.0),
#  ('Lesotho', 2019, 2.0),
#  ('Lesotho', 2020, 2.0),
#  ('Namibia', 2015, 11.0),
#  ('Namibia', 2016, 11.0),
#  ('Namibia', 2017, 13.0),
#  ('Namibia', 2018, 14.0),
#  ('Namibia', 2019, 13.0),
#  ('Namibia', 2020, 11.0),
#  ('South Africa', 2015, 347.0),
#  ('South Africa', 2016, 324.0),
#  ('South Africa', 2017, 381.0),
#  ('South Africa', 2018, 404.0),
#  ('South Africa', 2019, 389.0),
#  ('South Africa', 2020, 338.0),
#  ('Benin', 2015, 11.0),
#  ('Benin', 2016, 12.0),
#  ('Benin', 2017, 13.0),
#  ('Benin', 2018, 14.0),
#  ('Benin', 2019, 14.0),
#  ('Benin', 2020, 16.0),
#  ('Burkina Faso', 2015, 12.0),
#  ('Burkina Faso', 2016, 13.0),
#  ('Burkina Faso', 2017, 14.0),
#  ('Burkina Faso', 2018, 16.0),
#  ('Burkina Faso', 2019, 16.0),
#  ('Burkina Faso', 2020, 18.0),
#  ('Cabo Verde', 2015, 2.0),
#  ('Cabo Verde', 2016, 2.0),
#  ('Cabo Verde', 2017, 2.0),
#  ('Cabo Verde', 2018, 2.0),
#  ('Cabo Verde', 2019, 2.0),
#  ('Cabo Verde', 2020, 2.0),
#  ("CÃ´te d'Ivoire", 2015, None),
#  ("CÃ´te d'Ivoire", 2016, None),
#  ("CÃ´te d'Ivoire", 2017, None),
#  ("CÃ´te d'Ivoire", 2018, None),
#  ("CÃ´te d'Ivoire", 2019, None),
#  ("CÃ´te d'Ivoire", 2020, None),
#  ('Gambia', 2015, None),
#  ('Gambia', 2016, None),
#  ('Gambia', 2017, None),
#  ('Gambia', 2018, None),
#  ('Gambia', 2019, None),
#  ('Gambia', 2020, None),
#  ('Ghana', 2015, 49.0),
#  ('Ghana', 2016, 56.0),
#  ('Ghana', 2017, 60.0),
#  ('Ghana', 2018, 67.0),
#  ('Ghana', 2019, 68.0),
#  ('Ghana', 2020, 70.0),
#  ('Guinea', 2015, 9.0),
#  ('Guinea', 2016, 9.0),
#  ('Guinea', 2017, 10.0),
#  ('Guinea', 2018, 12.0),
#  ('Guinea', 2019, 13.0),
#  ('Guinea', 2020, 14.0),
#  ('Guinea-Bissau', 2015, 1.0),
#  ('Guinea-Bissau', 2016, 1.0),
#  ('Guinea-Bissau', 2017, 1.0),
#  ('Guinea-Bissau', 2018, 2.0),
#  ('Guinea-Bissau', 2019, 1.0),
#  ('Guinea-Bissau', 2020, 1.0),
#  ('Liberia', 2015, 3.0),
#  ('Liberia', 2016, 3.0),
#  ('Liberia', 2017, 3.0),
#  ('Liberia', 2018, 3.0),
#  ('Liberia', 2019, 3.0),
#  ('Liberia', 2020, 3.0),
#  ...]

# %% [markdown]
# **6. What is the logarithm of GDP for each country over the time period**
#
# In order to calculate the growth rate of GDP over the time period, we can use the logarithm of GDP. This is because using the logarithm allows for easier comparison and analysis of growth rates with more digestible representations of larger numbers. Logarithmic transformations capture proportional changes rather than absolute changes, which is often more meaningful when analysing economic growth rates.
#
# Calculate the logarithmic of the Est_gdp_in_billions column using the LOG function.

# %%
# %%sql
#
# Select Country_name,
#     Time_period,
#     LOG(Est_gdp_in_billions) AS Log_est_gdp_in_billions
# FROM Access_to_Basic_Services;
# Out:
#  * mysql+pymysql://root:***@127.0.0.1:3306/united_nations
# 1048 rows affected.
# [('Kazakhstan', 2015, 5.217053079717073),
#  ('Kazakhstan', 2016, 4.922022635739652),
#  ('Kazakhstan', 2017, 5.116855440165964),
#  ('Kazakhstan', 2018, 5.189283445523902),
#  ('Kazakhstan', 2019, 5.202191854450653),
#  ('Kazakhstan', 2020, 5.142131283358708),
#  ('Kyrgyzstan', 2015, None),
#  ('Kyrgyzstan', 2016, None),
#  ('Kyrgyzstan', 2017, None),
#  ('Kyrgyzstan', 2018, None),
#  ('Kyrgyzstan', 2019, None),
#  ('Kyrgyzstan', 2020, None),
#  ('Tajikistan', 2015, 2.1126345090356),
#  ('Tajikistan', 2016, 1.944480556245719),
#  ('Tajikistan', 2017, 2.020222182019865),
#  ('Tajikistan', 2018, 2.050270164379556),
#  ('Tajikistan', 2019, 2.1162555148025524),
#  ('Tajikistan', 2020, 2.0955609235597192),
#  ('Turkmenistan', 2015, 3.5779478934066544),
#  ('Turkmenistan', 2016, 3.5882300459640066),
#  ('Turkmenistan', 2017, 3.6357423557008075),
#  ('Turkmenistan', 2018, 3.707946516831162),
#  ('Turkmenistan', 2019, 3.8117605834897517),
#  ('Turkmenistan', 2020, None),
#  ('Uzbekistan', 2015, 4.456670177669648),
#  ('Uzbekistan', 2016, 4.455973879625964),
#  ('Uzbekistan', 2017, 4.128423875874963),
#  ('Uzbekistan', 2018, 3.9632862993656874),
#  ('Uzbekistan', 2019, 4.0928434360958335),
#  ('Uzbekistan', 2020, 4.092509546276371),
#  ('Afghanistan', 2015, 2.995732273553991),
#  ('Afghanistan', 2016, 2.8914822521801917),
#  ('Afghanistan', 2017, 2.9391619220655967),
#  ('Afghanistan', 2018, 2.913437030827161),
#  ('Afghanistan', 2019, 2.9391619220655967),
#  ('Afghanistan', 2020, 3.0027078872904163),
#  ('Bangladesh', 2015, 5.273409730841852),
#  ('Bangladesh', 2016, 5.580635076500667),
#  ('Bangladesh', 2017, 5.682729065458369),
#  ('Bangladesh', 2018, 5.772624223613607),
#  ('Bangladesh', 2019, 5.8614697504917945),
#  ('Bangladesh', 2020, 5.923988381983068),
#  ('Bhutan', 2015, 0.6931471805599453),
#  ('Bhutan', 2016, 0.7701082216960737),
#  ('Bhutan', 2017, 0.8960880245566357),
#  ('Bhutan', 2018, 0.8960880245566357),
#  ('Bhutan', 2019, 0.9321640810304452),
#  ('Bhutan', 2020, 0.8458682675776092),
#  ('India', 2015, 7.651400687948423),
#  ('India', 2016, 7.738400972727716),
#  ('India', 2017, 7.88286948216281),
#  ('India', 2018, 7.902091648789797),
#  ('India', 2019, 7.948579543882852),
#  ('India', 2020, 7.888968208380664),
#  ('Iran (Islamic Republic of)', 2015, None),
#  ('Iran (Islamic Republic of)', 2016, None),
#  ('Iran (Islamic Republic of)', 2017, None),
#  ('Iran (Islamic Republic of)', 2018, None),
#  ('Iran (Islamic Republic of)', 2019, None),
#  ('Iran (Islamic Republic of)', 2020, None),
#  ('Maldives', 2015, 1.4134230285081433),
#  ('Maldives', 2016, 1.4770487243883548),
#  ('Maldives', 2017, 1.55814461804655),
#  ('Maldives', 2018, 1.667706820558076),
#  ('Maldives', 2019, 1.724550719534605),
#  ('Maldives', 2020, 1.3217558399823195),
#  ('Nepal', 2015, 3.192942442841696),
#  ('Nepal', 2016, 3.1994891110680106),
#  ('Nepal', 2017, 3.366260811781259),
#  ('Nepal', 2018, 3.4998353515591547),
#  ('Nepal', 2019, 3.5319332036512097),
#  ('Nepal', 2020, 3.509453700432007),
#  ('Pakistan', 2015, 5.600493885150271),
#  ('Pakistan', 2016, 5.74821394716612),
#  ('Pakistan', 2017, 5.826619384615263),
#  ('Pakistan', 2018, 5.875295832733553),
#  ('Pakistan', 2019, 5.771160709986149),
#  ('Pakistan', 2020, 5.705214781747826),
#  ('Sri Lanka', 2015, 4.444296960400006),
#  ('Sri Lanka', 2016, 4.47745044438572),
#  ('Sri Lanka', 2017, 4.547329186298241),
#  ('Sri Lanka', 2018, 4.548494008794535),
#  ('Sri Lanka', 2019, 4.48874872297084),
#  ('Sri Lanka', 2020, 4.4467604492404496),
#  ('China', 2015, 9.311230409922441),
#  ('China', 2016, 9.326636079886592),
#  ('China', 2017, 9.418200524878936),
#  ('China', 2018, 9.539271387792589),
#  ('China', 2019, 9.566611034204076),
#  ('China', 2020, 9.594763645287616),
#  ("Democratic People's Republic of Korea", 2015, None),
#  ("Democratic People's Republic of Korea", 2016, None),
#  ("Democratic People's Republic of Korea", 2017, None),
#  ("Democratic People's Republic of Korea", 2018, None),
#  ("Democratic People's Republic of Korea", 2019, None),
#  ("Democratic People's Republic of Korea", 2020, None),
#  ('Japan', 2015, 8.399519399792508),
#  ('Japan', 2016, 8.51792892070106),
#  ('Japan', 2017, 8.503264637918331),
#  ('Japan', 2018, 8.52473269777386),
#  ('Japan', 2019, 8.541557945388796),
#  ('Japan', 2020, 8.52518318622407),
#  ('Mongolia', 2015, 2.4527277514237653),
#  ('Mongolia', 2016, 2.414126467726953),
#  ('Mongolia', 2017, 2.4406063908914204),
#  ('Mongolia', 2018, 2.578700529074361),
#  ('Mongolia', 2019, 2.6539459421090092),
#  ('Mongolia', 2020, 2.58851563240702),
#  ('Republic of Korea', 2015, None),
#  ('Republic of Korea', 2016, None),
#  ('Republic of Korea', 2017, None),
#  ('Republic of Korea', 2018, None),
#  ('Republic of Korea', 2019, None),
#  ('Republic of Korea', 2020, None),
#  ('Brunei Darussalam', 2015, 2.559550192783766),
#  ('Brunei Darussalam', 2016, 2.4336133554004498),
#  ('Brunei Darussalam', 2017, 2.495681722955959),
#  ('Brunei Darussalam', 2018, 2.6078614738467776),
#  ('Brunei Darussalam', 2019, 2.6004649904222727),
#  ('Brunei Darussalam', 2020, 2.485739636091892),
#  ('Cambodia', 2015, 2.89314568477889),
#  ('Cambodia', 2016, 2.9967317738870745),
#  ('Cambodia', 2017, 3.099190981922221),
#  ('Cambodia', 2018, 3.201526186533088),
#  ('Cambodia', 2019, 3.2991646560970036),
#  ('Cambodia', 2020, 3.2530839961979376),
#  ('Indonesia', 2015, 6.7579202732224815),
#  ('Indonesia', 2016, 6.837204051031101),
#  ('Indonesia', 2017, 6.923254542429061),
#  ('Indonesia', 2018, 6.949156305830813),
#  ('Indonesia', 2019, 7.020280069823982),
#  ('Indonesia', 2020, 6.9647875737583),
#  ("Lao People's Democratic Republic", 2015, None),
#  ("Lao People's Democratic Republic", 2016, None),
#  ("Lao People's Democratic Republic", 2017, None),
#  ("Lao People's Democratic Republic", 2018, None),
#  ("Lao People's Democratic Republic", 2019, None),
#  ("Lao People's Democratic Republic", 2020, None),
#  ('Malaysia', 2015, 5.708272379929054),
#  ('Malaysia', 2016, 5.707973679274669),
#  ('Malaysia', 2017, 5.765535870931683),
#  ('Malaysia', 2018, 5.882737259116202),
#  ('Malaysia', 2019, 5.900390382708587),
#  ('Malaysia', 2020, 5.821091323829869),
#  ('Myanmar', 2015, 4.143928062410929),
#  ('Myanmar', 2016, 4.099166252501314),
#  ('Myanmar', 2017, 4.118223836012044),
#  ('Myanmar', 2018, 4.206779991551889),
#  ('Myanmar', 2019, 4.229749199228304),
#  ('Myanmar', 2020, 4.368561383720311),
#  ('Philippines', 2015, 5.725054609931741),
#  ('Philippines', 2016, 5.764030555001558),
#  ('Philippines', 2017, 5.794475953270624),
#  ('Philippines', 2018, 5.8488635785089595),
#  ('Philippines', 2019, 5.931767619849855),
#  ('Philippines', 2020, 5.890953365511593),
#  ('Singapore', 2015, 5.730099782973574),
#  ('Singapore', 2016, 5.764658045374483),
#  ('Singapore', 2017, 5.838284229660164),
#  ('Singapore', 2018, 5.932245187448011),
#  ('Singapore', 2019, 5.92817857453717),
#  ('Singapore', 2020, 5.844413604395947),
#  ('Thailand', 2015, 5.994709277272871),
#  ('Thailand', 2016, 6.024343075673921),
#  ('Thailand', 2017, 6.123281971728169),
#  ('Thailand', 2018, 6.228017785332109),
#  ('Thailand', 2019, 6.299096294867383),
#  ('Thailand', 2020, 6.213967893534768),
#  ('Timor-Leste', 2015, 0.4637340162321402),
#  ('Timor-Leste', 2016, 0.5007752879124892),
#  ('Timor-Leste', 2017, 0.47000362924573563),
#  ('Timor-Leste', 2018, 0.44468582126144574),
#  ('Timor-Leste', 2019, 0.7080357930536959),
#  ('Timor-Leste', 2020, 0.7701082216960737),
#  ('Viet Nam', 2015, None),
#  ('Viet Nam', 2016, None),
#  ('Viet Nam', 2017, None),
#  ('Viet Nam', 2018, None),
#  ('Viet Nam', 2019, None),
#  ('Viet Nam', 2020, None),
#  ('Bermuda', 2015, 1.8946168546677629),
#  ('Bermuda', 2016, 1.9315214116032138),
#  ('Bermuda', 2017, 1.965712776351493),
#  ('Bermuda', 2018, 1.9782390361706734),
#  ('Bermuda', 2019, 2.004179057179289),
#  ('Bermuda', 2020, 1.9300710850255671),
#  ('Canada', 2015, 7.35020141453176),
#  ('Canada', 2016, 7.331708425202432),
#  ('Canada', 2017, 7.408088044753721),
#  ('Canada', 2018, 7.453173615516943),
#  ('Canada', 2019, 7.462800638402799),
#  ('Canada', 2020, 7.405750949760021),
#  ('Greenland', 2015, 0.9162907318741551),
#  ('Greenland', 2016, 0.9969486348916096),
#  ('Greenland', 2017, 1.0473189942805592),
#  ('Greenland', 2018, 1.1184149159642893),
#  ('Greenland', 2019, 1.095273387402595),
#  ('Greenland', 2020, 1.1249295969854831),
#  ('Saint Pierre and Miquelon', 2015, None),
#  ('Saint Pierre and Miquelon', 2016, None),
#  ('Saint Pierre and Miquelon', 2017, None),
#  ('Saint Pierre and Miquelon', 2018, None),
#  ('Saint Pierre and Miquelon', 2019, None),
#  ('Saint Pierre and Miquelon', 2020, None),
#  ('United States of America', 2015, None),
#  ('United States of America', 2016, None),
#  ('United States of America', 2017, None),
#  ('United States of America', 2018, None),
#  ('United States of America', 2019, None),
#  ('United States of America', 2020, None),
#  ('Anguilla', 2015, None),
#  ('Anguilla', 2016, None),
#  ('Anguilla', 2017, None),
#  ('Antigua and Barbuda', 2015, 0.29266961396282004),
#  ('Antigua and Barbuda', 2016, 0.36464311358790924),
#  ('Antigua and Barbuda', 2017, 0.3852624007906449),
#  ('Aruba', 2015, 1.085189268335969),
#  ('Aruba', 2016, 1.091923300517313),
#  ('Bahamas', 2015, None),
#  ('Bahamas', 2016, None),
#  ('Bahamas', 2017, None),
#  ('Bahamas', 2018, None),
#  ('Bahamas', 2019, None),
#  ('Barbados', 2015, 1.5518087995974639),
#  ('Barbados', 2016, 1.5748464676644813),
#  ('Barbados', 2017, 1.6054298910365616),
#  ('Barbados', 2018, 1.62924053973028),
#  ('Barbados', 2019, 1.6714733033535532),
#  ('Barbados', 2020, 1.541159071680806),
#  ('British Virgin Islands', 2015, None),
#  ('British Virgin Islands', 2016, None),
#  ('British Virgin Islands', 2017, None),
#  ('British Virgin Islands', 2018, None),
#  ('British Virgin Islands', 2019, None),
#  ('British Virgin Islands', 2020, None),
#  ('Cayman Islands', 2015, 1.5496879080283263),
#  ('Cayman Islands', 2016, 1.5912739418064292),
#  ('Cuba', 2015, 4.467401256243195),
#  ('Cuba', 2016, 4.514917197010529),
#  ('Cuba', 2017, 4.573163389853005),
#  ('Cuba', 2018, 4.605670061029742),
#  ('Cuba', 2019, 4.638895055389712),
#  ('Cuba', 2020, 4.67609452432479),
#  ('CuraÃ§ao', 2015, None),
#  ('CuraÃ§ao', 2016, None),
#  ('CuraÃ§ao', 2017, None),
#  ('Dominica', 2015, -0.616186139423817),
#  ('Dominica', 2016, -0.5447271754416722),
#  ('Dominica', 2017, -0.6539264674066639),
#  ('Dominican Republic', 2015, 4.264930862797635),
#  ('Dominican Republic', 2016, 4.3267781604434035),
#  ('Dominican Republic', 2017, 4.382026634673881),
#  ('Dominican Republic', 2018, 4.449217884214205),
#  ('Dominican Republic', 2019, 4.48796198508255),
#  ('Dominican Republic', 2020, 4.367420482284519),
#  ('Grenada', 2015, 0.0),
#  ('Grenada', 2016, 0.058268908123975824),
#  ('Grenada', 2017, 0.12221763272424911),
#  ('Guadeloupe', 2015, None),
#  ('Guadeloupe', 2016, None),
#  ('Guadeloupe', 2017, None),
#  ('Guadeloupe', 2018, None),
#  ('Guadeloupe', 2019, None),
#  ('Guadeloupe', 2020, None),
#  ('Haiti', 2015, 2.696652156149841),
#  ('Haiti', 2016, 2.63834278867739),
#  ('Haiti', 2017, 2.7107133185216936),
#  ('Haiti', 2018, 2.800933195248924),
#  ('Haiti', 2019, 2.6939512767227085),
#  ('Haiti', 2020, 2.6748380668960965),
#  ('Jamaica', 2015, 2.6525374911719513),
#  ('Jamaica', 2016, 2.644755350729896),
#  ('Jamaica', 2017, 2.6953026282797072),
#  ('Jamaica', 2018, 2.7555697170701863),
#  ('Jamaica', 2019, 2.761906873892921),
#  ('Jamaica', 2020, 2.6253929674212007),
#  ('Martinique', 2015, None),
#  ('Martinique', 2016, None),
#  ('Martinique', 2017, None),
#  ('Martinique', 2018, None),
#  ('Martinique', 2019, None),
#  ('Martinique', 2020, None),
#  ('Montserrat', 2015, None),
#  ('Montserrat', 2016, None),
#  ('Montserrat', 2017, None),
#  ('Montserrat', 2018, None),
#  ('Montserrat', 2019, None),
#  ('Montserrat', 2020, None),
#  ('Puerto Rico', 2015, 4.638411519767893),
#  ('Puerto Rico', 2016, 4.647654797594247),
#  ('Puerto Rico', 2017, 4.639088404191552),
#  ('Puerto Rico', 2018, 4.6147243987929025),
#  ('Puerto Rico', 2019, 4.655197679587739),
#  ('Puerto Rico', 2020, 4.634923144137439),
#  ('Saint BarthÃ©lemy', 2015, None),
#  ('Saint BarthÃ©lemy', 2016, None),
#  ('Saint BarthÃ©lemy', 2017, None),
#  ('Saint BarthÃ©lemy', 2018, None),
#  ('Saint BarthÃ©lemy', 2019, None),
#  ('Saint BarthÃ©lemy', 2020, None),
#  ('Saint Kitts and Nevis', 2015, None),
#  ('Saint Kitts and Nevis', 2016, None),
#  ('Saint Kitts and Nevis', 2017, None),
#  ('Saint Lucia', 2015, None),
#  ('Saint Lucia', 2016, None),
#  ('Saint Lucia', 2017, None),
#  ('Saint Lucia', 2018, None),
#  ('Saint Lucia', 2019, None),
#  ('Saint Lucia', 2020, None),
#  ('Saint Martin (French Part)', 2015, None),
#  ('Saint Martin (French Part)', 2016, None),
#  ('Saint Martin (French Part)', 2017, None),
#  ('Saint Martin (French Part)', 2018, None),
#  ('Saint Martin (French Part)', 2019, None),
#  ('Saint Martin (French Part)', 2020, None),
#  ('Saint Vincent and the Grenadines', 2015, None),
#  ('Saint Vincent and the Grenadines', 2016, None),
#  ('Saint Vincent and the Grenadines', 2017, None),
#  ('Saint Vincent and the Grenadines', 2018, None),
#  ('Sint Maarten (Dutch part)', 2015, 0.22314355131420976),
#  ('Sint Maarten (Dutch part)', 2016, 0.23111172096338664),
#  ('Sint Maarten (Dutch part)', 2017, 0.17395330712343798),
#  ('Trinidad and Tobago', 2015, 3.2902658209548736),
#  ('Trinidad and Tobago', 2016, 3.1570004211501135),
#  ('Trinidad and Tobago', 2017, 3.169685580677429),
#  ('Trinidad and Tobago', 2018, 3.1912990570979662),
#  ('Trinidad and Tobago', 2019, 3.1717842173343502),
#  ('Trinidad and Tobago', 2020, 3.0473755067058295),
#  ('Turks and Caicos Islands', 2015, -0.06187540371808753),
#  ('Turks and Caicos Islands', 2016, 0.02955880224154443),
#  ('Turks and Caicos Islands', 2017, 0.01980262729617973),
#  ('Turks and Caicos Islands', 2018, 0.10436001532424286),
#  ('United States Virgin Islands', 2015, None),
#  ('United States Virgin Islands', 2016, None),
#  ('United States Virgin Islands', 2017, None),
#  ('United States Virgin Islands', 2018, None),
#  ('United States Virgin Islands', 2019, None),
#  ('United States Virgin Islands', 2020, None),
#  ('Belize', 2015, 0.7929925155296614),
#  ('Belize', 2016, 0.8153648132841944),
#  ('Belize', 2017, 0.8285518175661483),
#  ('Belize', 2018, 0.8372475245337022),
#  ('Belize', 2019, 0.883767540168595),
#  ('Belize', 2020, 0.7323678937132266),
#  ('Costa Rica', 2015, 4.033178126984613),
#  ('Costa Rica', 2016, 4.074991833706286),
#  ('Costa Rica', 2017, 4.102973888920155),
#  ('Costa Rica', 2018, 4.133885736842633),
#  ('Costa Rica', 2019, 4.165424143903053),
#  ('Costa Rica', 2020, 4.129711706059392),
#  ('El Salvador', 2015, 3.154443964708812),
#  ('El Salvador', 2016, 3.185939324621936),
#  ('El Salvador', 2017, 3.2180755046974316),
#  ('El Salvador', 2018, 3.2588654730843594),
#  ('El Salvador', 2019, 3.2913825156549485),
#  ('El Salvador', 2020, 3.2011191032789417),
#  ('Guatemala', 2015, 4.1301942151157975),
#  ('Guatemala', 2016, 4.190412030968334),
#  ('Guatemala', 2017, 4.271793154274181),
#  ('Guatemala', 2018, 4.294969802105708),
#  ('Guatemala', 2019, 4.346010780469512),
#  ('Guatemala', 2020, 4.351953950417589),
#  ('Honduras', 2015, 3.043569602968151),
#  ('Honduras', 2016, 3.0782334950657346),
#  ('Honduras', 2017, 3.1415627217655304),
#  ('Honduras', 2018, 3.1809662517949806),
#  ('Honduras', 2019, 3.222469360378331),
#  ('Honduras', 2020, 3.170945291110651),
#  ('Mexico', 2015, 7.066356042483006),
#  ('Mexico', 2016, 6.983317193648997),
#  ('Mexico', 2017, 7.055235187175323),
#  ('Mexico', 2018, 7.108579599007067),
#  ('Mexico', 2019, 7.145992347903985),
#  ('Mexico', 2020, 6.994409925684416),
#  ('Nicaragua', 2015, 2.546315277916644),
#  ('Nicaragua', 2016, 2.587011872725154),
#  ('Nicaragua', 2017, 2.6239436918052106),
#  ('Nicaragua', 2018, 2.567254391136754),
#  ('Nicaragua', 2019, 2.533696813957432),
#  ('Nicaragua', 2020, 2.532902848056256),
#  ('Panama', 2015, 3.9906493258833358),
#  ('Panama', 2016, 4.058890081237698),
#  ('Panama', 2017, 4.130354999745133),
#  ('Panama', 2018, 4.173309766520395),
#  ('Panama', 2019, 4.204394067366058),
#  ('Panama', 2020, 3.9886136075898584),
#  ('Argentina', 2015, 6.388141149183067),
#  ('Argentina', 2016, 6.323516313545671),
#  ('Argentina', 2017, 6.467124026834869),
#  ('Argentina', 2018, 6.263055346659819),
#  ('Argentina', 2019, 6.1042350409408215),
#  ('Argentina', 2020, 5.954644948969445),
#  ('Bolivia (Plurinational State of)', 2015, None),
#  ('Bolivia (Plurinational State of)', 2016, None),
#  ('Bolivia (Plurinational State of)', 2017, None),
#  ('Bolivia (Plurinational State of)', 2018, None),
#  ('Bolivia (Plurinational State of)', 2019, None),
#  ('Bolivia (Plurinational State of)', 2020, None),
#  ('Brazil', 2015, 7.496768968559263),
#  ('Brazil', 2016, 7.493150197047852),
#  ('Brazil', 2017, 7.632163695316101),
#  ('Brazil', 2018, 7.5584906602850435),
#  ('Brazil', 2019, 7.535440845818948),
#  ('Brazil', 2020, 7.278325238512387),
#  ('Chile', 2015, 5.491001710377538),
#  ('Chile', 2016, 5.518656990529513),
#  ('Chile', 2017, 5.621704363620594),
#  ('Chile', 2018, 5.68833037009728),
#  ('Chile', 2019, 5.629705271259885),
#  ('Chile', 2020, 5.5323217251949925),
#  ('Colombia', 2015, 5.681809493845794),
#  ('Colombia', 2016, 5.644846010432891),
#  ('Colombia', 2017, 5.7426184984413995),
#  ('Colombia', 2018, 5.811739616161293),
#  ('Colombia', 2019, 5.777992822521732),
#  ('Colombia', 2020, 5.599532453282402),
#  ('Ecuador', 2015, 4.598044861045503),
#  ('Ecuador', 2016, 4.604570005916059),
#  ('Ecuador', 2017, 4.647271362006727),
#  ('Ecuador', 2018, 4.678048831400664),
#  ('Ecuador', 2019, 4.68314922730468),
#  ('Ecuador', 2020, 4.598044861045503),
#  ('Falkland Islands (Malvinas)', 2015, None),
#  ('Falkland Islands (Malvinas)', 2016, None),
#  ('Falkland Islands (Malvinas)', 2017, None),
#  ('Falkland Islands (Malvinas)', 2018, None),
#  ('Falkland Islands (Malvinas)', 2019, None),
#  ('Falkland Islands (Malvinas)', 2020, None),
#  ('French Guiana', 2015, None),
#  ('French Guiana', 2016, None),
#  ('French Guiana', 2017, None),
#  ('French Guiana', 2018, None),
#  ('French Guiana', 2019, None),
#  ('French Guiana', 2020, None),
#  ('Guyana', 2015, 1.4539530095937054),
#  ('Guyana', 2016, 1.4996230464268938),
#  ('Guyana', 2017, 1.55814461804655),
#  ('Guyana', 2018, 1.5665304114228238),
#  ('Guyana', 2019, 1.6428726885203377),
#  ('Guyana', 2020, 1.6992786164338898),
#  ('Paraguay', 2015, 3.58933532377755),
#  ('Paraguay', 2016, 3.586015818654697),
#  ('Paraguay', 2017, 3.6635616461296463),
#  ('Paraguay', 2018, 3.694612985961697),
#  ('Paraguay', 2019, 3.6357423557008075),
#  ('Paraguay', 2020, 3.5675589188773804),
#  ('Peru', 2015, 5.246023571826902),
#  ('Peru', 2016, 5.256974403013654),
#  ('Peru', 2017, 5.3519055257179655),
#  ('Peru', 2018, 5.4053764388414445),
#  ('Peru', 2019, 5.430748153728526),
#  ('Peru', 2020, 5.306831022313242),
#  ('Suriname', 2015, 1.6351056591826783),
#  ('Suriname', 2016, 1.199964782928397),
#  ('Suriname', 2017, 1.2781522025001875),
#  ('Suriname', 2018, 1.3862943611198906),
#  ('Suriname', 2019, 1.3912819026309295),
#  ('Suriname', 2020, 1.0681530811834012),
#  ('Uruguay', 2015, 3.9753733209289077),
#  ('Uruguay', 2016, 4.0472529546882505),
#  ('Uruguay', 2017, 4.162470391269701),
#  ('Uruguay', 2018, 4.166975253257008),
#  ('Uruguay', 2019, 4.114637265489863),
#  ('Uruguay', 2020, 3.9808025208229716),
#  ('Venezuela (Bolivarian Republic of)', 2015, None),
#  ('Venezuela (Bolivarian Republic of)', 2016, None),
#  ('Venezuela (Bolivarian Republic of)', 2017, None),
#  ('Venezuela (Bolivarian Republic of)', 2018, None),
#  ('Venezuela (Bolivarian Republic of)', 2019, None),
#  ('Venezuela (Bolivarian Republic of)', 2020, None),
#  ('Algeria', 2015, 5.111867299170302),
#  ('Algeria', 2016, 5.075361297657899),
#  ('Algeria', 2017, 5.136386499401816),
#  ('Algeria', 2018, 5.164271555918972),
#  ('Algeria', 2019, 5.146156372648934),
#  ('Algeria', 2020, 4.976802705559804),
#  ('Egypt', 2015, None),
#  ('Egypt', 2016, None),
#  ('Egypt', 2017, None),
#  ('Egypt', 2018, None),
#  ('Egypt', 2019, None),
#  ('Egypt', 2020, None),
#  ('Libya', 2015, 3.8860896234016415),
#  ('Libya', 2016, 3.9102213834815176),
#  ('Libya', 2017, 4.20707783220934),
#  ('Libya', 2018, 4.339640918177444),
#  ('Libya', 2019, 4.237723145067448),
#  ('Libya', 2020, 3.9191972091761462),
#  ('Morocco', 2015, 4.704200709451046),
#  ('Morocco', 2016, 4.714652196605089),
#  ('Morocco', 2017, 4.775250456359692),
#  ('Morocco', 2018, 4.846860674588879),
#  ('Morocco', 2019, 4.859192056947237),
#  ('Morocco', 2020, 4.79867893217261),
#  ('Sudan', 2015, 4.442533602510535),
#  ('Sudan', 2016, 4.6341462942246086),
#  ('Sudan', 2017, 4.865378281439117),
#  ('Sudan', 2018, 3.4759955917373415),
#  ('Sudan', 2019, 3.4763048541489607),
#  ('Sudan', 2020, 3.2969473602883563),
#  ('Tunisia', 2015, 3.8238473145244205),
#  ('Tunisia', 2016, 3.7923381624821664),
#  ('Tunisia', 2017, 3.741471904233107),
#  ('Tunisia', 2018, 3.7539647007698704),
#  ('Tunisia', 2019, 3.73552446193698),
#  ('Tunisia', 2020, 3.750444809772091),
#  ('Armenia', 2015, 2.3561258599220753),
#  ('Armenia', 2016, 2.3561258599220753),
#  ('Armenia', 2017, 2.4449523342809676),
#  ('Armenia', 2018, 2.522523513359307),
#  ('Armenia', 2019, 2.611539300721366),
#  ('Armenia', 2020, 2.5368663887187113),
#  ('Azerbaijan', 2015, 3.9716117968398037),
#  ('Azerbaijan', 2016, 3.634159241913703),
#  ('Azerbaijan', 2017, 3.7103962975761857),
#  ('Azerbaijan', 2018, 3.85248529271195),
#  ('Azerbaijan', 2019, 3.8747364206421295),
#  ('Azerbaijan', 2020, 3.7539647007698704),
#  ('Bahrain', 2015, 3.435598808379488),
#  ('Bahrain', 2016, 3.4728976958273465),
#  ('Bahrain', 2017, 3.5686872687855304),
#  ('Bahrain', 2018, 3.632309102625542),
#  ('Bahrain', 2019, 3.654546775033431),
#  ('Bahrain', 2020, 3.5473158897921495),
#  ('Cyprus', 2015, 2.991222118076105),
#  ('Cyprus', 2016, 3.0469005601283903),
#  ('Cyprus', 2017, 3.133317936506554),
#  ('Cyprus', 2018, 3.242592351485517),
#  ('Cyprus', 2019, 3.255786178888298),
#  ('Cyprus', 2020, 3.219275744889528),
#  ('Georgia', 2015, 2.7047112998366956),
#  ('Georgia', 2016, 2.717340248009303),
#  ('Georgia', 2017, 2.787477334733532),
#  ('Georgia', 2018, 2.8678989020441064),
#  ('Georgia', 2019, 2.8604851241459652),
#  ('Georgia', 2020, 2.7625383863862796),
#  ('Iraq', 2015, 5.116615617633488),
#  ('Iraq', 2016, 5.115595729732743),
#  ('Iraq', 2017, 5.232284395943599),
#  ('Iraq', 2018, 5.426578646492048),
#  ('Iraq', 2019, 5.4537814691721085),
#  ('Iraq', 2020, 5.216944608082299),
#  ('Israel', 2015, 5.715085026160327),
#  ('Israel', 2016, 5.774862056337153),
#  ('Israel', 2017, 5.881231066708281),
#  ('Israel', 2018, 5.931422568022302),
#  ('Israel', 2019, 5.997620559919318),
#  ('Israel', 2020, 6.024101132384248),
#  ('Jordan', 2015, 3.6529931755495273),
#  ('Jordan', 2016, 3.686125665917315),
#  ('Jordan', 2017, 3.72834052299485),
#  ('Jordan', 2018, 3.7697679578472747),
#  ('Jordan', 2019, 3.806440242853081),
#  ('Jordan', 2020, 3.788272197991971),
#  ('Kuwait', 2015, 4.741185989905534),
#  ('Kuwait', 2016, 4.69519368863568),
#  ('Kuwait', 2017, 4.793390974713035),
#  ('Kuwait', 2018, 4.928557183060649),
#  ('Kuwait', 2019, 4.9141243937154115),
#  ('Kuwait', 2020, 4.663061664403869),
#  ('Lebanon', 2015, 3.910622024512518),
#  ('Lebanon', 2016, 3.9347624923976356),
#  ('Lebanon', 2017, 3.970857791149039),
#  ('Lebanon', 2018, 4.005513348515485),
#  ('Lebanon', 2019, 3.9502817175452365),
#  ('Lebanon', 2020, 3.456632088550256),
#  ('Oman', 2015, 4.3657702121543585),
#  ('Oman', 2016, 4.319219946381069),
#  ('Oman', 2017, 4.392719264212625),
#  ('Oman', 2018, 4.516448255927287),
#  ('Oman', 2019, 4.478018400327608),
#  ('Oman', 2020, 4.3295484280286765),
#  ('Qatar', 2015, 5.085990107667676),
#  ('Qatar', 2016, 5.0221026255371495),
#  ('Qatar', 2017, 5.082025290182929),
#  ('Qatar', 2018, 5.211287807574934),
#  ('Qatar', 2019, 5.169574490655311),
#  ('Qatar', 2020, 4.972656476138474),
#  ('Saudi Arabia', 2015, 6.483520110297245),
#  ('Saudi Arabia', 2016, 6.469157289213027),
#  ('Saudi Arabia', 2017, 6.53464602857998),
#  ('Saudi Arabia', 2018, 6.705124886790298),
#  ('Saudi Arabia', 2019, 6.68912652063506),
#  ('Saudi Arabia', 2020, 6.555883069144563),
#  ('State of Palestine', 2015, None),
#  ('State of Palestine', 2016, None),
#  ('State of Palestine', 2017, None),
#  ('State of Palestine', 2018, None),
#  ('State of Palestine', 2019, None),
#  ('State of Palestine', 2020, None),
#  ('Syrian Arab Republic', 2015, 2.8015405441895487),
#  ('Syrian Arab Republic', 2016, 2.533696813957432),
#  ('Syrian Arab Republic', 2017, 2.7954503913830435),
#  ('Syrian Arab Republic', 2018, 3.0610517396746335),
#  ('Syrian Arab Republic', 2019, 3.110845080654496),
#  ('Syrian Arab Republic', 2020, 2.405141681319138),
#  ('TÃ¼rkiye', 2015, None),
#  ('TÃ¼rkiye', 2016, None),
#  ('TÃ¼rkiye', 2017, None),
#  ('TÃ¼rkiye', 2018, None),
#  ('TÃ¼rkiye', 2019, None),
#  ('TÃ¼rkiye', 2020, None),
#  ('United Arab Emirates', 2015, 5.91425947619901),
#  ('United Arab Emirates', 2016, 5.911501002967597),
#  ('United Arab Emirates', 2017, 5.967479184357471),
#  ('United Arab Emirates', 2018, 6.056901102392156),
#  ('United Arab Emirates', 2019, 6.03545750879361),
#  ('United Arab Emirates', 2020, 5.856417721079795),
#  ('Yemen', 2015, None),
#  ('Yemen', 2016, None),
#  ('Yemen', 2017, None),
#  ('Yemen', 2018, None),
#  ('Yemen', 2019, None),
#  ('Yemen', 2020, None),
#  ('Australia', 2015, 7.208319025264479),
#  ('Australia', 2016, 7.095512038266031),
#  ('Australia', 2017, 7.190314250735147),
#  ('Australia', 2018, 7.264233203513821),
#  ('Australia', 2019, 7.238662057130468),
#  ('Australia', 2020, 7.190600673542391),
#  ('New Zealand', 2015, 5.182120572145525),
#  ('New Zealand', 2016, 5.240900095678086),
#  ('New Zealand', 2017, 5.330881357421299),
#  ('New Zealand', 2018, 5.356350397798646),
#  ('New Zealand', 2019, 5.363308910055477),
#  ('New Zealand', 2020, 5.355311878067845),
#  ('Fiji', 2015, 1.5432981099295553),
#  ('Fiji', 2016, 1.5953389880545987),
#  ('Fiji', 2017, 1.6770965609079151),
#  ('Fiji', 2018, 1.7191887763932197),
#  ('Fiji', 2019, 1.7011051009599243),
#  ('Fiji', 2020, 1.4996230464268938),
#  ('New Caledonia', 2015, 2.167910189667444),
#  ('New Caledonia', 2016, 2.1656192379208883),
#  ('New Caledonia', 2017, 2.2159372862683733),
#  ('New Caledonia', 2018, 2.2874714551839976),
#  ('New Caledonia', 2019, 2.244955980157409),
#  ('New Caledonia', 2020, 2.244955980157409),
#  ('Papua New Guinea', 2015, 3.0782334950657346),
#  ('Papua New Guinea', 2016, 3.033028058297688),
#  ('Papua New Guinea', 2017, 3.12412548832239),
#  ('Papua New Guinea', 2018, 3.1826266921930797),
#  ('Papua New Guinea', 2019, 3.2088254890146994),
#  ('Papua New Guinea', 2020, 3.1717842173343502),
#  ('Solomon Islands', 2015, 0.2700271372130602),
#  ('Solomon Islands', 2016, 0.3220834991691132),
#  ('Solomon Islands', 2017, 0.3852624007906449),
#  ('Solomon Islands', 2018, 0.4824261492442928),
#  ('Solomon Islands', 2019, 0.4824261492442928),
#  ('Solomon Islands', 2020, 0.43178241642553783),
#  ('Vanuatu', 2015, -0.31471074483970024),
#  ('Vanuatu', 2016, -0.2484613592984996),
#  ('Vanuatu', 2017, -0.12783337150988489),
#  ('Vanuatu', 2018, -0.09431067947124129),
#  ('Vanuatu', 2019, -0.06187540371808753),
#  ('Vanuatu', 2020, -0.10536051565782628),
#  ('Guam', 2015, 1.7578579175523736),
#  ('Guam', 2016, 1.7749523509116738),
#  ('Guam', 2017, 1.7934247485471162),
#  ('Guam', 2018, 1.801709800081223),
#  ('Guam', 2019, 1.851599469584072),
#  ('Guam', 2020, 1.7732559976634952),
#  ('Kiribati', 2015, -1.7719568419318752),
#  ('Kiribati', 2016, -1.7147984280919266),
#  ('Kiribati', 2017, -1.6607312068216509),
#  ('Kiribati', 2018, -1.6094379124341003),
#  ('Kiribati', 2019, -1.7147984280919266),
#  ('Kiribati', 2020, -1.7147984280919266),
#  ('Marshall Islands', 2015, -1.7147984280919266),
#  ('Marshall Islands', 2016, -1.6094379124341003),
#  ('Marshall Islands', 2017, -1.5606477482646683),
#  ('Marshall Islands', 2018, -1.5141277326297755),
#  ('Marshall Islands', 2019, -1.4696759700589417),
#  ('Marshall Islands', 2020, -1.4271163556401458),
#  ('Micronesia (Federated States of)', 2015, None),
#  ('Micronesia (Federated States of)', 2016, None),
#  ('Micronesia (Federated States of)', 2017, None),
#  ('Micronesia (Federated States of)', 2018, None),
#  ('Micronesia (Federated States of)', 2019, None),
#  ('Nauru', 2015, -2.4079456086518722),
#  ('Nauru', 2016, -2.3025850929940455),
#  ('Nauru', 2017, -2.2072749131897207),
#  ('Nauru', 2018, -2.120263536200091),
#  ('Nauru', 2019, -2.120263536200091),
#  ('Nauru', 2020, -2.2072749131897207),
#  ('Northern Mariana Islands', 2015, -0.09431067947124129),
#  ('Northern Mariana Islands', 2016, 0.20701416938432612),
#  ('Northern Mariana Islands', 2017, 0.44468582126144574),
#  ('Northern Mariana Islands', 2018, 0.26236426446749106),
#  ('Northern Mariana Islands', 2019, 0.16551443847757333),
#  ('Northern Mariana Islands', 2020, None),
#  ('Palau', 2015, -1.2729656758128873),
#  ('Palau', 2016, -1.2039728043259361),
#  ('Palau', 2017, -1.2378743560016174),
#  ('Palau', 2018, -1.2729656758128873),
#  ('Palau', 2019, -1.2729656758128873),
#  ('Palau', 2020, -1.3862943611198906),
#  ('American Samoa', 2015, -0.40047756659712525),
#  ('American Samoa', 2016, -0.40047756659712525),
#  ('American Samoa', 2017, -0.4942963218147801),
#  ('American Samoa', 2018, -0.4462871026284195),
#  ('American Samoa', 2019, -0.4307829160924542),
#  ('American Samoa', 2020, -0.3285040669720361),
#  ('Cook Islands', 2015, None),
#  ('Cook Islands', 2016, None),
#  ('Cook Islands', 2017, None),
#  ('Cook Islands', 2018, None),
#  ('Cook Islands', 2019, None),
#  ('Cook Islands', 2020, None),
#  ('French Polynesia', 2015, 1.673351238177753),
#  ('French Polynesia', 2016, 1.7047480922384253),
#  ('French Polynesia', 2017, 1.763017000362401),
#  ('French Polynesia', 2018, 1.814824742159051),
#  ('French Polynesia', 2019, 1.791759469228055),
#  ('French Polynesia', 2020, 1.742219023667919),
#  ('Niue', 2015, None),
#  ('Niue', 2016, None),
#  ('Niue', 2017, None),
#  ('Niue', 2018, None),
#  ('Niue', 2019, None),
#  ('Niue', 2020, None),
#  ('Samoa', 2015, -0.19845093872383832),
#  ('Samoa', 2016, -0.1743533871447778),
#  ('Samoa', 2017, -0.12783337150988489),
#  ('Samoa', 2018, -0.12783337150988489),
#  ('Samoa', 2019, -0.09431067947124129),
#  ('Samoa', 2020, -0.13926206733350766),
#  ('Tokelau', 2015, None),
#  ('Tokelau', 2016, None),
#  ('Tokelau', 2017, None),
#  ('Tokelau', 2018, None),
#  ('Tokelau', 2019, None),
#  ('Tokelau', 2020, None),
#  ('Tonga', 2015, -0.8209805520698302),
#  ('Tonga', 2016, -0.8675005677047231),
#  ('Tonga', 2017, -0.7765287894989963),
#  ('Tonga', 2018, -0.7133498878774648),
#  ('Tonga', 2019, -0.6733445532637656),
#  ('Tonga', 2020, -0.7339691750802004),
#  ('Tuvalu', 2015, -3.2188758248682006),
#  ('Tuvalu', 2016, -3.2188758248682006),
#  ('Tuvalu', 2017, -2.995732273553991),
#  ('Tuvalu', 2018, -2.995732273553991),
#  ('Tuvalu', 2019, -2.995732273553991),
#  ('Tuvalu', 2020, -2.8134107167600364),
#  ('Wallis and Futuna Islands', 2015, None),
#  ('Wallis and Futuna Islands', 2016, None),
#  ('Wallis and Futuna Islands', 2017, None),
#  ('Wallis and Futuna Islands', 2018, None),
#  ('Wallis and Futuna Islands', 2019, None),
#  ('Wallis and Futuna Islands', 2020, None),
#  ('Burundi', 2015, 1.1314021114911006),
#  ('Burundi', 2016, 0.9707789171582248),
#  ('Burundi', 2017, 0.9969486348916096),
#  ('Burundi', 2018, 0.9783261227936078),
#  ('Burundi', 2019, 0.9477893989335261),
#  ('Burundi', 2020, 0.9745596399981308),
#  ('Comoros', 2015, -0.030459207484708574),
#  ('Comoros', 2016, 0.009950330853168092),
#  ('Comoros', 2017, 0.0769610411361284),
#  ('Comoros', 2018, 0.17395330712343798),
#  ('Comoros', 2019, 0.1823215567939546),
#  ('Djibouti', 2015, 0.883767540168595),
#  ('Djibouti', 2016, 0.9555114450274363),
#  ('Djibouti', 2017, 1.0152306797290584),
#  ('Djibouti', 2018, 1.0681530811834012),
#  ('Djibouti', 2019, 1.128171090909654),
#  ('Djibouti', 2020, 1.1568811967920856),
#  ('Eritrea', 2015, None),
#  ('Eritrea', 2016, None),
#  ('Ethiopia', 2015, 4.168059600044382),
#  ('Ethiopia', 2016, 4.308110951723713),
#  ('Ethiopia', 2017, 4.4039104281738854),
#  ('Ethiopia', 2018, 4.434025929784262),
#  ('Ethiopia', 2019, 4.563410251739859),
#  ('Ethiopia', 2020, 4.678978113132811),
#  ('Kenya', 2015, 4.250208060053033),
#  ('Kenya', 2016, 4.31508522892),
#  ('Kenya', 2017, 4.40720693320418),
#  ('Kenya', 2018, 4.523960130562548),
#  ('Kenya', 2019, 4.608962984226787),
#  ('Kenya', 2020, 4.611847840741332),
#  ('Madagascar', 2015, 2.4265710727750367),
#  ('Madagascar', 2016, 2.47232786758114),
#  ('Madagascar', 2017, 2.578700529074361),
#  ('Madagascar', 2018, 2.6217658325051976),
#  ('Madagascar', 2019, 2.6461747973841225),
#  ('Madagascar', 2020, 2.5687881337687024),
#  ('Malawi', 2015, 1.851599469584072),
#  ('Malawi', 2016, 1.691939133945844),
#  ('Malawi', 2017, 2.190535589185423),
#  ('Malawi', 2018, 2.2905125117597764),
#  ('Malawi', 2019, 2.400618833265411),
#  ('Malawi', 2020, 2.4997952622817508),
#  ('Mauritius', 2015, 2.485739636091892),
#  ('Mauritius', 2016, 2.532902848056256),
#  ('Mauritius', 2017, 2.6181254935742233),
#  ('Mauritius', 2018, 2.6905648867611904),
#  ('Mauritius', 2019, 2.67000213346468),
#  ('Mauritius', 2020, 2.4336133554004498),
#  ('Mayotte', 2015, None),
#  ('Mayotte', 2016, None),
#  ('Mayotte', 2017, None),
#  ('Mayotte', 2018, None),
#  ('Mayotte', 2019, None),
#  ('Mayotte', 2020, None),
#  ('Mozambique', 2015, 2.7694588292308535),
#  ('Mozambique', 2016, 2.479894107964456),
#  ('Mozambique', 2017, 2.5817308344235403),
#  ('Mozambique', 2018, 2.6979998652487085),
#  ('Mozambique', 2019, 2.733717947850788),
#  ('Mozambique', 2020, 2.6411978941143697),
#  ('Rwanda', 2015, 2.1447610078004784),
#  ('Rwanda', 2016, 2.162172939277301),
#  ('Rwanda', 2017, 2.224623551524334),
#  ('Rwanda', 2018, 2.265921108622454),
#  ('Rwanda', 2019, 2.337952236831337),
#  ('Rwanda', 2020, 2.3204250111223765),
#  ('RÃ©union', 2015, None),
#  ('RÃ©union', 2016, None),
#  ('RÃ©union', 2017, None),
#  ('RÃ©union', 2018, None),
#  ('RÃ©union', 2019, None),
#  ('RÃ©union', 2020, None),
#  ('Seychelles', 2015, 0.35065687161316933),
#  ('Seychelles', 2016, 0.3987761199573678),
#  ('Seychelles', 2017, 0.45107561936021673),
#  ('Seychelles', 2018, 0.494696241836107),
#  ('Seychelles', 2019, 0.5187937934151675),
#  ('Somalia', 2015, 1.673351238177753),
#  ('Somalia', 2016, 1.7101878155342434),
#  ('Somalia', 2017, 1.724550719534605),
#  ('Somalia', 2018, 1.7681496035889213),
#  ('Somalia', 2019, 1.8702625307159986),
#  ('Somalia', 2020, 1.9286186519452522),
#  ('South Sudan', 2015, 2.4849066497880004),
#  ('South Sudan', 2016, None),
#  ('South Sudan', 2017, None),
#  ('South Sudan', 2018, None),
#  ('South Sudan', 2019, None),
#  ('South Sudan', 2020, None),
#  ('Uganda', 2015, 3.477849733183238),
#  ('Uganda', 2016, 3.374168709274236),
#  ('Uganda', 2017, 3.4255647381104497),
#  ('Uganda', 2018, 3.494384096388273),
#  ('Uganda', 2019, 3.565298392342582),
#  ('Uganda', 2020, 3.6270040503958487),
#  ('United Republic of Tanzania', 2015, None),
#  ('United Republic of Tanzania', 2016, None),
#  ('United Republic of Tanzania', 2017, None),
#  ('United Republic of Tanzania', 2018, None),
#  ('United Republic of Tanzania', 2019, None),
#  ('United Republic of Tanzania', 2020, None),
#  ('Zambia', 2015, 3.056356895370426),
#  ('Zambia', 2016, 3.0426158594528414),
#  ('Zambia', 2017, 3.2530839961979376),
#  ('Zambia', 2018, 3.269949095052201),
#  ('Zambia', 2019, 3.1488824530476656),
#  ('Zambia', 2020, 2.896464271895322),
#  ('Zimbabwe', 2015, 2.993730270883318),
#  ('Zimbabwe', 2016, 3.022860940942244),
#  ('Zimbabwe', 2017, 2.866761892257031),
#  ('Zimbabwe', 2018, 3.531055368920369),
#  ('Zimbabwe', 2019, 3.0832851705618523),
#  ('Zimbabwe', 2020, 3.068517943279639),
#  ('Angola', 2015, 4.46843366241462),
#  ('Angola', 2016, 3.908817874479198),
#  ('Angola', 2017, 4.2336716274432),
#  ('Angola', 2018, 4.354012888218683),
#  ('Angola', 2019, 4.238589195929893),
#  ('Angola', 2020, 3.981922132807813),
#  ('Cameroon', 2015, 3.4722769633431074),
#  ('Cameroon', 2016, 3.520756616719795),
#  ('Cameroon', 2017, 3.586292865338835),
#  ('Cameroon', 2018, 3.688129172723232),
#  ('Cameroon', 2019, 3.6805952345262387),
#  ('Cameroon', 2020, 3.707946516831162),
#  ('Central African Republic', 2015, 0.5306282510621704),
#  ('Central African Republic', 2016, 0.6043159668533296),
#  ('Central African Republic', 2017, 0.7275486072772777),
#  ('Central African Republic', 2018, 0.7975071958841882),
#  ('Central African Republic', 2019, 0.7975071958841882),
#  ('Central African Republic', 2020, 0.8458682675776092),
#  ('Chad', 2015, 2.3933394562625097),
#  ('Chad', 2016, 2.312535423847214),
#  ('Chad', 2017, 2.302585092994046),
#  ('Chad', 2018, 2.419478844465545),
#  ('Chad', 2019, 2.425687290128029),
#  ('Chad', 2020, 2.372111155642656),
#  ('Congo', 2015, None),
#  ('Congo', 2016, None),
#  ('Congo', 2017, None),
#  ('Congo', 2018, None),
#  ('Congo', 2019, None),
#  ('Congo', 2020, None),
#  ('Democratic Republic of the Congo', 2015, None),
#  ('Democratic Republic of the Congo', 2016, None),
#  ('Democratic Republic of the Congo', 2017, None),
#  ('Democratic Republic of the Congo', 2018, None),
#  ('Democratic Republic of the Congo', 2019, None),
#  ('Democratic Republic of the Congo', 2020, None),
#  ('Equatorial Guinea', 2015, 2.579458966729223),
#  ('Equatorial Guinea', 2016, 2.419478844465545),
#  ('Equatorial Guinea', 2017, 2.501435951739211),
#  ('Gabon', 2015, 2.6658383522929006),
#  ('Gabon', 2016, 2.640484881606444),
#  ('Gabon', 2017, 2.703372611551099),
#  ('Gabon', 2018, 2.825536896557877),
#  ('Gabon', 2019, 2.825536896557877),
#  ('Gabon', 2020, 2.7285062096695922),
#  ('Sao Tome and Principe', 2015, -1.1394342831883648),
#  ('Sao Tome and Principe', 2016, -1.0498221244986778),
#  ('Sao Tome and Principe', 2017, -0.9675840262617056),
#  ('Sao Tome and Principe', 2018, -0.8915981192837836),
#  ('Sao Tome and Principe', 2019, -0.843970070294529),
#  ('Sao Tome and Principe', 2020, -0.7550225842780328),
#  ('Botswana', 2015, 2.604909442182697),
#  ('Botswana', 2016, 2.71336936257981),
#  ('Botswana', 2017, 2.779440197188883),
#  ('Botswana', 2018, 2.834976494674597),
#  ('Botswana', 2019, 2.8154087194227095),
#  ('Botswana', 2020, 2.703372611551099),
#  ('Eswatini', 2015, 1.4011829736136412),
#  ('Eswatini', 2016, 1.3402504226184837),
#  ('Eswatini', 2017, 1.4816045409242156),
#  ('Eswatini', 2018, 1.541159071680806),
#  ('Eswatini', 2019, 1.5040773967762742),
#  ('Eswatini', 2020, 1.3812818192963463),
#  ('Lesotho', 2015, 0.8586616190375187),
#  ('Lesotho', 2016, 0.7466879474879751),
#  ('Lesotho', 2017, 0.8372475245337022),
#  ('Lesotho', 2018, 0.9360933591703348),
#  ('Lesotho', 2019, 0.8960880245566357),
#  ('Lesotho', 2020, 0.8020015854720274),
#  ('Namibia', 2015, 2.428336298299606),
#  ('Namibia', 2016, 2.372111155642656),
#  ('Namibia', 2017, 2.5572273113676265),
#  ('Namibia', 2018, 2.615934912194404),
#  ('Namibia', 2019, 2.5289235352047745),
#  ('Namibia', 2020, 2.3589654264301534),
#  ('South Africa', 2015, 5.848488695655459),
#  ('South Africa', 2016, 5.779477282358271),
#  ('South Africa', 2017, 5.943979780536238),
#  ('South Africa', 2018, 6.001810839162126),
#  ('South Africa', 2019, 5.962370386903605),
#  ('South Africa', 2020, 5.821921002673243),
#  ('Benin', 2015, 2.432735777459091),
#  ('Benin', 2016, 2.469793011977952),
#  ('Benin', 2017, 2.5416019934645457),
#  ('Benin', 2018, 2.65745841498615),
#  ('Benin', 2019, 2.6665335208992764),
#  ('Benin', 2020, 2.750470916986162),
#  ('Burkina Faso', 2015, 2.4706386779902956),
#  ('Burkina Faso', 2016, 2.551786178627545),
#  ('Burkina Faso', 2017, 2.6468837658647226),
#  ('Burkina Faso', 2018, 2.7656899805486246),
#  ('Burkina Faso', 2019, 2.7837759116303458),
#  ('Burkina Faso', 2020, 2.8864752876170416),
#  ('Cabo Verde', 2015, 0.47000362924573563),
#  ('Cabo Verde', 2016, 0.5068176023684519),
#  ('Cabo Verde', 2017, 0.5709795465857378),
#  ('Cabo Verde', 2018, 0.6780335427498971),
#  ('Cabo Verde', 2019, 0.6830968447064438),
#  ('Cabo Verde', 2020, 0.5306282510621704),
#  ("CÃ´te d'Ivoire", 2015, None),
#  ("CÃ´te d'Ivoire", 2016, None),
#  ("CÃ´te d'Ivoire", 2017, None),
#  ("CÃ´te d'Ivoire", 2018, None),
#  ("CÃ´te d'Ivoire", 2019, None),
#  ("CÃ´te d'Ivoire", 2020, None),
#  ('Gambia', 2015, None),
#  ('Gambia', 2016, None),
#  ('Gambia', 2017, None),
#  ('Gambia', 2018, None),
#  ('Gambia', 2019, None),
#  ('Gambia', 2020, None),
#  ('Ghana', 2015, 3.9001528328576587),
#  ('Ghana', 2016, 4.028382806544341),
#  ('Ghana', 2017, 4.101154654150649),
#  ('Ghana', 2018, 4.209160236650682),
#  ('Ghana', 2019, 4.2244952466871455),
#  ('Ghana', 2020, 4.249066507417651),
#  ('Guinea', 2015, 2.1736147116970854),
#  ('Guinea', 2016, 2.151762203259462),
#  ('Guinea', 2017, 2.334083760053417),
#  ('Guinea', 2018, 2.4731713935695794),
#  ('Guinea', 2019, 2.5982353350950036),
#  ('Guinea', 2020, 2.6518325211039815),
#  ('Guinea-Bissau', 2015, 0.04879016416943204),
#  ('Guinea-Bissau', 2016, 0.16551443847757333),
#  ('Guinea-Bissau', 2017, 0.30010459245033816),
#  ('Guinea-Bissau', 2018, 0.4054651081081644),
#  ('Guinea-Bissau', 2019, 0.36464311358790924),
#  ('Guinea-Bissau', 2020, 0.3576744442718159),
#  ('Liberia', 2015, 1.172482137234565),
#  ('Liberia', 2016, 1.2237754316221157),
#  ('Liberia', 2017, 1.220829921392359),
#  ('Liberia', 2018, 1.2296405510745139),
#  ('Liberia', 2019, 1.199964782928397),
#  ('Liberia', 2020, 1.1118575154181303),
#  ...]

# %% [markdown]
# **7. What is the square root of GDP for each country over the time period?**
#
# Alternatively, to get a similar effect, we could use the SQRT function to calculate the square roots of the values in the Est_gdp_in_billions column in order to get a smaller representation of these values.

# %%
# %%sql
#
# Select Country_name,
#     Time_period,
#     SQRT(Est_gdp_in_billions) AS SQRT_est_gdp_in_billions
# FROM Access_to_Basic_Services
#
# LIMIT 10;
# Out:
#  * mysql+pymysql://root:***@127.0.0.1:3306/united_nations
# 10 rows affected.
# [('Kazakhstan', 2015, 13.579027947537334),
#  ('Kazakhstan', 2016, 11.716654812701448),
#  ('Kazakhstan', 2017, 12.915494570476191),
#  ('Kazakhstan', 2018, 13.391788528796294),
#  ('Kazakhstan', 2019, 13.478501400378308),
#  ('Kazakhstan', 2020, 13.079755349393963),
#  ('Kyrgyzstan', 2015, None),
#  ('Kyrgyzstan', 2016, None),
#  ('Kyrgyzstan', 2017, None),
#  ('Kyrgyzstan', 2018, None)]
