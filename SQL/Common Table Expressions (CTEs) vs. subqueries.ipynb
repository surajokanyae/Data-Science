# %%
#Preparing sql environment
# %load_ext sql

# %%
# %sql mysql+pymysql://root:0479%40Kanya@127.0.0.1:3306/united_nations

# %% [markdown]
# **Task 1: Calculate the average GDP for each region**
#
# Start by calculating the average GDP for each country’s region for 2020 using the AVG(Est_gdp_in_billions) OVER(PARTITION BY Region) window function.

# %%
# %%sql
# SELECT
#     Region,
#     Country_name,
#     Pct_managed_drinking_water_services,
#     Pct_managed_sanitation_services,
#     Est_gdp_in_billions,
#     AVG(Est_gdp_in_billions) OVER(PARTITION BY Region) AS Avg_gdp_for_region
# FROM united_nations.Access_to_Basic_Services
# WHERE Time_period = 2020;
# Out:
#  * mysql+pymysql://root:***@127.0.0.1:3306/united_nations
# 165 rows affected.
# [('Central and Southern Asia', 'Kazakhstan', 95.0, 98, 171.08, 338.7381818181818),
#  ('Central and Southern Asia', 'Kyrgyzstan', 92.67, 98, None, 338.7381818181818),
#  ('Central and Southern Asia', 'Tajikistan', 85.0, 96, 8.13, 338.7381818181818),
#  ('Central and Southern Asia', 'Turkmenistan', 100.0, 99, None, 338.7381818181818),
#  ('Central and Southern Asia', 'Uzbekistan', 98.0, 100, 59.89, 338.7381818181818),
#  ('Central and Southern Asia', 'Afghanistan', 80.33, 54, 20.14, 338.7381818181818),
#  ('Central and Southern Asia', 'Bangladesh', 97.67, 54, 373.9, 338.7381818181818),
#  ('Central and Southern Asia', 'Bhutan', 97.33, 77, 2.33, 338.7381818181818),
#  ('Central and Southern Asia', 'India', 91.0, 72, 2667.69, 338.7381818181818),
#  ('Central and Southern Asia', 'Iran (Islamic Republic of)', 96.67, 88, None, 338.7381818181818),
#  ('Central and Southern Asia', 'Maldives', 99.67, 99, 3.75, 338.7381818181818),
#  ('Central and Southern Asia', 'Nepal', 90.0, 77, 33.43, 338.7381818181818),
#  ('Central and Southern Asia', 'Pakistan', 90.67, 70, 300.43, 338.7381818181818),
#  ('Central and Southern Asia', 'Sri Lanka', 94.33, 94, 85.35, 338.7381818181818),
#  ('Eastern and South-Eastern Asia', 'China', 93.67, 92, 14687.67, 1871.9016666666664),
#  ('Eastern and South-Eastern Asia', "Democratic People's Republic of Korea", 93.33, 83, None, 1871.9016666666664),
#  ('Eastern and South-Eastern Asia', 'Japan', 99.0, 100, 5040.11, 1871.9016666666664),
#  ('Eastern and South-Eastern Asia', 'Mongolia', 81.0, 65, 13.31, 1871.9016666666664),
#  ('Eastern and South-Eastern Asia', 'Republic of Korea', 100.0, 100, None, 1871.9016666666664),
#  ('Eastern and South-Eastern Asia', 'Brunei Darussalam', 100.0, None, 12.01, 1871.9016666666664),
#  ('Eastern and South-Eastern Asia', 'Cambodia', 75.33, 74, 25.87, 1871.9016666666664),
#  ('Eastern and South-Eastern Asia', 'Indonesia', 92.0, 86, 1058.69, 1871.9016666666664),
#  ('Eastern and South-Eastern Asia', "Lao People's Democratic Republic", 86.67, 82, None, 1871.9016666666664),
#  ('Eastern and South-Eastern Asia', 'Malaysia', 95.33, 100, 337.34, 1871.9016666666664),
#  ('Eastern and South-Eastern Asia', 'Myanmar', 85.67, 75, 78.93, 1871.9016666666664),
#  ('Eastern and South-Eastern Asia', 'Philippines', 94.0, 82, 361.75, 1871.9016666666664),
#  ('Eastern and South-Eastern Asia', 'Singapore', 100.0, 100, 345.3, 1871.9016666666664),
#  ('Eastern and South-Eastern Asia', 'Thailand', 100.0, 99, 499.68, 1871.9016666666664),
#  ('Eastern and South-Eastern Asia', 'Timor-Leste', 87.0, 60, 2.16, 1871.9016666666664),
#  ('Eastern and South-Eastern Asia', 'Viet Nam', 97.33, 90, None, 1871.9016666666664),
#  ('Europe and Northern America', 'Bermuda', 100.0, 100, 6.89, 551.7966666666667),
#  ('Europe and Northern America', 'Canada', 99.0, 99, 1645.42, 551.7966666666667),
#  ('Europe and Northern America', 'Greenland', 100.0, 100, 3.08, 551.7966666666667),
#  ('Europe and Northern America', 'Saint Pierre and Miquelon', 91.0, 100, None, 551.7966666666667),
#  ('Europe and Northern America', 'United States of America', 100.0, 100, None, 551.7966666666667),
#  ('Latin America and the Caribbean', 'Barbados', 99.0, 98, 4.67, 177.84440000000006),
#  ('Latin America and the Caribbean', 'British Virgin Islands', 100.0, None, None, 177.84440000000006),
#  ('Latin America and the Caribbean', 'Cuba', 96.33, 90, 107.35, 177.84440000000006),
#  ('Latin America and the Caribbean', 'Dominican Republic', 95.0, 84, 78.84, 177.84440000000006),
#  ('Latin America and the Caribbean', 'Guadeloupe', 100.0, 100, None, 177.84440000000006),
#  ('Latin America and the Caribbean', 'Haiti', 65.0, 36, 14.51, 177.84440000000006),
#  ('Latin America and the Caribbean', 'Jamaica', 90.33, 87, 13.81, 177.84440000000006),
#  ('Latin America and the Caribbean', 'Martinique', 100.0, 100, None, 177.84440000000006),
#  ('Latin America and the Caribbean', 'Montserrat', 98.0, 89, None, 177.84440000000006),
#  ('Latin America and the Caribbean', 'Puerto Rico', 100.0, 100, 103.02, 177.84440000000006),
#  ('Latin America and the Caribbean', 'Saint BarthÃ©lemy', 100.0, 100, None, 177.84440000000006),
#  ('Latin America and the Caribbean', 'Saint Lucia', 97.0, 82, None, 177.84440000000006),
#  ('Latin America and the Caribbean', 'Saint Martin (French Part)', 100.0, 100, None, 177.84440000000006),
#  ('Latin America and the Caribbean', 'Trinidad and Tobago', 99.0, 94, 21.06, 177.84440000000006),
#  ('Latin America and the Caribbean', 'United States Virgin Islands', 99.0, 99, None, 177.84440000000006),
#  ('Latin America and the Caribbean', 'Belize', 98.33, 89, 2.08, 177.84440000000006),
#  ('Latin America and the Caribbean', 'Costa Rica', 100.0, 98, 62.16, 177.84440000000006),
#  ('Latin America and the Caribbean', 'El Salvador', 97.0, 80, 24.56, 177.84440000000006),
#  ('Latin America and the Caribbean', 'Guatemala', 94.0, 68, 77.63, 177.84440000000006),
#  ('Latin America and the Caribbean', 'Honduras', 95.33, 83, 23.83, 177.84440000000006),
#  ('Latin America and the Caribbean', 'Mexico', 99.33, 91, 1090.52, 177.84440000000006),
#  ('Latin America and the Caribbean', 'Nicaragua', 79.33, 72, 12.59, 177.84440000000006),
#  ('Latin America and the Caribbean', 'Panama', 92.67, 81, 53.98, 177.84440000000006),
#  ('Latin America and the Caribbean', 'Argentina', 100.0, 99, 385.54, 177.84440000000006),
#  ('Latin America and the Caribbean', 'Bolivia (Plurinational State of)', 90.67, 62, None, 177.84440000000006),
#  ('Latin America and the Caribbean', 'Brazil', 98.33, 82, 1448.56, 177.84440000000006),
#  ('Latin America and the Caribbean', 'Chile', 100.0, 100, 252.73, 177.84440000000006),
#  ('Latin America and the Caribbean', 'Colombia', 94.67, 91, 270.3, 177.84440000000006),
#  ('Latin America and the Caribbean', 'Ecuador', 94.0, 91, 99.29, 177.84440000000006),
#  ('Latin America and the Caribbean', 'Falkland Islands (Malvinas)', 91.0, 100, None, 177.84440000000006),
#  ('Latin America and the Caribbean', 'French Guiana', 94.0, 92, None, 177.84440000000006),
#  ('Latin America and the Caribbean', 'Guyana', 96.67, 87, 5.47, 177.84440000000006),
#  ('Latin America and the Caribbean', 'Paraguay', 99.67, 92, 35.43, 177.84440000000006),
#  ('Latin America and the Caribbean', 'Peru', 90.33, 74, 201.71, 177.84440000000006),
#  ('Latin America and the Caribbean', 'Suriname', 98.0, 89, 2.91, 177.84440000000006),
#  ('Latin America and the Caribbean', 'Uruguay', 98.0, 98, 53.56, 177.84440000000006),
#  ('Latin America and the Caribbean', 'Venezuela (Bolivarian Republic of)', 94.0, 96, None, 177.84440000000006),
#  ('Northern Africa and Western Asia', 'Algeria', 93.33, 84, 145.01, 129.046),
#  ('Northern Africa and Western Asia', 'Egypt', 99.33, 98, None, 129.046),
#  ('Northern Africa and Western Asia', 'Libya', 100.0, 92, 50.36, 129.046),
#  ('Northern Africa and Western Asia', 'Morocco', 88.33, 85, 121.35, 129.046),
#  ('Northern Africa and Western Asia', 'Sudan', 62.33, 40, 27.03, 129.046),
#  ('Northern Africa and Western Asia', 'Tunisia', 97.0, 97, 42.54, 129.046),
#  ('Northern Africa and Western Asia', 'Armenia', 100.0, 92, 12.64, 129.046),
#  ('Northern Africa and Western Asia', 'Azerbaijan', 95.67, 96, 42.69, 129.046),
#  ('Northern Africa and Western Asia', 'Bahrain', 100.0, 100, 34.72, 129.046),
#  ('Northern Africa and Western Asia', 'Cyprus', 100.0, 99, 25.01, 129.046),
#  ('Northern Africa and Western Asia', 'Georgia', 96.67, 84, 15.84, 129.046),
#  ('Northern Africa and Western Asia', 'Iraq', 97.67, 100, 184.37, 129.046),
#  ('Northern Africa and Western Asia', 'Israel', 100.0, 100, 413.27, 129.046),
#  ('Northern Africa and Western Asia', 'Jordan', 98.33, 96, 44.18, 129.046),
#  ('Northern Africa and Western Asia', 'Kuwait', 100.0, 100, 105.96, 129.046),
#  ('Northern Africa and Western Asia', 'Lebanon', 93.0, 99, 31.71, 129.046),
#  ('Northern Africa and Western Asia', 'Oman', 87.67, 99, 75.91, 129.046),
#  ('Northern Africa and Western Asia', 'Qatar', 100.0, 100, 144.41, 129.046),
#  ('Northern Africa and Western Asia', 'Saudi Arabia', 100.0, 100, 703.37, 129.046),
#  ('Northern Africa and Western Asia', 'State of Palestine', 98.33, 99, None, 129.046),
#  ('Northern Africa and Western Asia', 'Syrian Arab Republic', 93.67, 90, 11.08, 129.046),
#  ('Northern Africa and Western Asia', 'TÃ¼rkiye', 96.67, 99, None, 129.046),
#  ('Northern Africa and Western Asia', 'United Arab Emirates', 100.0, 99, 349.47, 129.046),
#  ('Northern Africa and Western Asia', 'Yemen', 63.0, 57, None, 129.046),
#  ('Oceania', 'Australia', 100.0, 100, 1326.9, 93.7264705882353),
#  ('Oceania', 'New Zealand', 100.0, 100, 211.73, 93.7264705882353),
#  ('Oceania', 'Fiji', 93.67, 99, 4.48, 93.7264705882353),
#  ('Oceania', 'New Caledonia', 99.0, 100, 9.44, 93.7264705882353),
#  ('Oceania', 'Papua New Guinea', 56.67, 28, 23.85, 93.7264705882353),
#  ('Oceania', 'Solomon Islands', 72.33, 45, 1.54, 93.7264705882353),
#  ('Oceania', 'Vanuatu', 93.0, 56, 0.9, 93.7264705882353),
#  ('Oceania', 'Guam', 100.0, None, 5.89, 93.7264705882353),
#  ('Oceania', 'Kiribati', 77.0, 45, 0.18, 93.7264705882353),
#  ('Oceania', 'Marshall Islands', 90.0, 78, 0.24, 93.7264705882353),
#  ('Oceania', 'Nauru', 100.0, None, 0.11, 93.7264705882353),
#  ('Oceania', 'Northern Mariana Islands', 100.0, 79, None, 93.7264705882353),
#  ('Oceania', 'Palau', 100.0, 100, 0.25, 93.7264705882353),
#  ('Oceania', 'American Samoa', 100.0, 54, 0.72, 93.7264705882353),
#  ('Oceania', 'Cook Islands', 100.0, 99, None, 93.7264705882353),
#  ('Oceania', 'French Polynesia', 100.0, 97, 5.71, 93.7264705882353),
#  ('Oceania', 'Niue', 97.0, 96, None, 93.7264705882353),
#  ('Oceania', 'Samoa', 92.0, 96, 0.87, 93.7264705882353),
#  ('Oceania', 'Tokelau', 100.0, 97, None, 93.7264705882353),
#  ('Oceania', 'Tonga', 99.0, 93, 0.48, 93.7264705882353),
#  ('Oceania', 'Tuvalu', 100.0, None, 0.06, 93.7264705882353),
#  ('Oceania', 'Wallis and Futuna Islands', 99.0, 93, None, 93.7264705882353),
#  ('Sub-Saharan Africa', 'Burundi', 70.33, 44, 2.65, 39.04131578947368),
#  ('Sub-Saharan Africa', 'Djibouti', 69.0, 56, 3.18, 39.04131578947368),
#  ('Sub-Saharan Africa', 'Ethiopia', 58.0, 12, 107.66, 39.04131578947368),
#  ('Sub-Saharan Africa', 'Kenya', 67.0, 34, 100.67, 39.04131578947368),
#  ('Sub-Saharan Africa', 'Madagascar', 56.33, 13, 13.05, 39.04131578947368),
#  ('Sub-Saharan Africa', 'Malawi', 74.33, 29, 12.18, 39.04131578947368),
#  ('Sub-Saharan Africa', 'Mauritius', 100.0, 96, 11.4, 39.04131578947368),
#  ('Sub-Saharan Africa', 'Mayotte', 96.0, 100, None, 39.04131578947368),
#  ('Sub-Saharan Africa', 'Mozambique', 66.67, 40, 14.03, 39.04131578947368),
#  ('Sub-Saharan Africa', 'Rwanda', 66.33, 64, 10.18, 39.04131578947368),
#  ('Sub-Saharan Africa', 'RÃ©union', 100.0, 100, None, 39.04131578947368),
#  ('Sub-Saharan Africa', 'Somalia', 57.33, 40, 6.88, 39.04131578947368),
#  ('Sub-Saharan Africa', 'South Sudan', 48.33, 22, None, 39.04131578947368),
#  ('Sub-Saharan Africa', 'Uganda', 61.0, 22, 37.6, 39.04131578947368),
#  ('Sub-Saharan Africa', 'United Republic of Tanzania', 65.0, 34, None, 39.04131578947368),
#  ('Sub-Saharan Africa', 'Zambia', 66.67, 33, 18.11, 39.04131578947368),
#  ('Sub-Saharan Africa', 'Zimbabwe', 68.0, 36, 21.51, 39.04131578947368),
#  ('Sub-Saharan Africa', 'Angola', 52.33, 47, 53.62, 39.04131578947368),
#  ('Sub-Saharan Africa', 'Cameroon', 64.0, 43, 40.77, 39.04131578947368),
#  ('Sub-Saharan Africa', 'Central African Republic', 38.33, 15, 2.33, 39.04131578947368),
#  ('Sub-Saharan Africa', 'Chad', 52.67, 19, 10.72, 39.04131578947368),
#  ('Sub-Saharan Africa', 'Congo', 69.0, 18, None, 39.04131578947368),
#  ('Sub-Saharan Africa', 'Democratic Republic of the Congo', 47.67, 15, None, 39.04131578947368),
#  ('Sub-Saharan Africa', 'Gabon', 73.33, 47, 15.31, 39.04131578947368),
#  ('Sub-Saharan Africa', 'Sao Tome and Principe', 77.33, 46, 0.47, 39.04131578947368),
#  ('Sub-Saharan Africa', 'Botswana', 89.67, 74, 14.93, 39.04131578947368),
#  ('Sub-Saharan Africa', 'Eswatini', 76.67, 61, 3.98, 39.04131578947368),
#  ('Sub-Saharan Africa', 'Lesotho', 76.33, 50, 2.23, 39.04131578947368),
#  ('Sub-Saharan Africa', 'Namibia', 83.67, 35, 10.58, 39.04131578947368),
#  ('Sub-Saharan Africa', 'South Africa', 92.0, 79, 337.62, 39.04131578947368),
#  ('Sub-Saharan Africa', 'Benin', 65.33, 17, 15.65, 39.04131578947368),
#  ('Sub-Saharan Africa', 'Burkina Faso', 53.33, 25, 17.93, 39.04131578947368),
#  ('Sub-Saharan Africa', 'Cabo Verde', 87.33, 78, 1.7, 39.04131578947368),
#  ('Sub-Saharan Africa', "CÃ´te d'Ivoire", 70.67, 35, None, 39.04131578947368),
#  ('Sub-Saharan Africa', 'Gambia', 79.33, 44, None, 39.04131578947368),
#  ('Sub-Saharan Africa', 'Ghana', 84.67, 23, 70.04, 39.04131578947368),
#  ('Sub-Saharan Africa', 'Guinea', 67.33, 32, 14.18, 39.04131578947368),
#  ('Sub-Saharan Africa', 'Guinea-Bissau', 60.0, 19, 1.43, 39.04131578947368),
#  ('Sub-Saharan Africa', 'Liberia', 75.0, 18, 3.04, 39.04131578947368),
#  ('Sub-Saharan Africa', 'Mali', 83.67, 46, 17.47, 39.04131578947368),
#  ('Sub-Saharan Africa', 'Mauritania', 70.33, 48, 8.41, 39.04131578947368),
#  ('Sub-Saharan Africa', 'Niger', 57.33, 25, 13.74, 39.04131578947368),
#  ('Sub-Saharan Africa', 'Nigeria', 77.33, 43, 432.2, 39.04131578947368),
#  ('Sub-Saharan Africa', 'Saint Helena', 99.0, 100, None, 39.04131578947368),
#  ('Sub-Saharan Africa', 'Senegal', 85.0, 57, 24.49, 39.04131578947368),
#  ('Sub-Saharan Africa', 'Sierra Leone', 65.0, 17, 4.06, 39.04131578947368),
#  ('Sub-Saharan Africa', 'Togo', 70.67, 20, 7.57, 39.04131578947368)]

# %% [markdown]
# **Task 2: Filter the data**
#
# Next, let’s filter the data to focus only on the Sub-Saharan African countries with underdeveloped economies and also limited access to managed drinking water services in 2020.

# %%
# %%sql
# SELECT
#     Region,
#     Country_name,
#     Pct_managed_drinking_water_services,
#     Pct_managed_sanitation_services,
#     Est_gdp_in_billions,
#     AVG(Est_gdp_in_billions) OVER(PARTITION BY Region) AS Avg_gdp_for_region
# FROM
#     united_nations.Access_to_Basic_Services
# WHERE
#     Region = 'Sub-Saharan Africa'
#     AND Time_period = 2020
#     AND Pct_managed_drinking_water_services < 60
#     AND Est_gdp_in_billions < Avg_gdp_for_region;
# Out:
#  * mysql+pymysql://root:***@127.0.0.1:3306/united_nations
# (pymysql.err.OperationalError) (1054, "Unknown column 'Avg_gdp_for_region' in 'where clause'")
# [SQL: SELECT
#     Region,
#     Country_name,
#     Pct_managed_drinking_water_services,
#     Pct_managed_sanitation_services,
#     Est_gdp_in_billions,
#     AVG(Est_gdp_in_billions) OVER(PARTITION BY Region) AS Avg_gdp_for_region
# FROM
#     united_nations.Access_to_Basic_Services
# WHERE
#     Region = 'Sub-Saharan Africa'
#     AND Time_period = 2020
#     AND Pct_managed_drinking_water_services < 60
#     AND Est_gdp_in_billions < Avg_gdp_for_region;]
# (Background on this error at: https://sqlalche.me/e/20/e3q8)

# %% [markdown]
# **Task 3: Implement the solution using subqueries**
#
# We can fix the error by using a subquery to calculate the average regional GDP, and then use those results in the main query.

# %%
# %%sql
# SELECT
#     Country_name,
#     Region,
#     Pct_managed_drinking_water_services,
#     Pct_managed_sanitation_services,
#     Est_gdp_in_billions,
#     Avg_gdp_for_region
# FROM (
#     SELECT
#         Region,
#         Country_name,
#         Pct_managed_drinking_water_services,
#         Pct_managed_sanitation_services,
#         Est_gdp_in_billions,
#         AVG(Est_gdp_in_billions) OVER(PARTITION BY Region) AS Avg_gdp_for_region
#     FROM
#         united_nations.Access_to_Basic_Services
#     WHERE
#         Time_period = 2020
#     ) AS Avg_world_GDP_2020
# WHERE
#     Region = 'Sub-Saharan Africa'
#     AND Pct_managed_drinking_water_services < 60
#     AND Est_gdp_in_billions < Avg_gdp_for_region;
# Out:
#  * mysql+pymysql://root:***@127.0.0.1:3306/united_nations
# 6 rows affected.
# [('Madagascar', 'Sub-Saharan Africa', 56.33, 13, 13.05, 39.04131578947368),
#  ('Somalia', 'Sub-Saharan Africa', 57.33, 40, 6.88, 39.04131578947368),
#  ('Central African Republic', 'Sub-Saharan Africa', 38.33, 15, 2.33, 39.04131578947368),
#  ('Chad', 'Sub-Saharan Africa', 52.67, 19, 10.72, 39.04131578947368),
#  ('Burkina Faso', 'Sub-Saharan Africa', 53.33, 25, 17.93, 39.04131578947368),
#  ('Niger', 'Sub-Saharan Africa', 57.33, 25, 13.74, 39.04131578947368)]

# %% [markdown]
# **Task 4: Implement the solution using Common Table Expressions (CTEs)**
#
# Now, let's attempt the same problem using Common Table Expressions (CTEs).

# %%
# %%sql
# -- This CTE calculates the average regional GDP for each country, for the year 2020.
# WITH Avg_world_GDP_2020 AS (
#     SELECT
#         Region,
#         Country_name,
#         Pct_managed_drinking_water_services,
#         Pct_managed_sanitation_services,
#         Est_gdp_in_billions,
#         AVG(Est_gdp_in_billions) OVER(PARTITION BY Region) AS Avg_gdp_for_region
#     FROM
#         united_nations.Access_to_Basic_Services
#     WHERE
#         Time_period = 2020
# )
#
# /*
# This query filters the Avg_world_GDP_2020 CTE for
# countries that have below-average GDP, in the
# Sub-Saharan Africa region, and struggling with water access.
# */
#
# SELECT
#     Country_name
# FROM
#     Avg_world_GDP_2020
# WHERE
#     Region = 'Sub-Saharan Africa'
#     AND Pct_managed_drinking_water_services < 60
#     AND Est_gdp_in_billions < Avg_gdp_for_region;
# Out:
#  * mysql+pymysql://root:***@127.0.0.1:3306/united_nations
# 6 rows affected.
# [('Madagascar',),
#  ('Somalia',),
#  ('Central African Republic',),
#  ('Chad',),
#  ('Burkina Faso',),
#  ('Niger',)]
