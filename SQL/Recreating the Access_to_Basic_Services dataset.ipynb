# %%
#Preparing sql environment
# %load_ext sql

# %%
# %sql mysql+pymysql://root:0479%40Kanya@127.0.0.1:3306/united_nations

# %% [markdown]
# **1. First LEFT JOIN**
#
# Combine the Geographic_Location table with the Economic_Indicators table based on the Country_name column.

# %%
# %%sql
#
# SELECT *
#     FROM
#     united_nations.geographic_location AS geo
# LEFT JOIN
#    united_nations.economic_indicators AS eco
# ON geo.country_name = eco.country_name
#
# LIMIT 50;
# Out:
#  * mysql+pymysql://root:***@127.0.0.1:3306/united_nations
# 50 rows affected.
# [('Afghanistan', 'Southern Asia', 'Central and Southern Asia', Decimal('652230.00'), 'Afghanistan', 2015, Decimal('20.00'), Decimal('33.753499'), None),
#  ('Afghanistan', 'Southern Asia', 'Central and Southern Asia', Decimal('652230.00'), 'Afghanistan', 2016, Decimal('18.02'), Decimal('34.636207'), None),
#  ('Afghanistan', 'Southern Asia', 'Central and Southern Asia', Decimal('652230.00'), 'Afghanistan', 2017, Decimal('18.90'), Decimal('35.643418'), Decimal('11.18')),
#  ('Afghanistan', 'Southern Asia', 'Central and Southern Asia', Decimal('652230.00'), 'Afghanistan', 2018, Decimal('18.42'), Decimal('36.686784'), None),
#  ('Afghanistan', 'Southern Asia', 'Central and Southern Asia', Decimal('652230.00'), 'Afghanistan', 2019, Decimal('18.90'), Decimal('37.769499'), None),
#  ('Afghanistan', 'Southern Asia', 'Central and Southern Asia', Decimal('652230.00'), 'Afghanistan', 2020, Decimal('20.14'), Decimal('38.972230'), Decimal('11.71')),
#  ('Algeria', 'Northern Africa', 'Northern Africa and Western Asia', Decimal('2381741.00'), 'Algeria', 2015, Decimal('165.98'), Decimal('39.543154'), Decimal('11.21')),
#  ('Algeria', 'Northern Africa', 'Northern Africa and Western Asia', Decimal('2381741.00'), 'Algeria', 2016, Decimal('160.03'), Decimal('40.339329'), Decimal('10.20')),
#  ('Algeria', 'Northern Africa', 'Northern Africa and Western Asia', Decimal('2381741.00'), 'Algeria', 2017, Decimal('170.10'), Decimal('41.136546'), Decimal('12.00')),
#  ('Algeria', 'Northern Africa', 'Northern Africa and Western Asia', Decimal('2381741.00'), 'Algeria', 2018, Decimal('174.91'), Decimal('41.927007'), None),
#  ('Algeria', 'Northern Africa', 'Northern Africa and Western Asia', Decimal('2381741.00'), 'Algeria', 2019, Decimal('171.77'), Decimal('42.705368'), None),
#  ('Algeria', 'Northern Africa', 'Northern Africa and Western Asia', Decimal('2381741.00'), 'Algeria', 2020, Decimal('145.01'), Decimal('43.451666'), None),
#  ('American Samoa', 'Polynesia', 'Oceania', Decimal('200.00'), 'American Samoa', 2015, Decimal('0.67'), Decimal('0.051368'), None),
#  ('American Samoa', 'Polynesia', 'Oceania', Decimal('200.00'), 'American Samoa', 2016, Decimal('0.67'), Decimal('0.050448'), None),
#  ('American Samoa', 'Polynesia', 'Oceania', Decimal('200.00'), 'American Samoa', 2017, Decimal('0.61'), Decimal('0.049463'), None),
#  ('American Samoa', 'Polynesia', 'Oceania', Decimal('200.00'), 'American Samoa', 2018, Decimal('0.64'), Decimal('0.048424'), None),
#  ('American Samoa', 'Polynesia', 'Oceania', Decimal('200.00'), 'American Samoa', 2019, Decimal('0.65'), Decimal('0.047321'), None),
#  ('American Samoa', 'Polynesia', 'Oceania', Decimal('200.00'), 'American Samoa', 2020, Decimal('0.72'), Decimal('0.046189'), None),
#  ('Angola', 'Middle Africa', 'Sub-Saharan Africa', Decimal('1246700.00'), 'Angola', 2015, Decimal('87.22'), Decimal('28.127721'), None),
#  ('Angola', 'Middle Africa', 'Sub-Saharan Africa', Decimal('1246700.00'), 'Angola', 2016, Decimal('49.84'), Decimal('29.154746'), None),
#  ('Angola', 'Middle Africa', 'Sub-Saharan Africa', Decimal('1246700.00'), 'Angola', 2017, Decimal('68.97'), Decimal('30.208628'), None),
#  ('Angola', 'Middle Africa', 'Sub-Saharan Africa', Decimal('1246700.00'), 'Angola', 2018, Decimal('77.79'), Decimal('31.273533'), None),
#  ('Angola', 'Middle Africa', 'Sub-Saharan Africa', Decimal('1246700.00'), 'Angola', 2019, Decimal('69.31'), Decimal('32.353588'), Decimal('16.50')),
#  ('Angola', 'Middle Africa', 'Sub-Saharan Africa', Decimal('1246700.00'), 'Angola', 2020, Decimal('53.62'), Decimal('33.428486'), None),
#  ('Anguilla', 'Caribbean', 'Latin America and the Caribbean', None, 'Anguilla', 2015, None, None, None),
#  ('Anguilla', 'Caribbean', 'Latin America and the Caribbean', None, 'Anguilla', 2016, None, None, None),
#  ('Anguilla', 'Caribbean', 'Latin America and the Caribbean', None, 'Anguilla', 2017, None, None, None),
#  ('Antigua and Barbuda', 'Caribbean', 'Latin America and the Caribbean', Decimal('440.00'), 'Antigua and Barbuda', 2015, Decimal('1.34'), Decimal('0.089941'), None),
#  ('Antigua and Barbuda', 'Caribbean', 'Latin America and the Caribbean', Decimal('440.00'), 'Antigua and Barbuda', 2016, Decimal('1.44'), Decimal('0.090564'), None),
#  ('Antigua and Barbuda', 'Caribbean', 'Latin America and the Caribbean', Decimal('440.00'), 'Antigua and Barbuda', 2017, Decimal('1.47'), Decimal('0.091119'), None),
#  ('Argentina', 'South America', 'Latin America and the Caribbean', Decimal('2736690.00'), 'Argentina', 2015, Decimal('594.75'), Decimal('43.131966'), None),
#  ('Argentina', 'South America', 'Latin America and the Caribbean', Decimal('2736690.00'), 'Argentina', 2016, Decimal('557.53'), Decimal('43.590368'), None),
#  ('Argentina', 'South America', 'Latin America and the Caribbean', Decimal('2736690.00'), 'Argentina', 2017, Decimal('643.63'), Decimal('44.044811'), Decimal('8.35')),
#  ('Argentina', 'South America', 'Latin America and the Caribbean', Decimal('2736690.00'), 'Argentina', 2018, Decimal('524.82'), Decimal('44.494502'), Decimal('9.22')),
#  ('Argentina', 'South America', 'Latin America and the Caribbean', Decimal('2736690.00'), 'Argentina', 2019, Decimal('447.75'), Decimal('44.938712'), Decimal('9.84')),
#  ('Argentina', 'South America', 'Latin America and the Caribbean', Decimal('2736690.00'), 'Argentina', 2020, Decimal('385.54'), Decimal('45.376763'), Decimal('11.46')),
#  ('Armenia', 'Western Asia', 'Northern Africa and Western Asia', Decimal('28470.00'), 'Armenia', 2015, Decimal('10.55'), Decimal('2.878595'), Decimal('18.26')),
#  ('Armenia', 'Western Asia', 'Northern Africa and Western Asia', Decimal('28470.00'), 'Armenia', 2016, Decimal('10.55'), Decimal('2.865835'), Decimal('17.62')),
#  ('Armenia', 'Western Asia', 'Northern Africa and Western Asia', Decimal('28470.00'), 'Armenia', 2017, Decimal('11.53'), Decimal('2.851923'), Decimal('17.70')),
#  ('Armenia', 'Western Asia', 'Northern Africa and Western Asia', Decimal('28470.00'), 'Armenia', 2018, Decimal('12.46'), Decimal('2.836557'), Decimal('13.21')),
#  ('Armenia', 'Western Asia', 'Northern Africa and Western Asia', Decimal('28470.00'), 'Armenia', 2019, Decimal('13.62'), Decimal('2.820602'), Decimal('12.20')),
#  ('Armenia', 'Western Asia', 'Northern Africa and Western Asia', Decimal('28470.00'), 'Armenia', 2020, Decimal('12.64'), Decimal('2.805608'), Decimal('12.18')),
#  ('Aruba', 'Caribbean', 'Latin America and the Caribbean', Decimal('180.00'), 'Aruba', 2015, Decimal('2.96'), Decimal('0.104257'), None),
#  ('Aruba', 'Caribbean', 'Latin America and the Caribbean', Decimal('180.00'), 'Aruba', 2016, Decimal('2.98'), Decimal('0.104874'), None),
#  ('Australia', 'Australia and New Zealand', 'Oceania', Decimal('7690400.00'), 'Australia', 2015, Decimal('1350.62'), Decimal('23.815995'), Decimal('6.06')),
#  ('Australia', 'Australia and New Zealand', 'Oceania', Decimal('7690400.00'), 'Australia', 2016, Decimal('1206.54'), Decimal('24.190907'), Decimal('5.71')),
#  ('Australia', 'Australia and New Zealand', 'Oceania', Decimal('7690400.00'), 'Australia', 2017, Decimal('1326.52'), Decimal('24.594202'), Decimal('5.59')),
#  ('Australia', 'Australia and New Zealand', 'Oceania', Decimal('7690400.00'), 'Australia', 2018, Decimal('1428.29'), Decimal('24.966643'), Decimal('5.30')),
#  ('Australia', 'Australia and New Zealand', 'Oceania', Decimal('7690400.00'), 'Australia', 2019, Decimal('1392.23'), Decimal('25.340217'), Decimal('5.16')),
#  ('Australia', 'Australia and New Zealand', 'Oceania', Decimal('7690400.00'), 'Australia', 2020, Decimal('1326.90'), Decimal('25.655289'), Decimal('6.46'))]

# %% [markdown]
# **2. Second LEFT JOIN**
#
# Combine the previously joined tables with the Basic_Services table, again based on the Country_name column.

# %%
# %%sql
#
# SELECT *
#     FROM
#     united_nations.geographic_location AS geo
# LEFT JOIN
#    united_nations.economic_indicators AS eco
# ON geo.country_name = eco.country_name
#
# LEFT JOIN
# 	united_nations.Basic_Services as svc
# 	ON geo.Country_name = svc.Country_name
# LIMIT 20;
# Out:
#  * mysql+pymysql://root:***@127.0.0.1:3306/united_nations
# 20 rows affected.
# [('Afghanistan', 'Southern Asia', 'Central and Southern Asia', Decimal('652230.00'), 'Afghanistan', 2015, Decimal('20.00'), Decimal('33.753499'), None, 'Afghanistan', 2015, Decimal('67.00'), Decimal('46.00')),
#  ('Afghanistan', 'Southern Asia', 'Central and Southern Asia', Decimal('652230.00'), 'Afghanistan', 2015, Decimal('20.00'), Decimal('33.753499'), None, 'Afghanistan', 2016, Decimal('69.67'), Decimal('47.00')),
#  ('Afghanistan', 'Southern Asia', 'Central and Southern Asia', Decimal('652230.00'), 'Afghanistan', 2015, Decimal('20.00'), Decimal('33.753499'), None, 'Afghanistan', 2017, Decimal('72.33'), Decimal('49.00')),
#  ('Afghanistan', 'Southern Asia', 'Central and Southern Asia', Decimal('652230.00'), 'Afghanistan', 2015, Decimal('20.00'), Decimal('33.753499'), None, 'Afghanistan', 2018, Decimal('75.33'), Decimal('51.00')),
#  ('Afghanistan', 'Southern Asia', 'Central and Southern Asia', Decimal('652230.00'), 'Afghanistan', 2015, Decimal('20.00'), Decimal('33.753499'), None, 'Afghanistan', 2019, Decimal('78.00'), Decimal('52.00')),
#  ('Afghanistan', 'Southern Asia', 'Central and Southern Asia', Decimal('652230.00'), 'Afghanistan', 2015, Decimal('20.00'), Decimal('33.753499'), None, 'Afghanistan', 2020, Decimal('80.33'), Decimal('54.00')),
#  ('Afghanistan', 'Southern Asia', 'Central and Southern Asia', Decimal('652230.00'), 'Afghanistan', 2016, Decimal('18.02'), Decimal('34.636207'), None, 'Afghanistan', 2015, Decimal('67.00'), Decimal('46.00')),
#  ('Afghanistan', 'Southern Asia', 'Central and Southern Asia', Decimal('652230.00'), 'Afghanistan', 2016, Decimal('18.02'), Decimal('34.636207'), None, 'Afghanistan', 2016, Decimal('69.67'), Decimal('47.00')),
#  ('Afghanistan', 'Southern Asia', 'Central and Southern Asia', Decimal('652230.00'), 'Afghanistan', 2016, Decimal('18.02'), Decimal('34.636207'), None, 'Afghanistan', 2017, Decimal('72.33'), Decimal('49.00')),
#  ('Afghanistan', 'Southern Asia', 'Central and Southern Asia', Decimal('652230.00'), 'Afghanistan', 2016, Decimal('18.02'), Decimal('34.636207'), None, 'Afghanistan', 2018, Decimal('75.33'), Decimal('51.00')),
#  ('Afghanistan', 'Southern Asia', 'Central and Southern Asia', Decimal('652230.00'), 'Afghanistan', 2016, Decimal('18.02'), Decimal('34.636207'), None, 'Afghanistan', 2019, Decimal('78.00'), Decimal('52.00')),
#  ('Afghanistan', 'Southern Asia', 'Central and Southern Asia', Decimal('652230.00'), 'Afghanistan', 2016, Decimal('18.02'), Decimal('34.636207'), None, 'Afghanistan', 2020, Decimal('80.33'), Decimal('54.00')),
#  ('Afghanistan', 'Southern Asia', 'Central and Southern Asia', Decimal('652230.00'), 'Afghanistan', 2017, Decimal('18.90'), Decimal('35.643418'), Decimal('11.18'), 'Afghanistan', 2015, Decimal('67.00'), Decimal('46.00')),
#  ('Afghanistan', 'Southern Asia', 'Central and Southern Asia', Decimal('652230.00'), 'Afghanistan', 2017, Decimal('18.90'), Decimal('35.643418'), Decimal('11.18'), 'Afghanistan', 2016, Decimal('69.67'), Decimal('47.00')),
#  ('Afghanistan', 'Southern Asia', 'Central and Southern Asia', Decimal('652230.00'), 'Afghanistan', 2017, Decimal('18.90'), Decimal('35.643418'), Decimal('11.18'), 'Afghanistan', 2017, Decimal('72.33'), Decimal('49.00')),
#  ('Afghanistan', 'Southern Asia', 'Central and Southern Asia', Decimal('652230.00'), 'Afghanistan', 2017, Decimal('18.90'), Decimal('35.643418'), Decimal('11.18'), 'Afghanistan', 2018, Decimal('75.33'), Decimal('51.00')),
#  ('Afghanistan', 'Southern Asia', 'Central and Southern Asia', Decimal('652230.00'), 'Afghanistan', 2017, Decimal('18.90'), Decimal('35.643418'), Decimal('11.18'), 'Afghanistan', 2019, Decimal('78.00'), Decimal('52.00')),
#  ('Afghanistan', 'Southern Asia', 'Central and Southern Asia', Decimal('652230.00'), 'Afghanistan', 2017, Decimal('18.90'), Decimal('35.643418'), Decimal('11.18'), 'Afghanistan', 2020, Decimal('80.33'), Decimal('54.00')),
#  ('Afghanistan', 'Southern Asia', 'Central and Southern Asia', Decimal('652230.00'), 'Afghanistan', 2018, Decimal('18.42'), Decimal('36.686784'), None, 'Afghanistan', 2015, Decimal('67.00'), Decimal('46.00')),
#  ('Afghanistan', 'Southern Asia', 'Central and Southern Asia', Decimal('652230.00'), 'Afghanistan', 2018, Decimal('18.42'), Decimal('36.686784'), None, 'Afghanistan', 2016, Decimal('69.67'), Decimal('47.00'))]

# %% [markdown]
# **3. Refine the second LEFT JOIN**
#
# At first glance, the results of the above query might seem fine, but take a closer look at the Time_periods. We can see that they don't align as we would expect.
#
# Refine the second LEFT JOIN query by adding an additional condition based on the Time_period column.

# %%
# %%sql
#
# SELECT *
#     FROM
#     united_nations.geographic_location AS geo
# LEFT JOIN
#    united_nations.economic_indicators AS eco
# ON geo.country_name = eco.country_name
#
# LEFT JOIN
# 	united_nations.Basic_Services as svc
# 	ON geo.Country_name = svc.Country_name
#     AND eco.Time_period = svc.Time_period
# LIMIT 20;
# Out:
#  * mysql+pymysql://root:***@127.0.0.1:3306/united_nations
# 20 rows affected.
# [('Afghanistan', 'Southern Asia', 'Central and Southern Asia', Decimal('652230.00'), 'Afghanistan', 2015, Decimal('20.00'), Decimal('33.753499'), None, 'Afghanistan', 2015, Decimal('67.00'), Decimal('46.00')),
#  ('Afghanistan', 'Southern Asia', 'Central and Southern Asia', Decimal('652230.00'), 'Afghanistan', 2016, Decimal('18.02'), Decimal('34.636207'), None, 'Afghanistan', 2016, Decimal('69.67'), Decimal('47.00')),
#  ('Afghanistan', 'Southern Asia', 'Central and Southern Asia', Decimal('652230.00'), 'Afghanistan', 2017, Decimal('18.90'), Decimal('35.643418'), Decimal('11.18'), 'Afghanistan', 2017, Decimal('72.33'), Decimal('49.00')),
#  ('Afghanistan', 'Southern Asia', 'Central and Southern Asia', Decimal('652230.00'), 'Afghanistan', 2018, Decimal('18.42'), Decimal('36.686784'), None, 'Afghanistan', 2018, Decimal('75.33'), Decimal('51.00')),
#  ('Afghanistan', 'Southern Asia', 'Central and Southern Asia', Decimal('652230.00'), 'Afghanistan', 2019, Decimal('18.90'), Decimal('37.769499'), None, 'Afghanistan', 2019, Decimal('78.00'), Decimal('52.00')),
#  ('Afghanistan', 'Southern Asia', 'Central and Southern Asia', Decimal('652230.00'), 'Afghanistan', 2020, Decimal('20.14'), Decimal('38.972230'), Decimal('11.71'), 'Afghanistan', 2020, Decimal('80.33'), Decimal('54.00')),
#  ('Algeria', 'Northern Africa', 'Northern Africa and Western Asia', Decimal('2381741.00'), 'Algeria', 2015, Decimal('165.98'), Decimal('39.543154'), Decimal('11.21'), 'Algeria', 2015, Decimal('92.00'), Decimal('85.00')),
#  ('Algeria', 'Northern Africa', 'Northern Africa and Western Asia', Decimal('2381741.00'), 'Algeria', 2016, Decimal('160.03'), Decimal('40.339329'), Decimal('10.20'), 'Algeria', 2016, Decimal('93.00'), Decimal('85.00')),
#  ('Algeria', 'Northern Africa', 'Northern Africa and Western Asia', Decimal('2381741.00'), 'Algeria', 2017, Decimal('170.10'), Decimal('41.136546'), Decimal('12.00'), 'Algeria', 2017, Decimal('93.00'), Decimal('85.00')),
#  ('Algeria', 'Northern Africa', 'Northern Africa and Western Asia', Decimal('2381741.00'), 'Algeria', 2018, Decimal('174.91'), Decimal('41.927007'), None, 'Algeria', 2018, Decimal('93.00'), Decimal('85.00')),
#  ('Algeria', 'Northern Africa', 'Northern Africa and Western Asia', Decimal('2381741.00'), 'Algeria', 2019, Decimal('171.77'), Decimal('42.705368'), None, 'Algeria', 2019, Decimal('93.33'), Decimal('85.00')),
#  ('Algeria', 'Northern Africa', 'Northern Africa and Western Asia', Decimal('2381741.00'), 'Algeria', 2020, Decimal('145.01'), Decimal('43.451666'), None, 'Algeria', 2020, Decimal('93.33'), Decimal('84.00')),
#  ('American Samoa', 'Polynesia', 'Oceania', Decimal('200.00'), 'American Samoa', 2015, Decimal('0.67'), Decimal('0.051368'), None, 'American Samoa', 2015, Decimal('100.00'), Decimal('57.00')),
#  ('American Samoa', 'Polynesia', 'Oceania', Decimal('200.00'), 'American Samoa', 2016, Decimal('0.67'), Decimal('0.050448'), None, 'American Samoa', 2016, Decimal('100.00'), Decimal('56.00')),
#  ('American Samoa', 'Polynesia', 'Oceania', Decimal('200.00'), 'American Samoa', 2017, Decimal('0.61'), Decimal('0.049463'), None, 'American Samoa', 2017, Decimal('100.00'), Decimal('54.00')),
#  ('American Samoa', 'Polynesia', 'Oceania', Decimal('200.00'), 'American Samoa', 2018, Decimal('0.64'), Decimal('0.048424'), None, 'American Samoa', 2018, Decimal('100.00'), Decimal('54.00')),
#  ('American Samoa', 'Polynesia', 'Oceania', Decimal('200.00'), 'American Samoa', 2019, Decimal('0.65'), Decimal('0.047321'), None, 'American Samoa', 2019, Decimal('100.00'), Decimal('54.00')),
#  ('American Samoa', 'Polynesia', 'Oceania', Decimal('200.00'), 'American Samoa', 2020, Decimal('0.72'), Decimal('0.046189'), None, 'American Samoa', 2020, Decimal('100.00'), Decimal('54.00')),
#  ('Angola', 'Middle Africa', 'Sub-Saharan Africa', Decimal('1246700.00'), 'Angola', 2015, Decimal('87.22'), Decimal('28.127721'), None, 'Angola', 2015, Decimal('50.33'), Decimal('43.00')),
#  ('Angola', 'Middle Africa', 'Sub-Saharan Africa', Decimal('1246700.00'), 'Angola', 2016, Decimal('49.84'), Decimal('29.154746'), None, 'Angola', 2016, Decimal('51.00'), Decimal('45.00'))]
